# %% [markdown]
# ***Import Libraries***

# %%
"""This program linearizes 3R planar dyanmics using koopman theory and autoencoder to map"""
import numpy as np
import matplotlib.pyplot as plt
import sklearn.preprocessing
import itertools
import scipy.io
import torch

# bilinear Koopman
from core.koopman_core import KoopDNN, KoopmanNet, KoopmanNetCtrl
from models.koop_model import model_matricies,lift
from core.util import fit_standardizer
from sklearn import preprocessing

# forward map neural net
from core.neural_fwd_map import map_Net
from models.neural_jacob_map import neural_jacobian, neural_jacobian_dot
# controllability
from core.util import Output_Con
import control as ct


## import paths
from paths.paths import path_pars, path_pars_2D

## extra libraries
import numpy as np
import scipy as sp
from scipy import sparse

# %%
## define paths
robot = '3R'
nature = 'bilinear'
modality = '3D'

robot_type_load = robot +'/' + modality # for data load0
robot_type = robot +'/'+ nature +'/' + modality # for saving purposes

train = True
mass_var = False
standardize = True


if mass_var == True:
    file_data = 'dynamics/Dataset_MATLAB/' + robot_type_load +'/data_mass_var.mat'
else:
    file_data = 'dynamics/Dataset_MATLAB/' + robot_type_load +'/data.mat'
    

    
file_data_fwd = 'dynamics/Dataset_MATLAB/' + robot_type_load +'/data_fw.mat'

# %%
file_data
# Out:
# 'dynamics/Dataset_MATLAB/3R/3D/data.mat'

# %% [markdown]
# ### Load Data

# %%
data = scipy.io.loadmat(file_data)
data_fw = scipy.io.loadmat(file_data_fwd)

X_end = np.array(data['X_end'], dtype = 'float64')
X_full = np.array(data['X'], dtype = 'float64')
U_full = np.array(data['tau'], dtype = 'float64')

X_end_fw = np.array(data_fw['X_end_fw'], dtype = 'float64')
X_fw = np.array(data_fw['X_fw'], dtype = 'float64')

print(X_end.shape, X_full.shape,U_full.shape)
# Out:
# (200, 1001, 3) (200, 1001, 6) (200, 1000, 3)

# %%
np.sum(np.sum(np.isnan(X_end))), np.sum(np.sum(np.isnan(U_full))), np.sum(np.sum(np.isnan(X_full)))
# Out:
# (0, 0, 0)

# %% [markdown]
# ***Simulation Parameters***

# %%
dt = float(data['dt']) #time step
num_snaps = int(data['num_snaps']) # no. of snapshots
num_traj = int(data['num_traj']) #no of trajectories
T = np.linspace(0,num_snaps*dt, num_snaps+1)
num_train = int(0.75*num_traj) # no. of training examples
num_val = num_traj-num_train # no of testing examples
num_traj = num_train+num_val #no of trajectories
num_states = X_full.shape[2] # no. of states
num_joints = int(num_states/2)
num_inputs = U_full.shape[2] # no. of inputs
num_states_cart = int(X_end.shape[2])

# %%
dt, num_snaps, num_traj, num_states, num_inputs
# Out:
# (0.005, 1000, 200, 6, 3)

# %% [markdown]
# ***Plotting the trajectories***

# %%
"""Training dataset visualization"""
#theta evolution
for i in range(int(num_joints)):
    plt.subplot(3,3,i+1)
    plt.xlabel("t")
    plt.ylabel("th"+str(i+1))
    for j in range(num_traj):
        plt.plot(T,X_full[j,:,i])

# %%
for i in range(int(num_joints)):
    plt.subplot(3,3,i+1)
    plt.xlabel("t")
    plt.ylabel("th"+str(i+1)+ ' dot')
    for j in range(num_traj):
        plt.plot(T,X_full[j,:,i+int(num_joints)])

# %%
#x and y positions of the end effector
# %matplotlib widget
# ax = plt.axes(projection='3d')
# ax.set_xlabel("x")
# ax.set_ylabel("y")
# ax.set_zlabel("z")
# for i in range(num_traj):
#     ax.plot3D(X_end[i,:,0],X_end[i,:,1],X_end[i,:,2])
    
# plt.axis('equal')

# %%
for i in range(num_traj):
    plt.plot(X_end[i,:,0],X_end[i,:,1])
    
plt.axis('equal')
# Out:
# (-1.0010293791311606,
#  1.0448667289248128,
#  -1.0558838603859724,
#  1.0621342328852472)

# %%
for i in range(num_inputs):
    plt.subplot(4,2,i+1)
    plt.xlabel("t")
    plt.ylabel("tau"+str(i))
    for j in range(num_traj):
        plt.plot(T[:-1],U_full[j,:,i])

# %% [markdown]
# ***Training and validation datasets***

# %%
# split training and vaidation datasets
xs_train, us_train = X_full[:num_train,:,:],U_full[:num_train,:,:]
xs_val, us_val = X_full[num_train:,:,:],U_full[num_train:,:,:]

# %%
# import scipy.io
# Data_set = {"x_end": X_end, "X_full": X_full}
# scipy.io.savemat("Data_set.mat",Data_set)

# %%
# import torch
# import torch.nn as nn
# import torch.nn.functional as F

# %% [markdown]
# ***Model Training***

# %%
net_params = {}
net_params['state_dim'] = num_states
net_params['ctrl_dim'] = num_inputs
net_params['encoder_hidden_width'] = 30 # 30
net_params['encoder_hidden_depth'] = 3  # 2
net_params['encoder_output_dim'] = 20   # 20
net_params['optimizer'] = 'adam'
net_params['activation_type'] = 'tanh'
net_params['lr'] = 5e-4 # 5e-4
net_params['epochs'] = 100
net_params['batch_size'] = 128
net_params['lifted_loss_penalty'] = 0.4 
net_params['l2_reg'] = 0.00       
net_params['l1_reg'] = 0.00
net_params['first_obs_const'] = True
net_params['override_C'] = True # this makes the state a part of lifetd state
net_params['dt'] = dt

# %%
                                                    
if mass_var == True:
    file_koop = 'saved_models/'+robot_type+'/koop_arch_con_mass_var.pth'
else:
    file_koop = 'saved_models/'+robot_type+'/koop_arch_con.pth'
    
standardizer_u_kdnn = fit_standardizer(us_train, preprocessing.StandardScaler(with_mean = True))
# standardizer_x_kdnn = fit_standardizer(xs_train, preprocessing.StandardScaler(with_mean=False))

if train == True:
    
    if standardize:
        net = KoopmanNetCtrl(net_params, standardizer_u=standardizer_u_kdnn)
    else:
        net = KoopmanNetCtrl(net_params)
    model_koop_dnn = KoopDNN(net)
    model_koop_dnn.set_datasets(xs_train, u_train=us_train, x_val=xs_val, u_val=us_val)
    model_koop_dnn.model_pipeline(net_params)
    model_koop_dnn.construct_koopman_model()
    torch.save(model_koop_dnn,file_koop)
else:
    model_koop_dnn = torch.load(file_koop)
# Out:
# Epoch   1: train loss: 0.4435122311, validation loss: 0.1622080624
# Epoch   2: train loss: 0.0891395509, validation loss: 0.0223390806
# Epoch   3: train loss: 0.0055436171, validation loss: 0.0029927327
# Epoch   4: train loss: 0.0017731267, validation loss: 0.0017482194
# Epoch   5: train loss: 0.0011153377, validation loss: 0.0012242683
# Epoch   6: train loss: 0.0008406938, validation loss: 0.0008629353
# Epoch   7: train loss: 0.0006845444, validation loss: 0.0007490973
# Epoch   8: train loss: 0.0005971787, validation loss: 0.0006305573
# Epoch   9: train loss: 0.0005198289, validation loss: 0.0005883115
# Epoch  10: train loss: 0.0004766310, validation loss: 0.0005329263
# Epoch  11: train loss: 0.0004380892, validation loss: 0.0005204822
# Epoch  12: train loss: 0.0004089562, validation loss: 0.0004667796
# Epoch  13: train loss: 0.0003850174, validation loss: 0.0004379998
# Epoch  14: train loss: 0.0003676526, validation loss: 0.0004750960
# Epoch  15: train loss: 0.0003397244, validation loss: 0.0004036017
# Epoch  16: train loss: 0.0003433177, validation loss: 0.0004458602
# Epoch  17: train loss: 0.0003136216, validation loss: 0.0004164534
# Epoch  18: train loss: 0.0003117221, validation loss: 0.0003274319
# Epoch  19: train loss: 0.0003017694, validation loss: 0.0003853305
# Epoch  20: train loss: 0.0002891717, validation loss: 0.0003239104
# Epoch  21: train loss: 0.0002793377, validation loss: 0.0003374725
# Epoch  22: train loss: 0.0002756420, validation loss: 0.0002917674
# Epoch  23: train loss: 0.0002701412, validation loss: 0.0002698739
# Epoch  24: train loss: 0.0002540906, validation loss: 0.0003360927
# Epoch  25: train loss: 0.0002532406, validation loss: 0.0002708709
# Epoch  26: train loss: 0.0002435656, validation loss: 0.0003620426
# Epoch  27: train loss: 0.0002401292, validation loss: 0.0002347758
# Epoch  28: train loss: 0.0002337838, validation loss: 0.0002350446
# Epoch  29: train loss: 0.0002265482, validation loss: 0.0004140226
# Epoch  30: train loss: 0.0002164892, validation loss: 0.0003276720
# Epoch  31: train loss: 0.0002117316, validation loss: 0.0002515621
# Epoch  32: train loss: 0.0002042765, validation loss: 0.0002084274
# Epoch  33: train loss: 0.0001908208, validation loss: 0.0002299198
# Epoch  34: train loss: 0.0001852519, validation loss: 0.0002204800
# Epoch  35: train loss: 0.0001760322, validation loss: 0.0001764934
# Epoch  36: train loss: 0.0001659700, validation loss: 0.0002093907
# Epoch  37: train loss: 0.0001612834, validation loss: 0.0002150639
# Epoch  38: train loss: 0.0001519799, validation loss: 0.0001787146
# Epoch  39: train loss: 0.0001473847, validation loss: 0.0001615323
# Epoch  40: train loss: 0.0001448434, validation loss: 0.0001876459
# Epoch  41: train loss: 0.0001375655, validation loss: 0.0001893468
# Epoch  42: train loss: 0.0001370650, validation loss: 0.0001401860
# Epoch  43: train loss: 0.0001248162, validation loss: 0.0001388008
# Epoch  44: train loss: 0.0001241546, validation loss: 0.0001562809
# Epoch  45: train loss: 0.0001220640, validation loss: 0.0001651701
# Epoch  46: train loss: 0.0001196220, validation loss: 0.0001308662
# Epoch  47: train loss: 0.0001147991, validation loss: 0.0001926090
# Epoch  48: train loss: 0.0001152298, validation loss: 0.0001333185
# Epoch  49: train loss: 0.0001094026, validation loss: 0.0001203780
# Epoch  50: train loss: 0.0001069703, validation loss: 0.0001304108
# Epoch  51: train loss: 0.0001079863, validation loss: 0.0001293833
# Epoch  52: train loss: 0.0001021325, validation loss: 0.0001138346
# Epoch  53: train loss: 0.0001009032, validation loss: 0.0001084107
# Epoch  54: train loss: 0.0000981020, validation loss: 0.0001022656
# Epoch  55: train loss: 0.0000970687, validation loss: 0.0001321137
# Epoch  56: train loss: 0.0000935213, validation loss: 0.0000924332
# Epoch  57: train loss: 0.0000932805, validation loss: 0.0000981946
# Epoch  58: train loss: 0.0000922954, validation loss: 0.0000983517
# Epoch  59: train loss: 0.0000905135, validation loss: 0.0001062383
# Epoch  60: train loss: 0.0000864289, validation loss: 0.0001028413
# Epoch  61: train loss: 0.0000850880, validation loss: 0.0000872931
# Epoch  62: train loss: 0.0000858389, validation loss: 0.0001080488
# Epoch  63: train loss: 0.0000835044, validation loss: 0.0000829509
# Epoch  64: train loss: 0.0000793624, validation loss: 0.0001261428
# Epoch  65: train loss: 0.0000833251, validation loss: 0.0000740131
# Epoch  66: train loss: 0.0000763353, validation loss: 0.0000783012
# Epoch  67: train loss: 0.0000777285, validation loss: 0.0000789619
# Epoch  68: train loss: 0.0000778255, validation loss: 0.0000879604
# Epoch  69: train loss: 0.0000756375, validation loss: 0.0000869249
# Epoch  70: train loss: 0.0000709734, validation loss: 0.0000808566
# Epoch  71: train loss: 0.0000741261, validation loss: 0.0000804507
# Epoch  72: train loss: 0.0000726608, validation loss: 0.0001115164
# Epoch  73: train loss: 0.0000717315, validation loss: 0.0000730259
# Epoch  74: train loss: 0.0000699268, validation loss: 0.0001244711
# Epoch  75: train loss: 0.0000698030, validation loss: 0.0000942676
# Epoch  76: train loss: 0.0000674571, validation loss: 0.0000751884
# Epoch  77: train loss: 0.0000663376, validation loss: 0.0000610453
# Epoch  78: train loss: 0.0000664754, validation loss: 0.0000939032
# Epoch  79: train loss: 0.0000660804, validation loss: 0.0000931120
# Epoch  80: train loss: 0.0000669488, validation loss: 0.0000751117
# Epoch  81: train loss: 0.0000642609, validation loss: 0.0000829117
# Epoch  82: train loss: 0.0000610862, validation loss: 0.0000652460
# Epoch  83: train loss: 0.0000657296, validation loss: 0.0000700329
# Epoch  84: train loss: 0.0000620657, validation loss: 0.0000671328
# Epoch  85: train loss: 0.0000629578, validation loss: 0.0000856117
# Epoch  86: train loss: 0.0000597157, validation loss: 0.0000545488
# Epoch  87: train loss: 0.0000604180, validation loss: 0.0000741745
# Epoch  88: train loss: 0.0000605778, validation loss: 0.0000699574
# Epoch  89: train loss: 0.0000608098, validation loss: 0.0000673295
# Epoch  90: train loss: 0.0000576182, validation loss: 0.0000949203
# Epoch  91: train loss: 0.0000597520, validation loss: 0.0000717464
# Epoch  92: train loss: 0.0000585550, validation loss: 0.0000604106
# Epoch  93: train loss: 0.0000561183, validation loss: 0.0000644673
# Epoch  94: train loss: 0.0000563447, validation loss: 0.0000858681
# Epoch  95: train loss: 0.0000564765, validation loss: 0.0000970161
# Epoch  96: train loss: 0.0000528773, validation loss: 0.0000748676
# Epoch  97: train loss: 0.0000564741, validation loss: 0.0000577841
# Epoch  98: train loss: 0.0000561694, validation loss: 0.0000559500
# Epoch  99: train loss: 0.0000538488, validation loss: 0.0000519834
# Epoch 100: train loss: 0.0000540607, validation loss: 0.0000801799
# Finished Training

# %% [markdown]
# ***Learning Curves***

# %%
train_loss = [l[0] for l in model_koop_dnn.train_loss_hist]
train_pred_loss = [l[1] for l in model_koop_dnn.train_loss_hist]
train_lifted_loss = [l[2] for l in model_koop_dnn.train_loss_hist]
val_loss = [l[0] for l in model_koop_dnn.val_loss_hist]
val_pred_loss = [l[1] for l in model_koop_dnn.val_loss_hist]
val_lifted_loss = [l[2] for l in model_koop_dnn.val_loss_hist]
epochs = np.arange(0, net_params['epochs'])

plt.figure(figsize=(15,8))
plt.plot(epochs, train_loss, color='tab:orange', label='Training loss')
plt.plot(epochs, train_pred_loss, '--', color='tab:orange', label='Training prediction loss')
plt.plot(epochs, train_lifted_loss, ':', color='tab:orange', label='Training lifted loss')
plt.plot(epochs, val_loss, color='tab:blue', label='Validation loss')
plt.plot(epochs, val_pred_loss, '--', color='tab:blue', label='Validation prediction loss')
plt.plot(epochs, val_lifted_loss, ':', color='tab:blue', label='Validation lifted loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale('log')
plt.savefig("convergence plot for arch1")
plt.show()

# %%
map_net_params = {}
map_net_params["input_dim"] = int(num_joints) #number of joint angles
map_net_params["output_dim"] = X_end.shape[2] #x and y position of the end effector
map_net_params["hidden_width"] = 20 #20
map_net_params["hidden_depth"] = 4  #2
map_net_params["batch_size"] = 128  #100
map_net_params["epochs"] = 200     # 500
map_net_params["activation_type"] = 'tanh'
map_net_params["lr"] = 1e-3     #1e-3
map_net_params["optimizer"] = 'adam'
map_net_params['l2_reg'] = 0.0
map_net_params['l1_reg'] = 0.0

# %%
#dataset
# split training and vaidation datasets
xs_map_train, ys_map_train = X_fw[:num_train,:,:int(num_joints)],X_end_fw[:num_train,:,:num_inputs]
xs_map_val, ys_map_val = X_fw[num_train:,:,:int(num_joints)],X_end_fw[num_train:,:,:num_inputs]

# %%
ys_map_train.shape, ys_map_val.shape,xs_map_train.shape, xs_map_val.shape
# Out:
# ((150, 1000, 3), (50, 1000, 3), (150, 1000, 3), (50, 1000, 3))

# %%
#Initalize network
#Initalize network
if mass_var == True:
    file_fwd = 'saved_models/'+ robot_type +'/map_net_con_mass_var.pth' 
else:
    file_fwd = 'saved_models/'+ robot_type +'/map_net_con.pth'

if train == True:
    map_net = map_Net(map_net_params)
    map_net.set_dataset_map(xs_map_train,ys_map_train,xs_map_val,ys_map_val)
    map_net.data_pipeline()
    torch.save(map_net,file_fwd)
else:
    map_net = torch.load(file_fwd)
# Out:
# Epoch   1: train loss: 0.0183033385, validation loss: 0.0043022580
# Epoch   2: train loss: 0.0027631137, validation loss: 0.0017570314
# Epoch   3: train loss: 0.0013738407, validation loss: 0.0012038487
# Epoch   4: train loss: 0.0008834114, validation loss: 0.0006625406
# Epoch   5: train loss: 0.0006324135, validation loss: 0.0005725353
# Epoch   6: train loss: 0.0004926511, validation loss: 0.0004801422
# Epoch   7: train loss: 0.0004071137, validation loss: 0.0003616070
# Epoch   8: train loss: 0.0003446868, validation loss: 0.0004088363
# Epoch   9: train loss: 0.0003083703, validation loss: 0.0003034445
# Epoch  10: train loss: 0.0002792721, validation loss: 0.0002496196
# Epoch  11: train loss: 0.0002515119, validation loss: 0.0002354304
# Epoch  12: train loss: 0.0002287840, validation loss: 0.0002022515
# Epoch  13: train loss: 0.0002191192, validation loss: 0.0001900780
# Epoch  14: train loss: 0.0001986214, validation loss: 0.0001768996
# Epoch  15: train loss: 0.0001852756, validation loss: 0.0001424719
# Epoch  16: train loss: 0.0001735867, validation loss: 0.0002121287
# Epoch  17: train loss: 0.0001643758, validation loss: 0.0001755863
# Epoch  18: train loss: 0.0001502658, validation loss: 0.0001269644
# Epoch  19: train loss: 0.0001449260, validation loss: 0.0001446878
# Epoch  20: train loss: 0.0001336471, validation loss: 0.0001337175
# Epoch  21: train loss: 0.0001264628, validation loss: 0.0001106348
# Epoch  22: train loss: 0.0001216703, validation loss: 0.0001095401
# Epoch  23: train loss: 0.0001139597, validation loss: 0.0000902844
# Epoch  24: train loss: 0.0001051304, validation loss: 0.0001283039
# Epoch  25: train loss: 0.0001026097, validation loss: 0.0000847726
# Epoch  26: train loss: 0.0001010599, validation loss: 0.0000869578
# Epoch  27: train loss: 0.0000930126, validation loss: 0.0000761870
# Epoch  28: train loss: 0.0000913307, validation loss: 0.0000834064
# Epoch  29: train loss: 0.0000861751, validation loss: 0.0000745744
# Epoch  30: train loss: 0.0000855219, validation loss: 0.0000750944
# Epoch  31: train loss: 0.0000825815, validation loss: 0.0000738964
# Epoch  32: train loss: 0.0000785934, validation loss: 0.0000653652
# Epoch  33: train loss: 0.0000771874, validation loss: 0.0000584229
# Epoch  34: train loss: 0.0000732447, validation loss: 0.0000930174
# Epoch  35: train loss: 0.0000748280, validation loss: 0.0001014409
# Epoch  36: train loss: 0.0000686538, validation loss: 0.0000621502
# Epoch  37: train loss: 0.0000689906, validation loss: 0.0000559918
# Epoch  38: train loss: 0.0000641917, validation loss: 0.0000543680
# Epoch  39: train loss: 0.0000656625, validation loss: 0.0000621322
# Epoch  40: train loss: 0.0000624022, validation loss: 0.0000453099
# Epoch  41: train loss: 0.0000603734, validation loss: 0.0000667986
# Epoch  42: train loss: 0.0000585442, validation loss: 0.0000402403
# Epoch  43: train loss: 0.0000572639, validation loss: 0.0000829979
# Epoch  44: train loss: 0.0000545194, validation loss: 0.0000375654
# Epoch  45: train loss: 0.0000551294, validation loss: 0.0000435685
# Epoch  46: train loss: 0.0000543623, validation loss: 0.0000387872
# Epoch  47: train loss: 0.0000505454, validation loss: 0.0000376596
# Epoch  48: train loss: 0.0000497533, validation loss: 0.0001093887
# Epoch  49: train loss: 0.0000510180, validation loss: 0.0000567582
# Epoch  50: train loss: 0.0000471784, validation loss: 0.0000510941
# Epoch  51: train loss: 0.0000464408, validation loss: 0.0000344336
# Epoch  52: train loss: 0.0000465730, validation loss: 0.0000678951
# Epoch  53: train loss: 0.0000458247, validation loss: 0.0000385363
# Epoch  54: train loss: 0.0000423332, validation loss: 0.0000714851
# Epoch  55: train loss: 0.0000423829, validation loss: 0.0000344944
# Epoch  56: train loss: 0.0000443600, validation loss: 0.0000280933
# Epoch  57: train loss: 0.0000394146, validation loss: 0.0000538253
# Epoch  58: train loss: 0.0000401102, validation loss: 0.0000325484
# Epoch  59: train loss: 0.0000396170, validation loss: 0.0000246618
# Epoch  60: train loss: 0.0000389200, validation loss: 0.0000250214
# Epoch  61: train loss: 0.0000378104, validation loss: 0.0000318756
# Epoch  62: train loss: 0.0000367898, validation loss: 0.0000510203
# Epoch  63: train loss: 0.0000364758, validation loss: 0.0000428547
# Epoch  64: train loss: 0.0000372117, validation loss: 0.0000430066
# Epoch  65: train loss: 0.0000342873, validation loss: 0.0000359091
# Epoch  66: train loss: 0.0000351491, validation loss: 0.0000338979
# Epoch  67: train loss: 0.0000351309, validation loss: 0.0000205999
# Epoch  68: train loss: 0.0000358771, validation loss: 0.0000423478
# Epoch  69: train loss: 0.0000332212, validation loss: 0.0000222909
# Epoch  70: train loss: 0.0000331417, validation loss: 0.0000356175
# Epoch  71: train loss: 0.0000332664, validation loss: 0.0000248507
# Epoch  72: train loss: 0.0000327003, validation loss: 0.0000285116
# Epoch  73: train loss: 0.0000317644, validation loss: 0.0000282043
# Epoch  74: train loss: 0.0000311677, validation loss: 0.0000167257
# Epoch  75: train loss: 0.0000301279, validation loss: 0.0000302316
# Epoch  76: train loss: 0.0000299697, validation loss: 0.0000279019
# Epoch  77: train loss: 0.0000316960, validation loss: 0.0000386356
# Epoch  78: train loss: 0.0000288994, validation loss: 0.0000216925
# Epoch  79: train loss: 0.0000286896, validation loss: 0.0000225708
# Epoch  80: train loss: 0.0000302115, validation loss: 0.0000210372
# Epoch  81: train loss: 0.0000279283, validation loss: 0.0001361921
# Epoch  82: train loss: 0.0000276307, validation loss: 0.0000219021
# Epoch  83: train loss: 0.0000302151, validation loss: 0.0000256895
# Epoch  84: train loss: 0.0000270489, validation loss: 0.0000508787
# Epoch  85: train loss: 0.0000288462, validation loss: 0.0000183171
# Epoch  86: train loss: 0.0000274856, validation loss: 0.0000378194
# Epoch  87: train loss: 0.0000267244, validation loss: 0.0000200897
# Epoch  88: train loss: 0.0000264508, validation loss: 0.0000400549
# Epoch  89: train loss: 0.0000271255, validation loss: 0.0000269951
# Epoch  90: train loss: 0.0000275550, validation loss: 0.0000359941
# Epoch  91: train loss: 0.0000266088, validation loss: 0.0000387523
# Epoch  92: train loss: 0.0000256238, validation loss: 0.0000318680
# Epoch  93: train loss: 0.0000246469, validation loss: 0.0000428411
# Epoch  94: train loss: 0.0000260501, validation loss: 0.0000219503
# Epoch  95: train loss: 0.0000235081, validation loss: 0.0000154871
# Epoch  96: train loss: 0.0000244340, validation loss: 0.0000232433
# Epoch  97: train loss: 0.0000236335, validation loss: 0.0000287649
# Epoch  98: train loss: 0.0000252045, validation loss: 0.0000137531
# Epoch  99: train loss: 0.0000236614, validation loss: 0.0000334827
# Epoch 100: train loss: 0.0000248368, validation loss: 0.0000238027
# Epoch 101: train loss: 0.0000234418, validation loss: 0.0000160479
# Epoch 102: train loss: 0.0000237346, validation loss: 0.0000178134
# Epoch 103: train loss: 0.0000233849, validation loss: 0.0000231812
# Epoch 104: train loss: 0.0000229887, validation loss: 0.0000239356
# Epoch 105: train loss: 0.0000227282, validation loss: 0.0000174195
# Epoch 106: train loss: 0.0000228878, validation loss: 0.0000238739
# Epoch 107: train loss: 0.0000230153, validation loss: 0.0000190604
# Epoch 108: train loss: 0.0000225830, validation loss: 0.0000163435
# Epoch 109: train loss: 0.0000221938, validation loss: 0.0000257832
# Epoch 110: train loss: 0.0000217830, validation loss: 0.0000261427
# Epoch 111: train loss: 0.0000238451, validation loss: 0.0000383328
# Epoch 112: train loss: 0.0000222027, validation loss: 0.0000234970
# Epoch 113: train loss: 0.0000213748, validation loss: 0.0000234096
# Epoch 114: train loss: 0.0000216566, validation loss: 0.0000460891
# Epoch 115: train loss: 0.0000217348, validation loss: 0.0000222616
# Epoch 116: train loss: 0.0000235362, validation loss: 0.0000241762
# Epoch 117: train loss: 0.0000207147, validation loss: 0.0000162188
# Epoch 118: train loss: 0.0000211142, validation loss: 0.0000176019
# Epoch 119: train loss: 0.0000216593, validation loss: 0.0000208835
# Epoch 120: train loss: 0.0000202573, validation loss: 0.0000214354
# Epoch 121: train loss: 0.0000214355, validation loss: 0.0000162038
# Epoch 122: train loss: 0.0000205890, validation loss: 0.0000201309
# Epoch 123: train loss: 0.0000207470, validation loss: 0.0000266878
# Epoch 124: train loss: 0.0000203225, validation loss: 0.0000186119
# Epoch 125: train loss: 0.0000214777, validation loss: 0.0000116790
# Epoch 126: train loss: 0.0000197827, validation loss: 0.0000168162
# Epoch 127: train loss: 0.0000199808, validation loss: 0.0000182146
# Epoch 128: train loss: 0.0000204244, validation loss: 0.0000166706
# Epoch 129: train loss: 0.0000196013, validation loss: 0.0000118268
# Epoch 130: train loss: 0.0000207280, validation loss: 0.0000237232
# Epoch 131: train loss: 0.0000186725, validation loss: 0.0000162526
# Epoch 132: train loss: 0.0000200089, validation loss: 0.0000139584
# Epoch 133: train loss: 0.0000193461, validation loss: 0.0000182101
# Epoch 134: train loss: 0.0000207170, validation loss: 0.0000160396
# Epoch 135: train loss: 0.0000186747, validation loss: 0.0000172471
# Epoch 136: train loss: 0.0000185865, validation loss: 0.0000156208
# Epoch 137: train loss: 0.0000194912, validation loss: 0.0000190287
# Epoch 138: train loss: 0.0000203453, validation loss: 0.0000169245
# Epoch 139: train loss: 0.0000180806, validation loss: 0.0000149595
# Epoch 140: train loss: 0.0000192244, validation loss: 0.0000105542
# Epoch 141: train loss: 0.0000201427, validation loss: 0.0000164387
# Epoch 142: train loss: 0.0000190694, validation loss: 0.0000205645
# Epoch 143: train loss: 0.0000188081, validation loss: 0.0000156979
# Epoch 144: train loss: 0.0000175586, validation loss: 0.0000176311
# Epoch 145: train loss: 0.0000189818, validation loss: 0.0000219219
# Epoch 146: train loss: 0.0000193719, validation loss: 0.0000144463
# Epoch 147: train loss: 0.0000174724, validation loss: 0.0000099405
# Epoch 148: train loss: 0.0000189147, validation loss: 0.0000173392
# Epoch 149: train loss: 0.0000182956, validation loss: 0.0000151759
# Epoch 150: train loss: 0.0000183128, validation loss: 0.0000183141
# Epoch 151: train loss: 0.0000187388, validation loss: 0.0000222919
# Epoch 152: train loss: 0.0000175210, validation loss: 0.0000130362
# Epoch 153: train loss: 0.0000183082, validation loss: 0.0000186992
# Epoch 154: train loss: 0.0000175433, validation loss: 0.0000226003
# Epoch 155: train loss: 0.0000187367, validation loss: 0.0000277298
# Epoch 156: train loss: 0.0000179593, validation loss: 0.0000446059
# Epoch 157: train loss: 0.0000172141, validation loss: 0.0000237951
# Epoch 158: train loss: 0.0000175238, validation loss: 0.0000130633
# Epoch 159: train loss: 0.0000176969, validation loss: 0.0000139735
# Epoch 160: train loss: 0.0000176195, validation loss: 0.0000124714
# Epoch 161: train loss: 0.0000174334, validation loss: 0.0000307252
# Epoch 162: train loss: 0.0000175213, validation loss: 0.0000137722
# Epoch 163: train loss: 0.0000169868, validation loss: 0.0000134542
# Epoch 164: train loss: 0.0000192303, validation loss: 0.0000168626
# Epoch 165: train loss: 0.0000171048, validation loss: 0.0000136098
# Epoch 166: train loss: 0.0000172880, validation loss: 0.0000123663
# Epoch 167: train loss: 0.0000163442, validation loss: 0.0000125771
# Epoch 168: train loss: 0.0000176890, validation loss: 0.0000389441
# Epoch 169: train loss: 0.0000167235, validation loss: 0.0000131736
# Epoch 170: train loss: 0.0000167323, validation loss: 0.0000139398
# Epoch 171: train loss: 0.0000176343, validation loss: 0.0000226999
# Epoch 172: train loss: 0.0000167943, validation loss: 0.0000195713
# Epoch 173: train loss: 0.0000177341, validation loss: 0.0000129783
# Epoch 174: train loss: 0.0000160071, validation loss: 0.0000215972
# Epoch 175: train loss: 0.0000174508, validation loss: 0.0000213692
# Epoch 176: train loss: 0.0000153288, validation loss: 0.0000127686
# Epoch 177: train loss: 0.0000168332, validation loss: 0.0000096647
# Epoch 178: train loss: 0.0000162018, validation loss: 0.0000180084
# Epoch 179: train loss: 0.0000157186, validation loss: 0.0000122234
# Epoch 180: train loss: 0.0000161164, validation loss: 0.0000161414
# Epoch 181: train loss: 0.0000174619, validation loss: 0.0000260216
# Epoch 182: train loss: 0.0000162550, validation loss: 0.0000099757
# Epoch 183: train loss: 0.0000165289, validation loss: 0.0000170889
# Epoch 184: train loss: 0.0000161635, validation loss: 0.0000112916
# Epoch 185: train loss: 0.0000158940, validation loss: 0.0000129305
# Epoch 186: train loss: 0.0000161516, validation loss: 0.0000102904
# Epoch 187: train loss: 0.0000145938, validation loss: 0.0000129151
# Epoch 188: train loss: 0.0000155647, validation loss: 0.0000161005
# Epoch 189: train loss: 0.0000161236, validation loss: 0.0000134205
# Epoch 190: train loss: 0.0000156800, validation loss: 0.0000154373
# Epoch 191: train loss: 0.0000149858, validation loss: 0.0000162826
# Epoch 192: train loss: 0.0000157729, validation loss: 0.0000116627
# Epoch 193: train loss: 0.0000158819, validation loss: 0.0000098415
# Epoch 194: train loss: 0.0000152889, validation loss: 0.0000219138
# Epoch 195: train loss: 0.0000153644, validation loss: 0.0000138084
# Epoch 196: train loss: 0.0000151902, validation loss: 0.0000124154
# Epoch 197: train loss: 0.0000157392, validation loss: 0.0000152288
# Epoch 198: train loss: 0.0000148758, validation loss: 0.0000192686
# Epoch 199: train loss: 0.0000148023, validation loss: 0.0000130276
# Epoch 200: train loss: 0.0000157512, validation loss: 0.0000187942
# Finished training

# %%
epochs = np.arange(0, map_net_params['epochs'])
plt.figure(figsize=(15,8))
plt.plot(epochs, map_net.train_loss_hist, color='tab:orange', label='Training loss')
plt.plot(epochs, map_net.val_loss_hist, color='tab:blue', label='Validation loss')

plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale('log')
plt.savefig("convergence plot of map net for arch1[3,20,20,2]")
plt.show()

# %%
# # import scipy.io
# path_model = 'saved_models/'+ robot_type +'/matlab_files/' 

# #save net parameters
# scipy.io.savemat(path_model + "map_in_weights.mat", {"map_in_weights": map_net.map_net_in.weight.detach().numpy()})
# scipy.io.savemat(path_model + "map_in_bias.mat", {"map_in_bias": map_net.map_net_in.bias.detach().numpy()})

# scipy.io.savemat(path_model +"map_hidden_weights_1.mat",
#                  {"map_hidden_weights_1": map_net.map_net_hid[0].weight.detach().numpy()})
# scipy.io.savemat(path_model +"map_hidden_bias_1.mat",
#                  {"map_hidden_bias_1": map_net.map_net_hid[0].bias.detach().numpy()})

# scipy.io.savemat(path_model +"map_hidden_weights_2.mat",
#                  {"map_hidden_weights_2": map_net.map_net_hid[1].weight.detach().numpy()})
# scipy.io.savemat(path_model + "map_hidden_bias_2.mat",
#                  {"map_hidden_bias_2": map_net.map_net_hid[1].bias.detach().numpy()})

# scipy.io.savemat(path_model + "map_hidden_weights_3.mat",
#                  {"map_hidden_weights_3": map_net.map_net_hid[2].weight.detach().numpy()})
# scipy.io.savemat(path_model +"map_hidden_bias_3.mat",
#                  {"map_hidden_bias_3": map_net.map_net_hid[2].bias.detach().numpy()})

# scipy.io.savemat(path_model + "map_out_weights.mat", {"map_out_weights": map_net.map_net_out.weight.detach().numpy()})
# scipy.io.savemat(path_model + "map_out_bias.mat", {"map_out_bias": map_net.map_net_out.bias.detach().numpy()})

# %%
map_net.map_net_hid
# Out:
# ModuleList(
#   (0-2): 3 x Linear(in_features=20, out_features=20, bias=True)
# )

# %% [markdown]
# ## Test Data Parameters

# %%
# test data parameters
num_snaps_val = num_snaps # no. of snapshots
T = np.linspace(0,num_snaps_val*dt, num_snaps_val+1)
num_traj_val = 1 # no. of training examples
first_obs_const = int(net_params['first_obs_const']) #only one state
override_C = net_params['override_C']
if override_C:
    n_obs = int(net_params['encoder_output_dim']) + num_states + first_obs_const 
else:
    n_obs = int(net_params['encoder_output_dim']) + first_obs_const

# %% [markdown]
# ***Koopman Bilinear Model***

# %%
A = np.array(model_koop_dnn.A)
#B = np.array(model_koop_dnn.B).reshape(-1,num_inputs*n_obs)
B = np.array(model_koop_dnn.B)
#B_tensor = np.empty((num_inputs,n_obs, n_obs))
#for ii, b in enumerate(B):
    #B_tensor[ii] = b
C = np.array(model_koop_dnn.C)

print(A.shape, B.shape, C.shape)
# Out:
# (27, 27) (27, 81) (6, 27)

# %% [markdown]
# ## Controlability

# %%
Ac = (A-np.eye(n_obs))/dt
Bc = B/dt
Cc = C
Cr = C[0:3,:]

Cr_v = C[num_joints:2*num_joints,:]

# %%
A.shape, B.shape
# Out:
# ((27, 27), (27, 81))

# %%
#check controllability
Con_lin = ct.ctrb(Ac, Bc)
rank_lin = np.linalg.matrix_rank(Con_lin)

print(rank_lin)
# Out:
# 26

# %%
out_con_mat, out_con_rank = Output_Con(Ac,Bc,Cc)


print(out_con_mat.shape)
print(out_con_rank)
# Out:
# (6, 2268)
# 6

# %%
# continiouts
print('mean full',np.linalg.pinv(Bc).mean())
print('rank full',np.linalg.matrix_rank(Bc))

print('mean full',np.linalg.pinv(Ac).mean())
print('rank full',np.linalg.matrix_rank(Ac))
# Out:
# mean full 0.009247737
# rank full 26
# mean full -23.34722006649871
# rank full 26

# %%
# continiouts
print('mean full',np.linalg.pinv(np.matmul(C,Bc)).mean(),np.linalg.pinv(np.matmul(C,Ac)).mean())
print('rank full',np.linalg.matrix_rank(np.matmul(C,Bc)), np.linalg.matrix_rank(np.matmul(C,Ac)))

print('mean reduced',np.linalg.pinv(np.matmul(Cr,Bc)).mean(),np.linalg.pinv(np.matmul(Cr,Ac)).mean())
print('rank reduced',np.linalg.matrix_rank(np.matmul(Cr,Bc)),np.linalg.matrix_rank(np.matmul(Cr,Ac)))
# Out:
# mean full -0.00011505315 0.08493235394172328
# rank full 6 6
# mean reduced 0.0072619827 0.12673659902551765
# rank reduced 3 3

# %%
# discreate
print('mean full',np.linalg.pinv(np.matmul(C,B)).mean(),np.linalg.pinv(np.matmul(C,A)).mean())
print('rank full',np.linalg.matrix_rank(np.matmul(C,B)), np.linalg.matrix_rank(np.matmul(C,A)))

print('mean reduced',np.linalg.pinv(np.matmul(Cr,B)).mean(),np.linalg.pinv(np.matmul(Cr,A)).mean())
print('rank reduced',np.linalg.matrix_rank(np.matmul(Cr,B)),np.linalg.matrix_rank(np.matmul(Cr,A)))
# Out:
# mean full -0.023003472 0.037013806
# rank full 6 6
# mean reduced 1.4523956 0.037065785
# rank reduced 3 3

# %%
print('mean full',np.linalg.pinv(np.matmul(C,B)).mean(),np.linalg.pinv(np.matmul(C,A)).mean())
print('rank full',np.linalg.matrix_rank(np.matmul(C,B)), np.linalg.matrix_rank(np.matmul(C,A)))

print('mean reduced',np.linalg.pinv(np.matmul(Cr_v,B)).mean(),np.linalg.pinv(np.matmul(Cr_v,A)).mean())
print('rank reduced',np.linalg.matrix_rank(np.matmul(Cr_v,B)),np.linalg.matrix_rank(np.matmul(Cr_v,A)))
# Out:
# mean full -0.023003472 0.037013806
# rank full 6 6
# mean reduced 3.0799754 0.03703244
# rank reduced 3 3

# %%
# # #SAVE MATRIX PARAMETERS AS MATLAB FILE
# # import scipy.io

# dyn_matrices = {"A": A, "B": B, "C": C}
# scipy.io.savemat(path_model + "dyn_mat.mat", dyn_matrices)
# #save encoder parameters

# scipy.io.savemat(path_model + "in_weights.mat", {"encode_in_weights": model_koop_dnn.net.encoder_fc_in.weight.detach().numpy()})
# scipy.io.savemat(path_model + "in_bias.mat", {"encode_in_bias": model_koop_dnn.net.encoder_fc_in.bias.detach().numpy()})

# scipy.io.savemat(path_model + "hidden_weights_1.mat",
#                  {"encode_hidden_weights_1": model_koop_dnn.net.encoder_fc_hid[0].weight.detach().numpy()})
# scipy.io.savemat(path_model + "hidden_bias_1.mat",
#                  {"encode_hidden_bias_1": model_koop_dnn.net.encoder_fc_hid[0].bias.detach().numpy()})

# scipy.io.savemat(path_model + "hidden_weights_2.mat",
#                  {"encode_hidden_weights_2": model_koop_dnn.net.encoder_fc_hid[1].weight.detach().numpy()})
# scipy.io.savemat(path_model + "hidden_bias_2.mat",
#                  {"encode_hidden_bias_2": model_koop_dnn.net.encoder_fc_hid[1].bias.detach().numpy()})

# scipy.io.savemat(path_model + "out_weights.mat", {"encode_out_weights": model_koop_dnn.net.encoder_fc_out.weight.detach().numpy()})
# scipy.io.savemat(path_model + "out_bias.mat", {"encode_out_bias": model_koop_dnn.net.encoder_fc_out.bias.detach().numpy()})

# if standardize:
#     scipy.io.savemat(path_model + "std.mat", {"standardize": standardize, 'mean': standardizer_u_kdnn.mean_, 'scale':standardizer_u_kdnn.scale_})
    
# else:
#     scipy.io.savemat(path_model + "std.mat", {"standardize": standardize})

# %% [markdown]
# ## Save Data

# %%
# #SAVE MATRIX PARAMETERS AS MATLAB FILE
# import scipy.io

path_model = 'saved_models/'+ robot_type +'/matlab_files/' 

dyn_matrices = {"A": A, "B": B, "C": C}
scipy.io.savemat(path_model + "dyn_mat.mat", dyn_matrices)
#save encoder parameters

encoder_dict = {}

encoder_dict["encoder_in_weights"] =  model_koop_dnn.net.encoder_fc_in.weight.detach().numpy()
encoder_dict["encoder_in_bias"] = model_koop_dnn.net.encoder_fc_in.bias.detach().numpy()
encoder_dict["encoder_hidden_depth"] = int(net_params["encoder_hidden_depth"]-1) 

encoder_dict["encoder_hidden_weights"] = np.empty((net_params["encoder_hidden_width"],net_params["encoder_hidden_width"],net_params["encoder_hidden_depth"]-1))
encoder_dict["encoder_hidden_bias"] = np.empty((1,net_params["encoder_hidden_width"],net_params["encoder_hidden_depth"]-1))


for i in range(net_params["encoder_hidden_depth"]-1):
    
    encoder_dict["encoder_hidden_weights"][:,:,i] = model_koop_dnn.net.encoder_fc_hid[i].weight.detach().numpy()
    encoder_dict["encoder_hidden_bias"][:,:,i] = model_koop_dnn.net.encoder_fc_hid[i].bias.detach().numpy()

encoder_dict["encoder_out_weights"] = model_koop_dnn.net.encoder_fc_out.weight.detach().numpy()
encoder_dict["encoder_out_bias"] = model_koop_dnn.net.encoder_fc_out.bias.detach().numpy()

scipy.io.savemat(path_model + "encoder.mat", encoder_dict)

if standardize:
    scipy.io.savemat(path_model + "std.mat", {"standardize": standardize, 'mean': standardizer_u_kdnn.mean_, 'scale':standardizer_u_kdnn.scale_})
    
else:
    scipy.io.savemat(path_model + "std.mat", {"standardize": standardize})

# %%
# save forward map
forward_map_dict = {}

forward_map_dict["map_in_weights"] = map_net.map_net_in.weight.detach().numpy()
forward_map_dict["map_in_bias"] = map_net.map_net_in.bias.detach().numpy()
forward_map_dict["map_hidden_depth"] = int(map_net_params["hidden_depth"]-1)

forward_map_dict["map_hidden_weights"] = np.empty((map_net_params["hidden_width"],map_net_params["hidden_width"],map_net_params["hidden_depth"]-1))
forward_map_dict["map_hidden_bias"] = np.empty((1,map_net_params["hidden_width"],map_net_params["hidden_depth"]-1))

for i in range(map_net_params["hidden_depth"]-1):
    
    forward_map_dict["map_hidden_weights"][:,:,i] = map_net.map_net_hid[i].weight.detach().numpy()
    forward_map_dict["map_hidden_bias"][:,:,i] = map_net.map_net_hid[i].bias.detach().numpy()

forward_map_dict["map_out_weights"] = map_net.map_net_out.weight.detach().numpy()
forward_map_dict["map_out_bias"] = map_net.map_net_out.bias.detach().numpy()


path_model = 'saved_models/'+ robot_type +'/matlab_files/' 
#save net parameters


scipy.io.savemat(path_model + "forward_map.mat", forward_map_dict)

# %%
net_params['encoder_hidden_depth']
# Out:
# 3

# %%
path_model
# Out:
# 'saved_models/3R/bilinear/3D/matlab_files/'

# %%
encode_out_bias = model_koop_dnn.net.encoder_fc_out.bias.detach().numpy()
encode_out_weights = model_koop_dnn.net.encoder_fc_out.weight.detach().numpy()

# %% [markdown]
# ***Test Data Generation***

# %%
# data_gen
j = 10
xs_end_test = X_end[j,:,:]
xs_test = X_full[j,:,:]
us_test = U_full[j,:,:]

# %%
print(xs_end_test.shape, xs_test.shape, us_test.shape)
# Out:
# (1001, 3) (1001, 6) (1000, 3)

# %%
print(model_koop_dnn.test_loss(xs_test.reshape(1,-1,num_states),u_test = us_test.reshape(1,-1,num_inputs)))
# Out:
# tensor(6.6502e-05)

# %%
basis = model_koop_dnn.net.encode_forward_

# %%
X,_ = model_koop_dnn.net.process(xs_test.reshape(1,-1,num_states),data_u = us_test.reshape(1,-1,num_inputs))
print(X.shape)
# Out:
# (1000, 15)

# %%
x = X[:, :num_states]
u = X[:, num_states:num_states+num_inputs]
x_prime = X[:,num_states+num_inputs:]

print(x.shape, u.shape, x_prime.shape)
# Out:
# (1000, 6) (1000, 3) (1000, 6)

# %% [markdown]
# ***Initial Condition Lifting***

# %%
# initialize the matricies
z = np.empty((n_obs,num_snaps_val+1)).T
x_est = np.zeros((num_states,num_snaps_val+1)).T
x_end_est = np.zeros((X_end.shape[2],num_snaps_val)).T

# %%
z[0,:] = lift(x[0,:],model_koop_dnn, net_params)
x_est[0,:] = x[0,:]

# %% [markdown]
# ***Time Evolution***

# %%
for i in range(num_snaps_val):
  #bilinear
    z[i+1,:] = np.matmul(z[i,:],A.T)+np.matmul(np.kron(u[i,:],z[i,:]),B.T)
    x_est[i+1,:] = np.matmul(z[i+1,:],C.T)  
    x_end_est[i,:] = map_net.forward(torch.from_numpy(x_est[i,:int(num_joints)]).float()).detach().numpy()

# %% [markdown]
# ***Visualization***

# %% [markdown]
# # Joint Space

# %%
plt.figure(figsize=(20,12))
for i in range(int(num_joints)):
    plt.subplot(3,3,i+1)
    plt.plot(T[:-1],x[:,i],label ='Actual')
    plt.plot(T[:],x_est[:,i],label = 'estimated(bilinear)')
    plt.xlabel('t')
    plt.ylabel('theta_' + str(i))
    plt.title('theta_' + str(i) + ' Comparison')
    plt.legend()

# %%
plt.figure(figsize=(20,12))
for i in range(int(num_joints)):
    plt.subplot(3,3,i+1)
    plt.plot(T[:-1],x[:,int(num_joints)+i],label ='Actual')
    plt.plot(T[:],x_est[:,int(num_joints)+i],label = 'estimated(bilinear)')
    plt.xlabel('t')
    plt.ylabel('theta_dot_' + str(i))
    plt.title('theta_dot_' + str(i) + ' Comparison')
    plt.legend()

# %%
plt.figure(figsize=(20,12))
for i in range(int(num_joints)):
    plt.subplot(3,3,i+1)
    plt.plot(T[:-1],u[:,i])
    plt.xlabel('t')
    plt.ylabel('tau' + str(i))

# %%
plt.figure(figsize=(20,12))
for i in range(int(num_joints)):
    plt.subplot(3,3,i+1)
    plt.plot(T[:-1],us_test[:,i])
    plt.xlabel('t')
    plt.ylabel('tau' + str(i))

# %%
if standardize:
    u_unscaled = np.array([standardizer_u_kdnn.inverse_transform(d.reshape(1,-1)) for d in u]).reshape(num_snaps_val,num_inputs)
    plt.figure(figsize=(20,12))
    for i in range(int(num_joints)):
        plt.subplot(3,3,i+1)
        plt.plot(T[:-1],us_test[:,i], label= 'original')
        plt.plot(T[:-1],u_unscaled[:,i], label= 'unscaled')
        plt.xlabel('t')
        plt.ylabel('tau' + str(i))
        
    print(u.shape)
    print(u_unscaled.shape)
# Out:
# (1000, 3)
# (1000, 3)

# %% [markdown]
# ## Cartesian Space

# %%
plt.figure(figsize=(20,6))
for i in range(X_end.shape[2]):
    plt.subplot(1,3,i+1)
    plt.plot(T[:],xs_end_test[:,i], label = 'Actual')
    plt.plot(T[:-1],x_end_est[:,i], label = 'Estimated')
    plt.legend()
plt.show()

# %%
error_joint_space = np.linalg.norm(xs_test-x_est,axis = 1)
error_cart_space = np.linalg.norm(xs_end_test[:-1]-x_end_est,axis = 1)

# %%
plt.figure(figsize =(20,6))
plt.subplot(1,2,1)
plt.plot(T[:],error_joint_space)
plt.title('Joint Space Error')

plt.subplot(1,2,2)
plt.plot(T[:-1],error_cart_space)
plt.title('Cartesian Space Error')
# Out:
# Text(0.5, 1.0, 'Cartesian Space Error')

# %%
xs_test[8,:]
# Out:
# array([ 4.52591365e-01, -1.31208954e+00,  8.12483627e-01,  4.77911903e-04,
#        -1.46906935e-03, -1.23776286e-04])

# %% [markdown]
# ## Controllers

# %% [markdown]
# ## ZNN full state

# %%
t_ctrl = np.arange(start=0, stop=10, step=dt)
num_snaps_ctrl = t_ctrl.shape[0]

# %%
gamma = np.diag([100,100,100,300,300,300])
shape = 'cardioid'
c = 0.02
tilt = np.pi/6

# %%
## specify the matricies
z_ctrl = np.zeros((n_obs,num_snaps_ctrl))
z_dot = np.zeros((n_obs,num_snaps_ctrl-1))
x_ctrl = np.zeros((num_states,num_snaps_ctrl))
x_ctrl_end = np.zeros((num_states_cart,num_snaps_ctrl))
x_ctrl_dot_end = np.zeros((num_states_cart,num_snaps_ctrl))
x_ctrl_dot = np.zeros((num_states_cart,num_snaps_ctrl))
rd = np.zeros((num_states_cart,num_snaps_ctrl-1))
rd_dot = np.zeros((num_states_cart,num_snaps_ctrl-1))
rd_ddot = np.zeros((num_states_cart,num_snaps_ctrl-1))
error = np.zeros((2*(num_states_cart),num_snaps_ctrl-1))

u_ctrl = np.zeros((num_inputs,num_snaps_ctrl))

## initialize the matricies
# x_ctrl[:,0] = np.hstack((x_ref[:,0],x_ref_dot[:,0]))
x_ctrl[:,0] = np.hstack((np.ones((num_joints,)), np.zeros((num_joints,))))
z_ctrl[:,0] = lift(x_ctrl[:,0],model_koop_dnn, net_params)
x_ctrl_end[:,0] = map_net.forward(torch.from_numpy(x_ctrl[:num_joints,0]).float()).detach().numpy()

# %%
for i in range(num_snaps_ctrl-1):
    t = t_ctrl[i]
    if modality == '2D':
        # rd[:,i], rd_dot[:,i],rd_ddot= path_pars_2D(t,t_ctrl[-1],c,tilt,x_ctrl_end[:,0], shape)
        rd[:,i], rd_dot[:,i] = x_end[:,i], x_end_dot[:,i]
    else:
        rd[:,i], rd_dot[:,i], rd_ddot[:,i] = path_pars(t,t_ctrl[-1],c,tilt,x_ctrl_end[:,0], shape)
        # rd[:,i], rd_dot[:,i] = x_end[:,i], x_end_dot[:,i]
        
    rd_full = np.hstack((rd[:,i], rd_dot[:,i]))
    rd_dot_full = np.hstack((rd_dot[:,i], rd_ddot[:,i]))
    error[:,i] = np.hstack((x_ctrl_end[:,i],x_ctrl_dot_end[:,i])) - rd_full
    
    W = neural_jacobian(map_net, x_ctrl[:num_joints,i])
    W_dot = neural_jacobian_dot(map_net, x_ctrl[:num_joints,i],x_ctrl[num_joints:,i])
    J_tilde = np.vstack((np.hstack((W,np.zeros_like(W))),np.hstack((W_dot,W))))
    
    u_ctrl[:,i] = np.dot(np.linalg.pinv(np.matmul(Bc,np.kron(z_ctrl[:,i],np.eye(num_inputs)).T)), -np.matmul(Ac,z_ctrl[:,i]) + np.matmul(np.linalg.pinv(np.matmul(J_tilde, Cc)), (rd_dot_full - np.matmul(gamma,error[:,i]))))
    
    # u_ctrl[:,i] = np.dot(np.linalg.pinv(np.matmul(J_tilde,np.matmul(Cc,Bc))), -np.matmul(np.matmul(J_tilde, Cc),np.matmul(Ac,z_ctrl[:,i])) + rd_dot_full - np.matmul(gamma,error[:,i]))
    # u_ctrl[:,i] = np.dot(np.linalg.pinv(np.matmul(Cc,Bc)), -np.matmul(np.matmul(Cc,Ac),z_ctrl[:,i]) + np.matmul(np.linalg.pinv(J_tilde), (rd_dot_full - np.matmul(gamma,error[:,i]))))
            
    
    z_ctrl[:,i+1] = np.matmul(z_ctrl[:,i],A.T) + np.matmul(np.kron(z_ctrl[:,i],u_ctrl[:,i]),B.T)
    x_ctrl[:,i+1] = np.matmul(z_ctrl[:,i+1],C.T)
    x_ctrl_end[:,i+1] = map_net.forward(torch.from_numpy(x_ctrl[:num_joints,i+1]).float()).detach().numpy()
    x_ctrl_dot_end[:,i+1] = np.matmul(neural_jacobian(map_net, x_ctrl[:num_joints,i+1]), x_ctrl[num_joints:,i+1])
    
                   
    # x_ctrl[0:3,i+1],x_ctrl[3:,i+1] = dynamics_3R(dt, u_ctrl[:,i], x_ctrl[0:3,i],x_ctrl[3:,i], robot_pars)
    # z_ctrl[:,i+1] = lift(x_ctrl[:,i+1],model_koop_dnn, net_params)

# %%
np.matmul(gamma,error[:,i])
# Out:
# array([ 3.03539118,  6.98432139, -1.57605407, -5.65629277, -1.9740501 ,
#         1.10152939])

# %%
np.matmul(np.matmul(J_tilde, Cc),A).mean()
# Out:
# -0.017858803

# %%
u_ctrl[:,10]
# Out:
# array([ 0.04333987,  0.06418385, -0.11804788])

# %%
np.matmul(J_tilde,Cc).shape
# Out:
# (6, 27)

# %%
np.vstack((rd_dot[:,i], rd_ddot[:,i]))
# Out:
# array([[ 3.72632458e-07, -7.90349403e-05,  1.86316229e-07],
#        [-1.49052370e-04,  1.58066237e-02, -7.45261848e-05]])

# %%
if modality == '2D':
    plt.figure(figsize=(20,12))
    plt.plot(x_ctrl_end[0,:],x_ctrl_end[1,:],label = 'traced')
    plt.plot(rd[0,:-1],rd[1,:-1],label ='reference')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend()
    plt.axis('equal')
else:
    ax = plt.axes(projection='3d')
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.set_zlabel("z")
    
    ax.plot3D(x_ctrl_end[0,:],x_ctrl_end[1,:],x_ctrl_end[2,:],label = 'traced')
    ax.plot3D(rd[0,:-1],rd[1,:-1],rd[2,:-1],label ='reference')
    plt.legend()

    plt.axis('equal')

# %%
plt.figure(figsize=(20,12))
for i in range(int(num_states_cart)):
    plt.subplot(3,3,i+1)
    plt.plot(t_ctrl[:-1],rd[i,:],label ='reference')
    plt.plot(t_ctrl[:],x_ctrl_end[i,:],label = 'traced')
    plt.xlabel('t')
    plt.legend()

# %%
plt.figure(figsize=(20,12))
for i in range(int(num_states_cart)):
    plt.subplot(3,3,i+1)
    plt.plot(t_ctrl[:-1],error[i,:])
    plt.xlabel('t')
    plt.ylabel('error_' + str(i))

# %%
plt.figure(figsize=(20,12))
for i in range(int(num_joints)):
    plt.subplot(3,3,i+1)
    plt.plot(t_ctrl[:u_ctrl.shape[1]],u_ctrl[i,:])
    plt.xlabel('t')
    plt.ylabel('tau' + str(i))
