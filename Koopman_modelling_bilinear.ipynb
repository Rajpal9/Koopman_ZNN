# %% [markdown]
# ***Import Libraries***

# %%
"""This program linearizes 3R planar dyanmics using koopman theory and autoencoder to map"""
import numpy as np
import matplotlib.pyplot as plt
import sklearn.preprocessing
import itertools
import scipy.io
import torch

# bilinear Koopman
from core.koopman_core import KoopDNN, KoopmanNet, KoopmanNetCtrl
from models.koop_model import model_matricies,lift
from core.util import fit_standardizer
from sklearn import preprocessing

# forward map neural net
from core.neural_fwd_map import map_Net
from models.neural_jacob_map import neural_jacobian, neural_jacobian_dot
# controllability
from core.util import Output_Con
import control as ct


## import paths
from paths.paths import path_pars, path_pars_2D

## extra libraries
import numpy as np
import scipy as sp
from scipy import sparse
import random

# %%
## define paths
robot = '3R'
nature = 'bilinear'
modality = '2D'

robot_type_load = robot +'/' + modality # for data load0
robot_type = robot +'/'+ nature +'/' + modality # for saving purposes

train = True
mass_var = False
standardize = True


if mass_var == True:
    file_data = 'dynamics/Dataset_MATLAB/' + robot_type_load +'/data_mass_var.mat'
    
else:
    file_data = 'dynamics/Dataset_MATLAB/' + robot_type_load +'/data.mat'
    

    
file_data_fwd = 'dynamics/Dataset_MATLAB/' + robot_type_load +'/data_fw.mat'

# %%
file_data
# Out:
# 'dynamics/Dataset_MATLAB/3R/2D/data.mat'

# %% [markdown]
# ### Load Data

# %%
data = scipy.io.loadmat(file_data)
data_fw = scipy.io.loadmat(file_data_fwd)

X_end = np.array(data['X_end'], dtype = 'float64')
X_full = np.array(data['X'], dtype = 'float64')
U_full = np.array(data['tau'], dtype = 'float64')

X_end_fw = np.array(data_fw['X_end_fw'], dtype = 'float64')
X_fw = np.array(data_fw['X_fw'], dtype = 'float64')

print(X_end.shape, X_full.shape,U_full.shape,X_fw.shape,X_end_fw.shape)
# Out:
# (200, 1001, 2) (200, 1001, 6) (200, 1000, 3) (200, 1000, 3) (200, 1000, 2)

# %%
np.sum(np.sum(np.isnan(X_end))), np.sum(np.sum(np.isnan(U_full))), np.sum(np.sum(np.isnan(X_full)))
# Out:
# (0, 0, 0)

# %% [markdown]
# ***Simulation Parameters***

# %%
dt = float(data['dt']) #time step
num_snaps = int(data['num_snaps']) # no. of snapshots
num_traj = int(data['num_traj']) #no of trajectories
T = np.linspace(0,num_snaps*dt, num_snaps+1)
num_train = int(0.75*num_traj) # no. of training examples
num_val = num_traj-num_train # no of testing examples
num_traj = num_train+num_val #no of trajectories
num_states = X_full.shape[2] # no. of states
num_joints = int(num_states/2)
num_inputs = U_full.shape[2] # no. of inputs
num_states_cart = int(X_end.shape[2])

# %%
dt, num_snaps, num_traj, num_states, num_inputs,num_states_cart, num_train, num_val
# Out:
# (0.005, 1000, 200, 6, 3, 2, 150, 50)

# %% [markdown]
# ***Plotting the trajectories***

# %%
"""Training dataset visualization"""
#theta evolution
for i in range(int(num_joints)):
    plt.subplot(3,3,i+1)
    plt.xlabel("t")
    plt.ylabel("th"+str(i+1))
    for j in range(num_traj):
        plt.plot(T,X_full[j,:,i])

# %%
for i in range(int(num_joints)):
    plt.subplot(3,3,i+1)
    plt.xlabel("t")
    plt.ylabel("th"+str(i+1)+ ' dot')
    for j in range(num_traj):
        plt.plot(T,X_full[j,:,i+int(num_joints)])

# %%
#x and y positions of the end effector
# %matplotlib widget
# ax = plt.axes(projection='3d')
# ax.set_xlabel("x")
# ax.set_ylabel("y")
# ax.set_zlabel("z")
# for i in range(num_traj):
#     ax.plot3D(X_end[i,:,0],X_end[i,:,1],X_end[i,:,2])
    
# plt.axis('equal')

# %%
for i in range(num_traj):
    plt.plot(X_end[i,:,0],X_end[i,:,1])
    
plt.axis('equal')
# Out:
# (-1.0350242087098405,
#  1.0499653634141526,
#  -1.0164808326962187,
#  1.0721931443330608)

# %%
for i in range(num_inputs):
    plt.subplot(4,2,i+1)
    plt.xlabel("t")
    plt.ylabel("tau"+str(i))
    for j in range(num_traj):
        plt.plot(T[:-1],U_full[j,:,i])

# %% [markdown]
# ***Training and validation datasets***

# %%
# split training and vaidation datasets
xs_train, us_train = X_full[:num_train,:,:],U_full[:num_train,:,:]
xs_val, us_val = X_full[num_train:,:,:],U_full[num_train:,:,:]

# %%
# import scipy.io
# Data_set = {"x_end": X_end, "X_full": X_full}
# scipy.io.savemat("Data_set.mat",Data_set)

# %%
# import torch
# import torch.nn as nn
# import torch.nn.functional as F

# %% [markdown]
# ***Model Training***

# %%
net_params = {}
net_params['state_dim'] = num_states
net_params['ctrl_dim'] = num_inputs
net_params['encoder_hidden_width'] = 30 # 30
net_params['encoder_hidden_depth'] = 3  # 2
net_params['encoder_output_dim'] = 23   # 20
net_params['optimizer'] = 'adam'
net_params['activation_type'] = 'tanh'
net_params['lr'] = 5e-4 # 5e-4
net_params['epochs'] = 600
net_params['batch_size'] = 128
net_params['lifted_loss_penalty'] = 0.4 
net_params['l2_reg'] = 0.00       
net_params['l1_reg'] = 0.00
net_params['first_obs_const'] = True
net_params['override_C'] = True # this makes the state a part of lifetd state
net_params['dt'] = dt

# %%
                                              
if mass_var == True:
    file_koop = 'saved_models/'+robot_type+'/koop_arch_con_mass_var.pth'
else:
    file_koop = 'saved_models/'+robot_type+'/koop_arch_con.pth'
    
standardizer_u_kdnn = fit_standardizer(us_train, preprocessing.StandardScaler(with_mean = True))
# standardizer_x_kdnn = fit_standardizer(xs_train, preprocessing.StandardScaler(with_mean=False))

if train == True:
    
    if standardize:
        net = KoopmanNetCtrl(net_params, standardizer_u=standardizer_u_kdnn)
    else:
        net = KoopmanNetCtrl(net_params)
    model_koop_dnn = KoopDNN(net)
    model_koop_dnn.set_datasets(xs_train, u_train=us_train, x_val=xs_val, u_val=us_val)
    model_koop_dnn.model_pipeline(net_params)
    model_koop_dnn.construct_koopman_model()
    torch.save(model_koop_dnn,file_koop)
else:
    model_koop_dnn = torch.load(file_koop)
# Out:
# Epoch   1: train loss: 0.5092571974, validation loss: 0.2113443428
# Epoch   2: train loss: 0.0966134667, validation loss: 0.0333878214
# Epoch   3: train loss: 0.0096851559, validation loss: 0.0034787350
# Epoch   4: train loss: 0.0020549546, validation loss: 0.0017235177
# Epoch   5: train loss: 0.0011893297, validation loss: 0.0010902778
# Epoch   6: train loss: 0.0008687818, validation loss: 0.0009866398
# Epoch   7: train loss: 0.0007192623, validation loss: 0.0007134843
# Epoch   8: train loss: 0.0006445606, validation loss: 0.0006017705
# Epoch   9: train loss: 0.0005798512, validation loss: 0.0004839510
# Epoch  10: train loss: 0.0005572816, validation loss: 0.0006531823
# Epoch  11: train loss: 0.0005186354, validation loss: 0.0004701961
# Epoch  12: train loss: 0.0005044250, validation loss: 0.0004956688
# Epoch  13: train loss: 0.0004746258, validation loss: 0.0005247748
# Epoch  14: train loss: 0.0004637622, validation loss: 0.0005175024
# Epoch  15: train loss: 0.0004463360, validation loss: 0.0004223374
# Epoch  16: train loss: 0.0004448203, validation loss: 0.0004275815
# Epoch  17: train loss: 0.0004262078, validation loss: 0.0004148155
# Epoch  18: train loss: 0.0004215159, validation loss: 0.0003868104
# Epoch  19: train loss: 0.0004061495, validation loss: 0.0004349642
# Epoch  20: train loss: 0.0004000546, validation loss: 0.0003576232
# Epoch  21: train loss: 0.0003948933, validation loss: 0.0003859134
# Epoch  22: train loss: 0.0003732128, validation loss: 0.0003488354
# Epoch  23: train loss: 0.0003678146, validation loss: 0.0003304374
# Epoch  24: train loss: 0.0003585182, validation loss: 0.0003197500
# Epoch  25: train loss: 0.0003444519, validation loss: 0.0005187168
# Epoch  26: train loss: 0.0003400056, validation loss: 0.0003180652
# Epoch  27: train loss: 0.0003260609, validation loss: 0.0002809693
# Epoch  28: train loss: 0.0003114074, validation loss: 0.0002683143
# Epoch  29: train loss: 0.0003004749, validation loss: 0.0002928595
# Epoch  30: train loss: 0.0002947876, validation loss: 0.0002388275
# Epoch  31: train loss: 0.0002822526, validation loss: 0.0003153066
# Epoch  32: train loss: 0.0002750246, validation loss: 0.0002679069
# Epoch  33: train loss: 0.0002668954, validation loss: 0.0003155896
# Epoch  34: train loss: 0.0002647207, validation loss: 0.0002668812
# Epoch  35: train loss: 0.0002574612, validation loss: 0.0002836044
# Epoch  36: train loss: 0.0002418692, validation loss: 0.0002274976
# Epoch  37: train loss: 0.0002483907, validation loss: 0.0002498860
# Epoch  38: train loss: 0.0002373402, validation loss: 0.0002102519
# Epoch  39: train loss: 0.0002358745, validation loss: 0.0002255049
# Epoch  40: train loss: 0.0002261224, validation loss: 0.0002619413
# Epoch  41: train loss: 0.0002177822, validation loss: 0.0002592247
# Epoch  42: train loss: 0.0002159327, validation loss: 0.0001839956
# Epoch  43: train loss: 0.0002108403, validation loss: 0.0002006250
# Epoch  44: train loss: 0.0002067511, validation loss: 0.0002020512
# Epoch  45: train loss: 0.0002038132, validation loss: 0.0003246907
# Epoch  46: train loss: 0.0002020046, validation loss: 0.0002557381
# Epoch  47: train loss: 0.0001925854, validation loss: 0.0001671307
# Epoch  48: train loss: 0.0001857537, validation loss: 0.0001713867
# Epoch  49: train loss: 0.0001822383, validation loss: 0.0001715542
# Epoch  50: train loss: 0.0001754576, validation loss: 0.0002005967
# Epoch  51: train loss: 0.0001734861, validation loss: 0.0001740251
# Epoch  52: train loss: 0.0001696756, validation loss: 0.0001296114
# Epoch  53: train loss: 0.0001677589, validation loss: 0.0002091052
# Epoch  54: train loss: 0.0001587387, validation loss: 0.0001725670
# Epoch  55: train loss: 0.0001554785, validation loss: 0.0001558244
# Epoch  56: train loss: 0.0001554531, validation loss: 0.0001260785
# Epoch  57: train loss: 0.0001502527, validation loss: 0.0001759785
# Epoch  58: train loss: 0.0001463257, validation loss: 0.0001771237
# Epoch  59: train loss: 0.0001424674, validation loss: 0.0001348749
# Epoch  60: train loss: 0.0001431930, validation loss: 0.0001521613
# Epoch  61: train loss: 0.0001373306, validation loss: 0.0001431232
# Epoch  62: train loss: 0.0001345909, validation loss: 0.0001180102
# Epoch  63: train loss: 0.0001327484, validation loss: 0.0001134284
# Epoch  64: train loss: 0.0001283494, validation loss: 0.0002128845
# Epoch  65: train loss: 0.0001297336, validation loss: 0.0002334457
# Epoch  66: train loss: 0.0001228677, validation loss: 0.0001118039
# Epoch  67: train loss: 0.0001210326, validation loss: 0.0001197081
# Epoch  68: train loss: 0.0001249929, validation loss: 0.0001266247
# Epoch  69: train loss: 0.0001129755, validation loss: 0.0001353439
# Epoch  70: train loss: 0.0001160493, validation loss: 0.0001049945
# Epoch  71: train loss: 0.0001132808, validation loss: 0.0001001625
# Epoch  72: train loss: 0.0001116961, validation loss: 0.0001254207
# Epoch  73: train loss: 0.0001083694, validation loss: 0.0001277702
# Epoch  74: train loss: 0.0001058119, validation loss: 0.0001188065
# Epoch  75: train loss: 0.0001017622, validation loss: 0.0001562586
# Epoch  76: train loss: 0.0001047290, validation loss: 0.0000944240
# Epoch  77: train loss: 0.0001032494, validation loss: 0.0000781189
# Epoch  78: train loss: 0.0000995820, validation loss: 0.0000987940
# Epoch  79: train loss: 0.0000978601, validation loss: 0.0000851580
# Epoch  80: train loss: 0.0000935532, validation loss: 0.0000881221
# Epoch  81: train loss: 0.0000937219, validation loss: 0.0000897868
# Epoch  82: train loss: 0.0000893867, validation loss: 0.0000712822
# Epoch  83: train loss: 0.0000907183, validation loss: 0.0000926332
# Epoch  84: train loss: 0.0000875451, validation loss: 0.0000753177
# Epoch  85: train loss: 0.0000856869, validation loss: 0.0001023208
# Epoch  86: train loss: 0.0000778892, validation loss: 0.0001087374
# Epoch  87: train loss: 0.0000836922, validation loss: 0.0000919615
# Epoch  88: train loss: 0.0000783436, validation loss: 0.0001312934
# Epoch  89: train loss: 0.0000793424, validation loss: 0.0000613900
# Epoch  90: train loss: 0.0000739390, validation loss: 0.0000986178
# Epoch  91: train loss: 0.0000771434, validation loss: 0.0000574744
# Epoch  92: train loss: 0.0000736420, validation loss: 0.0000946455
# Epoch  93: train loss: 0.0000698260, validation loss: 0.0000555040
# Epoch  94: train loss: 0.0000693359, validation loss: 0.0000681488
# Epoch  95: train loss: 0.0000677715, validation loss: 0.0000541389
# Epoch  96: train loss: 0.0000675402, validation loss: 0.0000524679
# Epoch  97: train loss: 0.0000675679, validation loss: 0.0000815369
# Epoch  98: train loss: 0.0000655824, validation loss: 0.0000493146
# Epoch  99: train loss: 0.0000613460, validation loss: 0.0000737909
# Epoch 100: train loss: 0.0000651879, validation loss: 0.0000679757
# Epoch 101: train loss: 0.0000591008, validation loss: 0.0000505929
# Epoch 102: train loss: 0.0000611716, validation loss: 0.0000398853
# Epoch 103: train loss: 0.0000611987, validation loss: 0.0002312700
# Epoch 104: train loss: 0.0000568295, validation loss: 0.0000435355
# Epoch 105: train loss: 0.0000575591, validation loss: 0.0000852675
# Epoch 106: train loss: 0.0000563607, validation loss: 0.0001183998
# Epoch 107: train loss: 0.0000583975, validation loss: 0.0000578443
# Epoch 108: train loss: 0.0000520590, validation loss: 0.0000319552
# Epoch 109: train loss: 0.0000545478, validation loss: 0.0000386034
# Epoch 110: train loss: 0.0000556007, validation loss: 0.0000483563
# Epoch 111: train loss: 0.0000523076, validation loss: 0.0000423916
# Epoch 112: train loss: 0.0000533435, validation loss: 0.0000599611
# Epoch 113: train loss: 0.0000524993, validation loss: 0.0000276186
# Epoch 114: train loss: 0.0000518541, validation loss: 0.0000456728
# Epoch 115: train loss: 0.0000482456, validation loss: 0.0000574088
# Epoch 116: train loss: 0.0000531855, validation loss: 0.0000428385
# Epoch 117: train loss: 0.0000470617, validation loss: 0.0000394619
# Epoch 118: train loss: 0.0000496924, validation loss: 0.0000891134
# Epoch 119: train loss: 0.0000464212, validation loss: 0.0000424517
# Epoch 120: train loss: 0.0000471277, validation loss: 0.0000524498
# Epoch 121: train loss: 0.0000469420, validation loss: 0.0000400087
# Epoch 122: train loss: 0.0000466513, validation loss: 0.0000458196
# Epoch 123: train loss: 0.0000485512, validation loss: 0.0000526948
# Epoch 124: train loss: 0.0000462546, validation loss: 0.0000797410
# Epoch 125: train loss: 0.0000443333, validation loss: 0.0000499129
# Epoch 126: train loss: 0.0000474533, validation loss: 0.0000293430
# Epoch 127: train loss: 0.0000459805, validation loss: 0.0000267867
# Epoch 128: train loss: 0.0000443810, validation loss: 0.0000378461
# Epoch 129: train loss: 0.0000438277, validation loss: 0.0000971999
# Epoch 130: train loss: 0.0000445212, validation loss: 0.0000775980
# Epoch 131: train loss: 0.0000414299, validation loss: 0.0000526480
# Epoch 132: train loss: 0.0000468975, validation loss: 0.0000250330
# Epoch 133: train loss: 0.0000410344, validation loss: 0.0000293123
# Epoch 134: train loss: 0.0000405331, validation loss: 0.0000739399
# Epoch 135: train loss: 0.0000404609, validation loss: 0.0000405428
# Epoch 136: train loss: 0.0000416832, validation loss: 0.0000370536
# Epoch 137: train loss: 0.0000406131, validation loss: 0.0000443846
# Epoch 138: train loss: 0.0000414172, validation loss: 0.0000325850
# Epoch 139: train loss: 0.0000393890, validation loss: 0.0000247602
# Epoch 140: train loss: 0.0000382259, validation loss: 0.0000240102
# Epoch 141: train loss: 0.0000411058, validation loss: 0.0000686238
# Epoch 142: train loss: 0.0000376623, validation loss: 0.0000486146
# Epoch 143: train loss: 0.0000393757, validation loss: 0.0000320613
# Epoch 144: train loss: 0.0000361116, validation loss: 0.0000284115
# Epoch 145: train loss: 0.0000404925, validation loss: 0.0000216610
# Epoch 146: train loss: 0.0000374127, validation loss: 0.0000300934
# Epoch 147: train loss: 0.0000371092, validation loss: 0.0000819352
# Epoch 148: train loss: 0.0000376413, validation loss: 0.0000412489
# Epoch 149: train loss: 0.0000361642, validation loss: 0.0000256064
# Epoch 150: train loss: 0.0000363805, validation loss: 0.0000310672
# Epoch 151: train loss: 0.0000393172, validation loss: 0.0000313845
# Epoch 152: train loss: 0.0000362969, validation loss: 0.0000335439
# Epoch 153: train loss: 0.0000351304, validation loss: 0.0000577689
# Epoch 154: train loss: 0.0000345400, validation loss: 0.0000917610
# Epoch 155: train loss: 0.0000371064, validation loss: 0.0000333699
# Epoch 156: train loss: 0.0000363800, validation loss: 0.0000238566
# Epoch 157: train loss: 0.0000347536, validation loss: 0.0000417519
# Epoch 158: train loss: 0.0000343107, validation loss: 0.0000198826
# Epoch 159: train loss: 0.0000356382, validation loss: 0.0000260728
# Epoch 160: train loss: 0.0000327440, validation loss: 0.0000315638
# Epoch 161: train loss: 0.0000325054, validation loss: 0.0000207586
# Epoch 162: train loss: 0.0000320073, validation loss: 0.0000290063
# Epoch 163: train loss: 0.0000367444, validation loss: 0.0000285343
# Epoch 164: train loss: 0.0000301768, validation loss: 0.0000315643
# Epoch 165: train loss: 0.0000334961, validation loss: 0.0000592303
# Epoch 166: train loss: 0.0000321836, validation loss: 0.0000272461
# Epoch 167: train loss: 0.0000333929, validation loss: 0.0000204738
# Epoch 168: train loss: 0.0000364877, validation loss: 0.0000158282
# Epoch 169: train loss: 0.0000286551, validation loss: 0.0000813873
# Epoch 170: train loss: 0.0000309820, validation loss: 0.0000344500
# Epoch 171: train loss: 0.0000312356, validation loss: 0.0000312539
# Epoch 172: train loss: 0.0000316756, validation loss: 0.0000347257
# Epoch 173: train loss: 0.0000309878, validation loss: 0.0000207292
# Epoch 174: train loss: 0.0000319291, validation loss: 0.0000623058
# Epoch 175: train loss: 0.0000287007, validation loss: 0.0000184970
# Epoch 176: train loss: 0.0000299289, validation loss: 0.0000299096
# Epoch 177: train loss: 0.0000288246, validation loss: 0.0000214629
# Epoch 178: train loss: 0.0000318377, validation loss: 0.0000253381
# Epoch 179: train loss: 0.0000271425, validation loss: 0.0000221871
# Epoch 180: train loss: 0.0000286936, validation loss: 0.0000188317
# Epoch 181: train loss: 0.0000301634, validation loss: 0.0000452896
# Epoch 182: train loss: 0.0000278021, validation loss: 0.0000184688
# Epoch 183: train loss: 0.0000282598, validation loss: 0.0000401549
# Epoch 184: train loss: 0.0000274993, validation loss: 0.0000383459
# Epoch 185: train loss: 0.0000288122, validation loss: 0.0000691592
# Epoch 186: train loss: 0.0000290514, validation loss: 0.0000292475
# Epoch 187: train loss: 0.0000290049, validation loss: 0.0000241584
# Epoch 188: train loss: 0.0000292358, validation loss: 0.0000161631
# Epoch 189: train loss: 0.0000256824, validation loss: 0.0000212129
# Epoch 190: train loss: 0.0000251163, validation loss: 0.0000242491
# Epoch 191: train loss: 0.0000285753, validation loss: 0.0000322466
# Epoch 192: train loss: 0.0000253434, validation loss: 0.0000154791
# Epoch 193: train loss: 0.0000258344, validation loss: 0.0000461013
# Epoch 194: train loss: 0.0000258068, validation loss: 0.0000216117
# Epoch 195: train loss: 0.0000290069, validation loss: 0.0000241366
# Epoch 196: train loss: 0.0000252769, validation loss: 0.0000198927
# Epoch 197: train loss: 0.0000261336, validation loss: 0.0000137899
# Epoch 198: train loss: 0.0000274592, validation loss: 0.0000411148
# Epoch 199: train loss: 0.0000244526, validation loss: 0.0000182853
# Epoch 200: train loss: 0.0000245321, validation loss: 0.0000431207
# Epoch 201: train loss: 0.0000266802, validation loss: 0.0000139335
# Epoch 202: train loss: 0.0000251443, validation loss: 0.0000161576
# Epoch 203: train loss: 0.0000245261, validation loss: 0.0000289391
# Epoch 204: train loss: 0.0000242363, validation loss: 0.0000145829
# Epoch 205: train loss: 0.0000230867, validation loss: 0.0000356180
# Epoch 206: train loss: 0.0000257306, validation loss: 0.0000180417
# Epoch 207: train loss: 0.0000232081, validation loss: 0.0000334509
# Epoch 208: train loss: 0.0000218560, validation loss: 0.0000338971
# Epoch 209: train loss: 0.0000253488, validation loss: 0.0000174162
# Epoch 210: train loss: 0.0000240395, validation loss: 0.0000166917
# Epoch 211: train loss: 0.0000300080, validation loss: 0.0000170554
# Epoch 212: train loss: 0.0000180235, validation loss: 0.0000216166
# Epoch 213: train loss: 0.0000253890, validation loss: 0.0000242378
# Epoch 214: train loss: 0.0000218507, validation loss: 0.0000250684
# Epoch 215: train loss: 0.0000226078, validation loss: 0.0000196916
# Epoch 216: train loss: 0.0000213841, validation loss: 0.0000151139
# Epoch 217: train loss: 0.0000226681, validation loss: 0.0000223651
# Epoch 218: train loss: 0.0000211301, validation loss: 0.0000189947
# Epoch 219: train loss: 0.0000221656, validation loss: 0.0000181028
# Epoch 220: train loss: 0.0000221141, validation loss: 0.0000503762
# Epoch 221: train loss: 0.0000220478, validation loss: 0.0000155522
# Epoch 222: train loss: 0.0000213662, validation loss: 0.0000209059
# Epoch 223: train loss: 0.0000213611, validation loss: 0.0000286051
# Epoch 224: train loss: 0.0000240445, validation loss: 0.0000140301
# Epoch 225: train loss: 0.0000212227, validation loss: 0.0000159743
# Epoch 226: train loss: 0.0000212747, validation loss: 0.0000222785
# Epoch 227: train loss: 0.0000217151, validation loss: 0.0000473701
# Epoch 228: train loss: 0.0000189328, validation loss: 0.0000209387
# Epoch 229: train loss: 0.0000215593, validation loss: 0.0000132183
# Epoch 230: train loss: 0.0000210524, validation loss: 0.0000250186
# Epoch 231: train loss: 0.0000203408, validation loss: 0.0000106212
# Epoch 232: train loss: 0.0000230361, validation loss: 0.0000092778
# Epoch 233: train loss: 0.0000190486, validation loss: 0.0000131509
# Epoch 234: train loss: 0.0000201979, validation loss: 0.0000196174
# Epoch 235: train loss: 0.0000210565, validation loss: 0.0000164144
# Epoch 236: train loss: 0.0000192846, validation loss: 0.0000429771
# Epoch 237: train loss: 0.0000201736, validation loss: 0.0000145937
# Epoch 238: train loss: 0.0000180494, validation loss: 0.0000120406
# Epoch 239: train loss: 0.0000221658, validation loss: 0.0000227441
# Epoch 240: train loss: 0.0000192414, validation loss: 0.0000138175
# Epoch 241: train loss: 0.0000183640, validation loss: 0.0000120764
# Epoch 242: train loss: 0.0000194806, validation loss: 0.0000120471
# Epoch 243: train loss: 0.0000204410, validation loss: 0.0000125089
# Epoch 244: train loss: 0.0000171158, validation loss: 0.0000141071
# Epoch 245: train loss: 0.0000220940, validation loss: 0.0000129032
# Epoch 246: train loss: 0.0000168421, validation loss: 0.0000277632
# Epoch 247: train loss: 0.0000191402, validation loss: 0.0000207784
# Epoch 248: train loss: 0.0000190432, validation loss: 0.0000126750
# Epoch 249: train loss: 0.0000176200, validation loss: 0.0000205929
# Epoch 250: train loss: 0.0000185286, validation loss: 0.0000179369
# Epoch 251: train loss: 0.0000182154, validation loss: 0.0000298490
# Epoch 252: train loss: 0.0000166853, validation loss: 0.0000117603
# Epoch 253: train loss: 0.0000199401, validation loss: 0.0000079388
# Epoch 254: train loss: 0.0000170811, validation loss: 0.0000257916
# Epoch 255: train loss: 0.0000180121, validation loss: 0.0000199419
# Epoch 256: train loss: 0.0000194164, validation loss: 0.0000084142
# Epoch 257: train loss: 0.0000168127, validation loss: 0.0000249995
# Epoch 258: train loss: 0.0000176015, validation loss: 0.0000287161
# Epoch 259: train loss: 0.0000164462, validation loss: 0.0000258096
# Epoch 260: train loss: 0.0000172590, validation loss: 0.0000536986
# Epoch 261: train loss: 0.0000173621, validation loss: 0.0000236161
# Epoch 262: train loss: 0.0000173746, validation loss: 0.0000126139
# Epoch 263: train loss: 0.0000213139, validation loss: 0.0000061928
# Epoch 264: train loss: 0.0000147894, validation loss: 0.0000139612
# Epoch 265: train loss: 0.0000156309, validation loss: 0.0000153355
# Epoch 266: train loss: 0.0000165976, validation loss: 0.0000461414
# Epoch 267: train loss: 0.0000174620, validation loss: 0.0000141930
# Epoch 268: train loss: 0.0000159800, validation loss: 0.0000454898
# Epoch 269: train loss: 0.0000162393, validation loss: 0.0000120708
# Epoch 270: train loss: 0.0000167210, validation loss: 0.0000196032
# Epoch 271: train loss: 0.0000163434, validation loss: 0.0000111842
# Epoch 272: train loss: 0.0000160449, validation loss: 0.0000103960
# Epoch 273: train loss: 0.0000158834, validation loss: 0.0000108959
# Epoch 274: train loss: 0.0000152938, validation loss: 0.0000209746
# Epoch 275: train loss: 0.0000163676, validation loss: 0.0000190145
# Epoch 276: train loss: 0.0000156135, validation loss: 0.0000091859
# Epoch 277: train loss: 0.0000158894, validation loss: 0.0000110831
# Epoch 278: train loss: 0.0000165875, validation loss: 0.0000141949
# Epoch 279: train loss: 0.0000165536, validation loss: 0.0000527908
# Epoch 280: train loss: 0.0000144599, validation loss: 0.0000235832
# Epoch 281: train loss: 0.0000162793, validation loss: 0.0000374618
# Epoch 282: train loss: 0.0000154263, validation loss: 0.0000097113
# Epoch 283: train loss: 0.0000151507, validation loss: 0.0000079420
# Epoch 284: train loss: 0.0000159733, validation loss: 0.0000069891
# Epoch 285: train loss: 0.0000142952, validation loss: 0.0000149818
# Epoch 286: train loss: 0.0000157728, validation loss: 0.0000061832
# Epoch 287: train loss: 0.0000155912, validation loss: 0.0000385379
# Epoch 288: train loss: 0.0000140623, validation loss: 0.0000139512
# Epoch 289: train loss: 0.0000151650, validation loss: 0.0000128922
# Epoch 290: train loss: 0.0000147865, validation loss: 0.0000118492
# Epoch 291: train loss: 0.0000144417, validation loss: 0.0000168541
# Epoch 292: train loss: 0.0000148884, validation loss: 0.0000219602
# Epoch 293: train loss: 0.0000137324, validation loss: 0.0000152614
# Epoch 294: train loss: 0.0000159474, validation loss: 0.0000481885
# Epoch 295: train loss: 0.0000165328, validation loss: 0.0000072914
# Epoch 296: train loss: 0.0000128937, validation loss: 0.0000124822
# Epoch 297: train loss: 0.0000146467, validation loss: 0.0000074417
# Epoch 298: train loss: 0.0000155678, validation loss: 0.0000100869
# Epoch 299: train loss: 0.0000133142, validation loss: 0.0000129247
# Epoch 300: train loss: 0.0000141045, validation loss: 0.0000060895
# Epoch 301: train loss: 0.0000138945, validation loss: 0.0000301757
# Epoch 302: train loss: 0.0000140112, validation loss: 0.0000181065
# Epoch 303: train loss: 0.0000128962, validation loss: 0.0000119601
# Epoch 304: train loss: 0.0000141479, validation loss: 0.0000082412
# Epoch 305: train loss: 0.0000143167, validation loss: 0.0000076511
# Epoch 306: train loss: 0.0000134347, validation loss: 0.0000090667
# Epoch 307: train loss: 0.0000144278, validation loss: 0.0000116548
# Epoch 308: train loss: 0.0000127462, validation loss: 0.0000703367
# Epoch 309: train loss: 0.0000138205, validation loss: 0.0000159837
# Epoch 310: train loss: 0.0000145743, validation loss: 0.0000077428
# Epoch 311: train loss: 0.0000117556, validation loss: 0.0000082236
# Epoch 312: train loss: 0.0000121712, validation loss: 0.0000195084
# Epoch 313: train loss: 0.0000138191, validation loss: 0.0000271068
# Epoch 314: train loss: 0.0000133344, validation loss: 0.0000060640
# Epoch 315: train loss: 0.0000120411, validation loss: 0.0000226436
# Epoch 316: train loss: 0.0000128014, validation loss: 0.0000105697
# Epoch 317: train loss: 0.0000126601, validation loss: 0.0000054071
# Epoch 318: train loss: 0.0000124054, validation loss: 0.0000689159
# Epoch 319: train loss: 0.0000128494, validation loss: 0.0000136423
# Epoch 320: train loss: 0.0000141581, validation loss: 0.0000065718
# Epoch 321: train loss: 0.0000148851, validation loss: 0.0000297892
# Epoch 322: train loss: 0.0000127470, validation loss: 0.0000145078
# Epoch 323: train loss: 0.0000106138, validation loss: 0.0000088607
# Epoch 324: train loss: 0.0000153556, validation loss: 0.0000293630
# Epoch 325: train loss: 0.0000112018, validation loss: 0.0000100858
# Epoch 326: train loss: 0.0000134294, validation loss: 0.0000128525
# Epoch 327: train loss: 0.0000119475, validation loss: 0.0000138168
# Epoch 328: train loss: 0.0000116911, validation loss: 0.0000343685
# Epoch 329: train loss: 0.0000118879, validation loss: 0.0000084604
# Epoch 330: train loss: 0.0000115933, validation loss: 0.0000179268
# Epoch 331: train loss: 0.0000123382, validation loss: 0.0000122905
# Epoch 332: train loss: 0.0000142270, validation loss: 0.0000052395
# Epoch 333: train loss: 0.0000112117, validation loss: 0.0000089648
# Epoch 334: train loss: 0.0000118474, validation loss: 0.0000127252
# Epoch 335: train loss: 0.0000123219, validation loss: 0.0000127971
# Epoch 336: train loss: 0.0000127091, validation loss: 0.0000084394
# Epoch 337: train loss: 0.0000096051, validation loss: 0.0000110804
# Epoch 338: train loss: 0.0000120597, validation loss: 0.0000065043
# Epoch 339: train loss: 0.0000121634, validation loss: 0.0000095243
# Epoch 340: train loss: 0.0000133896, validation loss: 0.0000056901
# Epoch 341: train loss: 0.0000101611, validation loss: 0.0000082862
# Epoch 342: train loss: 0.0000118108, validation loss: 0.0000121443
# Epoch 343: train loss: 0.0000114642, validation loss: 0.0000062182
# Epoch 344: train loss: 0.0000130201, validation loss: 0.0000058686
# Epoch 345: train loss: 0.0000109441, validation loss: 0.0000070140
# Epoch 346: train loss: 0.0000120980, validation loss: 0.0000108419
# Epoch 347: train loss: 0.0000111808, validation loss: 0.0000043339
# Epoch 348: train loss: 0.0000102229, validation loss: 0.0000150413
# Epoch 349: train loss: 0.0000117109, validation loss: 0.0000058182
# Epoch 350: train loss: 0.0000115412, validation loss: 0.0000410989
# Epoch 351: train loss: 0.0000103587, validation loss: 0.0000065914
# Epoch 352: train loss: 0.0000117384, validation loss: 0.0000123974
# Epoch 353: train loss: 0.0000137771, validation loss: 0.0000046363
# Epoch 354: train loss: 0.0000088097, validation loss: 0.0000258600
# Epoch 355: train loss: 0.0000106571, validation loss: 0.0000128141
# Epoch 356: train loss: 0.0000114315, validation loss: 0.0000056719
# Epoch 357: train loss: 0.0000106908, validation loss: 0.0000066259
# Epoch 358: train loss: 0.0000100968, validation loss: 0.0000057315
# Epoch 359: train loss: 0.0000102763, validation loss: 0.0000106627
# Epoch 360: train loss: 0.0000128525, validation loss: 0.0000074226
# Epoch 361: train loss: 0.0000101734, validation loss: 0.0000058794
# Epoch 362: train loss: 0.0000096479, validation loss: 0.0000173156
# Epoch 363: train loss: 0.0000115974, validation loss: 0.0000197867
# Epoch 364: train loss: 0.0000100429, validation loss: 0.0000171647
# Epoch 365: train loss: 0.0000092774, validation loss: 0.0000076523
# Epoch 366: train loss: 0.0000108910, validation loss: 0.0000129966
# Epoch 367: train loss: 0.0000118960, validation loss: 0.0000058559
# Epoch 368: train loss: 0.0000103817, validation loss: 0.0000092433
# Epoch 369: train loss: 0.0000086709, validation loss: 0.0000061836
# Epoch 370: train loss: 0.0000099111, validation loss: 0.0000049598
# Epoch 371: train loss: 0.0000101789, validation loss: 0.0000091384
# Epoch 372: train loss: 0.0000105450, validation loss: 0.0000521486
# Epoch 373: train loss: 0.0000087443, validation loss: 0.0000094048
# Epoch 374: train loss: 0.0000107242, validation loss: 0.0000039402
# Epoch 375: train loss: 0.0000093168, validation loss: 0.0000349967
# Epoch 376: train loss: 0.0000121868, validation loss: 0.0000047556
# Epoch 377: train loss: 0.0000071844, validation loss: 0.0000056139
# Epoch 378: train loss: 0.0000100968, validation loss: 0.0000081636
# Epoch 379: train loss: 0.0000096524, validation loss: 0.0000096496
# Epoch 380: train loss: 0.0000097631, validation loss: 0.0000039181
# Epoch 381: train loss: 0.0000117472, validation loss: 0.0000033174
# Epoch 382: train loss: 0.0000081485, validation loss: 0.0000360008
# Epoch 383: train loss: 0.0000102328, validation loss: 0.0000052106
# Epoch 384: train loss: 0.0000088228, validation loss: 0.0000173811
# Epoch 385: train loss: 0.0000088763, validation loss: 0.0000112567
# Epoch 386: train loss: 0.0000094144, validation loss: 0.0000056988
# Epoch 387: train loss: 0.0000099433, validation loss: 0.0000220750
# Epoch 388: train loss: 0.0000085367, validation loss: 0.0000067106
# Epoch 389: train loss: 0.0000103024, validation loss: 0.0000066816
# Epoch 390: train loss: 0.0000079434, validation loss: 0.0000109103
# Epoch 391: train loss: 0.0000101778, validation loss: 0.0000606579
# Epoch 392: train loss: 0.0000089639, validation loss: 0.0000056982
# Epoch 393: train loss: 0.0000096051, validation loss: 0.0000247010
# Epoch 394: train loss: 0.0000079234, validation loss: 0.0000037416
# Epoch 395: train loss: 0.0000099803, validation loss: 0.0000150888
# Epoch 396: train loss: 0.0000091073, validation loss: 0.0000039467
# Epoch 397: train loss: 0.0000083964, validation loss: 0.0000227072
# Epoch 398: train loss: 0.0000094760, validation loss: 0.0000154549
# Epoch 399: train loss: 0.0000084673, validation loss: 0.0000144134
# Epoch 400: train loss: 0.0000090687, validation loss: 0.0000065336
# Epoch 401: train loss: 0.0000095569, validation loss: 0.0000100439
# Epoch 402: train loss: 0.0000079499, validation loss: 0.0000061155
# Epoch 403: train loss: 0.0000086019, validation loss: 0.0000226568
# Epoch 404: train loss: 0.0000116257, validation loss: 0.0000032535
# Epoch 405: train loss: 0.0000088366, validation loss: 0.0000043777
# Epoch 406: train loss: 0.0000085475, validation loss: 0.0000067186
# Epoch 407: train loss: 0.0000089587, validation loss: 0.0000114197
# Epoch 408: train loss: 0.0000079682, validation loss: 0.0000047189
# Epoch 409: train loss: 0.0000097120, validation loss: 0.0000095416
# Epoch 410: train loss: 0.0000071154, validation loss: 0.0000065464
# Epoch 411: train loss: 0.0000095288, validation loss: 0.0000332832
# Epoch 412: train loss: 0.0000094364, validation loss: 0.0000043916
# Epoch 413: train loss: 0.0000074026, validation loss: 0.0000111242
# Epoch 414: train loss: 0.0000080575, validation loss: 0.0000077420
# Epoch 415: train loss: 0.0000085974, validation loss: 0.0000139145
# Epoch 416: train loss: 0.0000076363, validation loss: 0.0000048875
# Epoch 417: train loss: 0.0000096363, validation loss: 0.0000089919
# Epoch 418: train loss: 0.0000075937, validation loss: 0.0000035126
# Epoch 419: train loss: 0.0000082808, validation loss: 0.0000031339
# Epoch 420: train loss: 0.0000079125, validation loss: 0.0000040457
# Epoch 421: train loss: 0.0000075772, validation loss: 0.0000098157
# Epoch 422: train loss: 0.0000088869, validation loss: 0.0000116980
# Epoch 423: train loss: 0.0000081080, validation loss: 0.0000125776
# Epoch 424: train loss: 0.0000073802, validation loss: 0.0000074384
# Epoch 425: train loss: 0.0000077824, validation loss: 0.0000066287
# Epoch 426: train loss: 0.0000084025, validation loss: 0.0000052880
# Epoch 427: train loss: 0.0000071995, validation loss: 0.0000090397
# Epoch 428: train loss: 0.0000089128, validation loss: 0.0000077345
# Epoch 429: train loss: 0.0000079736, validation loss: 0.0000167459
# Epoch 430: train loss: 0.0000076155, validation loss: 0.0000087435
# Epoch 431: train loss: 0.0000081486, validation loss: 0.0000110355
# Epoch 432: train loss: 0.0000069948, validation loss: 0.0000152343
# Epoch 433: train loss: 0.0000117999, validation loss: 0.0000033245
# Epoch 434: train loss: 0.0000062158, validation loss: 0.0000028694
# Epoch 435: train loss: 0.0000077472, validation loss: 0.0000085166
# Epoch 436: train loss: 0.0000077767, validation loss: 0.0000056499
# Epoch 437: train loss: 0.0000077622, validation loss: 0.0000117976
# Epoch 438: train loss: 0.0000085085, validation loss: 0.0000047863
# Epoch 439: train loss: 0.0000071374, validation loss: 0.0000028214
# Epoch 440: train loss: 0.0000082099, validation loss: 0.0000051255
# Epoch 441: train loss: 0.0000071935, validation loss: 0.0000069686
# Epoch 442: train loss: 0.0000089513, validation loss: 0.0000065048
# Epoch 443: train loss: 0.0000059550, validation loss: 0.0000328503
# Epoch 444: train loss: 0.0000088721, validation loss: 0.0000027882
# Epoch 445: train loss: 0.0000098131, validation loss: 0.0000025352
# Epoch 446: train loss: 0.0000058938, validation loss: 0.0000076904
# Epoch 447: train loss: 0.0000068788, validation loss: 0.0000040957
# Epoch 448: train loss: 0.0000080247, validation loss: 0.0000055537
# Epoch 449: train loss: 0.0000076547, validation loss: 0.0000131822
# Epoch 450: train loss: 0.0000067896, validation loss: 0.0000030337
# Epoch 451: train loss: 0.0000070788, validation loss: 0.0000085816
# Epoch 452: train loss: 0.0000087800, validation loss: 0.0000045862
# Epoch 453: train loss: 0.0000059707, validation loss: 0.0000062044
# Epoch 454: train loss: 0.0000081559, validation loss: 0.0000055090
# Epoch 455: train loss: 0.0000077182, validation loss: 0.0000113963
# Epoch 456: train loss: 0.0000063344, validation loss: 0.0000215026
# Epoch 457: train loss: 0.0000076856, validation loss: 0.0000062082
# Epoch 458: train loss: 0.0000073707, validation loss: 0.0000033320
# Epoch 459: train loss: 0.0000070214, validation loss: 0.0000029527
# Epoch 460: train loss: 0.0000065366, validation loss: 0.0000043405
# Epoch 461: train loss: 0.0000070210, validation loss: 0.0000053784
# Epoch 462: train loss: 0.0000079612, validation loss: 0.0000044033
# Epoch 463: train loss: 0.0000063858, validation loss: 0.0000040641
# Epoch 464: train loss: 0.0000072418, validation loss: 0.0000057569
# Epoch 465: train loss: 0.0000086298, validation loss: 0.0000083745
# Epoch 466: train loss: 0.0000064602, validation loss: 0.0000035641
# Epoch 467: train loss: 0.0000069074, validation loss: 0.0000030437
# Epoch 468: train loss: 0.0000060390, validation loss: 0.0000055230
# Epoch 469: train loss: 0.0000088532, validation loss: 0.0000075799
# Epoch 470: train loss: 0.0000054320, validation loss: 0.0000048939
# Epoch 471: train loss: 0.0000071199, validation loss: 0.0000086234
# Epoch 472: train loss: 0.0000074840, validation loss: 0.0000028624
# Epoch 473: train loss: 0.0000068410, validation loss: 0.0000026228
# Epoch 474: train loss: 0.0000063409, validation loss: 0.0000069934
# Epoch 475: train loss: 0.0000075306, validation loss: 0.0000047637
# Epoch 476: train loss: 0.0000063515, validation loss: 0.0000025059
# Epoch 477: train loss: 0.0000067505, validation loss: 0.0000077946
# Epoch 478: train loss: 0.0000061945, validation loss: 0.0000058594
# Epoch 479: train loss: 0.0000075234, validation loss: 0.0000039197
# Epoch 480: train loss: 0.0000077095, validation loss: 0.0000046757
# Epoch 481: train loss: 0.0000061589, validation loss: 0.0000058935
# Epoch 482: train loss: 0.0000068700, validation loss: 0.0000037212
# Epoch 483: train loss: 0.0000063506, validation loss: 0.0000035028
# Epoch 484: train loss: 0.0000075338, validation loss: 0.0000022173
# Epoch 485: train loss: 0.0000067875, validation loss: 0.0000021027
# Epoch 486: train loss: 0.0000074900, validation loss: 0.0000132156
# Epoch 487: train loss: 0.0000056325, validation loss: 0.0000031744
# Epoch 488: train loss: 0.0000062411, validation loss: 0.0000038796
# Epoch 489: train loss: 0.0000062000, validation loss: 0.0000051384
# Epoch 490: train loss: 0.0000064769, validation loss: 0.0000027129
# Epoch 491: train loss: 0.0000070540, validation loss: 0.0000023948
# Epoch 492: train loss: 0.0000054164, validation loss: 0.0000024916
# Epoch 493: train loss: 0.0000067470, validation loss: 0.0000071212
# Epoch 494: train loss: 0.0000061977, validation loss: 0.0000033152
# Epoch 495: train loss: 0.0000076223, validation loss: 0.0000042510
# Epoch 496: train loss: 0.0000057749, validation loss: 0.0000165346
# Epoch 497: train loss: 0.0000059352, validation loss: 0.0000034633
# Epoch 498: train loss: 0.0000064889, validation loss: 0.0000043471
# Epoch 499: train loss: 0.0000058314, validation loss: 0.0000028840
# Epoch 500: train loss: 0.0000065162, validation loss: 0.0000026080
# Epoch 501: train loss: 0.0000061330, validation loss: 0.0000025886
# Epoch 502: train loss: 0.0000064812, validation loss: 0.0000024296
# Epoch 503: train loss: 0.0000068571, validation loss: 0.0000049794
# Epoch 504: train loss: 0.0000059236, validation loss: 0.0000030868
# Epoch 505: train loss: 0.0000073964, validation loss: 0.0000073799
# Epoch 506: train loss: 0.0000050377, validation loss: 0.0000041772
# Epoch 507: train loss: 0.0000069397, validation loss: 0.0000032857
# Epoch 508: train loss: 0.0000048666, validation loss: 0.0000044256
# Epoch 509: train loss: 0.0000065273, validation loss: 0.0000029042
# Epoch 510: train loss: 0.0000055823, validation loss: 0.0000095604
# Epoch 511: train loss: 0.0000069748, validation loss: 0.0000066131
# Epoch 512: train loss: 0.0000066468, validation loss: 0.0000032686
# Epoch 513: train loss: 0.0000059438, validation loss: 0.0000043432
# Epoch 514: train loss: 0.0000059862, validation loss: 0.0000045211
# Epoch 515: train loss: 0.0000058435, validation loss: 0.0000074075
# Epoch 516: train loss: 0.0000080052, validation loss: 0.0000096254
# Epoch 517: train loss: 0.0000055178, validation loss: 0.0000019492
# Epoch 518: train loss: 0.0000048837, validation loss: 0.0000092037
# Epoch 519: train loss: 0.0000075306, validation loss: 0.0000298743
# Epoch 520: train loss: 0.0000053642, validation loss: 0.0000034326
# Epoch 521: train loss: 0.0000057755, validation loss: 0.0000024813
# Epoch 522: train loss: 0.0000057242, validation loss: 0.0000070538
# Epoch 523: train loss: 0.0000052362, validation loss: 0.0000026071
# Epoch 524: train loss: 0.0000067072, validation loss: 0.0000030954
# Epoch 525: train loss: 0.0000057328, validation loss: 0.0000130229
# Epoch 526: train loss: 0.0000064159, validation loss: 0.0000141623
# Epoch 527: train loss: 0.0000053230, validation loss: 0.0000056424
# Epoch 528: train loss: 0.0000055093, validation loss: 0.0000044447
# Epoch 529: train loss: 0.0000058748, validation loss: 0.0000061202
# Epoch 530: train loss: 0.0000053639, validation loss: 0.0000058943
# Epoch 531: train loss: 0.0000059183, validation loss: 0.0000092126
# Epoch 532: train loss: 0.0000052932, validation loss: 0.0000066247
# Epoch 533: train loss: 0.0000078359, validation loss: 0.0000064813
# Epoch 534: train loss: 0.0000043331, validation loss: 0.0000058930
# Epoch 535: train loss: 0.0000061918, validation loss: 0.0000035000
# Epoch 536: train loss: 0.0000049913, validation loss: 0.0000044907
# Epoch 537: train loss: 0.0000058797, validation loss: 0.0000025469
# Epoch 538: train loss: 0.0000068076, validation loss: 0.0000042741
# Epoch 539: train loss: 0.0000041099, validation loss: 0.0000076301
# Epoch 540: train loss: 0.0000064921, validation loss: 0.0000021441
# Epoch 541: train loss: 0.0000052156, validation loss: 0.0000119176
# Epoch 542: train loss: 0.0000049436, validation loss: 0.0000044704
# Epoch 543: train loss: 0.0000071529, validation loss: 0.0000032319
# Epoch 544: train loss: 0.0000040036, validation loss: 0.0000069320
# Epoch 545: train loss: 0.0000061640, validation loss: 0.0000034640
# Epoch 546: train loss: 0.0000048796, validation loss: 0.0000025696
# Epoch 547: train loss: 0.0000062416, validation loss: 0.0000020826
# Epoch 548: train loss: 0.0000046483, validation loss: 0.0000080940
# Epoch 549: train loss: 0.0000055331, validation loss: 0.0000019458
# Epoch 550: train loss: 0.0000068524, validation loss: 0.0000028327
# Epoch 551: train loss: 0.0000039344, validation loss: 0.0000052574
# Epoch 552: train loss: 0.0000065755, validation loss: 0.0000024070
# Epoch 553: train loss: 0.0000044681, validation loss: 0.0000042906
# Epoch 554: train loss: 0.0000055570, validation loss: 0.0000025156
# Epoch 555: train loss: 0.0000058483, validation loss: 0.0000108565
# Epoch 556: train loss: 0.0000050773, validation loss: 0.0000035416
# Epoch 557: train loss: 0.0000051335, validation loss: 0.0000038651
# Epoch 558: train loss: 0.0000052936, validation loss: 0.0000025140
# Epoch 559: train loss: 0.0000056727, validation loss: 0.0000021247
# Epoch 560: train loss: 0.0000046916, validation loss: 0.0000043900
# Epoch 561: train loss: 0.0000058305, validation loss: 0.0000046300
# Epoch 562: train loss: 0.0000054234, validation loss: 0.0000038943
# Epoch 563: train loss: 0.0000046375, validation loss: 0.0000048450
# Epoch 564: train loss: 0.0000056478, validation loss: 0.0000035273
# Epoch 565: train loss: 0.0000054332, validation loss: 0.0000016065
# Epoch 566: train loss: 0.0000053045, validation loss: 0.0000041163
# Epoch 567: train loss: 0.0000045477, validation loss: 0.0000027317
# Epoch 568: train loss: 0.0000057306, validation loss: 0.0000029123
# Epoch 569: train loss: 0.0000052821, validation loss: 0.0000042320
# Epoch 570: train loss: 0.0000052734, validation loss: 0.0000046473
# Epoch 571: train loss: 0.0000057915, validation loss: 0.0000021928
# Epoch 572: train loss: 0.0000042269, validation loss: 0.0000048874
# Epoch 573: train loss: 0.0000064732, validation loss: 0.0000030916
# Epoch 574: train loss: 0.0000041841, validation loss: 0.0000029183
# Epoch 575: train loss: 0.0000053973, validation loss: 0.0000036168
# Epoch 576: train loss: 0.0000048145, validation loss: 0.0000048351
# Epoch 577: train loss: 0.0000051940, validation loss: 0.0000049854
# Epoch 578: train loss: 0.0000051189, validation loss: 0.0000141482
# Epoch 579: train loss: 0.0000051777, validation loss: 0.0000030931
# Epoch 580: train loss: 0.0000050596, validation loss: 0.0000046480
# Epoch 581: train loss: 0.0000053211, validation loss: 0.0000052557
# Epoch 582: train loss: 0.0000050363, validation loss: 0.0000146110
# Epoch 583: train loss: 0.0000049084, validation loss: 0.0000119384
# Epoch 584: train loss: 0.0000054092, validation loss: 0.0000016779
# Epoch 585: train loss: 0.0000049325, validation loss: 0.0000035379
# Epoch 586: train loss: 0.0000050788, validation loss: 0.0000040115
# Epoch 587: train loss: 0.0000052942, validation loss: 0.0000016799
# Epoch 588: train loss: 0.0000042159, validation loss: 0.0000040700
# Epoch 589: train loss: 0.0000052449, validation loss: 0.0000028181
# Epoch 590: train loss: 0.0000052220, validation loss: 0.0000041923
# Epoch 591: train loss: 0.0000041695, validation loss: 0.0000036474
# Epoch 592: train loss: 0.0000047834, validation loss: 0.0000076885
# Epoch 593: train loss: 0.0000060477, validation loss: 0.0000026027
# Epoch 594: train loss: 0.0000051470, validation loss: 0.0000029410
# Epoch 595: train loss: 0.0000045599, validation loss: 0.0000021858
# Epoch 596: train loss: 0.0000047166, validation loss: 0.0000024326
# Epoch 597: train loss: 0.0000051261, validation loss: 0.0000055812
# Epoch 598: train loss: 0.0000048115, validation loss: 0.0000018778
# Epoch 599: train loss: 0.0000041746, validation loss: 0.0000041182
# Epoch 600: train loss: 0.0000048947, validation loss: 0.0000075468
# Finished Training

# %% [markdown]
# ***Learning Curves***

# %%
train_loss = [l[0] for l in model_koop_dnn.train_loss_hist]
train_pred_loss = [l[1] for l in model_koop_dnn.train_loss_hist]
train_lifted_loss = [l[2] for l in model_koop_dnn.train_loss_hist]
val_loss = [l[0] for l in model_koop_dnn.val_loss_hist]
val_pred_loss = [l[1] for l in model_koop_dnn.val_loss_hist]
val_lifted_loss = [l[2] for l in model_koop_dnn.val_loss_hist]
epochs = np.arange(0, net_params['epochs'])

plt.figure(figsize=(15,8))
plt.plot(epochs, train_loss, color='tab:orange', label='Training loss')
plt.plot(epochs, train_pred_loss, '--', color='tab:orange', label='Training prediction loss')
plt.plot(epochs, train_lifted_loss, ':', color='tab:orange', label='Training lifted loss')
plt.plot(epochs, val_loss, color='tab:blue', label='Validation loss')
plt.plot(epochs, val_pred_loss, '--', color='tab:blue', label='Validation prediction loss')
plt.plot(epochs, val_lifted_loss, ':', color='tab:blue', label='Validation lifted loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale('log')
plt.savefig("convergence plot for arch1")
plt.show()

# %%
map_net_params = {}
map_net_params["input_dim"] = int(num_joints) #number of joint angles
map_net_params["output_dim"] = X_end.shape[2] #x and y position of the end effector
map_net_params["hidden_width"] = 20 #20
map_net_params["hidden_depth"] = 4  #2
map_net_params["batch_size"] = 128  #100
map_net_params["epochs"] = 500   # 500
map_net_params["activation_type"] = 'tanh'
map_net_params["lr"] = 1e-3     #1e-3
map_net_params["optimizer"] = 'adam'
map_net_params['l2_reg'] = 0.0
map_net_params['l1_reg'] = 0.0

# %%
#dataset
# split training and vaidation datasets
xs_map_train, ys_map_train = X_fw[:num_train,:,:int(num_joints)],X_end_fw[:num_train,:,:num_inputs]
xs_map_val, ys_map_val = X_fw[num_train:,:,:int(num_joints)],X_end_fw[num_train:,:,:num_inputs]

# %%
ys_map_train.shape, ys_map_val.shape,xs_map_train.shape, xs_map_val.shape
# Out:
# ((150, 1000, 2), (50, 1000, 2), (150, 1000, 3), (50, 1000, 3))

# %%
#Initalize network
#Initalize network

if mass_var == True:
    file_fwd = 'saved_models/'+ robot_type +'/map_net_con_mass_var.pth' 
else:
    file_fwd = 'saved_models/'+ robot_type +'/map_net_con.pth'

if train == True:
    map_net = map_Net(map_net_params)
    map_net.set_dataset_map(xs_map_train,ys_map_train,xs_map_val,ys_map_val)
    map_net.data_pipeline()
    torch.save(map_net,file_fwd)
else:
    map_net = torch.load(file_fwd)
# Out:
# Epoch   1: train loss: 0.0324561352, validation loss: 0.0053737343
# Epoch   2: train loss: 0.0030636117, validation loss: 0.0019527380
# Epoch   3: train loss: 0.0015131117, validation loss: 0.0012794964
# Epoch   4: train loss: 0.0010515484, validation loss: 0.0008669229
# Epoch   5: train loss: 0.0007783061, validation loss: 0.0007211756
# Epoch   6: train loss: 0.0006129746, validation loss: 0.0005140934
# Epoch   7: train loss: 0.0005066283, validation loss: 0.0005982872
# Epoch   8: train loss: 0.0004322242, validation loss: 0.0004096537
# Epoch   9: train loss: 0.0003765963, validation loss: 0.0003339798
# Epoch  10: train loss: 0.0003351141, validation loss: 0.0003005832
# Epoch  11: train loss: 0.0002884166, validation loss: 0.0002945558
# Epoch  12: train loss: 0.0002599271, validation loss: 0.0002628938
# Epoch  13: train loss: 0.0002337566, validation loss: 0.0001995529
# Epoch  14: train loss: 0.0002125330, validation loss: 0.0002189226
# Epoch  15: train loss: 0.0001949749, validation loss: 0.0001552541
# Epoch  16: train loss: 0.0001740563, validation loss: 0.0001563089
# Epoch  17: train loss: 0.0001564708, validation loss: 0.0001465945
# Epoch  18: train loss: 0.0001502547, validation loss: 0.0001442348
# Epoch  19: train loss: 0.0001340629, validation loss: 0.0001271495
# Epoch  20: train loss: 0.0001284000, validation loss: 0.0001579412
# Epoch  21: train loss: 0.0001194270, validation loss: 0.0001066134
# Epoch  22: train loss: 0.0001101271, validation loss: 0.0000806019
# Epoch  23: train loss: 0.0001028908, validation loss: 0.0000803353
# Epoch  24: train loss: 0.0000973020, validation loss: 0.0001040633
# Epoch  25: train loss: 0.0000923933, validation loss: 0.0000943045
# Epoch  26: train loss: 0.0000897461, validation loss: 0.0000760364
# Epoch  27: train loss: 0.0000823405, validation loss: 0.0000911015
# Epoch  28: train loss: 0.0000781318, validation loss: 0.0000726892
# Epoch  29: train loss: 0.0000758557, validation loss: 0.0000741043
# Epoch  30: train loss: 0.0000717940, validation loss: 0.0000516666
# Epoch  31: train loss: 0.0000696403, validation loss: 0.0000635676
# Epoch  32: train loss: 0.0000658644, validation loss: 0.0000424286
# Epoch  33: train loss: 0.0000644863, validation loss: 0.0000541471
# Epoch  34: train loss: 0.0000641713, validation loss: 0.0000612863
# Epoch  35: train loss: 0.0000581637, validation loss: 0.0000528380
# Epoch  36: train loss: 0.0000588213, validation loss: 0.0000461346
# Epoch  37: train loss: 0.0000561077, validation loss: 0.0000602746
# Epoch  38: train loss: 0.0000516110, validation loss: 0.0000553628
# Epoch  39: train loss: 0.0000518272, validation loss: 0.0000361230
# Epoch  40: train loss: 0.0000522078, validation loss: 0.0000688373
# Epoch  41: train loss: 0.0000501601, validation loss: 0.0000502765
# Epoch  42: train loss: 0.0000477309, validation loss: 0.0000389427
# Epoch  43: train loss: 0.0000486872, validation loss: 0.0000655408
# Epoch  44: train loss: 0.0000463834, validation loss: 0.0000481472
# Epoch  45: train loss: 0.0000427378, validation loss: 0.0000566059
# Epoch  46: train loss: 0.0000449270, validation loss: 0.0000583514
# Epoch  47: train loss: 0.0000410522, validation loss: 0.0000638928
# Epoch  48: train loss: 0.0000431378, validation loss: 0.0000518584
# Epoch  49: train loss: 0.0000446293, validation loss: 0.0000272847
# Epoch  50: train loss: 0.0000391467, validation loss: 0.0000327069
# Epoch  51: train loss: 0.0000409450, validation loss: 0.0000356085
# Epoch  52: train loss: 0.0000387667, validation loss: 0.0000347716
# Epoch  53: train loss: 0.0000366398, validation loss: 0.0000386985
# Epoch  54: train loss: 0.0000363637, validation loss: 0.0000236259
# Epoch  55: train loss: 0.0000347585, validation loss: 0.0000535469
# Epoch  56: train loss: 0.0000371806, validation loss: 0.0000217011
# Epoch  57: train loss: 0.0000351986, validation loss: 0.0000376971
# Epoch  58: train loss: 0.0000336222, validation loss: 0.0000222646
# Epoch  59: train loss: 0.0000356677, validation loss: 0.0000428003
# Epoch  60: train loss: 0.0000343047, validation loss: 0.0000219792
# Epoch  61: train loss: 0.0000324737, validation loss: 0.0000273790
# Epoch  62: train loss: 0.0000330751, validation loss: 0.0000302349
# Epoch  63: train loss: 0.0000319760, validation loss: 0.0000177476
# Epoch  64: train loss: 0.0000321688, validation loss: 0.0000179319
# Epoch  65: train loss: 0.0000314958, validation loss: 0.0000202858
# Epoch  66: train loss: 0.0000293389, validation loss: 0.0000245305
# Epoch  67: train loss: 0.0000323181, validation loss: 0.0000311403
# Epoch  68: train loss: 0.0000292120, validation loss: 0.0000219209
# Epoch  69: train loss: 0.0000288254, validation loss: 0.0000372812
# Epoch  70: train loss: 0.0000302124, validation loss: 0.0000163370
# Epoch  71: train loss: 0.0000303426, validation loss: 0.0000189560
# Epoch  72: train loss: 0.0000285761, validation loss: 0.0000352448
# Epoch  73: train loss: 0.0000298178, validation loss: 0.0000384374
# Epoch  74: train loss: 0.0000260558, validation loss: 0.0000201920
# Epoch  75: train loss: 0.0000270770, validation loss: 0.0000348068
# Epoch  76: train loss: 0.0000271526, validation loss: 0.0000431554
# Epoch  77: train loss: 0.0000265150, validation loss: 0.0000419378
# Epoch  78: train loss: 0.0000262130, validation loss: 0.0000384449
# Epoch  79: train loss: 0.0000263431, validation loss: 0.0000453408
# Epoch  80: train loss: 0.0000251039, validation loss: 0.0000215713
# Epoch  81: train loss: 0.0000265436, validation loss: 0.0000281067
# Epoch  82: train loss: 0.0000264120, validation loss: 0.0000174958
# Epoch  83: train loss: 0.0000233787, validation loss: 0.0000297465
# Epoch  84: train loss: 0.0000239251, validation loss: 0.0000263877
# Epoch  85: train loss: 0.0000260385, validation loss: 0.0000228603
# Epoch  86: train loss: 0.0000244721, validation loss: 0.0000175284
# Epoch  87: train loss: 0.0000240133, validation loss: 0.0000259797
# Epoch  88: train loss: 0.0000230937, validation loss: 0.0000475030
# Epoch  89: train loss: 0.0000226036, validation loss: 0.0000177287
# Epoch  90: train loss: 0.0000239801, validation loss: 0.0000156203
# Epoch  91: train loss: 0.0000223838, validation loss: 0.0000325551
# Epoch  92: train loss: 0.0000226490, validation loss: 0.0000169475
# Epoch  93: train loss: 0.0000220849, validation loss: 0.0000358063
# Epoch  94: train loss: 0.0000218264, validation loss: 0.0000216830
# Epoch  95: train loss: 0.0000228436, validation loss: 0.0000131660
# Epoch  96: train loss: 0.0000225145, validation loss: 0.0000142803
# Epoch  97: train loss: 0.0000216904, validation loss: 0.0000137552
# Epoch  98: train loss: 0.0000216542, validation loss: 0.0000151793
# Epoch  99: train loss: 0.0000199449, validation loss: 0.0000252275
# Epoch 100: train loss: 0.0000222314, validation loss: 0.0000188342
# Epoch 101: train loss: 0.0000232956, validation loss: 0.0000112063
# Epoch 102: train loss: 0.0000185027, validation loss: 0.0000107918
# Epoch 103: train loss: 0.0000194001, validation loss: 0.0000141052
# Epoch 104: train loss: 0.0000200914, validation loss: 0.0000169850
# Epoch 105: train loss: 0.0000215702, validation loss: 0.0000134507
# Epoch 106: train loss: 0.0000208542, validation loss: 0.0000442752
# Epoch 107: train loss: 0.0000185391, validation loss: 0.0000125649
# Epoch 108: train loss: 0.0000201391, validation loss: 0.0000110887
# Epoch 109: train loss: 0.0000184302, validation loss: 0.0000185158
# Epoch 110: train loss: 0.0000194670, validation loss: 0.0000180550
# Epoch 111: train loss: 0.0000191033, validation loss: 0.0000383731
# Epoch 112: train loss: 0.0000209571, validation loss: 0.0000173829
# Epoch 113: train loss: 0.0000178554, validation loss: 0.0000175864
# Epoch 114: train loss: 0.0000190621, validation loss: 0.0000091649
# Epoch 115: train loss: 0.0000187619, validation loss: 0.0000091907
# Epoch 116: train loss: 0.0000188459, validation loss: 0.0000169777
# Epoch 117: train loss: 0.0000199141, validation loss: 0.0000224338
# Epoch 118: train loss: 0.0000179374, validation loss: 0.0000184245
# Epoch 119: train loss: 0.0000181126, validation loss: 0.0000167230
# Epoch 120: train loss: 0.0000172512, validation loss: 0.0000145576
# Epoch 121: train loss: 0.0000189070, validation loss: 0.0000305061
# Epoch 122: train loss: 0.0000174587, validation loss: 0.0000153034
# Epoch 123: train loss: 0.0000160625, validation loss: 0.0000154078
# Epoch 124: train loss: 0.0000172665, validation loss: 0.0000275866
# Epoch 125: train loss: 0.0000183197, validation loss: 0.0000101203
# Epoch 126: train loss: 0.0000165293, validation loss: 0.0000213415
# Epoch 127: train loss: 0.0000171441, validation loss: 0.0000166915
# Epoch 128: train loss: 0.0000169400, validation loss: 0.0000094266
# Epoch 129: train loss: 0.0000170545, validation loss: 0.0000130521
# Epoch 130: train loss: 0.0000170533, validation loss: 0.0000260190
# Epoch 131: train loss: 0.0000168187, validation loss: 0.0000200824
# Epoch 132: train loss: 0.0000152656, validation loss: 0.0000243872
# Epoch 133: train loss: 0.0000164014, validation loss: 0.0000139235
# Epoch 134: train loss: 0.0000160847, validation loss: 0.0000155759
# Epoch 135: train loss: 0.0000169627, validation loss: 0.0000246000
# Epoch 136: train loss: 0.0000165048, validation loss: 0.0000077827
# Epoch 137: train loss: 0.0000156158, validation loss: 0.0000116837
# Epoch 138: train loss: 0.0000160787, validation loss: 0.0000098286
# Epoch 139: train loss: 0.0000162585, validation loss: 0.0000123123
# Epoch 140: train loss: 0.0000171208, validation loss: 0.0000087320
# Epoch 141: train loss: 0.0000144546, validation loss: 0.0000136873
# Epoch 142: train loss: 0.0000155804, validation loss: 0.0000103205
# Epoch 143: train loss: 0.0000146961, validation loss: 0.0000161163
# Epoch 144: train loss: 0.0000160106, validation loss: 0.0000158693
# Epoch 145: train loss: 0.0000155935, validation loss: 0.0000138779
# Epoch 146: train loss: 0.0000151221, validation loss: 0.0000134624
# Epoch 147: train loss: 0.0000160122, validation loss: 0.0000080419
# Epoch 148: train loss: 0.0000145352, validation loss: 0.0000089647
# Epoch 149: train loss: 0.0000146159, validation loss: 0.0000104220
# Epoch 150: train loss: 0.0000145444, validation loss: 0.0000105197
# Epoch 151: train loss: 0.0000154718, validation loss: 0.0000123784
# Epoch 152: train loss: 0.0000145126, validation loss: 0.0000114615
# Epoch 153: train loss: 0.0000163952, validation loss: 0.0000111392
# Epoch 154: train loss: 0.0000139312, validation loss: 0.0000270370
# Epoch 155: train loss: 0.0000145755, validation loss: 0.0000078068
# Epoch 156: train loss: 0.0000145400, validation loss: 0.0000081373
# Epoch 157: train loss: 0.0000140141, validation loss: 0.0000080198
# Epoch 158: train loss: 0.0000145953, validation loss: 0.0000109598
# Epoch 159: train loss: 0.0000148390, validation loss: 0.0000099132
# Epoch 160: train loss: 0.0000154838, validation loss: 0.0000082551
# Epoch 161: train loss: 0.0000137930, validation loss: 0.0000091123
# Epoch 162: train loss: 0.0000143354, validation loss: 0.0000134049
# Epoch 163: train loss: 0.0000140371, validation loss: 0.0000081705
# Epoch 164: train loss: 0.0000137868, validation loss: 0.0000068111
# Epoch 165: train loss: 0.0000145312, validation loss: 0.0000070489
# Epoch 166: train loss: 0.0000152308, validation loss: 0.0000067045
# Epoch 167: train loss: 0.0000125526, validation loss: 0.0000098828
# Epoch 168: train loss: 0.0000145165, validation loss: 0.0000136488
# Epoch 169: train loss: 0.0000143259, validation loss: 0.0000143781
# Epoch 170: train loss: 0.0000137906, validation loss: 0.0000122437
# Epoch 171: train loss: 0.0000134392, validation loss: 0.0000093269
# Epoch 172: train loss: 0.0000138478, validation loss: 0.0000164663
# Epoch 173: train loss: 0.0000137764, validation loss: 0.0000155066
# Epoch 174: train loss: 0.0000144585, validation loss: 0.0000079867
# Epoch 175: train loss: 0.0000132615, validation loss: 0.0000097655
# Epoch 176: train loss: 0.0000133358, validation loss: 0.0000086963
# Epoch 177: train loss: 0.0000128707, validation loss: 0.0000112091
# Epoch 178: train loss: 0.0000138413, validation loss: 0.0000236276
# Epoch 179: train loss: 0.0000120040, validation loss: 0.0000239511
# Epoch 180: train loss: 0.0000133138, validation loss: 0.0000060737
# Epoch 181: train loss: 0.0000133487, validation loss: 0.0000237933
# Epoch 182: train loss: 0.0000134023, validation loss: 0.0000119155
# Epoch 183: train loss: 0.0000140039, validation loss: 0.0000057745
# Epoch 184: train loss: 0.0000117350, validation loss: 0.0000178794
# Epoch 185: train loss: 0.0000133166, validation loss: 0.0000071780
# Epoch 186: train loss: 0.0000130413, validation loss: 0.0000128147
# Epoch 187: train loss: 0.0000126772, validation loss: 0.0000093253
# Epoch 188: train loss: 0.0000121000, validation loss: 0.0000132924
# Epoch 189: train loss: 0.0000135161, validation loss: 0.0000111368
# Epoch 190: train loss: 0.0000118772, validation loss: 0.0000184869
# Epoch 191: train loss: 0.0000131186, validation loss: 0.0000111219
# Epoch 192: train loss: 0.0000124859, validation loss: 0.0000112350
# Epoch 193: train loss: 0.0000123114, validation loss: 0.0000453343
# Epoch 194: train loss: 0.0000135159, validation loss: 0.0000070816
# Epoch 195: train loss: 0.0000118176, validation loss: 0.0000113299
# Epoch 196: train loss: 0.0000137509, validation loss: 0.0000073628
# Epoch 197: train loss: 0.0000110417, validation loss: 0.0000095717
# Epoch 198: train loss: 0.0000125498, validation loss: 0.0000126726
# Epoch 199: train loss: 0.0000122572, validation loss: 0.0000126892
# Epoch 200: train loss: 0.0000123316, validation loss: 0.0000222336
# Epoch 201: train loss: 0.0000119539, validation loss: 0.0000129884
# Epoch 202: train loss: 0.0000114428, validation loss: 0.0000099227
# Epoch 203: train loss: 0.0000128179, validation loss: 0.0000105144
# Epoch 204: train loss: 0.0000121776, validation loss: 0.0000110217
# Epoch 205: train loss: 0.0000118684, validation loss: 0.0000084455
# Epoch 206: train loss: 0.0000115729, validation loss: 0.0000143964
# Epoch 207: train loss: 0.0000119839, validation loss: 0.0000066787
# Epoch 208: train loss: 0.0000129474, validation loss: 0.0000251605
# Epoch 209: train loss: 0.0000127923, validation loss: 0.0000090165
# Epoch 210: train loss: 0.0000109161, validation loss: 0.0000065487
# Epoch 211: train loss: 0.0000126226, validation loss: 0.0000100112
# Epoch 212: train loss: 0.0000120320, validation loss: 0.0000166241
# Epoch 213: train loss: 0.0000120377, validation loss: 0.0000108559
# Epoch 214: train loss: 0.0000112214, validation loss: 0.0000238568
# Epoch 215: train loss: 0.0000119767, validation loss: 0.0000090546
# Epoch 216: train loss: 0.0000112266, validation loss: 0.0000086721
# Epoch 217: train loss: 0.0000121204, validation loss: 0.0000158356
# Epoch 218: train loss: 0.0000111535, validation loss: 0.0000071110
# Epoch 219: train loss: 0.0000121959, validation loss: 0.0000075949
# Epoch 220: train loss: 0.0000120041, validation loss: 0.0000242232
# Epoch 221: train loss: 0.0000114670, validation loss: 0.0000171452
# Epoch 222: train loss: 0.0000115180, validation loss: 0.0000124966
# Epoch 223: train loss: 0.0000110613, validation loss: 0.0000634806
# Epoch 224: train loss: 0.0000117561, validation loss: 0.0000076992
# Epoch 225: train loss: 0.0000114065, validation loss: 0.0000063010
# Epoch 226: train loss: 0.0000108443, validation loss: 0.0000216910
# Epoch 227: train loss: 0.0000115848, validation loss: 0.0000078935
# Epoch 228: train loss: 0.0000120265, validation loss: 0.0000073604
# Epoch 229: train loss: 0.0000106544, validation loss: 0.0000075343
# Epoch 230: train loss: 0.0000110468, validation loss: 0.0000070743
# Epoch 231: train loss: 0.0000114349, validation loss: 0.0000142521
# Epoch 232: train loss: 0.0000111389, validation loss: 0.0000159319
# Epoch 233: train loss: 0.0000113098, validation loss: 0.0000083929
# Epoch 234: train loss: 0.0000116723, validation loss: 0.0000172037
# Epoch 235: train loss: 0.0000110930, validation loss: 0.0000083669
# Epoch 236: train loss: 0.0000106703, validation loss: 0.0000066478
# Epoch 237: train loss: 0.0000120540, validation loss: 0.0000052234
# Epoch 238: train loss: 0.0000098155, validation loss: 0.0000110427
# Epoch 239: train loss: 0.0000117041, validation loss: 0.0000075011
# Epoch 240: train loss: 0.0000103994, validation loss: 0.0000256904
# Epoch 241: train loss: 0.0000107241, validation loss: 0.0000070133
# Epoch 242: train loss: 0.0000115023, validation loss: 0.0000068138
# Epoch 243: train loss: 0.0000103633, validation loss: 0.0000085094
# Epoch 244: train loss: 0.0000104803, validation loss: 0.0000496622
# Epoch 245: train loss: 0.0000111684, validation loss: 0.0000049854
# Epoch 246: train loss: 0.0000106398, validation loss: 0.0000206912
# Epoch 247: train loss: 0.0000114389, validation loss: 0.0000127587
# Epoch 248: train loss: 0.0000094489, validation loss: 0.0000100663
# Epoch 249: train loss: 0.0000109556, validation loss: 0.0000096447
# Epoch 250: train loss: 0.0000102019, validation loss: 0.0000041891
# Epoch 251: train loss: 0.0000112941, validation loss: 0.0000416913
# Epoch 252: train loss: 0.0000105399, validation loss: 0.0000116249
# Epoch 253: train loss: 0.0000100566, validation loss: 0.0000150842
# Epoch 254: train loss: 0.0000107991, validation loss: 0.0000104884
# Epoch 255: train loss: 0.0000107509, validation loss: 0.0000066363
# Epoch 256: train loss: 0.0000104676, validation loss: 0.0000068636
# Epoch 257: train loss: 0.0000111234, validation loss: 0.0000073531
# Epoch 258: train loss: 0.0000102485, validation loss: 0.0000077613
# Epoch 259: train loss: 0.0000107773, validation loss: 0.0000068035
# Epoch 260: train loss: 0.0000107260, validation loss: 0.0000061105
# Epoch 261: train loss: 0.0000118119, validation loss: 0.0000050427
# Epoch 262: train loss: 0.0000097924, validation loss: 0.0000122015
# Epoch 263: train loss: 0.0000097114, validation loss: 0.0000079872
# Epoch 264: train loss: 0.0000101753, validation loss: 0.0000084256
# Epoch 265: train loss: 0.0000103386, validation loss: 0.0000181543
# Epoch 266: train loss: 0.0000104206, validation loss: 0.0000103088
# Epoch 267: train loss: 0.0000116809, validation loss: 0.0000349758
# Epoch 268: train loss: 0.0000091917, validation loss: 0.0000102051
# Epoch 269: train loss: 0.0000108451, validation loss: 0.0000084734
# Epoch 270: train loss: 0.0000106555, validation loss: 0.0000061253
# Epoch 271: train loss: 0.0000099462, validation loss: 0.0000054063
# Epoch 272: train loss: 0.0000101992, validation loss: 0.0000129104
# Epoch 273: train loss: 0.0000105807, validation loss: 0.0000063762
# Epoch 274: train loss: 0.0000096877, validation loss: 0.0000148739
# Epoch 275: train loss: 0.0000102202, validation loss: 0.0000065475
# Epoch 276: train loss: 0.0000102684, validation loss: 0.0000097976
# Epoch 277: train loss: 0.0000097094, validation loss: 0.0000084725
# Epoch 278: train loss: 0.0000102794, validation loss: 0.0000063901
# Epoch 279: train loss: 0.0000101462, validation loss: 0.0000058533
# Epoch 280: train loss: 0.0000098034, validation loss: 0.0000069358
# Epoch 281: train loss: 0.0000102260, validation loss: 0.0000054771
# Epoch 282: train loss: 0.0000094363, validation loss: 0.0000088402
# Epoch 283: train loss: 0.0000114090, validation loss: 0.0000061592
# Epoch 284: train loss: 0.0000092771, validation loss: 0.0000109296
# Epoch 285: train loss: 0.0000095470, validation loss: 0.0000083535
# Epoch 286: train loss: 0.0000097251, validation loss: 0.0000187847
# Epoch 287: train loss: 0.0000098087, validation loss: 0.0000050154
# Epoch 288: train loss: 0.0000099151, validation loss: 0.0000065467
# Epoch 289: train loss: 0.0000096533, validation loss: 0.0000073289
# Epoch 290: train loss: 0.0000097280, validation loss: 0.0000167631
# Epoch 291: train loss: 0.0000091838, validation loss: 0.0000058064
# Epoch 292: train loss: 0.0000102169, validation loss: 0.0000100792
# Epoch 293: train loss: 0.0000096600, validation loss: 0.0000157260
# Epoch 294: train loss: 0.0000090859, validation loss: 0.0000069322
# Epoch 295: train loss: 0.0000099831, validation loss: 0.0000134450
# Epoch 296: train loss: 0.0000098974, validation loss: 0.0000093350
# Epoch 297: train loss: 0.0000095028, validation loss: 0.0000058712
# Epoch 298: train loss: 0.0000093677, validation loss: 0.0000110711
# Epoch 299: train loss: 0.0000094456, validation loss: 0.0000113005
# Epoch 300: train loss: 0.0000094368, validation loss: 0.0000057055
# Epoch 301: train loss: 0.0000094832, validation loss: 0.0000073060
# Epoch 302: train loss: 0.0000098662, validation loss: 0.0000135756
# Epoch 303: train loss: 0.0000097322, validation loss: 0.0000060347
# Epoch 304: train loss: 0.0000098592, validation loss: 0.0000192364
# Epoch 305: train loss: 0.0000099533, validation loss: 0.0000098349
# Epoch 306: train loss: 0.0000089341, validation loss: 0.0000095075
# Epoch 307: train loss: 0.0000094720, validation loss: 0.0000056997
# Epoch 308: train loss: 0.0000093318, validation loss: 0.0000192712
# Epoch 309: train loss: 0.0000095341, validation loss: 0.0000065157
# Epoch 310: train loss: 0.0000096762, validation loss: 0.0000063606
# Epoch 311: train loss: 0.0000089350, validation loss: 0.0000087583
# Epoch 312: train loss: 0.0000091685, validation loss: 0.0000070518
# Epoch 313: train loss: 0.0000098879, validation loss: 0.0000177317
# Epoch 314: train loss: 0.0000089578, validation loss: 0.0000077155
# Epoch 315: train loss: 0.0000108746, validation loss: 0.0000109475
# Epoch 316: train loss: 0.0000082865, validation loss: 0.0000082451
# Epoch 317: train loss: 0.0000101407, validation loss: 0.0000113286
# Epoch 318: train loss: 0.0000081271, validation loss: 0.0000084425
# Epoch 319: train loss: 0.0000099219, validation loss: 0.0000290809
# Epoch 320: train loss: 0.0000089122, validation loss: 0.0000051179
# Epoch 321: train loss: 0.0000087139, validation loss: 0.0000131687
# Epoch 322: train loss: 0.0000099793, validation loss: 0.0000127411
# Epoch 323: train loss: 0.0000078765, validation loss: 0.0000133806
# Epoch 324: train loss: 0.0000095194, validation loss: 0.0000057200
# Epoch 325: train loss: 0.0000094283, validation loss: 0.0000070908
# Epoch 326: train loss: 0.0000088323, validation loss: 0.0000068445
# Epoch 327: train loss: 0.0000087135, validation loss: 0.0000053602
# Epoch 328: train loss: 0.0000093403, validation loss: 0.0000096692
# Epoch 329: train loss: 0.0000077909, validation loss: 0.0000123439
# Epoch 330: train loss: 0.0000092512, validation loss: 0.0000067325
# Epoch 331: train loss: 0.0000085126, validation loss: 0.0000097319
# Epoch 332: train loss: 0.0000091690, validation loss: 0.0000062212
# Epoch 333: train loss: 0.0000087017, validation loss: 0.0000138655
# Epoch 334: train loss: 0.0000085767, validation loss: 0.0000051141
# Epoch 335: train loss: 0.0000096867, validation loss: 0.0000059026
# Epoch 336: train loss: 0.0000087220, validation loss: 0.0000055222
# Epoch 337: train loss: 0.0000096437, validation loss: 0.0000079509
# Epoch 338: train loss: 0.0000085053, validation loss: 0.0000084875
# Epoch 339: train loss: 0.0000089040, validation loss: 0.0000101533
# Epoch 340: train loss: 0.0000084712, validation loss: 0.0000043627
# Epoch 341: train loss: 0.0000088590, validation loss: 0.0000091503
# Epoch 342: train loss: 0.0000088976, validation loss: 0.0000038070
# Epoch 343: train loss: 0.0000087747, validation loss: 0.0000032620
# Epoch 344: train loss: 0.0000080976, validation loss: 0.0000076699
# Epoch 345: train loss: 0.0000088275, validation loss: 0.0000035311
# Epoch 346: train loss: 0.0000077328, validation loss: 0.0000066833
# Epoch 347: train loss: 0.0000097288, validation loss: 0.0000060951
# Epoch 348: train loss: 0.0000078145, validation loss: 0.0000039003
# Epoch 349: train loss: 0.0000095234, validation loss: 0.0000081812
# Epoch 350: train loss: 0.0000084745, validation loss: 0.0000133668
# Epoch 351: train loss: 0.0000082092, validation loss: 0.0000055091
# Epoch 352: train loss: 0.0000088473, validation loss: 0.0000035188
# Epoch 353: train loss: 0.0000094606, validation loss: 0.0000091768
# Epoch 354: train loss: 0.0000086606, validation loss: 0.0000052294
# Epoch 355: train loss: 0.0000084579, validation loss: 0.0000047675
# Epoch 356: train loss: 0.0000085646, validation loss: 0.0000051323
# Epoch 357: train loss: 0.0000085647, validation loss: 0.0000303044
# Epoch 358: train loss: 0.0000080821, validation loss: 0.0000054091
# Epoch 359: train loss: 0.0000092106, validation loss: 0.0000072578
# Epoch 360: train loss: 0.0000077935, validation loss: 0.0000102151
# Epoch 361: train loss: 0.0000090397, validation loss: 0.0000056433
# Epoch 362: train loss: 0.0000087187, validation loss: 0.0000218094
# Epoch 363: train loss: 0.0000079639, validation loss: 0.0000058531
# Epoch 364: train loss: 0.0000074806, validation loss: 0.0000084090
# Epoch 365: train loss: 0.0000086939, validation loss: 0.0000211261
# Epoch 366: train loss: 0.0000084358, validation loss: 0.0000041259
# Epoch 367: train loss: 0.0000087541, validation loss: 0.0000114564
# Epoch 368: train loss: 0.0000079689, validation loss: 0.0000158100
# Epoch 369: train loss: 0.0000086410, validation loss: 0.0000076238
# Epoch 370: train loss: 0.0000094510, validation loss: 0.0000271148
# Epoch 371: train loss: 0.0000074380, validation loss: 0.0000068545
# Epoch 372: train loss: 0.0000087260, validation loss: 0.0000101382
# Epoch 373: train loss: 0.0000076927, validation loss: 0.0000067508
# Epoch 374: train loss: 0.0000089845, validation loss: 0.0000041280
# Epoch 375: train loss: 0.0000082818, validation loss: 0.0000071477
# Epoch 376: train loss: 0.0000079144, validation loss: 0.0000086379
# Epoch 377: train loss: 0.0000087323, validation loss: 0.0000045645
# Epoch 378: train loss: 0.0000082973, validation loss: 0.0000039197
# Epoch 379: train loss: 0.0000083382, validation loss: 0.0000084637
# Epoch 380: train loss: 0.0000078515, validation loss: 0.0000170110
# Epoch 381: train loss: 0.0000079900, validation loss: 0.0000040169
# Epoch 382: train loss: 0.0000077159, validation loss: 0.0000165999
# Epoch 383: train loss: 0.0000084316, validation loss: 0.0000113002
# Epoch 384: train loss: 0.0000076760, validation loss: 0.0000080396
# Epoch 385: train loss: 0.0000085718, validation loss: 0.0000091947
# Epoch 386: train loss: 0.0000086112, validation loss: 0.0000056337
# Epoch 387: train loss: 0.0000077096, validation loss: 0.0000078509
# Epoch 388: train loss: 0.0000076949, validation loss: 0.0000105714
# Epoch 389: train loss: 0.0000084308, validation loss: 0.0000040755
# Epoch 390: train loss: 0.0000082626, validation loss: 0.0000224402
# Epoch 391: train loss: 0.0000082060, validation loss: 0.0000102711
# Epoch 392: train loss: 0.0000083431, validation loss: 0.0000127005
# Epoch 393: train loss: 0.0000079741, validation loss: 0.0000036040
# Epoch 394: train loss: 0.0000075173, validation loss: 0.0000075695
# Epoch 395: train loss: 0.0000083218, validation loss: 0.0000053098
# Epoch 396: train loss: 0.0000086264, validation loss: 0.0000066172
# Epoch 397: train loss: 0.0000075695, validation loss: 0.0000046516
# Epoch 398: train loss: 0.0000080082, validation loss: 0.0000051430
# Epoch 399: train loss: 0.0000082713, validation loss: 0.0000041151
# Epoch 400: train loss: 0.0000084340, validation loss: 0.0000119157
# Epoch 401: train loss: 0.0000074165, validation loss: 0.0000068554
# Epoch 402: train loss: 0.0000079800, validation loss: 0.0000047340
# Epoch 403: train loss: 0.0000078799, validation loss: 0.0000087515
# Epoch 404: train loss: 0.0000077102, validation loss: 0.0000027925
# Epoch 405: train loss: 0.0000082728, validation loss: 0.0000042555
# Epoch 406: train loss: 0.0000078604, validation loss: 0.0000081558
# Epoch 407: train loss: 0.0000076303, validation loss: 0.0000077651
# Epoch 408: train loss: 0.0000078138, validation loss: 0.0000063148
# Epoch 409: train loss: 0.0000081775, validation loss: 0.0000047174
# Epoch 410: train loss: 0.0000075431, validation loss: 0.0000059683
# Epoch 411: train loss: 0.0000076821, validation loss: 0.0000059898
# Epoch 412: train loss: 0.0000082673, validation loss: 0.0000092683
# Epoch 413: train loss: 0.0000073382, validation loss: 0.0000083558
# Epoch 414: train loss: 0.0000080970, validation loss: 0.0000063925
# Epoch 415: train loss: 0.0000078339, validation loss: 0.0000093076
# Epoch 416: train loss: 0.0000075979, validation loss: 0.0000122158
# Epoch 417: train loss: 0.0000082005, validation loss: 0.0000074452
# Epoch 418: train loss: 0.0000073246, validation loss: 0.0000028526
# Epoch 419: train loss: 0.0000077683, validation loss: 0.0000044142
# Epoch 420: train loss: 0.0000076684, validation loss: 0.0000032751
# Epoch 421: train loss: 0.0000082325, validation loss: 0.0000070067
# Epoch 422: train loss: 0.0000075660, validation loss: 0.0000082961
# Epoch 423: train loss: 0.0000080799, validation loss: 0.0000022741
# Epoch 424: train loss: 0.0000078888, validation loss: 0.0000067045
# Epoch 425: train loss: 0.0000079590, validation loss: 0.0000104075
# Epoch 426: train loss: 0.0000076683, validation loss: 0.0000042237
# Epoch 427: train loss: 0.0000079199, validation loss: 0.0000096645
# Epoch 428: train loss: 0.0000071533, validation loss: 0.0000040920
# Epoch 429: train loss: 0.0000081309, validation loss: 0.0000113354
# Epoch 430: train loss: 0.0000078107, validation loss: 0.0000086454
# Epoch 431: train loss: 0.0000080641, validation loss: 0.0000058795
# Epoch 432: train loss: 0.0000073852, validation loss: 0.0000063765
# Epoch 433: train loss: 0.0000074189, validation loss: 0.0000109907
# Epoch 434: train loss: 0.0000075640, validation loss: 0.0000067735
# Epoch 435: train loss: 0.0000085142, validation loss: 0.0000184514
# Epoch 436: train loss: 0.0000076627, validation loss: 0.0000049153
# Epoch 437: train loss: 0.0000073678, validation loss: 0.0000068523
# Epoch 438: train loss: 0.0000076498, validation loss: 0.0000053477
# Epoch 439: train loss: 0.0000083794, validation loss: 0.0000040524
# Epoch 440: train loss: 0.0000075301, validation loss: 0.0000044426
# Epoch 441: train loss: 0.0000071250, validation loss: 0.0000066492
# Epoch 442: train loss: 0.0000072787, validation loss: 0.0000126699
# Epoch 443: train loss: 0.0000078072, validation loss: 0.0000063277
# Epoch 444: train loss: 0.0000076673, validation loss: 0.0000074560
# Epoch 445: train loss: 0.0000072506, validation loss: 0.0000037129
# Epoch 446: train loss: 0.0000099657, validation loss: 0.0000030856
# Epoch 447: train loss: 0.0000063493, validation loss: 0.0000270538
# Epoch 448: train loss: 0.0000074828, validation loss: 0.0000034415
# Epoch 449: train loss: 0.0000080111, validation loss: 0.0000116629
# Epoch 450: train loss: 0.0000068061, validation loss: 0.0000037639
# Epoch 451: train loss: 0.0000074486, validation loss: 0.0000078673
# Epoch 452: train loss: 0.0000072516, validation loss: 0.0000099988
# Epoch 453: train loss: 0.0000072689, validation loss: 0.0000040710
# Epoch 454: train loss: 0.0000078879, validation loss: 0.0000050269
# Epoch 455: train loss: 0.0000077222, validation loss: 0.0000036946
# Epoch 456: train loss: 0.0000090099, validation loss: 0.0000067073
# Epoch 457: train loss: 0.0000059665, validation loss: 0.0000038919
# Epoch 458: train loss: 0.0000071679, validation loss: 0.0000034889
# Epoch 459: train loss: 0.0000075468, validation loss: 0.0000117194
# Epoch 460: train loss: 0.0000071172, validation loss: 0.0000047281
# Epoch 461: train loss: 0.0000078112, validation loss: 0.0000120389
# Epoch 462: train loss: 0.0000069250, validation loss: 0.0000052991
# Epoch 463: train loss: 0.0000077817, validation loss: 0.0000122268
# Epoch 464: train loss: 0.0000075827, validation loss: 0.0000051961
# Epoch 465: train loss: 0.0000072717, validation loss: 0.0000354400
# Epoch 466: train loss: 0.0000074716, validation loss: 0.0000062299
# Epoch 467: train loss: 0.0000076779, validation loss: 0.0000120709
# Epoch 468: train loss: 0.0000074985, validation loss: 0.0000103090
# Epoch 469: train loss: 0.0000075099, validation loss: 0.0000032733
# Epoch 470: train loss: 0.0000064883, validation loss: 0.0000111378
# Epoch 471: train loss: 0.0000069883, validation loss: 0.0000072168
# Epoch 472: train loss: 0.0000096633, validation loss: 0.0000054357
# Epoch 473: train loss: 0.0000057337, validation loss: 0.0000070596
# Epoch 474: train loss: 0.0000077483, validation loss: 0.0000050625
# Epoch 475: train loss: 0.0000073359, validation loss: 0.0000034182
# Epoch 476: train loss: 0.0000077252, validation loss: 0.0000057902
# Epoch 477: train loss: 0.0000066112, validation loss: 0.0000099933
# Epoch 478: train loss: 0.0000074735, validation loss: 0.0000111119
# Epoch 479: train loss: 0.0000075976, validation loss: 0.0000059822
# Epoch 480: train loss: 0.0000070328, validation loss: 0.0000087825
# Epoch 481: train loss: 0.0000069844, validation loss: 0.0000080307
# Epoch 482: train loss: 0.0000071638, validation loss: 0.0000139674
# Epoch 483: train loss: 0.0000072778, validation loss: 0.0000037752
# Epoch 484: train loss: 0.0000072421, validation loss: 0.0000076489
# Epoch 485: train loss: 0.0000071285, validation loss: 0.0000069672
# Epoch 486: train loss: 0.0000071242, validation loss: 0.0000134554
# Epoch 487: train loss: 0.0000068213, validation loss: 0.0000040346
# Epoch 488: train loss: 0.0000075043, validation loss: 0.0000042728
# Epoch 489: train loss: 0.0000067966, validation loss: 0.0000078730
# Epoch 490: train loss: 0.0000075239, validation loss: 0.0000070390
# Epoch 491: train loss: 0.0000072306, validation loss: 0.0000071056
# Epoch 492: train loss: 0.0000071233, validation loss: 0.0000024047
# Epoch 493: train loss: 0.0000070748, validation loss: 0.0000049116
# Epoch 494: train loss: 0.0000069382, validation loss: 0.0000040801
# Epoch 495: train loss: 0.0000075512, validation loss: 0.0000057589
# Epoch 496: train loss: 0.0000070689, validation loss: 0.0000029126
# Epoch 497: train loss: 0.0000065356, validation loss: 0.0000136525
# Epoch 498: train loss: 0.0000071346, validation loss: 0.0000121401
# Epoch 499: train loss: 0.0000072526, validation loss: 0.0000028251
# Epoch 500: train loss: 0.0000076694, validation loss: 0.0000046487
# Finished training

# %%
epochs = np.arange(0, map_net_params['epochs'])
plt.figure(figsize=(15,8))
plt.plot(epochs, map_net.train_loss_hist, color='tab:orange', label='Training loss')
plt.plot(epochs, map_net.val_loss_hist, color='tab:blue', label='Validation loss')

plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale('log')
plt.savefig("convergence plot of map net for arch1[3,20,20,2]")
plt.show()

# %%
# # import scipy.io
# path_model = 'saved_models/'+ robot_type +'/matlab_files/' 

# #save net parameters
# scipy.io.savemat(path_model + "map_in_weights.mat", {"map_in_weights": map_net.map_net_in.weight.detach().numpy()})
# scipy.io.savemat(path_model + "map_in_bias.mat", {"map_in_bias": map_net.map_net_in.bias.detach().numpy()})

# scipy.io.savemat(path_model +"map_hidden_weights_1.mat",
#                  {"map_hidden_weights_1": map_net.map_net_hid[0].weight.detach().numpy()})
# scipy.io.savemat(path_model +"map_hidden_bias_1.mat",
#                  {"map_hidden_bias_1": map_net.map_net_hid[0].bias.detach().numpy()})

# scipy.io.savemat(path_model +"map_hidden_weights_2.mat",
#                  {"map_hidden_weights_2": map_net.map_net_hid[1].weight.detach().numpy()})
# scipy.io.savemat(path_model + "map_hidden_bias_2.mat",
#                  {"map_hidden_bias_2": map_net.map_net_hid[1].bias.detach().numpy()})

# scipy.io.savemat(path_model + "map_hidden_weights_3.mat",
#                  {"map_hidden_weights_3": map_net.map_net_hid[2].weight.detach().numpy()})
# scipy.io.savemat(path_model +"map_hidden_bias_3.mat",
#                  {"map_hidden_bias_3": map_net.map_net_hid[2].bias.detach().numpy()})

# scipy.io.savemat(path_model + "map_out_weights.mat", {"map_out_weights": map_net.map_net_out.weight.detach().numpy()})
# scipy.io.savemat(path_model + "map_out_bias.mat", {"map_out_bias": map_net.map_net_out.bias.detach().numpy()})

# %%
map_net.map_net_hid
# Out:
# ModuleList(
#   (0-2): 3 x Linear(in_features=20, out_features=20, bias=True)
# )

# %% [markdown]
# ## Test Data Parameters

# %%
first_obs_const = int(net_params['first_obs_const']) #only one state
override_C = net_params['override_C']
if override_C:
    n_obs = int(net_params['encoder_output_dim']) + num_states + first_obs_const 
else:
    n_obs = int(net_params['encoder_output_dim']) + first_obs_const

# %% [markdown]
# ***Koopman Bilinear Model***

# %%
A = np.array(model_koop_dnn.A)
#B = np.array(model_koop_dnn.B).reshape(-1,num_inputs*n_obs)
B = np.array(model_koop_dnn.B)
#B_tensor = np.empty((num_inputs,n_obs, n_obs))
#for ii, b in enumerate(B):
    #B_tensor[ii] = b
C = np.array(model_koop_dnn.C)

print(A.shape, B.shape, C.shape)
# Out:
# (30, 30) (30, 90) (6, 30)

# %% [markdown]
# ## Controlability

# %%
Ac = (A-np.eye(n_obs))/dt
Bc = B/dt
Cc = C
Cr = C[0:3,:]

Cr_v = C[num_joints:2*num_joints,:]

# %%
A.shape, B.shape
# Out:
# ((30, 30), (30, 90))

# %%
#check controllability
Con_lin = ct.ctrb(Ac, Bc)
rank_lin = np.linalg.matrix_rank(Con_lin)

print(rank_lin)
# Out:
# 29

# %%
out_con_mat, out_con_rank = Output_Con(Ac,Bc,Cc)


print(out_con_mat.shape)
print(out_con_rank)
# Out:
# (6, 2790)
# 6

# %%
# continiouts
print('mean full',np.linalg.pinv(Bc).mean())
print('rank full',np.linalg.matrix_rank(Bc))

print('mean full',np.linalg.pinv(Ac).mean())
print('rank full',np.linalg.matrix_rank(Ac))
# Out:
# mean full 0.02139581
# rank full 29
# mean full -15.68472349636724
# rank full 29

# %%
# continiouts
print('mean full',np.linalg.pinv(np.matmul(C,Bc)).mean(),np.linalg.pinv(np.matmul(C,Ac)).mean())
print('rank full',np.linalg.matrix_rank(np.matmul(C,Bc)), np.linalg.matrix_rank(np.matmul(C,Ac)))

print('mean reduced',np.linalg.pinv(np.matmul(Cr,Bc)).mean(),np.linalg.pinv(np.matmul(Cr,Ac)).mean())
print('rank reduced',np.linalg.matrix_rank(np.matmul(Cr,Bc)),np.linalg.matrix_rank(np.matmul(Cr,Ac)))
# Out:
# mean full -0.0009325663 0.11402026245026255
# rank full 6 6
# mean reduced -0.0014731231 0.03624802343490912
# rank reduced 3 3

# %%
# discreate
print('mean full',np.linalg.pinv(np.matmul(C,B)).mean(),np.linalg.pinv(np.matmul(C,A)).mean())
print('rank full',np.linalg.matrix_rank(np.matmul(C,B)), np.linalg.matrix_rank(np.matmul(C,A)))

print('mean reduced',np.linalg.pinv(np.matmul(Cr,B)).mean(),np.linalg.pinv(np.matmul(Cr,A)).mean())
print('rank reduced',np.linalg.matrix_rank(np.matmul(Cr,B)),np.linalg.matrix_rank(np.matmul(Cr,A)))
# Out:
# mean full -0.18651439 0.033265457
# rank full 6 6
# mean reduced -0.29461807 0.03348737
# rank reduced 3 3

# %%
print('mean full',np.linalg.pinv(np.matmul(C,B)).mean(),np.linalg.pinv(np.matmul(C,A)).mean())
print('rank full',np.linalg.matrix_rank(np.matmul(C,B)), np.linalg.matrix_rank(np.matmul(C,A)))

print('mean reduced',np.linalg.pinv(np.matmul(Cr_v,B)).mean(),np.linalg.pinv(np.matmul(Cr_v,A)).mean())
print('rank reduced',np.linalg.matrix_rank(np.matmul(Cr_v,B)),np.linalg.matrix_rank(np.matmul(Cr_v,A)))
# Out:
# mean full -0.18651439 0.033265457
# rank full 6 6
# mean reduced 1.5622486 0.033350583
# rank reduced 3 3

# %%
# # #SAVE MATRIX PARAMETERS AS MATLAB FILE
# # import scipy.io

# dyn_matrices = {"A": A, "B": B, "C": C}
# scipy.io.savemat(path_model + "dyn_mat.mat", dyn_matrices)
# #save encoder parameters

# scipy.io.savemat(path_model + "in_weights.mat", {"encode_in_weights": model_koop_dnn.net.encoder_fc_in.weight.detach().numpy()})
# scipy.io.savemat(path_model + "in_bias.mat", {"encode_in_bias": model_koop_dnn.net.encoder_fc_in.bias.detach().numpy()})

# scipy.io.savemat(path_model + "hidden_weights_1.mat",
#                  {"encode_hidden_weights_1": model_koop_dnn.net.encoder_fc_hid[0].weight.detach().numpy()})
# scipy.io.savemat(path_model + "hidden_bias_1.mat",
#                  {"encode_hidden_bias_1": model_koop_dnn.net.encoder_fc_hid[0].bias.detach().numpy()})

# scipy.io.savemat(path_model + "hidden_weights_2.mat",
#                  {"encode_hidden_weights_2": model_koop_dnn.net.encoder_fc_hid[1].weight.detach().numpy()})
# scipy.io.savemat(path_model + "hidden_bias_2.mat",
#                  {"encode_hidden_bias_2": model_koop_dnn.net.encoder_fc_hid[1].bias.detach().numpy()})

# scipy.io.savemat(path_model + "out_weights.mat", {"encode_out_weights": model_koop_dnn.net.encoder_fc_out.weight.detach().numpy()})
# scipy.io.savemat(path_model + "out_bias.mat", {"encode_out_bias": model_koop_dnn.net.encoder_fc_out.bias.detach().numpy()})

# if standardize:
#     scipy.io.savemat(path_model + "std.mat", {"standardize": standardize, 'mean': standardizer_u_kdnn.mean_, 'scale':standardizer_u_kdnn.scale_})
    
# else:
#     scipy.io.savemat(path_model + "std.mat", {"standardize": standardize})

# %% [markdown]
# ## Save Data

# %%
# #SAVE MATRIX PARAMETERS AS MATLAB FILE
# import scipy.io

path_model = 'saved_models/'+ robot_type +'/matlab_files/' 

dyn_matrices = {"A": A, "B": B, "C": C}
scipy.io.savemat(path_model + "dyn_mat.mat", dyn_matrices)
#save encoder parameters

encoder_dict = {}

encoder_dict["encoder_in_weights"] =  model_koop_dnn.net.encoder_fc_in.weight.detach().numpy()
encoder_dict["encoder_in_bias"] = model_koop_dnn.net.encoder_fc_in.bias.detach().numpy()
encoder_dict["encoder_hidden_depth"] = int(net_params["encoder_hidden_depth"]-1) 

encoder_dict["encoder_hidden_weights"] = np.empty((net_params["encoder_hidden_width"],net_params["encoder_hidden_width"],net_params["encoder_hidden_depth"]-1))
encoder_dict["encoder_hidden_bias"] = np.empty((1,net_params["encoder_hidden_width"],net_params["encoder_hidden_depth"]-1))


for i in range(net_params["encoder_hidden_depth"]-1):
    
    encoder_dict["encoder_hidden_weights"][:,:,i] = model_koop_dnn.net.encoder_fc_hid[i].weight.detach().numpy()
    encoder_dict["encoder_hidden_bias"][:,:,i] = model_koop_dnn.net.encoder_fc_hid[i].bias.detach().numpy()

encoder_dict["encoder_out_weights"] = model_koop_dnn.net.encoder_fc_out.weight.detach().numpy()
encoder_dict["encoder_out_bias"] = model_koop_dnn.net.encoder_fc_out.bias.detach().numpy()

scipy.io.savemat(path_model + "encoder.mat", encoder_dict)

if standardize:
    scipy.io.savemat(path_model + "std.mat", {"standardize": standardize, 'mean': standardizer_u_kdnn.mean_, 'scale':standardizer_u_kdnn.scale_})
    
else:
    scipy.io.savemat(path_model + "std.mat", {"standardize": standardize})

# %%
# save forward map
forward_map_dict = {}

forward_map_dict["map_in_weights"] = map_net.map_net_in.weight.detach().numpy()
forward_map_dict["map_in_bias"] = map_net.map_net_in.bias.detach().numpy()
forward_map_dict["map_hidden_depth"] = int(map_net_params["hidden_depth"]-1)

forward_map_dict["map_hidden_weights"] = np.empty((map_net_params["hidden_width"],map_net_params["hidden_width"],map_net_params["hidden_depth"]-1))
forward_map_dict["map_hidden_bias"] = np.empty((1,map_net_params["hidden_width"],map_net_params["hidden_depth"]-1))

for i in range(map_net_params["hidden_depth"]-1):
    
    forward_map_dict["map_hidden_weights"][:,:,i] = map_net.map_net_hid[i].weight.detach().numpy()
    forward_map_dict["map_hidden_bias"][:,:,i] = map_net.map_net_hid[i].bias.detach().numpy()

forward_map_dict["map_out_weights"] = map_net.map_net_out.weight.detach().numpy()
forward_map_dict["map_out_bias"] = map_net.map_net_out.bias.detach().numpy()


path_model = 'saved_models/'+ robot_type +'/matlab_files/' 
#save net parameters


scipy.io.savemat(path_model + "forward_map.mat", forward_map_dict)

# %%
net_params['encoder_hidden_depth']
# Out:
# 3

# %%
path_model
# Out:
# 'saved_models/3R/bilinear/2D/matlab_files/'

# %%
encode_out_bias = model_koop_dnn.net.encoder_fc_out.bias.detach().numpy()
encode_out_weights = model_koop_dnn.net.encoder_fc_out.weight.detach().numpy()

# %% [markdown]
# ***Test Data Generation***

# %%
test_data = 'dynamics/Dataset_MATLAB/' + robot_type_load +'/data_test.mat'
data_test = scipy.io.loadmat(test_data)

# %%
X_end_test = np.array(data_test['X_end'], dtype = 'float64')
X_test = np.array(data_test['X'], dtype = 'float64')
U_test = np.array(data_test['tau'], dtype = 'float64')
num_snaps_test = int(data_test['num_snaps'])
num_traj_test = int(data_test['num_traj'])
# test data parameters
T = np.linspace(0,num_snaps_test*dt, num_snaps_test+1)

# %%
# data_gen
j = random.choice(range(num_traj_test))
xs_end_test = X_end_test[j,:,:]
xs_test = X_test[j,:,:]
us_test = U_test[j,:,:]

# %%
print(xs_end_test.shape, xs_test.shape, us_test.shape)
# Out:
# (1001, 2) (1001, 6) (1000, 3)

# %%
print(model_koop_dnn.test_loss(xs_test.reshape(1,-1,num_states),u_test = us_test.reshape(1,-1,num_inputs)))
# Out:
# tensor(5.1903e-06)

# %%
basis = model_koop_dnn.net.encode_forward_

# %%
X,_ = model_koop_dnn.net.process(xs_test.reshape(1,-1,num_states),data_u = us_test.reshape(1,-1,num_inputs))
print(X.shape)
# Out:
# (1000, 15)

# %%
x = X[:, :num_states]
u = X[:, num_states:num_states+num_inputs]
x_prime = X[:,num_states+num_inputs:]

print(x.shape, u.shape, x_prime.shape)
# Out:
# (1000, 6) (1000, 3) (1000, 6)

# %% [markdown]
# ***Initial Condition Lifting***

# %%
# initialize the matricies
z = np.empty((n_obs,num_snaps_test+1)).T
x_est = np.zeros((num_states,num_snaps_test+1)).T
x_end_est = np.zeros((X_end.shape[2],num_snaps_test)).T

# %%
z[0,:] = lift(x[0,:],model_koop_dnn, net_params)
x_est[0,:] = x[0,:]

# %% [markdown]
# ***Time Evolution***

# %%
for i in range(num_snaps_test):
  #bilinear
    z[i+1,:] = np.matmul(z[i,:],A.T)+np.matmul(np.kron(u[i,:],z[i,:]),B.T)
    x_est[i+1,:] = np.matmul(z[i+1,:],C.T)  
    x_end_est[i,:] = map_net.forward(torch.from_numpy(x_est[i,:int(num_joints)]).float()).detach().numpy()

# %% [markdown]
# ***Visualization***

# %% [markdown]
# # Joint Space

# %%
plt.figure(figsize=(20,12))
for i in range(int(num_joints)):
    plt.subplot(3,3,i+1)
    plt.plot(T[:-1],x[:,i],label ='Actual')
    plt.plot(T[:],x_est[:,i],label = 'estimated(bilinear)')
    plt.xlabel('t')
    plt.ylabel('theta_' + str(i))
    plt.title('theta_' + str(i) + ' Comparison')
    plt.legend()

# %%
plt.figure(figsize=(20,12))
for i in range(int(num_joints)):
    plt.subplot(3,3,i+1)
    plt.plot(T[:-1],x[:,int(num_joints)+i],label ='Actual')
    plt.plot(T[:],x_est[:,int(num_joints)+i],label = 'estimated(bilinear)')
    plt.xlabel('t')
    plt.ylabel('theta_dot_' + str(i))
    plt.title('theta_dot_' + str(i) + ' Comparison')
    plt.legend()

# %%
plt.figure(figsize=(20,12))
for i in range(int(num_joints)):
    plt.subplot(3,3,i+1)
    plt.plot(T[:-1],u[:,i])
    plt.xlabel('t')
    plt.ylabel('tau' + str(i))

# %%
plt.figure(figsize=(20,12))
for i in range(int(num_joints)):
    plt.subplot(3,3,i+1)
    plt.plot(T[:-1],us_test[:,i])
    plt.xlabel('t')
    plt.ylabel('tau' + str(i))

# %%
if standardize:
    u_unscaled = np.array([standardizer_u_kdnn.inverse_transform(d.reshape(1,-1)) for d in u]).reshape(num_snaps_test,num_inputs)
    plt.figure(figsize=(20,12))
    for i in range(int(num_joints)):
        plt.subplot(3,3,i+1)
        plt.plot(T[:-1],us_test[:,i], label= 'original')
        plt.plot(T[:-1],u_unscaled[:,i], label= 'unscaled')
        plt.xlabel('t')
        plt.ylabel('tau' + str(i))
        
    print(u.shape)
    print(u_unscaled.shape)
# Out:
# (1000, 3)
# (1000, 3)

# %% [markdown]
# ## Cartesian Space

# %%
plt.figure(figsize=(20,6))
for i in range(X_end.shape[2]):
    plt.subplot(1,3,i+1)
    plt.plot(T[:],xs_end_test[:,i], label = 'Actual')
    plt.plot(T[:-1],x_end_est[:,i], label = 'Estimated')
    plt.legend()
plt.show()

# %%
error_joint_space = np.linalg.norm(xs_test-x_est,axis = 1)
error_cart_space = np.linalg.norm(xs_end_test[:-1]-x_end_est,axis = 1)

# %%
plt.figure(figsize =(20,6))
plt.subplot(1,2,1)
plt.plot(T[:],error_joint_space)
plt.title('Joint Space Error')

plt.subplot(1,2,2)
plt.plot(T[:-1],error_cart_space)
plt.title('Cartesian Space Error')
# Out:
# Text(0.5, 1.0, 'Cartesian Space Error')

# %%
xs_test[8,:]
# Out:
# array([-1.98268599e-01, -1.35487964e+00, -1.21784278e+00,  6.02322627e-04,
#         1.51927647e-03, -5.41900687e-04])

# %%
# the mean error for the whole test dataset
error_ang_traj =  np.empty((num_snaps_test))
error_vel_traj =  np.empty((num_snaps_test))

error_ang_total  = np.empty((num_traj_test))
error_vel_total  = np.empty((num_traj_test))

for j in range(num_traj_test):
    xs_test = X_test[j,:,:]
    us_test = U_test[j,:,:]
    X,_ = model_koop_dnn.net.process(xs_test.reshape(1,-1,num_states),data_u = us_test.reshape(1,-1,num_inputs))
    x = X[:, :num_states]
    u = X[:, num_states:num_states+num_inputs]
    x_prime = X[:,num_states+num_inputs:]
    z[0,:] = lift(x[0,:],model_koop_dnn, net_params)
    x_est[0,:] = x[0,:]
    
    for i in range(num_snaps_test):
        #bilinear
        z[i+1,:] = np.matmul(z[i,:],A.T)+np.matmul(np.kron(u[i,:],z[i,:]),B.T)
        x_est[i+1,:] = np.matmul(z[i+1,:],C.T)  
        error_ang_traj[i] = np.mean(abs(x_est[i,:num_joints] - x[i,:num_joints]))
        error_vel_traj[i] = np.mean(abs(x_est[i,num_joints:] - x[i,num_joints:]))
        
    error_ang_total[j] = np.mean(error_ang_traj)
    error_vel_total[j] = np.mean(error_vel_traj)

# %%
print("Mean Absolute Error for joint angles for testing data :", np.mean(error_ang_total))
print("Mean Absolute Error for joint velocity for testing data :", np.mean(error_vel_total))
# Out:
# Mean Absolute Error for joint angles for testing data : 0.001139173202291025
# Mean Absolute Error for joint velocity for testing data : 0.0007389176766423017

# %%
abs(x_est[i,:] - x[i,:])
# Out:
# array([0.00248394, 0.00376118, 0.00913702, 0.00114755, 0.00117313,
#        0.00363111])
