# %% [markdown]
# ***Import Libraries***

# %%
"""This program linearizes 3R planar dyanmics using koopman theory and autoencoder to map"""
import numpy as np
import matplotlib.pyplot as plt
import sklearn.preprocessing
import itertools
import scipy.io
import torch

# bilinear Koopman
from core.koopman_core import KoopDNN, KoopmanNet, KoopmanNetCtrl
from models.koop_model import model_matricies,lift
from core.util import fit_standardizer
from sklearn import preprocessing

# forward map neural net
from core.neural_fwd_map import map_Net
from models.neural_jacob_map import neural_jacobian, neural_jacobian_dot
# controllability
from core.util import Output_Con
import control as ct


## import paths
from paths.paths import path_pars, path_pars_2D

## extra libraries
import numpy as np
import scipy as sp
from scipy import sparse
import random

# %%
## define paths
robot = '3R'
nature = 'bilinear'
modality = '2D'

robot_type_load = robot +'/' + modality # for data load0
robot_type = robot +'/'+ nature +'/' + modality # for saving purposes

train = True
mass_var = False
standardize = True


if mass_var == True:
    file_data = 'dynamics/Dataset_MATLAB/' + robot_type_load +'/data_mass_var.mat'
    
else:
    file_data = 'dynamics/Dataset_MATLAB/' + robot_type_load +'/data.mat'
    

    
file_data_fwd = 'dynamics/Dataset_MATLAB/' + robot_type_load +'/data_fw.mat'

# %%
file_data
# Out:
# 'dynamics/Dataset_MATLAB/3R/2D/data.mat'

# %% [markdown]
# ### Load Data

# %%
data = scipy.io.loadmat(file_data)
data_fw = scipy.io.loadmat(file_data_fwd)

X_end = np.array(data['X_end'], dtype = 'float64')
X_full = np.array(data['X'], dtype = 'float64')
U_full = np.array(data['tau'], dtype = 'float64')

X_end_fw = np.array(data_fw['X_end_fw'], dtype = 'float64')
X_fw = np.array(data_fw['X_fw'], dtype = 'float64')

print(X_end.shape, X_full.shape,U_full.shape,X_fw.shape,X_end_fw.shape)
# Out:
# (200, 1001, 2) (200, 1001, 6) (200, 1000, 3) (200, 1000, 3) (200, 1000, 2)

# %%
np.sum(np.sum(np.isnan(X_end))), np.sum(np.sum(np.isnan(U_full))), np.sum(np.sum(np.isnan(X_full)))
# Out:
# (0, 0, 0)

# %% [markdown]
# ***Simulation Parameters***

# %%
dt = float(data['dt']) #time step
num_snaps = int(data['num_snaps']) # no. of snapshots
num_traj = int(data['num_traj']) #no of trajectories
T = np.linspace(0,num_snaps*dt, num_snaps+1)
num_train = int(0.75*num_traj) # no. of training examples
num_val = num_traj-num_train # no of testing examples
num_traj = num_train+num_val #no of trajectories
num_states = X_full.shape[2] # no. of states
num_joints = int(num_states/2)
num_inputs = U_full.shape[2] # no. of inputs
num_states_cart = int(X_end.shape[2])

# %%
dt, num_snaps, num_traj, num_states, num_inputs,num_states_cart, num_train, num_val
# Out:
# (0.005, 1000, 200, 6, 3, 2, 150, 50)

# %% [markdown]
# ***Plotting the trajectories***

# %%
"""Training dataset visualization"""
#theta evolution
for i in range(int(num_joints)):
    plt.subplot(3,3,i+1)
    plt.xlabel("t")
    plt.ylabel("th"+str(i+1))
    for j in range(num_traj):
        plt.plot(T,X_full[j,:,i])

# %%
for i in range(int(num_joints)):
    plt.subplot(3,3,i+1)
    plt.xlabel("t")
    plt.ylabel("th"+str(i+1)+ ' dot')
    for j in range(num_traj):
        plt.plot(T,X_full[j,:,i+int(num_joints)])

# %%
#x and y positions of the end effector
# %matplotlib widget
# ax = plt.axes(projection='3d')
# ax.set_xlabel("x")
# ax.set_ylabel("y")
# ax.set_zlabel("z")
# for i in range(num_traj):
#     ax.plot3D(X_end[i,:,0],X_end[i,:,1],X_end[i,:,2])
    
# plt.axis('equal')

# %%
for i in range(num_traj):
    plt.plot(X_end[i,:,0],X_end[i,:,1])
    
plt.axis('equal')
# Out:
# (-1.0350242087098405,
#  1.0499653634141526,
#  -1.0164808326962187,
#  1.0721931443330608)

# %%
for i in range(num_inputs):
    plt.subplot(4,2,i+1)
    plt.xlabel("t")
    plt.ylabel("tau"+str(i))
    for j in range(num_traj):
        plt.plot(T[:-1],U_full[j,:,i])

# %% [markdown]
# ***Training and validation datasets***

# %%
# split training and vaidation datasets
xs_train, us_train = X_full[:num_train,:,:],U_full[:num_train,:,:]
xs_val, us_val = X_full[num_train:,:,:],U_full[num_train:,:,:]

# %%
# import scipy.io
# Data_set = {"x_end": X_end, "X_full": X_full}
# scipy.io.savemat("Data_set.mat",Data_set)

# %%
# import torch
# import torch.nn as nn
# import torch.nn.functional as F

# %% [markdown]
# ***Model Training***

# %%
net_params = {}
net_params['state_dim'] = num_states
net_params['ctrl_dim'] = num_inputs
net_params['encoder_hidden_width'] = 30 # 30
net_params['encoder_hidden_depth'] = 3  # 2
net_params['encoder_output_dim'] = 23   # 20
net_params['optimizer'] = 'adam'
net_params['activation_type'] = 'tanh'
net_params['lr'] = 5e-4 # 5e-4
net_params['epochs'] = 600
net_params['batch_size'] = 128
net_params['lifted_loss_penalty'] = 0.4 
net_params['l2_reg'] = 0.00       
net_params['l1_reg'] = 0.00
net_params['first_obs_const'] = True
net_params['override_C'] = True # this makes the state a part of lifetd state
net_params['dt'] = dt

# %%
                                              
if mass_var == True:
    file_koop = 'saved_models/'+robot_type+'/koop_arch_con_mass_var.pth'
else:
    file_koop = 'saved_models/'+robot_type+'/koop_arch_con.pth'
    
standardizer_u_kdnn = fit_standardizer(us_train, preprocessing.StandardScaler(with_mean = True))
# standardizer_x_kdnn = fit_standardizer(xs_train, preprocessing.StandardScaler(with_mean=False))

if train == True:
    
    if standardize:
        net = KoopmanNetCtrl(net_params, standardizer_u=standardizer_u_kdnn)
    else:
        net = KoopmanNetCtrl(net_params)
    model_koop_dnn = KoopDNN(net)
    model_koop_dnn.set_datasets(xs_train, u_train=us_train, x_val=xs_val, u_val=us_val)
    model_koop_dnn.model_pipeline(net_params)
    model_koop_dnn.construct_koopman_model()
    torch.save(model_koop_dnn,file_koop)
else:
    model_koop_dnn = torch.load(file_koop)
# Out:
# Epoch   1: train loss: 0.5220780969, validation loss: 0.2778831349
# Epoch   2: train loss: 0.1007783711, validation loss: 0.0134685942
# Epoch   3: train loss: 0.0051406492, validation loss: 0.0033143646
# Epoch   4: train loss: 0.0020245623, validation loss: 0.0017970823
# Epoch   5: train loss: 0.0012610696, validation loss: 0.0011707357
# Epoch   6: train loss: 0.0009417960, validation loss: 0.0009492803
# Epoch   7: train loss: 0.0007744943, validation loss: 0.0008017965
# Epoch   8: train loss: 0.0006706836, validation loss: 0.0008170338
# Epoch   9: train loss: 0.0006161625, validation loss: 0.0005793164
# Epoch  10: train loss: 0.0005680437, validation loss: 0.0006514687
# Epoch  11: train loss: 0.0005246651, validation loss: 0.0006064495
# Epoch  12: train loss: 0.0005080458, validation loss: 0.0006093204
# Epoch  13: train loss: 0.0004773650, validation loss: 0.0004293807
# Epoch  14: train loss: 0.0004510969, validation loss: 0.0003778756
# Epoch  15: train loss: 0.0004393863, validation loss: 0.0005129801
# Epoch  16: train loss: 0.0004203280, validation loss: 0.0003950155
# Epoch  17: train loss: 0.0004072455, validation loss: 0.0005402558
# Epoch  18: train loss: 0.0004027796, validation loss: 0.0003699016
# Epoch  19: train loss: 0.0003766103, validation loss: 0.0004817281
# Epoch  20: train loss: 0.0003781067, validation loss: 0.0003163732
# Epoch  21: train loss: 0.0003580683, validation loss: 0.0003502773
# Epoch  22: train loss: 0.0003559327, validation loss: 0.0003007348
# Epoch  23: train loss: 0.0003345797, validation loss: 0.0003376105
# Epoch  24: train loss: 0.0003315814, validation loss: 0.0002988564
# Epoch  25: train loss: 0.0003249883, validation loss: 0.0002876434
# Epoch  26: train loss: 0.0003125032, validation loss: 0.0002874973
# Epoch  27: train loss: 0.0003089237, validation loss: 0.0004192169
# Epoch  28: train loss: 0.0003089195, validation loss: 0.0003169591
# Epoch  29: train loss: 0.0002914612, validation loss: 0.0002762573
# Epoch  30: train loss: 0.0002901979, validation loss: 0.0002492648
# Epoch  31: train loss: 0.0002926425, validation loss: 0.0002951882
# Epoch  32: train loss: 0.0002653080, validation loss: 0.0002259730
# Epoch  33: train loss: 0.0002751755, validation loss: 0.0002446266
# Epoch  34: train loss: 0.0002648622, validation loss: 0.0002536557
# Epoch  35: train loss: 0.0002578914, validation loss: 0.0002319184
# Epoch  36: train loss: 0.0002598938, validation loss: 0.0002414721
# Epoch  37: train loss: 0.0002498562, validation loss: 0.0002430939
# Epoch  38: train loss: 0.0002442149, validation loss: 0.0003947503
# Epoch  39: train loss: 0.0002379485, validation loss: 0.0002738185
# Epoch  40: train loss: 0.0002405337, validation loss: 0.0001999787
# Epoch  41: train loss: 0.0002288739, validation loss: 0.0002690880
# Epoch  42: train loss: 0.0002317711, validation loss: 0.0002713487
# Epoch  43: train loss: 0.0002220568, validation loss: 0.0001938603
# Epoch  44: train loss: 0.0002268967, validation loss: 0.0002266945
# Epoch  45: train loss: 0.0002186658, validation loss: 0.0002053415
# Epoch  46: train loss: 0.0002116922, validation loss: 0.0002023918
# Epoch  47: train loss: 0.0002086291, validation loss: 0.0001824696
# Epoch  48: train loss: 0.0002026020, validation loss: 0.0001739163
# Epoch  49: train loss: 0.0002038092, validation loss: 0.0002100158
# Epoch  50: train loss: 0.0001971061, validation loss: 0.0002949544
# Epoch  51: train loss: 0.0001965024, validation loss: 0.0001538952
# Epoch  52: train loss: 0.0001939891, validation loss: 0.0001822161
# Epoch  53: train loss: 0.0001867143, validation loss: 0.0001958793
# Epoch  54: train loss: 0.0001839192, validation loss: 0.0001655144
# Epoch  55: train loss: 0.0001757939, validation loss: 0.0002166577
# Epoch  56: train loss: 0.0001784960, validation loss: 0.0001812396
# Epoch  57: train loss: 0.0001697845, validation loss: 0.0001467615
# Epoch  58: train loss: 0.0001711869, validation loss: 0.0002094857
# Epoch  59: train loss: 0.0001643249, validation loss: 0.0001524422
# Epoch  60: train loss: 0.0001615704, validation loss: 0.0001348211
# Epoch  61: train loss: 0.0001554447, validation loss: 0.0001553592
# Epoch  62: train loss: 0.0001563794, validation loss: 0.0001488034
# Epoch  63: train loss: 0.0001488812, validation loss: 0.0001682480
# Epoch  64: train loss: 0.0001491337, validation loss: 0.0001463621
# Epoch  65: train loss: 0.0001455407, validation loss: 0.0001669817
# Epoch  66: train loss: 0.0001410286, validation loss: 0.0001659121
# Epoch  67: train loss: 0.0001429354, validation loss: 0.0001828670
# Epoch  68: train loss: 0.0001358694, validation loss: 0.0002060541
# Epoch  69: train loss: 0.0001326846, validation loss: 0.0001542438
# Epoch  70: train loss: 0.0001369745, validation loss: 0.0001390187
# Epoch  71: train loss: 0.0001282976, validation loss: 0.0001131917
# Epoch  72: train loss: 0.0001263382, validation loss: 0.0001021780
# Epoch  73: train loss: 0.0001263640, validation loss: 0.0001604610
# Epoch  74: train loss: 0.0001252893, validation loss: 0.0001250292
# Epoch  75: train loss: 0.0001179064, validation loss: 0.0001556341
# Epoch  76: train loss: 0.0001191271, validation loss: 0.0000997814
# Epoch  77: train loss: 0.0001189017, validation loss: 0.0001152830
# Epoch  78: train loss: 0.0001150249, validation loss: 0.0001031843
# Epoch  79: train loss: 0.0001109961, validation loss: 0.0001241563
# Epoch  80: train loss: 0.0001095605, validation loss: 0.0000885000
# Epoch  81: train loss: 0.0001041792, validation loss: 0.0001458796
# Epoch  82: train loss: 0.0001050474, validation loss: 0.0000824255
# Epoch  83: train loss: 0.0001024481, validation loss: 0.0000976147
# Epoch  84: train loss: 0.0001004037, validation loss: 0.0001266189
# Epoch  85: train loss: 0.0001006407, validation loss: 0.0000982978
# Epoch  86: train loss: 0.0000954739, validation loss: 0.0001995502
# Epoch  87: train loss: 0.0000927853, validation loss: 0.0000988748
# Epoch  88: train loss: 0.0000943682, validation loss: 0.0000866363
# Epoch  89: train loss: 0.0000914362, validation loss: 0.0001119680
# Epoch  90: train loss: 0.0000929056, validation loss: 0.0000850120
# Epoch  91: train loss: 0.0000896260, validation loss: 0.0001014542
# Epoch  92: train loss: 0.0000908983, validation loss: 0.0000759211
# Epoch  93: train loss: 0.0000868217, validation loss: 0.0000949560
# Epoch  94: train loss: 0.0000847370, validation loss: 0.0000864274
# Epoch  95: train loss: 0.0000856661, validation loss: 0.0000867507
# Epoch  96: train loss: 0.0000806125, validation loss: 0.0000952385
# Epoch  97: train loss: 0.0000821961, validation loss: 0.0000770675
# Epoch  98: train loss: 0.0000807402, validation loss: 0.0000889004
# Epoch  99: train loss: 0.0000818413, validation loss: 0.0000790941
# Epoch 100: train loss: 0.0000768483, validation loss: 0.0000971299
# Epoch 101: train loss: 0.0000748735, validation loss: 0.0000753223
# Epoch 102: train loss: 0.0000775694, validation loss: 0.0000775735
# Epoch 103: train loss: 0.0000730765, validation loss: 0.0001009941
# Epoch 104: train loss: 0.0000737754, validation loss: 0.0000940879
# Epoch 105: train loss: 0.0000751874, validation loss: 0.0000675422
# Epoch 106: train loss: 0.0000742287, validation loss: 0.0000558630
# Epoch 107: train loss: 0.0000684113, validation loss: 0.0000771486
# Epoch 108: train loss: 0.0000722780, validation loss: 0.0001052737
# Epoch 109: train loss: 0.0000686676, validation loss: 0.0000599204
# Epoch 110: train loss: 0.0000711160, validation loss: 0.0000608160
# Epoch 111: train loss: 0.0000668294, validation loss: 0.0000644636
# Epoch 112: train loss: 0.0000666563, validation loss: 0.0000810746
# Epoch 113: train loss: 0.0000655777, validation loss: 0.0000483096
# Epoch 114: train loss: 0.0000650418, validation loss: 0.0000571028
# Epoch 115: train loss: 0.0000643954, validation loss: 0.0000621126
# Epoch 116: train loss: 0.0000653967, validation loss: 0.0000756230
# Epoch 117: train loss: 0.0000621747, validation loss: 0.0001552033
# Epoch 118: train loss: 0.0000619956, validation loss: 0.0000418382
# Epoch 119: train loss: 0.0000628642, validation loss: 0.0000581493
# Epoch 120: train loss: 0.0000639639, validation loss: 0.0000513807
# Epoch 121: train loss: 0.0000584647, validation loss: 0.0000530494
# Epoch 122: train loss: 0.0000596011, validation loss: 0.0000829785
# Epoch 123: train loss: 0.0000625940, validation loss: 0.0000414333
# Epoch 124: train loss: 0.0000551935, validation loss: 0.0000606738
# Epoch 125: train loss: 0.0000570367, validation loss: 0.0000472263
# Epoch 126: train loss: 0.0000566478, validation loss: 0.0000605161
# Epoch 127: train loss: 0.0000551483, validation loss: 0.0000550179
# Epoch 128: train loss: 0.0000551171, validation loss: 0.0000521647
# Epoch 129: train loss: 0.0000589697, validation loss: 0.0000471103
# Epoch 130: train loss: 0.0000508595, validation loss: 0.0000437045
# Epoch 131: train loss: 0.0000534109, validation loss: 0.0000542036
# Epoch 132: train loss: 0.0000526849, validation loss: 0.0000554570
# Epoch 133: train loss: 0.0000554669, validation loss: 0.0000437972
# Epoch 134: train loss: 0.0000476324, validation loss: 0.0000345804
# Epoch 135: train loss: 0.0000536236, validation loss: 0.0000319979
# Epoch 136: train loss: 0.0000495431, validation loss: 0.0000744364
# Epoch 137: train loss: 0.0000485141, validation loss: 0.0000469277
# Epoch 138: train loss: 0.0000516128, validation loss: 0.0000330999
# Epoch 139: train loss: 0.0000455699, validation loss: 0.0000328784
# Epoch 140: train loss: 0.0000466942, validation loss: 0.0000426752
# Epoch 141: train loss: 0.0000462746, validation loss: 0.0000422924
# Epoch 142: train loss: 0.0000445285, validation loss: 0.0000490950
# Epoch 143: train loss: 0.0000473883, validation loss: 0.0000465861
# Epoch 144: train loss: 0.0000439819, validation loss: 0.0000742625
# Epoch 145: train loss: 0.0000435532, validation loss: 0.0000383447
# Epoch 146: train loss: 0.0000441451, validation loss: 0.0000322147
# Epoch 147: train loss: 0.0000411444, validation loss: 0.0000456444
# Epoch 148: train loss: 0.0000435600, validation loss: 0.0000368122
# Epoch 149: train loss: 0.0000403651, validation loss: 0.0000319247
# Epoch 150: train loss: 0.0000404058, validation loss: 0.0000281625
# Epoch 151: train loss: 0.0000416676, validation loss: 0.0000330188
# Epoch 152: train loss: 0.0000395664, validation loss: 0.0000339292
# Epoch 153: train loss: 0.0000387227, validation loss: 0.0000284580
# Epoch 154: train loss: 0.0000412487, validation loss: 0.0000399547
# Epoch 155: train loss: 0.0000373128, validation loss: 0.0000670024
# Epoch 156: train loss: 0.0000381263, validation loss: 0.0000581022
# Epoch 157: train loss: 0.0000383114, validation loss: 0.0000367139
# Epoch 158: train loss: 0.0000351087, validation loss: 0.0000516989
# Epoch 159: train loss: 0.0000385724, validation loss: 0.0000290597
# Epoch 160: train loss: 0.0000376756, validation loss: 0.0000334004
# Epoch 161: train loss: 0.0000358072, validation loss: 0.0000378723
# Epoch 162: train loss: 0.0000384652, validation loss: 0.0000294143
# Epoch 163: train loss: 0.0000336936, validation loss: 0.0000302049
# Epoch 164: train loss: 0.0000364355, validation loss: 0.0000686413
# Epoch 165: train loss: 0.0000360978, validation loss: 0.0000267195
# Epoch 166: train loss: 0.0000345943, validation loss: 0.0000462224
# Epoch 167: train loss: 0.0000341129, validation loss: 0.0000344890
# Epoch 168: train loss: 0.0000346335, validation loss: 0.0000241695
# Epoch 169: train loss: 0.0000329724, validation loss: 0.0000322917
# Epoch 170: train loss: 0.0000383424, validation loss: 0.0000215684
# Epoch 171: train loss: 0.0000278832, validation loss: 0.0000269881
# Epoch 172: train loss: 0.0000325790, validation loss: 0.0000580883
# Epoch 173: train loss: 0.0000317107, validation loss: 0.0000464342
# Epoch 174: train loss: 0.0000319416, validation loss: 0.0000275620
# Epoch 175: train loss: 0.0000331796, validation loss: 0.0000199161
# Epoch 176: train loss: 0.0000318726, validation loss: 0.0000251132
# Epoch 177: train loss: 0.0000308506, validation loss: 0.0000260649
# Epoch 178: train loss: 0.0000310346, validation loss: 0.0000170475
# Epoch 179: train loss: 0.0000307861, validation loss: 0.0000341598
# Epoch 180: train loss: 0.0000286129, validation loss: 0.0000185147
# Epoch 181: train loss: 0.0000303058, validation loss: 0.0000224113
# Epoch 182: train loss: 0.0000288726, validation loss: 0.0000476570
# Epoch 183: train loss: 0.0000292281, validation loss: 0.0000494725
# Epoch 184: train loss: 0.0000275847, validation loss: 0.0000216159
# Epoch 185: train loss: 0.0000286421, validation loss: 0.0000328419
# Epoch 186: train loss: 0.0000268824, validation loss: 0.0000261770
# Epoch 187: train loss: 0.0000298958, validation loss: 0.0000238885
# Epoch 188: train loss: 0.0000285198, validation loss: 0.0000358219
# Epoch 189: train loss: 0.0000257606, validation loss: 0.0000216378
# Epoch 190: train loss: 0.0000272671, validation loss: 0.0000191785
# Epoch 191: train loss: 0.0000288710, validation loss: 0.0000144404
# Epoch 192: train loss: 0.0000255541, validation loss: 0.0000182928
# Epoch 193: train loss: 0.0000258903, validation loss: 0.0000241760
# Epoch 194: train loss: 0.0000250776, validation loss: 0.0000162371
# Epoch 195: train loss: 0.0000288940, validation loss: 0.0000207212
# Epoch 196: train loss: 0.0000266429, validation loss: 0.0000928232
# Epoch 197: train loss: 0.0000238782, validation loss: 0.0000147830
# Epoch 198: train loss: 0.0000244938, validation loss: 0.0000328375
# Epoch 199: train loss: 0.0000239924, validation loss: 0.0000368249
# Epoch 200: train loss: 0.0000267716, validation loss: 0.0000381842
# Epoch 201: train loss: 0.0000225053, validation loss: 0.0000139301
# Epoch 202: train loss: 0.0000274237, validation loss: 0.0000204270
# Epoch 203: train loss: 0.0000206500, validation loss: 0.0000365530
# Epoch 204: train loss: 0.0000237248, validation loss: 0.0000205095
# Epoch 205: train loss: 0.0000241063, validation loss: 0.0000625776
# Epoch 206: train loss: 0.0000247188, validation loss: 0.0000160015
# Epoch 207: train loss: 0.0000223717, validation loss: 0.0000322328
# Epoch 208: train loss: 0.0000233794, validation loss: 0.0000192199
# Epoch 209: train loss: 0.0000220876, validation loss: 0.0000160028
# Epoch 210: train loss: 0.0000220639, validation loss: 0.0000245564
# Epoch 211: train loss: 0.0000241113, validation loss: 0.0000124880
# Epoch 212: train loss: 0.0000211953, validation loss: 0.0000193511
# Epoch 213: train loss: 0.0000219296, validation loss: 0.0000210042
# Epoch 214: train loss: 0.0000229556, validation loss: 0.0000164825
# Epoch 215: train loss: 0.0000206769, validation loss: 0.0000419229
# Epoch 216: train loss: 0.0000232261, validation loss: 0.0000168477
# Epoch 217: train loss: 0.0000223141, validation loss: 0.0000487316
# Epoch 218: train loss: 0.0000187181, validation loss: 0.0000102961
# Epoch 219: train loss: 0.0000239218, validation loss: 0.0000162087
# Epoch 220: train loss: 0.0000214904, validation loss: 0.0000112902
# Epoch 221: train loss: 0.0000190372, validation loss: 0.0000199007
# Epoch 222: train loss: 0.0000219395, validation loss: 0.0000130644
# Epoch 223: train loss: 0.0000201756, validation loss: 0.0000611759
# Epoch 224: train loss: 0.0000193754, validation loss: 0.0000179328
# Epoch 225: train loss: 0.0000224935, validation loss: 0.0000208329
# Epoch 226: train loss: 0.0000201246, validation loss: 0.0000354340
# Epoch 227: train loss: 0.0000189784, validation loss: 0.0000129895
# Epoch 228: train loss: 0.0000203896, validation loss: 0.0000482816
# Epoch 229: train loss: 0.0000205144, validation loss: 0.0000283649
# Epoch 230: train loss: 0.0000199129, validation loss: 0.0000160168
# Epoch 231: train loss: 0.0000189509, validation loss: 0.0000251548
# Epoch 232: train loss: 0.0000199936, validation loss: 0.0000107599
# Epoch 233: train loss: 0.0000197795, validation loss: 0.0000182538
# Epoch 234: train loss: 0.0000177533, validation loss: 0.0000200743
# Epoch 235: train loss: 0.0000198715, validation loss: 0.0000344118
# Epoch 236: train loss: 0.0000179245, validation loss: 0.0000402311
# Epoch 237: train loss: 0.0000198814, validation loss: 0.0000129699
# Epoch 238: train loss: 0.0000189726, validation loss: 0.0000123125
# Epoch 239: train loss: 0.0000210970, validation loss: 0.0000089145
# Epoch 240: train loss: 0.0000156275, validation loss: 0.0000142006
# Epoch 241: train loss: 0.0000175607, validation loss: 0.0000124223
# Epoch 242: train loss: 0.0000193487, validation loss: 0.0000089229
# Epoch 243: train loss: 0.0000185206, validation loss: 0.0000083495
# Epoch 244: train loss: 0.0000172028, validation loss: 0.0000438940
# Epoch 245: train loss: 0.0000178524, validation loss: 0.0000266144
# Epoch 246: train loss: 0.0000228138, validation loss: 0.0000226609
# Epoch 247: train loss: 0.0000137696, validation loss: 0.0000115464
# Epoch 248: train loss: 0.0000180643, validation loss: 0.0000098909
# Epoch 249: train loss: 0.0000165045, validation loss: 0.0000104817
# Epoch 250: train loss: 0.0000193486, validation loss: 0.0000150662
# Epoch 251: train loss: 0.0000172933, validation loss: 0.0000109374
# Epoch 252: train loss: 0.0000165214, validation loss: 0.0000190687
# Epoch 253: train loss: 0.0000167204, validation loss: 0.0000180805
# Epoch 254: train loss: 0.0000173271, validation loss: 0.0000126256
# Epoch 255: train loss: 0.0000163078, validation loss: 0.0001109237
# Epoch 256: train loss: 0.0000164025, validation loss: 0.0000127526
# Epoch 257: train loss: 0.0000162457, validation loss: 0.0000121773
# Epoch 258: train loss: 0.0000160624, validation loss: 0.0000103765
# Epoch 259: train loss: 0.0000163613, validation loss: 0.0000317242
# Epoch 260: train loss: 0.0000164984, validation loss: 0.0000125536
# Epoch 261: train loss: 0.0000156618, validation loss: 0.0000130201
# Epoch 262: train loss: 0.0000178170, validation loss: 0.0000149480
# Epoch 263: train loss: 0.0000168219, validation loss: 0.0000765491
# Epoch 264: train loss: 0.0000150484, validation loss: 0.0000163816
# Epoch 265: train loss: 0.0000186762, validation loss: 0.0000068605
# Epoch 266: train loss: 0.0000132000, validation loss: 0.0000076123
# Epoch 267: train loss: 0.0000156194, validation loss: 0.0000102564
# Epoch 268: train loss: 0.0000156265, validation loss: 0.0000284532
# Epoch 269: train loss: 0.0000163700, validation loss: 0.0000086513
# Epoch 270: train loss: 0.0000136561, validation loss: 0.0000084726
# Epoch 271: train loss: 0.0000161420, validation loss: 0.0000098160
# Epoch 272: train loss: 0.0000143938, validation loss: 0.0000066376
# Epoch 273: train loss: 0.0000156159, validation loss: 0.0000196093
# Epoch 274: train loss: 0.0000148288, validation loss: 0.0000094039
# Epoch 275: train loss: 0.0000138778, validation loss: 0.0000156930
# Epoch 276: train loss: 0.0000153156, validation loss: 0.0000122011
# Epoch 277: train loss: 0.0000153279, validation loss: 0.0000073052
# Epoch 278: train loss: 0.0000126099, validation loss: 0.0000473301
# Epoch 279: train loss: 0.0000144354, validation loss: 0.0000064224
# Epoch 280: train loss: 0.0000140795, validation loss: 0.0000128932
# Epoch 281: train loss: 0.0000148849, validation loss: 0.0000104974
# Epoch 282: train loss: 0.0000144075, validation loss: 0.0000077869
# Epoch 283: train loss: 0.0000162984, validation loss: 0.0000353302
# Epoch 284: train loss: 0.0000125522, validation loss: 0.0000240608
# Epoch 285: train loss: 0.0000139636, validation loss: 0.0000053856
# Epoch 286: train loss: 0.0000133629, validation loss: 0.0000088637
# Epoch 287: train loss: 0.0000136105, validation loss: 0.0000154785
# Epoch 288: train loss: 0.0000157790, validation loss: 0.0000068905
# Epoch 289: train loss: 0.0000120958, validation loss: 0.0000085440
# Epoch 290: train loss: 0.0000135043, validation loss: 0.0000159276
# Epoch 291: train loss: 0.0000170590, validation loss: 0.0000177702
# Epoch 292: train loss: 0.0000139782, validation loss: 0.0000286247
# Epoch 293: train loss: 0.0000123154, validation loss: 0.0000184451
# Epoch 294: train loss: 0.0000122924, validation loss: 0.0000147791
# Epoch 295: train loss: 0.0000140765, validation loss: 0.0000115225
# Epoch 296: train loss: 0.0000128054, validation loss: 0.0000085083
# Epoch 297: train loss: 0.0000140630, validation loss: 0.0000078762
# Epoch 298: train loss: 0.0000122255, validation loss: 0.0000427335
# Epoch 299: train loss: 0.0000129981, validation loss: 0.0000367644
# Epoch 300: train loss: 0.0000136694, validation loss: 0.0000048678
# Epoch 301: train loss: 0.0000126122, validation loss: 0.0000322543
# Epoch 302: train loss: 0.0000125403, validation loss: 0.0000060890
# Epoch 303: train loss: 0.0000120028, validation loss: 0.0000114110
# Epoch 304: train loss: 0.0000163507, validation loss: 0.0000047355
# Epoch 305: train loss: 0.0000118414, validation loss: 0.0000131180
# Epoch 306: train loss: 0.0000111022, validation loss: 0.0000118594
# Epoch 307: train loss: 0.0000119496, validation loss: 0.0000088548
# Epoch 308: train loss: 0.0000138293, validation loss: 0.0000149003
# Epoch 309: train loss: 0.0000116703, validation loss: 0.0000104829
# Epoch 310: train loss: 0.0000133533, validation loss: 0.0000108788
# Epoch 311: train loss: 0.0000117310, validation loss: 0.0000154953
# Epoch 312: train loss: 0.0000117810, validation loss: 0.0000088555
# Epoch 313: train loss: 0.0000131608, validation loss: 0.0000142425
# Epoch 314: train loss: 0.0000119062, validation loss: 0.0000142893
# Epoch 315: train loss: 0.0000127586, validation loss: 0.0000095153
# Epoch 316: train loss: 0.0000107171, validation loss: 0.0000068644
# Epoch 317: train loss: 0.0000117506, validation loss: 0.0000106406
# Epoch 318: train loss: 0.0000159190, validation loss: 0.0000046947
# Epoch 319: train loss: 0.0000101286, validation loss: 0.0000090339
# Epoch 320: train loss: 0.0000127099, validation loss: 0.0000090159
# Epoch 321: train loss: 0.0000107565, validation loss: 0.0000111017
# Epoch 322: train loss: 0.0000115006, validation loss: 0.0000438696
# Epoch 323: train loss: 0.0000122070, validation loss: 0.0000056798
# Epoch 324: train loss: 0.0000112642, validation loss: 0.0000133037
# Epoch 325: train loss: 0.0000115512, validation loss: 0.0000082737
# Epoch 326: train loss: 0.0000113982, validation loss: 0.0000069279
# Epoch 327: train loss: 0.0000141334, validation loss: 0.0000083774
# Epoch 328: train loss: 0.0000084720, validation loss: 0.0000115445
# Epoch 329: train loss: 0.0000115508, validation loss: 0.0000112027
# Epoch 330: train loss: 0.0000101800, validation loss: 0.0000162265
# Epoch 331: train loss: 0.0000136258, validation loss: 0.0000051089
# Epoch 332: train loss: 0.0000098082, validation loss: 0.0000075304
# Epoch 333: train loss: 0.0000138349, validation loss: 0.0000037894
# Epoch 334: train loss: 0.0000090351, validation loss: 0.0000062843
# Epoch 335: train loss: 0.0000123277, validation loss: 0.0000175548
# Epoch 336: train loss: 0.0000119045, validation loss: 0.0000365619
# Epoch 337: train loss: 0.0000099165, validation loss: 0.0000136782
# Epoch 338: train loss: 0.0000105341, validation loss: 0.0000100200
# Epoch 339: train loss: 0.0000112786, validation loss: 0.0000063947
# Epoch 340: train loss: 0.0000105463, validation loss: 0.0000148221
# Epoch 341: train loss: 0.0000100640, validation loss: 0.0000125691
# Epoch 342: train loss: 0.0000103718, validation loss: 0.0000100512
# Epoch 343: train loss: 0.0000104862, validation loss: 0.0000148986
# Epoch 344: train loss: 0.0000100112, validation loss: 0.0000273858
# Epoch 345: train loss: 0.0000096718, validation loss: 0.0000132692
# Epoch 346: train loss: 0.0000106278, validation loss: 0.0000253335
# Epoch 347: train loss: 0.0000112782, validation loss: 0.0000166500
# Epoch 348: train loss: 0.0000089991, validation loss: 0.0000057379
# Epoch 349: train loss: 0.0000112383, validation loss: 0.0000492893
# Epoch 350: train loss: 0.0000098831, validation loss: 0.0000051308
# Epoch 351: train loss: 0.0000112073, validation loss: 0.0000036394
# Epoch 352: train loss: 0.0000089937, validation loss: 0.0000093077
# Epoch 353: train loss: 0.0000096157, validation loss: 0.0000155083
# Epoch 354: train loss: 0.0000103346, validation loss: 0.0000048013
# Epoch 355: train loss: 0.0000085709, validation loss: 0.0000278688
# Epoch 356: train loss: 0.0000109731, validation loss: 0.0000160547
# Epoch 357: train loss: 0.0000100985, validation loss: 0.0000046381
# Epoch 358: train loss: 0.0000092325, validation loss: 0.0000108639
# Epoch 359: train loss: 0.0000099717, validation loss: 0.0000094456
# Epoch 360: train loss: 0.0000090667, validation loss: 0.0000119882
# Epoch 361: train loss: 0.0000100360, validation loss: 0.0000085301
# Epoch 362: train loss: 0.0000078429, validation loss: 0.0000142095
# Epoch 363: train loss: 0.0000105518, validation loss: 0.0000080660
# Epoch 364: train loss: 0.0000090892, validation loss: 0.0000058870
# Epoch 365: train loss: 0.0000122723, validation loss: 0.0000046103
# Epoch 366: train loss: 0.0000076361, validation loss: 0.0000038293
# Epoch 367: train loss: 0.0000096388, validation loss: 0.0000121020
# Epoch 368: train loss: 0.0000096679, validation loss: 0.0000123994
# Epoch 369: train loss: 0.0000097258, validation loss: 0.0000059535
# Epoch 370: train loss: 0.0000086573, validation loss: 0.0000043045
# Epoch 371: train loss: 0.0000095799, validation loss: 0.0000053972
# Epoch 372: train loss: 0.0000086422, validation loss: 0.0000072250
# Epoch 373: train loss: 0.0000087246, validation loss: 0.0000060691
# Epoch 374: train loss: 0.0000098607, validation loss: 0.0000094190
# Epoch 375: train loss: 0.0000088789, validation loss: 0.0000040722
# Epoch 376: train loss: 0.0000083326, validation loss: 0.0000089342
# Epoch 377: train loss: 0.0000097860, validation loss: 0.0000045104
# Epoch 378: train loss: 0.0000085404, validation loss: 0.0000127324
# Epoch 379: train loss: 0.0000098478, validation loss: 0.0000086187
# Epoch 380: train loss: 0.0000089280, validation loss: 0.0000056839
# Epoch 381: train loss: 0.0000087464, validation loss: 0.0000054049
# Epoch 382: train loss: 0.0000087466, validation loss: 0.0000046633
# Epoch 383: train loss: 0.0000080895, validation loss: 0.0000118653
# Epoch 384: train loss: 0.0000089965, validation loss: 0.0000045252
# Epoch 385: train loss: 0.0000083959, validation loss: 0.0000176921
# Epoch 386: train loss: 0.0000092564, validation loss: 0.0000055103
# Epoch 387: train loss: 0.0000084421, validation loss: 0.0000069394
# Epoch 388: train loss: 0.0000087185, validation loss: 0.0000057145
# Epoch 389: train loss: 0.0000092494, validation loss: 0.0000059606
# Epoch 390: train loss: 0.0000082859, validation loss: 0.0000085437
# Epoch 391: train loss: 0.0000086820, validation loss: 0.0000110759
# Epoch 392: train loss: 0.0000091482, validation loss: 0.0000087320
# Epoch 393: train loss: 0.0000075138, validation loss: 0.0000041028
# Epoch 394: train loss: 0.0000085703, validation loss: 0.0000066664
# Epoch 395: train loss: 0.0000085457, validation loss: 0.0000041806
# Epoch 396: train loss: 0.0000089613, validation loss: 0.0000035151
# Epoch 397: train loss: 0.0000078152, validation loss: 0.0000080802
# Epoch 398: train loss: 0.0000085876, validation loss: 0.0000070823
# Epoch 399: train loss: 0.0000093183, validation loss: 0.0000245028
# Epoch 400: train loss: 0.0000062784, validation loss: 0.0000056189
# Epoch 401: train loss: 0.0000093231, validation loss: 0.0000046033
# Epoch 402: train loss: 0.0000081185, validation loss: 0.0000085953
# Epoch 403: train loss: 0.0000069807, validation loss: 0.0000085269
# Epoch 404: train loss: 0.0000083975, validation loss: 0.0000081824
# Epoch 405: train loss: 0.0000086603, validation loss: 0.0000155293
# Epoch 406: train loss: 0.0000075071, validation loss: 0.0000067286
# Epoch 407: train loss: 0.0000083816, validation loss: 0.0000089783
# Epoch 408: train loss: 0.0000080266, validation loss: 0.0000048303
# Epoch 409: train loss: 0.0000072198, validation loss: 0.0000095293
# Epoch 410: train loss: 0.0000081818, validation loss: 0.0000096290
# Epoch 411: train loss: 0.0000075948, validation loss: 0.0000087453
# Epoch 412: train loss: 0.0000069115, validation loss: 0.0000041410
# Epoch 413: train loss: 0.0000079518, validation loss: 0.0000032258
# Epoch 414: train loss: 0.0000082076, validation loss: 0.0000186825
# Epoch 415: train loss: 0.0000071176, validation loss: 0.0000072395
# Epoch 416: train loss: 0.0000077820, validation loss: 0.0000049894
# Epoch 417: train loss: 0.0000089867, validation loss: 0.0000072398
# Epoch 418: train loss: 0.0000087468, validation loss: 0.0000034087
# Epoch 419: train loss: 0.0000076344, validation loss: 0.0000043471
# Epoch 420: train loss: 0.0000086802, validation loss: 0.0000024518
# Epoch 421: train loss: 0.0000056766, validation loss: 0.0000069769
# Epoch 422: train loss: 0.0000088942, validation loss: 0.0000085796
# Epoch 423: train loss: 0.0000066750, validation loss: 0.0000074214
# Epoch 424: train loss: 0.0000074105, validation loss: 0.0000184662
# Epoch 425: train loss: 0.0000076858, validation loss: 0.0000052217
# Epoch 426: train loss: 0.0000079925, validation loss: 0.0000114326
# Epoch 427: train loss: 0.0000063921, validation loss: 0.0000074036
# Epoch 428: train loss: 0.0000075147, validation loss: 0.0000047245
# Epoch 429: train loss: 0.0000082076, validation loss: 0.0000093713
# Epoch 430: train loss: 0.0000063138, validation loss: 0.0000092800
# Epoch 431: train loss: 0.0000073833, validation loss: 0.0000047747
# Epoch 432: train loss: 0.0000070354, validation loss: 0.0000073433
# Epoch 433: train loss: 0.0000082986, validation loss: 0.0000080560
# Epoch 434: train loss: 0.0000067113, validation loss: 0.0000041324
# Epoch 435: train loss: 0.0000073539, validation loss: 0.0000157178
# Epoch 436: train loss: 0.0000062177, validation loss: 0.0000034545
# Epoch 437: train loss: 0.0000073788, validation loss: 0.0000046694
# Epoch 438: train loss: 0.0000069305, validation loss: 0.0000047222
# Epoch 439: train loss: 0.0000063258, validation loss: 0.0000078290
# Epoch 440: train loss: 0.0000079037, validation loss: 0.0000042069
# Epoch 441: train loss: 0.0000076670, validation loss: 0.0000034842
# Epoch 442: train loss: 0.0000061979, validation loss: 0.0000075301
# Epoch 443: train loss: 0.0000068185, validation loss: 0.0000075683
# Epoch 444: train loss: 0.0000065646, validation loss: 0.0000072689
# Epoch 445: train loss: 0.0000063193, validation loss: 0.0000035777
# Epoch 446: train loss: 0.0000078542, validation loss: 0.0000049460
# Epoch 447: train loss: 0.0000072373, validation loss: 0.0000030510
# Epoch 448: train loss: 0.0000060882, validation loss: 0.0000031054
# Epoch 449: train loss: 0.0000058388, validation loss: 0.0000080183
# Epoch 450: train loss: 0.0000071693, validation loss: 0.0000032611
# Epoch 451: train loss: 0.0000074146, validation loss: 0.0000226128
# Epoch 452: train loss: 0.0000062878, validation loss: 0.0000041583
# Epoch 453: train loss: 0.0000067116, validation loss: 0.0000044157
# Epoch 454: train loss: 0.0000066966, validation loss: 0.0000073401
# Epoch 455: train loss: 0.0000067395, validation loss: 0.0000044332
# Epoch 456: train loss: 0.0000067774, validation loss: 0.0000121730
# Epoch 457: train loss: 0.0000061922, validation loss: 0.0000058970
# Epoch 458: train loss: 0.0000069682, validation loss: 0.0000042908
# Epoch 459: train loss: 0.0000065007, validation loss: 0.0000060189
# Epoch 460: train loss: 0.0000062277, validation loss: 0.0000053500
# Epoch 461: train loss: 0.0000060632, validation loss: 0.0000054701
# Epoch 462: train loss: 0.0000071115, validation loss: 0.0000057673
# Epoch 463: train loss: 0.0000061643, validation loss: 0.0000061766
# Epoch 464: train loss: 0.0000060757, validation loss: 0.0000035136
# Epoch 465: train loss: 0.0000064244, validation loss: 0.0000166118
# Epoch 466: train loss: 0.0000061505, validation loss: 0.0000149249
# Epoch 467: train loss: 0.0000060228, validation loss: 0.0000073844
# Epoch 468: train loss: 0.0000063450, validation loss: 0.0000075605
# Epoch 469: train loss: 0.0000061538, validation loss: 0.0000077302
# Epoch 470: train loss: 0.0000065491, validation loss: 0.0000034019
# Epoch 471: train loss: 0.0000061628, validation loss: 0.0000037089
# Epoch 472: train loss: 0.0000060067, validation loss: 0.0000318800
# Epoch 473: train loss: 0.0000061665, validation loss: 0.0000107521
# Epoch 474: train loss: 0.0000069926, validation loss: 0.0000049099
# Epoch 475: train loss: 0.0000068347, validation loss: 0.0000174200
# Epoch 476: train loss: 0.0000066906, validation loss: 0.0000031358
# Epoch 477: train loss: 0.0000047774, validation loss: 0.0000049592
# Epoch 478: train loss: 0.0000061244, validation loss: 0.0000038667
# Epoch 479: train loss: 0.0000054610, validation loss: 0.0000212057
# Epoch 480: train loss: 0.0000066912, validation loss: 0.0000048846
# Epoch 481: train loss: 0.0000061456, validation loss: 0.0000040493
# Epoch 482: train loss: 0.0000060009, validation loss: 0.0000043563
# Epoch 483: train loss: 0.0000057959, validation loss: 0.0000047498
# Epoch 484: train loss: 0.0000058711, validation loss: 0.0000047515
# Epoch 485: train loss: 0.0000063365, validation loss: 0.0000024609
# Epoch 486: train loss: 0.0000059541, validation loss: 0.0000068029
# Epoch 487: train loss: 0.0000052590, validation loss: 0.0000045356
# Epoch 488: train loss: 0.0000062426, validation loss: 0.0000032349
# Epoch 489: train loss: 0.0000056443, validation loss: 0.0000022564
# Epoch 490: train loss: 0.0000058530, validation loss: 0.0000288080
# Epoch 491: train loss: 0.0000058412, validation loss: 0.0000121384
# Epoch 492: train loss: 0.0000063542, validation loss: 0.0000028193
# Epoch 493: train loss: 0.0000055423, validation loss: 0.0000026287
# Epoch 494: train loss: 0.0000050244, validation loss: 0.0000053500
# Epoch 495: train loss: 0.0000066833, validation loss: 0.0000084087
# Epoch 496: train loss: 0.0000047505, validation loss: 0.0000038675
# Epoch 497: train loss: 0.0000069851, validation loss: 0.0000030016
# Epoch 498: train loss: 0.0000050559, validation loss: 0.0000023258
# Epoch 499: train loss: 0.0000058600, validation loss: 0.0000085681
# Epoch 500: train loss: 0.0000051606, validation loss: 0.0000034552
# Epoch 501: train loss: 0.0000060169, validation loss: 0.0000038996
# Epoch 502: train loss: 0.0000048797, validation loss: 0.0000029096
# Epoch 503: train loss: 0.0000061064, validation loss: 0.0000035910
# Epoch 504: train loss: 0.0000056545, validation loss: 0.0000035972
# Epoch 505: train loss: 0.0000058972, validation loss: 0.0000027144
# Epoch 506: train loss: 0.0000053868, validation loss: 0.0000037763
# Epoch 507: train loss: 0.0000057968, validation loss: 0.0000083661
# Epoch 508: train loss: 0.0000050968, validation loss: 0.0000024533
# Epoch 509: train loss: 0.0000055889, validation loss: 0.0000025417
# Epoch 510: train loss: 0.0000060584, validation loss: 0.0000172162
# Epoch 511: train loss: 0.0000047618, validation loss: 0.0000096278
# Epoch 512: train loss: 0.0000057911, validation loss: 0.0000038987
# Epoch 513: train loss: 0.0000048128, validation loss: 0.0000032160
# Epoch 514: train loss: 0.0000055376, validation loss: 0.0000038311
# Epoch 515: train loss: 0.0000048927, validation loss: 0.0000072207
# Epoch 516: train loss: 0.0000059110, validation loss: 0.0000033655
# Epoch 517: train loss: 0.0000051137, validation loss: 0.0000040193
# Epoch 518: train loss: 0.0000051503, validation loss: 0.0000089221
# Epoch 519: train loss: 0.0000056258, validation loss: 0.0000023218
# Epoch 520: train loss: 0.0000054433, validation loss: 0.0000038029
# Epoch 521: train loss: 0.0000053559, validation loss: 0.0000067249
# Epoch 522: train loss: 0.0000049564, validation loss: 0.0000055806
# Epoch 523: train loss: 0.0000055395, validation loss: 0.0000108552
# Epoch 524: train loss: 0.0000049721, validation loss: 0.0000043626
# Epoch 525: train loss: 0.0000056459, validation loss: 0.0000104240
# Epoch 526: train loss: 0.0000046935, validation loss: 0.0000033520
# Epoch 527: train loss: 0.0000053314, validation loss: 0.0000145519
# Epoch 528: train loss: 0.0000050500, validation loss: 0.0000051478
# Epoch 529: train loss: 0.0000051453, validation loss: 0.0000047030
# Epoch 530: train loss: 0.0000047710, validation loss: 0.0000046661
# Epoch 531: train loss: 0.0000047365, validation loss: 0.0000034998
# Epoch 532: train loss: 0.0000050374, validation loss: 0.0000191909
# Epoch 533: train loss: 0.0000055067, validation loss: 0.0000034170
# Epoch 534: train loss: 0.0000055611, validation loss: 0.0000689794
# Epoch 535: train loss: 0.0000052177, validation loss: 0.0000052967
# Epoch 536: train loss: 0.0000052207, validation loss: 0.0000035549
# Epoch 537: train loss: 0.0000042279, validation loss: 0.0000117625
# Epoch 538: train loss: 0.0000057229, validation loss: 0.0000035070
# Epoch 539: train loss: 0.0000046212, validation loss: 0.0000034551
# Epoch 540: train loss: 0.0000046606, validation loss: 0.0000032367
# Epoch 541: train loss: 0.0000047940, validation loss: 0.0000045453
# Epoch 542: train loss: 0.0000046040, validation loss: 0.0000031671
# Epoch 543: train loss: 0.0000050174, validation loss: 0.0000052545
# Epoch 544: train loss: 0.0000047866, validation loss: 0.0000040658
# Epoch 545: train loss: 0.0000055025, validation loss: 0.0000047874
# Epoch 546: train loss: 0.0000050374, validation loss: 0.0000019815
# Epoch 547: train loss: 0.0000042266, validation loss: 0.0000038568
# Epoch 548: train loss: 0.0000050599, validation loss: 0.0000063653
# Epoch 549: train loss: 0.0000065627, validation loss: 0.0000021432
# Epoch 550: train loss: 0.0000038900, validation loss: 0.0000064634
# Epoch 551: train loss: 0.0000044937, validation loss: 0.0000061629
# Epoch 552: train loss: 0.0000049577, validation loss: 0.0000039634
# Epoch 553: train loss: 0.0000043378, validation loss: 0.0000039186
# Epoch 554: train loss: 0.0000048843, validation loss: 0.0000025722
# Epoch 555: train loss: 0.0000050369, validation loss: 0.0000032715
# Epoch 556: train loss: 0.0000045146, validation loss: 0.0000029178
# Epoch 557: train loss: 0.0000045595, validation loss: 0.0000092387
# Epoch 558: train loss: 0.0000051538, validation loss: 0.0000058626
# Epoch 559: train loss: 0.0000041803, validation loss: 0.0000068027
# Epoch 560: train loss: 0.0000044125, validation loss: 0.0000022386
# Epoch 561: train loss: 0.0000051979, validation loss: 0.0000020375
# Epoch 562: train loss: 0.0000044547, validation loss: 0.0000070461
# Epoch 563: train loss: 0.0000052051, validation loss: 0.0000096851
# Epoch 564: train loss: 0.0000039793, validation loss: 0.0000050938
# Epoch 565: train loss: 0.0000040350, validation loss: 0.0000025777
# Epoch 566: train loss: 0.0000045481, validation loss: 0.0000030858
# Epoch 567: train loss: 0.0000049122, validation loss: 0.0000018150
# Epoch 568: train loss: 0.0000047485, validation loss: 0.0000017138
# Epoch 569: train loss: 0.0000039385, validation loss: 0.0000024379
# Epoch 570: train loss: 0.0000057036, validation loss: 0.0000229159
# Epoch 571: train loss: 0.0000040829, validation loss: 0.0000035899
# Epoch 572: train loss: 0.0000045686, validation loss: 0.0000025386
# Epoch 573: train loss: 0.0000051189, validation loss: 0.0000059152
# Epoch 574: train loss: 0.0000041282, validation loss: 0.0000072048
# Epoch 575: train loss: 0.0000042270, validation loss: 0.0000090903
# Epoch 576: train loss: 0.0000046437, validation loss: 0.0000065871
# Epoch 577: train loss: 0.0000044938, validation loss: 0.0000075077
# Epoch 578: train loss: 0.0000052254, validation loss: 0.0000047792
# Epoch 579: train loss: 0.0000041932, validation loss: 0.0000021638
# Epoch 580: train loss: 0.0000048876, validation loss: 0.0000018410
# Epoch 581: train loss: 0.0000036098, validation loss: 0.0000027654
# Epoch 582: train loss: 0.0000045621, validation loss: 0.0000082294
# Epoch 583: train loss: 0.0000044372, validation loss: 0.0000041879
# Epoch 584: train loss: 0.0000041025, validation loss: 0.0000021882
# Epoch 585: train loss: 0.0000048203, validation loss: 0.0000020266
# Epoch 586: train loss: 0.0000041841, validation loss: 0.0000090889
# Epoch 587: train loss: 0.0000038962, validation loss: 0.0000029990
# Epoch 588: train loss: 0.0000049197, validation loss: 0.0000017540
# Epoch 589: train loss: 0.0000036973, validation loss: 0.0000026527
# Epoch 590: train loss: 0.0000046672, validation loss: 0.0000052738
# Epoch 591: train loss: 0.0000038713, validation loss: 0.0000028117
# Epoch 592: train loss: 0.0000041260, validation loss: 0.0000089367
# Epoch 593: train loss: 0.0000045923, validation loss: 0.0000030804
# Epoch 594: train loss: 0.0000039131, validation loss: 0.0000019175
# Epoch 595: train loss: 0.0000045618, validation loss: 0.0000029190
# Epoch 596: train loss: 0.0000051215, validation loss: 0.0000078107
# Epoch 597: train loss: 0.0000043769, validation loss: 0.0000019303
# Epoch 598: train loss: 0.0000036550, validation loss: 0.0000054048
# Epoch 599: train loss: 0.0000041779, validation loss: 0.0000042588
# Epoch 600: train loss: 0.0000041957, validation loss: 0.0000024581
# Finished Training

# %% [markdown]
# ***Learning Curves***

# %%
train_loss = [l[0] for l in model_koop_dnn.train_loss_hist]
train_pred_loss = [l[1] for l in model_koop_dnn.train_loss_hist]
train_lifted_loss = [l[2] for l in model_koop_dnn.train_loss_hist]
val_loss = [l[0] for l in model_koop_dnn.val_loss_hist]
val_pred_loss = [l[1] for l in model_koop_dnn.val_loss_hist]
val_lifted_loss = [l[2] for l in model_koop_dnn.val_loss_hist]
epochs = np.arange(0, net_params['epochs'])

plt.figure(figsize=(15,8))
plt.plot(epochs, train_loss, color='tab:orange', label='Training loss')
plt.plot(epochs, train_pred_loss, '--', color='tab:orange', label='Training prediction loss')
plt.plot(epochs, train_lifted_loss, ':', color='tab:orange', label='Training lifted loss')
plt.plot(epochs, val_loss, color='tab:blue', label='Validation loss')
plt.plot(epochs, val_pred_loss, '--', color='tab:blue', label='Validation prediction loss')
plt.plot(epochs, val_lifted_loss, ':', color='tab:blue', label='Validation lifted loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale('log')
plt.savefig("convergence plot for arch1")
plt.show()

# %%
map_net_params = {}
map_net_params["input_dim"] = int(num_joints) #number of joint angles
map_net_params["output_dim"] = X_end.shape[2] #x and y position of the end effector
map_net_params["hidden_width"] = 20 #20
map_net_params["hidden_depth"] = 4  #2
map_net_params["batch_size"] = 128  #100
map_net_params["epochs"] = 500   # 500
map_net_params["activation_type"] = 'tanh'
map_net_params["lr"] = 1e-3     #1e-3
map_net_params["optimizer"] = 'adam'
map_net_params['l2_reg'] = 0.0
map_net_params['l1_reg'] = 0.0

# %%
#dataset
# split training and vaidation datasets
xs_map_train, ys_map_train = X_fw[:num_train,:,:int(num_joints)],X_end_fw[:num_train,:,:num_inputs]
xs_map_val, ys_map_val = X_fw[num_train:,:,:int(num_joints)],X_end_fw[num_train:,:,:num_inputs]

# %%
ys_map_train.shape, ys_map_val.shape,xs_map_train.shape, xs_map_val.shape
# Out:
# ((150, 1000, 2), (50, 1000, 2), (150, 1000, 3), (50, 1000, 3))

# %%
#Initalize network
#Initalize network

if mass_var == True:
    file_fwd = 'saved_models/'+ robot_type +'/map_net_con_mass_var.pth' 
else:
    file_fwd = 'saved_models/'+ robot_type +'/map_net_con.pth'

if train == True:
    map_net = map_Net(map_net_params)
    map_net.set_dataset_map(xs_map_train,ys_map_train,xs_map_val,ys_map_val)
    map_net.data_pipeline()
    torch.save(map_net,file_fwd)
else:
    map_net = torch.load(file_fwd)
# Out:
# Epoch   1: train loss: 0.0357923943, validation loss: 0.0057662185
# Epoch   2: train loss: 0.0039980863, validation loss: 0.0028009160
# Epoch   3: train loss: 0.0023030365, validation loss: 0.0018463255
# Epoch   4: train loss: 0.0015863292, validation loss: 0.0012911173
# Epoch   5: train loss: 0.0012252681, validation loss: 0.0011201916
# Epoch   6: train loss: 0.0010079131, validation loss: 0.0009816085
# Epoch   7: train loss: 0.0008581242, validation loss: 0.0008339413
# Epoch   8: train loss: 0.0007576901, validation loss: 0.0007728074
# Epoch   9: train loss: 0.0006723127, validation loss: 0.0005618794
# Epoch  10: train loss: 0.0005937318, validation loss: 0.0006086037
# Epoch  11: train loss: 0.0005360949, validation loss: 0.0004561471
# Epoch  12: train loss: 0.0005016848, validation loss: 0.0004939842
# Epoch  13: train loss: 0.0004481740, validation loss: 0.0004981311
# Epoch  14: train loss: 0.0004341302, validation loss: 0.0004647871
# Epoch  15: train loss: 0.0003976126, validation loss: 0.0005513043
# Epoch  16: train loss: 0.0003687810, validation loss: 0.0004560832
# Epoch  17: train loss: 0.0003458875, validation loss: 0.0004013809
# Epoch  18: train loss: 0.0003322104, validation loss: 0.0002814538
# Epoch  19: train loss: 0.0003135722, validation loss: 0.0002415299
# Epoch  20: train loss: 0.0002935332, validation loss: 0.0002556454
# Epoch  21: train loss: 0.0002786285, validation loss: 0.0003162508
# Epoch  22: train loss: 0.0002681730, validation loss: 0.0004813803
# Epoch  23: train loss: 0.0002482501, validation loss: 0.0002207791
# Epoch  24: train loss: 0.0002370768, validation loss: 0.0002078463
# Epoch  25: train loss: 0.0002266276, validation loss: 0.0002490257
# Epoch  26: train loss: 0.0002164391, validation loss: 0.0001796340
# Epoch  27: train loss: 0.0001968994, validation loss: 0.0001803133
# Epoch  28: train loss: 0.0001925431, validation loss: 0.0001711385
# Epoch  29: train loss: 0.0001914286, validation loss: 0.0001589546
# Epoch  30: train loss: 0.0001773878, validation loss: 0.0002547246
# Epoch  31: train loss: 0.0001707307, validation loss: 0.0001442578
# Epoch  32: train loss: 0.0001638240, validation loss: 0.0002247682
# Epoch  33: train loss: 0.0001547931, validation loss: 0.0001354913
# Epoch  34: train loss: 0.0001526202, validation loss: 0.0001312480
# Epoch  35: train loss: 0.0001481787, validation loss: 0.0002410139
# Epoch  36: train loss: 0.0001395758, validation loss: 0.0001233226
# Epoch  37: train loss: 0.0001377936, validation loss: 0.0001168848
# Epoch  38: train loss: 0.0001270889, validation loss: 0.0000964964
# Epoch  39: train loss: 0.0001308232, validation loss: 0.0001179351
# Epoch  40: train loss: 0.0001211489, validation loss: 0.0000883620
# Epoch  41: train loss: 0.0001201928, validation loss: 0.0000954037
# Epoch  42: train loss: 0.0001156629, validation loss: 0.0001326722
# Epoch  43: train loss: 0.0001087084, validation loss: 0.0000761810
# Epoch  44: train loss: 0.0001161956, validation loss: 0.0000830987
# Epoch  45: train loss: 0.0001045695, validation loss: 0.0000751047
# Epoch  46: train loss: 0.0001034258, validation loss: 0.0001271301
# Epoch  47: train loss: 0.0000950112, validation loss: 0.0000731404
# Epoch  48: train loss: 0.0000981452, validation loss: 0.0000779505
# Epoch  49: train loss: 0.0000881733, validation loss: 0.0000845340
# Epoch  50: train loss: 0.0000929500, validation loss: 0.0000888000
# Epoch  51: train loss: 0.0000869680, validation loss: 0.0000620218
# Epoch  52: train loss: 0.0000826841, validation loss: 0.0001163626
# Epoch  53: train loss: 0.0000793069, validation loss: 0.0000737357
# Epoch  54: train loss: 0.0000787614, validation loss: 0.0000640445
# Epoch  55: train loss: 0.0000763071, validation loss: 0.0000890493
# Epoch  56: train loss: 0.0000785846, validation loss: 0.0000472197
# Epoch  57: train loss: 0.0000752401, validation loss: 0.0000752835
# Epoch  58: train loss: 0.0000737500, validation loss: 0.0001063454
# Epoch  59: train loss: 0.0000703304, validation loss: 0.0000779918
# Epoch  60: train loss: 0.0000704437, validation loss: 0.0000730333
# Epoch  61: train loss: 0.0000652243, validation loss: 0.0000631302
# Epoch  62: train loss: 0.0000704227, validation loss: 0.0000532949
# Epoch  63: train loss: 0.0000629458, validation loss: 0.0000382482
# Epoch  64: train loss: 0.0000651986, validation loss: 0.0000438846
# Epoch  65: train loss: 0.0000634736, validation loss: 0.0000591087
# Epoch  66: train loss: 0.0000602216, validation loss: 0.0000631785
# Epoch  67: train loss: 0.0000596660, validation loss: 0.0000565200
# Epoch  68: train loss: 0.0000591339, validation loss: 0.0000600905
# Epoch  69: train loss: 0.0000579267, validation loss: 0.0000640882
# Epoch  70: train loss: 0.0000560616, validation loss: 0.0000377819
# Epoch  71: train loss: 0.0000534734, validation loss: 0.0000939809
# Epoch  72: train loss: 0.0000538419, validation loss: 0.0000727286
# Epoch  73: train loss: 0.0000549830, validation loss: 0.0000580564
# Epoch  74: train loss: 0.0000517535, validation loss: 0.0000851802
# Epoch  75: train loss: 0.0000505317, validation loss: 0.0000335374
# Epoch  76: train loss: 0.0000496711, validation loss: 0.0000489908
# Epoch  77: train loss: 0.0000526871, validation loss: 0.0000393945
# Epoch  78: train loss: 0.0000490482, validation loss: 0.0000684517
# Epoch  79: train loss: 0.0000486866, validation loss: 0.0000394925
# Epoch  80: train loss: 0.0000467598, validation loss: 0.0000328136
# Epoch  81: train loss: 0.0000491125, validation loss: 0.0000304015
# Epoch  82: train loss: 0.0000437140, validation loss: 0.0000358869
# Epoch  83: train loss: 0.0000456470, validation loss: 0.0000464743
# Epoch  84: train loss: 0.0000472752, validation loss: 0.0000276083
# Epoch  85: train loss: 0.0000432006, validation loss: 0.0000320708
# Epoch  86: train loss: 0.0000474942, validation loss: 0.0000364755
# Epoch  87: train loss: 0.0000444296, validation loss: 0.0000466262
# Epoch  88: train loss: 0.0000430620, validation loss: 0.0000244139
# Epoch  89: train loss: 0.0000435606, validation loss: 0.0000322449
# Epoch  90: train loss: 0.0000421115, validation loss: 0.0000367173
# Epoch  91: train loss: 0.0000430038, validation loss: 0.0000301665
# Epoch  92: train loss: 0.0000386144, validation loss: 0.0000320022
# Epoch  93: train loss: 0.0000411111, validation loss: 0.0000389859
# Epoch  94: train loss: 0.0000418669, validation loss: 0.0000274789
# Epoch  95: train loss: 0.0000392252, validation loss: 0.0000321076
# Epoch  96: train loss: 0.0000381222, validation loss: 0.0000403149
# Epoch  97: train loss: 0.0000387798, validation loss: 0.0000238767
# Epoch  98: train loss: 0.0000388644, validation loss: 0.0000543068
# Epoch  99: train loss: 0.0000396769, validation loss: 0.0000297197
# Epoch 100: train loss: 0.0000364173, validation loss: 0.0000398990
# Epoch 101: train loss: 0.0000344934, validation loss: 0.0000458941
# Epoch 102: train loss: 0.0000389740, validation loss: 0.0000262260
# Epoch 103: train loss: 0.0000376980, validation loss: 0.0000426075
# Epoch 104: train loss: 0.0000336342, validation loss: 0.0000405535
# Epoch 105: train loss: 0.0000360079, validation loss: 0.0000380195
# Epoch 106: train loss: 0.0000349056, validation loss: 0.0000254837
# Epoch 107: train loss: 0.0000365041, validation loss: 0.0000292077
# Epoch 108: train loss: 0.0000327261, validation loss: 0.0000278381
# Epoch 109: train loss: 0.0000336138, validation loss: 0.0000183691
# Epoch 110: train loss: 0.0000328896, validation loss: 0.0000280581
# Epoch 111: train loss: 0.0000309965, validation loss: 0.0000323335
# Epoch 112: train loss: 0.0000337290, validation loss: 0.0000393539
# Epoch 113: train loss: 0.0000333494, validation loss: 0.0000444553
# Epoch 114: train loss: 0.0000308815, validation loss: 0.0000374884
# Epoch 115: train loss: 0.0000338722, validation loss: 0.0000604267
# Epoch 116: train loss: 0.0000299073, validation loss: 0.0000238892
# Epoch 117: train loss: 0.0000317535, validation loss: 0.0000254927
# Epoch 118: train loss: 0.0000336498, validation loss: 0.0000139340
# Epoch 119: train loss: 0.0000277675, validation loss: 0.0000371115
# Epoch 120: train loss: 0.0000299730, validation loss: 0.0000199080
# Epoch 121: train loss: 0.0000288796, validation loss: 0.0000201503
# Epoch 122: train loss: 0.0000285438, validation loss: 0.0000371108
# Epoch 123: train loss: 0.0000296486, validation loss: 0.0000438963
# Epoch 124: train loss: 0.0000287424, validation loss: 0.0000424981
# Epoch 125: train loss: 0.0000287167, validation loss: 0.0000256726
# Epoch 126: train loss: 0.0000284163, validation loss: 0.0000183440
# Epoch 127: train loss: 0.0000286814, validation loss: 0.0000227317
# Epoch 128: train loss: 0.0000267006, validation loss: 0.0000286114
# Epoch 129: train loss: 0.0000282700, validation loss: 0.0000411910
# Epoch 130: train loss: 0.0000286613, validation loss: 0.0000206002
# Epoch 131: train loss: 0.0000265312, validation loss: 0.0000276928
# Epoch 132: train loss: 0.0000263238, validation loss: 0.0000281996
# Epoch 133: train loss: 0.0000282672, validation loss: 0.0000284203
# Epoch 134: train loss: 0.0000281529, validation loss: 0.0000478251
# Epoch 135: train loss: 0.0000243985, validation loss: 0.0000210749
# Epoch 136: train loss: 0.0000251928, validation loss: 0.0000170382
# Epoch 137: train loss: 0.0000271492, validation loss: 0.0000195525
# Epoch 138: train loss: 0.0000237397, validation loss: 0.0000238495
# Epoch 139: train loss: 0.0000268892, validation loss: 0.0000811719
# Epoch 140: train loss: 0.0000224873, validation loss: 0.0000171363
# Epoch 141: train loss: 0.0000252956, validation loss: 0.0000300804
# Epoch 142: train loss: 0.0000239774, validation loss: 0.0000198606
# Epoch 143: train loss: 0.0000228413, validation loss: 0.0000180441
# Epoch 144: train loss: 0.0000241365, validation loss: 0.0000166169
# Epoch 145: train loss: 0.0000254104, validation loss: 0.0001005623
# Epoch 146: train loss: 0.0000233615, validation loss: 0.0000602302
# Epoch 147: train loss: 0.0000236350, validation loss: 0.0000151298
# Epoch 148: train loss: 0.0000228720, validation loss: 0.0000407763
# Epoch 149: train loss: 0.0000221785, validation loss: 0.0000162340
# Epoch 150: train loss: 0.0000225189, validation loss: 0.0000240123
# Epoch 151: train loss: 0.0000203406, validation loss: 0.0000190607
# Epoch 152: train loss: 0.0000239239, validation loss: 0.0000177298
# Epoch 153: train loss: 0.0000216631, validation loss: 0.0000215321
# Epoch 154: train loss: 0.0000217563, validation loss: 0.0000098352
# Epoch 155: train loss: 0.0000211883, validation loss: 0.0000209251
# Epoch 156: train loss: 0.0000217014, validation loss: 0.0000147949
# Epoch 157: train loss: 0.0000209954, validation loss: 0.0000234667
# Epoch 158: train loss: 0.0000205417, validation loss: 0.0000261261
# Epoch 159: train loss: 0.0000193457, validation loss: 0.0000217331
# Epoch 160: train loss: 0.0000199686, validation loss: 0.0000271358
# Epoch 161: train loss: 0.0000197509, validation loss: 0.0000327730
# Epoch 162: train loss: 0.0000201316, validation loss: 0.0000157807
# Epoch 163: train loss: 0.0000192563, validation loss: 0.0000206194
# Epoch 164: train loss: 0.0000211249, validation loss: 0.0000144071
# Epoch 165: train loss: 0.0000215980, validation loss: 0.0000103796
# Epoch 166: train loss: 0.0000190868, validation loss: 0.0000329846
# Epoch 167: train loss: 0.0000198514, validation loss: 0.0000148071
# Epoch 168: train loss: 0.0000187033, validation loss: 0.0000098423
# Epoch 169: train loss: 0.0000180074, validation loss: 0.0000233665
# Epoch 170: train loss: 0.0000193223, validation loss: 0.0000154504
# Epoch 171: train loss: 0.0000206438, validation loss: 0.0000084912
# Epoch 172: train loss: 0.0000193546, validation loss: 0.0000178240
# Epoch 173: train loss: 0.0000164594, validation loss: 0.0000221570
# Epoch 174: train loss: 0.0000193521, validation loss: 0.0000413733
# Epoch 175: train loss: 0.0000183770, validation loss: 0.0000177667
# Epoch 176: train loss: 0.0000180601, validation loss: 0.0000120564
# Epoch 177: train loss: 0.0000176237, validation loss: 0.0000289372
# Epoch 178: train loss: 0.0000186764, validation loss: 0.0000124412
# Epoch 179: train loss: 0.0000173208, validation loss: 0.0000399297
# Epoch 180: train loss: 0.0000180695, validation loss: 0.0000099555
# Epoch 181: train loss: 0.0000175927, validation loss: 0.0000270354
# Epoch 182: train loss: 0.0000174250, validation loss: 0.0000274525
# Epoch 183: train loss: 0.0000173472, validation loss: 0.0000138195
# Epoch 184: train loss: 0.0000165323, validation loss: 0.0000249656
# Epoch 185: train loss: 0.0000186526, validation loss: 0.0000123314
# Epoch 186: train loss: 0.0000167363, validation loss: 0.0000162070
# Epoch 187: train loss: 0.0000173685, validation loss: 0.0000097995
# Epoch 188: train loss: 0.0000170567, validation loss: 0.0000341302
# Epoch 189: train loss: 0.0000169764, validation loss: 0.0000119030
# Epoch 190: train loss: 0.0000164778, validation loss: 0.0000190872
# Epoch 191: train loss: 0.0000177564, validation loss: 0.0000225161
# Epoch 192: train loss: 0.0000172753, validation loss: 0.0000109798
# Epoch 193: train loss: 0.0000168186, validation loss: 0.0000081362
# Epoch 194: train loss: 0.0000159022, validation loss: 0.0000108548
# Epoch 195: train loss: 0.0000156276, validation loss: 0.0000196161
# Epoch 196: train loss: 0.0000164261, validation loss: 0.0000125007
# Epoch 197: train loss: 0.0000153555, validation loss: 0.0000135675
# Epoch 198: train loss: 0.0000175122, validation loss: 0.0000091456
# Epoch 199: train loss: 0.0000152579, validation loss: 0.0000117918
# Epoch 200: train loss: 0.0000164885, validation loss: 0.0000078375
# Epoch 201: train loss: 0.0000152360, validation loss: 0.0000156723
# Epoch 202: train loss: 0.0000170757, validation loss: 0.0000176829
# Epoch 203: train loss: 0.0000163429, validation loss: 0.0000248296
# Epoch 204: train loss: 0.0000146180, validation loss: 0.0000167128
# Epoch 205: train loss: 0.0000157741, validation loss: 0.0000091360
# Epoch 206: train loss: 0.0000148264, validation loss: 0.0000120185
# Epoch 207: train loss: 0.0000153343, validation loss: 0.0000138092
# Epoch 208: train loss: 0.0000148146, validation loss: 0.0000125827
# Epoch 209: train loss: 0.0000164248, validation loss: 0.0000236531
# Epoch 210: train loss: 0.0000147671, validation loss: 0.0000119000
# Epoch 211: train loss: 0.0000156677, validation loss: 0.0000608685
# Epoch 212: train loss: 0.0000167195, validation loss: 0.0000084366
# Epoch 213: train loss: 0.0000143190, validation loss: 0.0000172740
# Epoch 214: train loss: 0.0000152884, validation loss: 0.0000144513
# Epoch 215: train loss: 0.0000153669, validation loss: 0.0000249666
# Epoch 216: train loss: 0.0000139707, validation loss: 0.0000072730
# Epoch 217: train loss: 0.0000154598, validation loss: 0.0000083436
# Epoch 218: train loss: 0.0000149743, validation loss: 0.0000088195
# Epoch 219: train loss: 0.0000140283, validation loss: 0.0000273819
# Epoch 220: train loss: 0.0000147946, validation loss: 0.0000091815
# Epoch 221: train loss: 0.0000146032, validation loss: 0.0000163759
# Epoch 222: train loss: 0.0000154139, validation loss: 0.0000106865
# Epoch 223: train loss: 0.0000144227, validation loss: 0.0000133517
# Epoch 224: train loss: 0.0000144585, validation loss: 0.0000159959
# Epoch 225: train loss: 0.0000147414, validation loss: 0.0000102232
# Epoch 226: train loss: 0.0000142004, validation loss: 0.0000232366
# Epoch 227: train loss: 0.0000139730, validation loss: 0.0000148825
# Epoch 228: train loss: 0.0000139298, validation loss: 0.0000087234
# Epoch 229: train loss: 0.0000155338, validation loss: 0.0000233568
# Epoch 230: train loss: 0.0000142837, validation loss: 0.0000065931
# Epoch 231: train loss: 0.0000130371, validation loss: 0.0000210657
# Epoch 232: train loss: 0.0000138838, validation loss: 0.0000765472
# Epoch 233: train loss: 0.0000147050, validation loss: 0.0000115036
# Epoch 234: train loss: 0.0000140060, validation loss: 0.0000106342
# Epoch 235: train loss: 0.0000145372, validation loss: 0.0000152228
# Epoch 236: train loss: 0.0000137839, validation loss: 0.0000076017
# Epoch 237: train loss: 0.0000135745, validation loss: 0.0000197524
# Epoch 238: train loss: 0.0000143722, validation loss: 0.0000067112
# Epoch 239: train loss: 0.0000149081, validation loss: 0.0000176566
# Epoch 240: train loss: 0.0000128018, validation loss: 0.0000131709
# Epoch 241: train loss: 0.0000134495, validation loss: 0.0000116712
# Epoch 242: train loss: 0.0000138399, validation loss: 0.0000135531
# Epoch 243: train loss: 0.0000131487, validation loss: 0.0000081209
# Epoch 244: train loss: 0.0000134703, validation loss: 0.0000151683
# Epoch 245: train loss: 0.0000142641, validation loss: 0.0000150331
# Epoch 246: train loss: 0.0000133048, validation loss: 0.0000134037
# Epoch 247: train loss: 0.0000136754, validation loss: 0.0000061667
# Epoch 248: train loss: 0.0000130583, validation loss: 0.0000172330
# Epoch 249: train loss: 0.0000133129, validation loss: 0.0000096565
# Epoch 250: train loss: 0.0000135985, validation loss: 0.0000098813
# Epoch 251: train loss: 0.0000133867, validation loss: 0.0000076809
# Epoch 252: train loss: 0.0000140434, validation loss: 0.0000075219
# Epoch 253: train loss: 0.0000122294, validation loss: 0.0000147026
# Epoch 254: train loss: 0.0000134893, validation loss: 0.0000094789
# Epoch 255: train loss: 0.0000135401, validation loss: 0.0000124975
# Epoch 256: train loss: 0.0000147866, validation loss: 0.0000081598
# Epoch 257: train loss: 0.0000123201, validation loss: 0.0000119646
# Epoch 258: train loss: 0.0000122999, validation loss: 0.0000185327
# Epoch 259: train loss: 0.0000128052, validation loss: 0.0000117061
# Epoch 260: train loss: 0.0000138161, validation loss: 0.0000065780
# Epoch 261: train loss: 0.0000126187, validation loss: 0.0000147411
# Epoch 262: train loss: 0.0000125195, validation loss: 0.0000127870
# Epoch 263: train loss: 0.0000146707, validation loss: 0.0000073947
# Epoch 264: train loss: 0.0000132863, validation loss: 0.0000217902
# Epoch 265: train loss: 0.0000127631, validation loss: 0.0000219775
# Epoch 266: train loss: 0.0000136149, validation loss: 0.0000067840
# Epoch 267: train loss: 0.0000116161, validation loss: 0.0000072466
# Epoch 268: train loss: 0.0000128345, validation loss: 0.0000079995
# Epoch 269: train loss: 0.0000127352, validation loss: 0.0000218014
# Epoch 270: train loss: 0.0000126825, validation loss: 0.0000104648
# Epoch 271: train loss: 0.0000127339, validation loss: 0.0000082199
# Epoch 272: train loss: 0.0000129685, validation loss: 0.0000249798
# Epoch 273: train loss: 0.0000133472, validation loss: 0.0000124909
# Epoch 274: train loss: 0.0000130323, validation loss: 0.0000073017
# Epoch 275: train loss: 0.0000115216, validation loss: 0.0000145107
# Epoch 276: train loss: 0.0000136683, validation loss: 0.0000057096
# Epoch 277: train loss: 0.0000131314, validation loss: 0.0000101302
# Epoch 278: train loss: 0.0000133022, validation loss: 0.0000093635
# Epoch 279: train loss: 0.0000125068, validation loss: 0.0000082206
# Epoch 280: train loss: 0.0000114858, validation loss: 0.0000088691
# Epoch 281: train loss: 0.0000136269, validation loss: 0.0000111159
# Epoch 282: train loss: 0.0000121879, validation loss: 0.0000064712
# Epoch 283: train loss: 0.0000117462, validation loss: 0.0000078217
# Epoch 284: train loss: 0.0000130741, validation loss: 0.0000115589
# Epoch 285: train loss: 0.0000123107, validation loss: 0.0000229454
# Epoch 286: train loss: 0.0000124056, validation loss: 0.0000066128
# Epoch 287: train loss: 0.0000117302, validation loss: 0.0000118585
# Epoch 288: train loss: 0.0000119711, validation loss: 0.0000157732
# Epoch 289: train loss: 0.0000134338, validation loss: 0.0000092987
# Epoch 290: train loss: 0.0000114706, validation loss: 0.0000077932
# Epoch 291: train loss: 0.0000117546, validation loss: 0.0000069188
# Epoch 292: train loss: 0.0000121446, validation loss: 0.0000111681
# Epoch 293: train loss: 0.0000131502, validation loss: 0.0000098114
# Epoch 294: train loss: 0.0000106582, validation loss: 0.0000092421
# Epoch 295: train loss: 0.0000117448, validation loss: 0.0000055621
# Epoch 296: train loss: 0.0000123761, validation loss: 0.0000078701
# Epoch 297: train loss: 0.0000112351, validation loss: 0.0000083934
# Epoch 298: train loss: 0.0000128108, validation loss: 0.0000080174
# Epoch 299: train loss: 0.0000123585, validation loss: 0.0000077268
# Epoch 300: train loss: 0.0000120538, validation loss: 0.0000107463
# Epoch 301: train loss: 0.0000111752, validation loss: 0.0000157753
# Epoch 302: train loss: 0.0000108283, validation loss: 0.0000084636
# Epoch 303: train loss: 0.0000128323, validation loss: 0.0000208612
# Epoch 304: train loss: 0.0000118569, validation loss: 0.0000089285
# Epoch 305: train loss: 0.0000118560, validation loss: 0.0000167054
# Epoch 306: train loss: 0.0000125620, validation loss: 0.0000178152
# Epoch 307: train loss: 0.0000119449, validation loss: 0.0000096168
# Epoch 308: train loss: 0.0000120734, validation loss: 0.0000046165
# Epoch 309: train loss: 0.0000130875, validation loss: 0.0000416072
# Epoch 310: train loss: 0.0000100611, validation loss: 0.0000245730
# Epoch 311: train loss: 0.0000113721, validation loss: 0.0000067779
# Epoch 312: train loss: 0.0000113437, validation loss: 0.0000163892
# Epoch 313: train loss: 0.0000119922, validation loss: 0.0000101581
# Epoch 314: train loss: 0.0000113951, validation loss: 0.0000159358
# Epoch 315: train loss: 0.0000111223, validation loss: 0.0000134790
# Epoch 316: train loss: 0.0000119342, validation loss: 0.0000104874
# Epoch 317: train loss: 0.0000105757, validation loss: 0.0000103388
# Epoch 318: train loss: 0.0000118743, validation loss: 0.0000094655
# Epoch 319: train loss: 0.0000115017, validation loss: 0.0000301763
# Epoch 320: train loss: 0.0000110265, validation loss: 0.0000070397
# Epoch 321: train loss: 0.0000104667, validation loss: 0.0000139450
# Epoch 322: train loss: 0.0000116760, validation loss: 0.0000115553
# Epoch 323: train loss: 0.0000104622, validation loss: 0.0000075117
# Epoch 324: train loss: 0.0000118234, validation loss: 0.0000126768
# Epoch 325: train loss: 0.0000111535, validation loss: 0.0000076612
# Epoch 326: train loss: 0.0000116171, validation loss: 0.0000086486
# Epoch 327: train loss: 0.0000098579, validation loss: 0.0000160369
# Epoch 328: train loss: 0.0000113364, validation loss: 0.0000199992
# Epoch 329: train loss: 0.0000107776, validation loss: 0.0000111564
# Epoch 330: train loss: 0.0000118931, validation loss: 0.0000097852
# Epoch 331: train loss: 0.0000108830, validation loss: 0.0000081487
# Epoch 332: train loss: 0.0000108128, validation loss: 0.0000136207
# Epoch 333: train loss: 0.0000107209, validation loss: 0.0000062995
# Epoch 334: train loss: 0.0000105775, validation loss: 0.0000106225
# Epoch 335: train loss: 0.0000114590, validation loss: 0.0000077904
# Epoch 336: train loss: 0.0000097970, validation loss: 0.0000053543
# Epoch 337: train loss: 0.0000105696, validation loss: 0.0000119031
# Epoch 338: train loss: 0.0000117992, validation loss: 0.0000168358
# Epoch 339: train loss: 0.0000104794, validation loss: 0.0000077762
# Epoch 340: train loss: 0.0000110804, validation loss: 0.0000175691
# Epoch 341: train loss: 0.0000105061, validation loss: 0.0000101168
# Epoch 342: train loss: 0.0000116107, validation loss: 0.0000110486
# Epoch 343: train loss: 0.0000109931, validation loss: 0.0000121155
# Epoch 344: train loss: 0.0000101701, validation loss: 0.0000064728
# Epoch 345: train loss: 0.0000107859, validation loss: 0.0000134959
# Epoch 346: train loss: 0.0000110036, validation loss: 0.0000099024
# Epoch 347: train loss: 0.0000102421, validation loss: 0.0000070579
# Epoch 348: train loss: 0.0000106186, validation loss: 0.0000077881
# Epoch 349: train loss: 0.0000100154, validation loss: 0.0000066762
# Epoch 350: train loss: 0.0000115508, validation loss: 0.0000248110
# Epoch 351: train loss: 0.0000106378, validation loss: 0.0000090190
# Epoch 352: train loss: 0.0000103796, validation loss: 0.0000100950
# Epoch 353: train loss: 0.0000113908, validation loss: 0.0000167630
# Epoch 354: train loss: 0.0000100815, validation loss: 0.0000067236
# Epoch 355: train loss: 0.0000109927, validation loss: 0.0000151707
# Epoch 356: train loss: 0.0000109309, validation loss: 0.0000083632
# Epoch 357: train loss: 0.0000102263, validation loss: 0.0000155603
# Epoch 358: train loss: 0.0000110916, validation loss: 0.0000059927
# Epoch 359: train loss: 0.0000103513, validation loss: 0.0000070983
# Epoch 360: train loss: 0.0000103631, validation loss: 0.0000148448
# Epoch 361: train loss: 0.0000100032, validation loss: 0.0000059679
# Epoch 362: train loss: 0.0000112428, validation loss: 0.0000077926
# Epoch 363: train loss: 0.0000102875, validation loss: 0.0000077093
# Epoch 364: train loss: 0.0000103050, validation loss: 0.0000112603
# Epoch 365: train loss: 0.0000113889, validation loss: 0.0000071031
# Epoch 366: train loss: 0.0000101192, validation loss: 0.0000112040
# Epoch 367: train loss: 0.0000111495, validation loss: 0.0000065261
# Epoch 368: train loss: 0.0000101150, validation loss: 0.0000062813
# Epoch 369: train loss: 0.0000098170, validation loss: 0.0000090646
# Epoch 370: train loss: 0.0000108378, validation loss: 0.0000135842
# Epoch 371: train loss: 0.0000106263, validation loss: 0.0000091715
# Epoch 372: train loss: 0.0000102657, validation loss: 0.0000142176
# Epoch 373: train loss: 0.0000095880, validation loss: 0.0000136243
# Epoch 374: train loss: 0.0000113615, validation loss: 0.0000082073
# Epoch 375: train loss: 0.0000097426, validation loss: 0.0000066549
# Epoch 376: train loss: 0.0000103086, validation loss: 0.0000045278
# Epoch 377: train loss: 0.0000102501, validation loss: 0.0000132596
# Epoch 378: train loss: 0.0000111414, validation loss: 0.0000057979
# Epoch 379: train loss: 0.0000107680, validation loss: 0.0000104703
# Epoch 380: train loss: 0.0000099918, validation loss: 0.0000089895
# Epoch 381: train loss: 0.0000096544, validation loss: 0.0000097088
# Epoch 382: train loss: 0.0000103476, validation loss: 0.0000049055
# Epoch 383: train loss: 0.0000114030, validation loss: 0.0000087676
# Epoch 384: train loss: 0.0000107702, validation loss: 0.0000039051
# Epoch 385: train loss: 0.0000091574, validation loss: 0.0000137417
# Epoch 386: train loss: 0.0000102321, validation loss: 0.0000162649
# Epoch 387: train loss: 0.0000102216, validation loss: 0.0000058661
# Epoch 388: train loss: 0.0000093826, validation loss: 0.0000077502
# Epoch 389: train loss: 0.0000098008, validation loss: 0.0000103841
# Epoch 390: train loss: 0.0000106556, validation loss: 0.0000067936
# Epoch 391: train loss: 0.0000095534, validation loss: 0.0000066794
# Epoch 392: train loss: 0.0000100997, validation loss: 0.0000077624
# Epoch 393: train loss: 0.0000115899, validation loss: 0.0000049880
# Epoch 394: train loss: 0.0000092886, validation loss: 0.0000051965
# Epoch 395: train loss: 0.0000097750, validation loss: 0.0000068982
# Epoch 396: train loss: 0.0000102977, validation loss: 0.0000263568
# Epoch 397: train loss: 0.0000101556, validation loss: 0.0000084760
# Epoch 398: train loss: 0.0000109294, validation loss: 0.0000078789
# Epoch 399: train loss: 0.0000094039, validation loss: 0.0000118581
# Epoch 400: train loss: 0.0000097232, validation loss: 0.0000050235
# Epoch 401: train loss: 0.0000097491, validation loss: 0.0000073822
# Epoch 402: train loss: 0.0000094572, validation loss: 0.0000054311
# Epoch 403: train loss: 0.0000098522, validation loss: 0.0000074085
# Epoch 404: train loss: 0.0000099980, validation loss: 0.0000091251
# Epoch 405: train loss: 0.0000099246, validation loss: 0.0000210529
# Epoch 406: train loss: 0.0000098405, validation loss: 0.0000063412
# Epoch 407: train loss: 0.0000093042, validation loss: 0.0000125575
# Epoch 408: train loss: 0.0000089792, validation loss: 0.0000078345
# Epoch 409: train loss: 0.0000109362, validation loss: 0.0000063023
# Epoch 410: train loss: 0.0000092783, validation loss: 0.0000073166
# Epoch 411: train loss: 0.0000103497, validation loss: 0.0000118954
# Epoch 412: train loss: 0.0000101002, validation loss: 0.0000052033
# Epoch 413: train loss: 0.0000103725, validation loss: 0.0000075542
# Epoch 414: train loss: 0.0000094110, validation loss: 0.0000071176
# Epoch 415: train loss: 0.0000095012, validation loss: 0.0000073559
# Epoch 416: train loss: 0.0000094549, validation loss: 0.0000080600
# Epoch 417: train loss: 0.0000106332, validation loss: 0.0000064788
# Epoch 418: train loss: 0.0000084831, validation loss: 0.0000080089
# Epoch 419: train loss: 0.0000095885, validation loss: 0.0000066517
# Epoch 420: train loss: 0.0000102436, validation loss: 0.0000172683
# Epoch 421: train loss: 0.0000096144, validation loss: 0.0000081559
# Epoch 422: train loss: 0.0000095072, validation loss: 0.0000048668
# Epoch 423: train loss: 0.0000091591, validation loss: 0.0000061849
# Epoch 424: train loss: 0.0000101274, validation loss: 0.0000053874
# Epoch 425: train loss: 0.0000093723, validation loss: 0.0000091136
# Epoch 426: train loss: 0.0000098086, validation loss: 0.0000132496
# Epoch 427: train loss: 0.0000094641, validation loss: 0.0000071674
# Epoch 428: train loss: 0.0000101918, validation loss: 0.0000067742
# Epoch 429: train loss: 0.0000092139, validation loss: 0.0000066489
# Epoch 430: train loss: 0.0000095121, validation loss: 0.0000065472
# Epoch 431: train loss: 0.0000107605, validation loss: 0.0000063805
# Epoch 432: train loss: 0.0000097078, validation loss: 0.0000087022
# Epoch 433: train loss: 0.0000094765, validation loss: 0.0000131786
# Epoch 434: train loss: 0.0000088458, validation loss: 0.0000077443
# Epoch 435: train loss: 0.0000091030, validation loss: 0.0000059961
# Epoch 436: train loss: 0.0000104405, validation loss: 0.0000071880
# Epoch 437: train loss: 0.0000088793, validation loss: 0.0000056107
# Epoch 438: train loss: 0.0000097743, validation loss: 0.0000101712
# Epoch 439: train loss: 0.0000100726, validation loss: 0.0000145635
# Epoch 440: train loss: 0.0000102101, validation loss: 0.0000038194
# Epoch 441: train loss: 0.0000081599, validation loss: 0.0000081129
# Epoch 442: train loss: 0.0000098092, validation loss: 0.0000102560
# Epoch 443: train loss: 0.0000089226, validation loss: 0.0000104542
# Epoch 444: train loss: 0.0000105113, validation loss: 0.0000138444
# Epoch 445: train loss: 0.0000089171, validation loss: 0.0000059124
# Epoch 446: train loss: 0.0000084347, validation loss: 0.0000062817
# Epoch 447: train loss: 0.0000085502, validation loss: 0.0000085999
# Epoch 448: train loss: 0.0000102829, validation loss: 0.0000119316
# Epoch 449: train loss: 0.0000098864, validation loss: 0.0000057286
# Epoch 450: train loss: 0.0000088645, validation loss: 0.0000065701
# Epoch 451: train loss: 0.0000087731, validation loss: 0.0000083497
# Epoch 452: train loss: 0.0000093323, validation loss: 0.0000039662
# Epoch 453: train loss: 0.0000087894, validation loss: 0.0000080729
# Epoch 454: train loss: 0.0000098541, validation loss: 0.0000040686
# Epoch 455: train loss: 0.0000084655, validation loss: 0.0000058358
# Epoch 456: train loss: 0.0000097524, validation loss: 0.0000042379
# Epoch 457: train loss: 0.0000093127, validation loss: 0.0000067878
# Epoch 458: train loss: 0.0000088974, validation loss: 0.0000069081
# Epoch 459: train loss: 0.0000087938, validation loss: 0.0000069012
# Epoch 460: train loss: 0.0000093346, validation loss: 0.0000221030
# Epoch 461: train loss: 0.0000094405, validation loss: 0.0000055546
# Epoch 462: train loss: 0.0000089275, validation loss: 0.0000098146
# Epoch 463: train loss: 0.0000093767, validation loss: 0.0000106153
# Epoch 464: train loss: 0.0000091158, validation loss: 0.0000063470
# Epoch 465: train loss: 0.0000094816, validation loss: 0.0000064826
# Epoch 466: train loss: 0.0000083672, validation loss: 0.0000130395
# Epoch 467: train loss: 0.0000087411, validation loss: 0.0000129121
# Epoch 468: train loss: 0.0000087879, validation loss: 0.0000057018
# Epoch 469: train loss: 0.0000097187, validation loss: 0.0000069205
# Epoch 470: train loss: 0.0000088375, validation loss: 0.0000105361
# Epoch 471: train loss: 0.0000087580, validation loss: 0.0000125966
# Epoch 472: train loss: 0.0000094178, validation loss: 0.0000104011
# Epoch 473: train loss: 0.0000091963, validation loss: 0.0000132136
# Epoch 474: train loss: 0.0000088970, validation loss: 0.0000096811
# Epoch 475: train loss: 0.0000086441, validation loss: 0.0000091077
# Epoch 476: train loss: 0.0000091906, validation loss: 0.0000089410
# Epoch 477: train loss: 0.0000085435, validation loss: 0.0000134387
# Epoch 478: train loss: 0.0000095214, validation loss: 0.0000114772
# Epoch 479: train loss: 0.0000085606, validation loss: 0.0000053404
# Epoch 480: train loss: 0.0000085446, validation loss: 0.0000102385
# Epoch 481: train loss: 0.0000086890, validation loss: 0.0000172266
# Epoch 482: train loss: 0.0000091278, validation loss: 0.0000090595
# Epoch 483: train loss: 0.0000095105, validation loss: 0.0000095302
# Epoch 484: train loss: 0.0000083749, validation loss: 0.0000060151
# Epoch 485: train loss: 0.0000088515, validation loss: 0.0000114847
# Epoch 486: train loss: 0.0000089071, validation loss: 0.0000145476
# Epoch 487: train loss: 0.0000092988, validation loss: 0.0000077666
# Epoch 488: train loss: 0.0000080861, validation loss: 0.0000088712
# Epoch 489: train loss: 0.0000093479, validation loss: 0.0000096307
# Epoch 490: train loss: 0.0000084145, validation loss: 0.0000083710
# Epoch 491: train loss: 0.0000088779, validation loss: 0.0000181975
# Epoch 492: train loss: 0.0000085973, validation loss: 0.0000078290
# Epoch 493: train loss: 0.0000086697, validation loss: 0.0000063411
# Epoch 494: train loss: 0.0000090040, validation loss: 0.0000034991
# Epoch 495: train loss: 0.0000096931, validation loss: 0.0000267304
# Epoch 496: train loss: 0.0000086317, validation loss: 0.0000063341
# Epoch 497: train loss: 0.0000086105, validation loss: 0.0000054603
# Epoch 498: train loss: 0.0000085716, validation loss: 0.0000051887
# Epoch 499: train loss: 0.0000090249, validation loss: 0.0000065239
# Epoch 500: train loss: 0.0000091541, validation loss: 0.0000068513
# Finished training

# %%
epochs = np.arange(0, map_net_params['epochs'])
plt.figure(figsize=(15,8))
plt.plot(epochs, map_net.train_loss_hist, color='tab:orange', label='Training loss')
plt.plot(epochs, map_net.val_loss_hist, color='tab:blue', label='Validation loss')

plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale('log')
plt.savefig("convergence plot of map net for arch1[3,20,20,2]")
plt.show()

# %%
# # import scipy.io
# path_model = 'saved_models/'+ robot_type +'/matlab_files/' 

# #save net parameters
# scipy.io.savemat(path_model + "map_in_weights.mat", {"map_in_weights": map_net.map_net_in.weight.detach().numpy()})
# scipy.io.savemat(path_model + "map_in_bias.mat", {"map_in_bias": map_net.map_net_in.bias.detach().numpy()})

# scipy.io.savemat(path_model +"map_hidden_weights_1.mat",
#                  {"map_hidden_weights_1": map_net.map_net_hid[0].weight.detach().numpy()})
# scipy.io.savemat(path_model +"map_hidden_bias_1.mat",
#                  {"map_hidden_bias_1": map_net.map_net_hid[0].bias.detach().numpy()})

# scipy.io.savemat(path_model +"map_hidden_weights_2.mat",
#                  {"map_hidden_weights_2": map_net.map_net_hid[1].weight.detach().numpy()})
# scipy.io.savemat(path_model + "map_hidden_bias_2.mat",
#                  {"map_hidden_bias_2": map_net.map_net_hid[1].bias.detach().numpy()})

# scipy.io.savemat(path_model + "map_hidden_weights_3.mat",
#                  {"map_hidden_weights_3": map_net.map_net_hid[2].weight.detach().numpy()})
# scipy.io.savemat(path_model +"map_hidden_bias_3.mat",
#                  {"map_hidden_bias_3": map_net.map_net_hid[2].bias.detach().numpy()})

# scipy.io.savemat(path_model + "map_out_weights.mat", {"map_out_weights": map_net.map_net_out.weight.detach().numpy()})
# scipy.io.savemat(path_model + "map_out_bias.mat", {"map_out_bias": map_net.map_net_out.bias.detach().numpy()})

# %%
map_net.map_net_hid
# Out:
# ModuleList(
#   (0-2): 3 x Linear(in_features=20, out_features=20, bias=True)
# )

# %% [markdown]
# ## Test Data Parameters

# %%
first_obs_const = int(net_params['first_obs_const']) #only one state
override_C = net_params['override_C']
if override_C:
    n_obs = int(net_params['encoder_output_dim']) + num_states + first_obs_const 
else:
    n_obs = int(net_params['encoder_output_dim']) + first_obs_const

# %% [markdown]
# ***Koopman Bilinear Model***

# %%
A = np.array(model_koop_dnn.A)
#B = np.array(model_koop_dnn.B).reshape(-1,num_inputs*n_obs)
B = np.array(model_koop_dnn.B)
#B_tensor = np.empty((num_inputs,n_obs, n_obs))
#for ii, b in enumerate(B):
    #B_tensor[ii] = b
C = np.array(model_koop_dnn.C)

print(A.shape, B.shape, C.shape)
# Out:
# (30, 30) (30, 90) (6, 30)

# %% [markdown]
# ## Controlability

# %%
Ac = (A-np.eye(n_obs))/dt
Bc = B/dt
Cc = C
Cr = C[0:3,:]

Cr_v = C[num_joints:2*num_joints,:]

# %%
A.shape, B.shape
# Out:
# ((30, 30), (30, 90))

# %%
#check controllability
Con_lin = ct.ctrb(Ac, Bc)
rank_lin = np.linalg.matrix_rank(Con_lin)

print(rank_lin)
# Out:
# 29

# %%
out_con_mat, out_con_rank = Output_Con(Ac,Bc,Cc)


print(out_con_mat.shape)
print(out_con_rank)
# Out:
# (6, 2790)
# 6

# %%
# continiouts
print('mean full',np.linalg.pinv(Bc).mean())
print('rank full',np.linalg.matrix_rank(Bc))

print('mean full',np.linalg.pinv(Ac).mean())
print('rank full',np.linalg.matrix_rank(Ac))
# Out:
# mean full 0.012893939
# rank full 29
# mean full 7.501188856401871
# rank full 29

# %%
# continiouts
print('mean full',np.linalg.pinv(np.matmul(C,Bc)).mean(),np.linalg.pinv(np.matmul(C,Ac)).mean())
print('rank full',np.linalg.matrix_rank(np.matmul(C,Bc)), np.linalg.matrix_rank(np.matmul(C,Ac)))

print('mean reduced',np.linalg.pinv(np.matmul(Cr,Bc)).mean(),np.linalg.pinv(np.matmul(Cr,Ac)).mean())
print('rank reduced',np.linalg.matrix_rank(np.matmul(Cr,Bc)),np.linalg.matrix_rank(np.matmul(Cr,Ac)))
# Out:
# mean full 0.035564393 -0.06535339145533309
# rank full 6 6
# mean reduced 0.0896902 0.036142412792038114
# rank reduced 3 3

# %%
# discreate
print('mean full',np.linalg.pinv(np.matmul(C,B)).mean(),np.linalg.pinv(np.matmul(C,A)).mean())
print('rank full',np.linalg.matrix_rank(np.matmul(C,B)), np.linalg.matrix_rank(np.matmul(C,A)))

print('mean reduced',np.linalg.pinv(np.matmul(Cr,B)).mean(),np.linalg.pinv(np.matmul(Cr,A)).mean())
print('rank reduced',np.linalg.matrix_rank(np.matmul(Cr,B)),np.linalg.matrix_rank(np.matmul(Cr,A)))
# Out:
# mean full 7.1128798 0.03325162
# rank full 6 6
# mean reduced 17.938036 0.03349656
# rank reduced 3 3

# %%
print('mean full',np.linalg.pinv(np.matmul(C,B)).mean(),np.linalg.pinv(np.matmul(C,A)).mean())
print('rank full',np.linalg.matrix_rank(np.matmul(C,B)), np.linalg.matrix_rank(np.matmul(C,A)))

print('mean reduced',np.linalg.pinv(np.matmul(Cr_v,B)).mean(),np.linalg.pinv(np.matmul(Cr_v,A)).mean())
print('rank reduced',np.linalg.matrix_rank(np.matmul(Cr_v,B)),np.linalg.matrix_rank(np.matmul(Cr_v,A)))
# Out:
# mean full 7.1128798 0.03325162
# rank full 6 6
# mean reduced 1.4412153 0.033323385
# rank reduced 3 3

# %%
# # #SAVE MATRIX PARAMETERS AS MATLAB FILE
# # import scipy.io

# dyn_matrices = {"A": A, "B": B, "C": C}
# scipy.io.savemat(path_model + "dyn_mat.mat", dyn_matrices)
# #save encoder parameters

# scipy.io.savemat(path_model + "in_weights.mat", {"encode_in_weights": model_koop_dnn.net.encoder_fc_in.weight.detach().numpy()})
# scipy.io.savemat(path_model + "in_bias.mat", {"encode_in_bias": model_koop_dnn.net.encoder_fc_in.bias.detach().numpy()})

# scipy.io.savemat(path_model + "hidden_weights_1.mat",
#                  {"encode_hidden_weights_1": model_koop_dnn.net.encoder_fc_hid[0].weight.detach().numpy()})
# scipy.io.savemat(path_model + "hidden_bias_1.mat",
#                  {"encode_hidden_bias_1": model_koop_dnn.net.encoder_fc_hid[0].bias.detach().numpy()})

# scipy.io.savemat(path_model + "hidden_weights_2.mat",
#                  {"encode_hidden_weights_2": model_koop_dnn.net.encoder_fc_hid[1].weight.detach().numpy()})
# scipy.io.savemat(path_model + "hidden_bias_2.mat",
#                  {"encode_hidden_bias_2": model_koop_dnn.net.encoder_fc_hid[1].bias.detach().numpy()})

# scipy.io.savemat(path_model + "out_weights.mat", {"encode_out_weights": model_koop_dnn.net.encoder_fc_out.weight.detach().numpy()})
# scipy.io.savemat(path_model + "out_bias.mat", {"encode_out_bias": model_koop_dnn.net.encoder_fc_out.bias.detach().numpy()})

# if standardize:
#     scipy.io.savemat(path_model + "std.mat", {"standardize": standardize, 'mean': standardizer_u_kdnn.mean_, 'scale':standardizer_u_kdnn.scale_})
    
# else:
#     scipy.io.savemat(path_model + "std.mat", {"standardize": standardize})

# %% [markdown]
# ## Save Data

# %%
# #SAVE MATRIX PARAMETERS AS MATLAB FILE
# import scipy.io

path_model = 'saved_models/'+ robot_type +'/matlab_files/' 

dyn_matrices = {"A": A, "B": B, "C": C}
scipy.io.savemat(path_model + "dyn_mat.mat", dyn_matrices)
#save encoder parameters

encoder_dict = {}

encoder_dict["encoder_in_weights"] =  model_koop_dnn.net.encoder_fc_in.weight.detach().numpy()
encoder_dict["encoder_in_bias"] = model_koop_dnn.net.encoder_fc_in.bias.detach().numpy()
encoder_dict["encoder_hidden_depth"] = int(net_params["encoder_hidden_depth"]-1) 

encoder_dict["encoder_hidden_weights"] = np.empty((net_params["encoder_hidden_width"],net_params["encoder_hidden_width"],net_params["encoder_hidden_depth"]-1))
encoder_dict["encoder_hidden_bias"] = np.empty((1,net_params["encoder_hidden_width"],net_params["encoder_hidden_depth"]-1))


for i in range(net_params["encoder_hidden_depth"]-1):
    
    encoder_dict["encoder_hidden_weights"][:,:,i] = model_koop_dnn.net.encoder_fc_hid[i].weight.detach().numpy()
    encoder_dict["encoder_hidden_bias"][:,:,i] = model_koop_dnn.net.encoder_fc_hid[i].bias.detach().numpy()

encoder_dict["encoder_out_weights"] = model_koop_dnn.net.encoder_fc_out.weight.detach().numpy()
encoder_dict["encoder_out_bias"] = model_koop_dnn.net.encoder_fc_out.bias.detach().numpy()

scipy.io.savemat(path_model + "encoder.mat", encoder_dict)

if standardize:
    scipy.io.savemat(path_model + "std.mat", {"standardize": standardize, 'mean': standardizer_u_kdnn.mean_, 'scale':standardizer_u_kdnn.scale_})
    
else:
    scipy.io.savemat(path_model + "std.mat", {"standardize": standardize})

# %%
# save forward map
forward_map_dict = {}

forward_map_dict["map_in_weights"] = map_net.map_net_in.weight.detach().numpy()
forward_map_dict["map_in_bias"] = map_net.map_net_in.bias.detach().numpy()
forward_map_dict["map_hidden_depth"] = int(map_net_params["hidden_depth"]-1)

forward_map_dict["map_hidden_weights"] = np.empty((map_net_params["hidden_width"],map_net_params["hidden_width"],map_net_params["hidden_depth"]-1))
forward_map_dict["map_hidden_bias"] = np.empty((1,map_net_params["hidden_width"],map_net_params["hidden_depth"]-1))

for i in range(map_net_params["hidden_depth"]-1):
    
    forward_map_dict["map_hidden_weights"][:,:,i] = map_net.map_net_hid[i].weight.detach().numpy()
    forward_map_dict["map_hidden_bias"][:,:,i] = map_net.map_net_hid[i].bias.detach().numpy()

forward_map_dict["map_out_weights"] = map_net.map_net_out.weight.detach().numpy()
forward_map_dict["map_out_bias"] = map_net.map_net_out.bias.detach().numpy()


path_model = 'saved_models/'+ robot_type +'/matlab_files/' 
#save net parameters


scipy.io.savemat(path_model + "forward_map.mat", forward_map_dict)

# %%
net_params['encoder_hidden_depth']
# Out:
# 3

# %%
path_model
# Out:
# 'saved_models/3R/bilinear/2D/matlab_files/'

# %%
encode_out_bias = model_koop_dnn.net.encoder_fc_out.bias.detach().numpy()
encode_out_weights = model_koop_dnn.net.encoder_fc_out.weight.detach().numpy()

# %% [markdown]
# ***Test Data Generation***

# %%
test_data = 'dynamics/Dataset_MATLAB/' + robot_type_load +'/data_test.mat'
data_test = scipy.io.loadmat(test_data)

# %%
X_end_test = np.array(data_test['X_end'], dtype = 'float64')
X_test = np.array(data_test['X'], dtype = 'float64')
U_test = np.array(data_test['tau'], dtype = 'float64')
num_snaps_test = int(data_test['num_snaps'])
num_traj_test = int(data_test['num_traj'])
# test data parameters
T = np.linspace(0,num_snaps_test*dt, num_snaps_test+1)

# %%
# data_gen
j = random.choice(range(num_traj_test))
xs_end_test = X_end_test[j,:,:]
xs_test = X_test[j,:,:]
us_test = U_test[j,:,:]

# %%
print(xs_end_test.shape, xs_test.shape, us_test.shape)
# Out:
# (1001, 2) (1001, 6) (1000, 3)

# %%
print(model_koop_dnn.test_loss(xs_test.reshape(1,-1,num_states),u_test = us_test.reshape(1,-1,num_inputs)))
# Out:
# tensor(1.2762e-06)

# %%
basis = model_koop_dnn.net.encode_forward_

# %%
X,_ = model_koop_dnn.net.process(xs_test.reshape(1,-1,num_states),data_u = us_test.reshape(1,-1,num_inputs))
print(X.shape)
# Out:
# (1000, 15)

# %%
x = X[:, :num_states]
u = X[:, num_states:num_states+num_inputs]
x_prime = X[:,num_states+num_inputs:]

print(x.shape, u.shape, x_prime.shape)
# Out:
# (1000, 6) (1000, 3) (1000, 6)

# %% [markdown]
# ***Initial Condition Lifting***

# %%
# initialize the matricies
z = np.empty((n_obs,num_snaps_test+1)).T
x_est = np.zeros((num_states,num_snaps_test+1)).T
x_end_est = np.zeros((X_end.shape[2],num_snaps_test)).T

# %%
z[0,:] = lift(x[0,:],model_koop_dnn, net_params)
x_est[0,:] = x[0,:]

# %% [markdown]
# ***Time Evolution***

# %%
for i in range(num_snaps_test):
  #bilinear
    z[i+1,:] = np.matmul(z[i,:],A.T)+np.matmul(np.kron(u[i,:],z[i,:]),B.T)
    x_est[i+1,:] = np.matmul(z[i+1,:],C.T)  
    x_end_est[i,:] = map_net.forward(torch.from_numpy(x_est[i,:int(num_joints)]).float()).detach().numpy()

# %% [markdown]
# ***Visualization***

# %% [markdown]
# # Joint Space

# %%
plt.figure(figsize=(20,12))
for i in range(int(num_joints)):
    plt.subplot(3,3,i+1)
    plt.plot(T[:-1],x[:,i],label ='Actual')
    plt.plot(T[:],x_est[:,i],label = 'estimated(bilinear)')
    plt.xlabel('t')
    plt.ylabel('theta_' + str(i))
    plt.title('theta_' + str(i) + ' Comparison')
    plt.legend()

# %%
plt.figure(figsize=(20,12))
for i in range(int(num_joints)):
    plt.subplot(3,3,i+1)
    plt.plot(T[:-1],x[:,int(num_joints)+i],label ='Actual')
    plt.plot(T[:],x_est[:,int(num_joints)+i],label = 'estimated(bilinear)')
    plt.xlabel('t')
    plt.ylabel('theta_dot_' + str(i))
    plt.title('theta_dot_' + str(i) + ' Comparison')
    plt.legend()

# %%
plt.figure(figsize=(20,12))
for i in range(int(num_joints)):
    plt.subplot(3,3,i+1)
    plt.plot(T[:-1],u[:,i])
    plt.xlabel('t')
    plt.ylabel('tau' + str(i))

# %%
plt.figure(figsize=(20,12))
for i in range(int(num_joints)):
    plt.subplot(3,3,i+1)
    plt.plot(T[:-1],us_test[:,i])
    plt.xlabel('t')
    plt.ylabel('tau' + str(i))

# %%
if standardize:
    u_unscaled = np.array([standardizer_u_kdnn.inverse_transform(d.reshape(1,-1)) for d in u]).reshape(num_snaps_test,num_inputs)
    plt.figure(figsize=(20,12))
    for i in range(int(num_joints)):
        plt.subplot(3,3,i+1)
        plt.plot(T[:-1],us_test[:,i], label= 'original')
        plt.plot(T[:-1],u_unscaled[:,i], label= 'unscaled')
        plt.xlabel('t')
        plt.ylabel('tau' + str(i))
        
    print(u.shape)
    print(u_unscaled.shape)
# Out:
# (1000, 3)
# (1000, 3)

# %% [markdown]
# ## Cartesian Space

# %%
plt.figure(figsize=(20,6))
for i in range(X_end.shape[2]):
    plt.subplot(1,3,i+1)
    plt.plot(T[:],xs_end_test[:,i], label = 'Actual')
    plt.plot(T[:-1],x_end_est[:,i], label = 'Estimated')
    plt.legend()
plt.show()

# %%
error_joint_space = np.linalg.norm(xs_test-x_est,axis = 1)
error_cart_space = np.linalg.norm(xs_end_test[:-1]-x_end_est,axis = 1)

# %%
plt.figure(figsize =(20,6))
plt.subplot(1,2,1)
plt.plot(T[:],error_joint_space)
plt.title('Joint Space Error')

plt.subplot(1,2,2)
plt.plot(T[:-1],error_cart_space)
plt.title('Cartesian Space Error')
# Out:
# Text(0.5, 1.0, 'Cartesian Space Error')

# %%
xs_test[8,:]
# Out:
# array([ 1.17723295e+00,  1.05254237e-01, -1.66769564e+00,  9.53694656e-04,
#         2.15921758e-04, -1.13237606e-04])

# %%
# the mean error for the whole test dataset
error_ang_traj =  np.empty((num_snaps_test))
error_vel_traj =  np.empty((num_snaps_test))

error_ang_total  = np.empty((num_traj_test))
error_vel_total  = np.empty((num_traj_test))

for j in range(num_traj_test):
    xs_test = X_test[j,:,:]
    us_test = U_test[j,:,:]
    X,_ = model_koop_dnn.net.process(xs_test.reshape(1,-1,num_states),data_u = us_test.reshape(1,-1,num_inputs))
    x = X[:, :num_states]
    u = X[:, num_states:num_states+num_inputs]
    x_prime = X[:,num_states+num_inputs:]
    z[0,:] = lift(x[0,:],model_koop_dnn, net_params)
    x_est[0,:] = x[0,:]
    
    for i in range(num_snaps_test):
        #bilinear
        z[i+1,:] = np.matmul(z[i,:],A.T)+np.matmul(np.kron(u[i,:],z[i,:]),B.T)
        x_est[i+1,:] = np.matmul(z[i+1,:],C.T)  
        error_ang_traj[i] = np.mean(abs(x_est[i,:num_joints] - x[i,:num_joints]))
        error_vel_traj[i] = np.mean(abs(x_est[i,num_joints:] - x[i,num_joints:]))
        
    error_ang_total[j] = np.mean(error_ang_traj)
    error_vel_total[j] = np.mean(error_vel_traj)

# %%
print("Mean Absolute Error for joint angles for testing data :", np.mean(error_ang_total))
print("Mean Absolute Error for joint velocity for testing data :", np.mean(error_vel_total))
# Out:
# Mean Absolute Error for joint angles for testing data : 0.0006959655016660591
# Mean Absolute Error for joint velocity for testing data : 0.00041858655241741415

# %%
abs(x_est[i,:] - x[i,:])
# Out:
# array([0.0019775 , 0.00038762, 0.00071021, 0.00083939, 0.00021415,
#        0.00030509])

# %% [markdown]
# ## Controllers

# %% [markdown]
# ## ZNN full state

# %%
t_ctrl = np.arange(start=0, stop=10, step=dt)
num_snaps_ctrl = t_ctrl.shape[0]

# %%
gamma = 10*np.diag([1,1,1,3,3,3])
shape = 'cardioid'
c = 0.02
tilt = np.pi/6

# %%
## specify the matricies
z_ctrl = np.zeros((n_obs,num_snaps_ctrl))
z_dot = np.zeros((n_obs,num_snaps_ctrl-1))
x_ctrl = np.zeros((num_states,num_snaps_ctrl))
x_ctrl_end = np.zeros((num_states_cart,num_snaps_ctrl))
x_ctrl_dot_end = np.zeros((num_states_cart,num_snaps_ctrl))
x_ctrl_dot = np.zeros((num_states_cart,num_snaps_ctrl))
rd = np.zeros((num_states_cart,num_snaps_ctrl-1))
rd_dot = np.zeros((num_states_cart,num_snaps_ctrl-1))
rd_ddot = np.zeros((num_states_cart,num_snaps_ctrl-1))
error = np.zeros((2*(num_states_cart),num_snaps_ctrl-1))

u_ctrl = np.zeros((num_inputs,num_snaps_ctrl))

## initialize the matricies
# x_ctrl[:,0] = np.hstack((x_ref[:,0],x_ref_dot[:,0]))
x_ctrl[:,0] = np.hstack((np.ones((num_joints,)), np.zeros((num_joints,))))
z_ctrl[:,0] = lift(x_ctrl[:,0],model_koop_dnn, net_params)
x_ctrl_end[:,0] = map_net.forward(torch.from_numpy(x_ctrl[:num_joints,0]).float()).detach().numpy()

# %%
for i in range(num_snaps_ctrl-1):
    t = t_ctrl[i]
    if modality == '2D':
        # rd[:,i], rd_dot[:,i],rd_ddot= path_pars_2D(t,t_ctrl[-1],c,tilt,x_ctrl_end[:,0], shape)
        rd[:,i], rd_dot[:,i] = x_end[:,i], x_end_dot[:,i]
    else:
        rd[:,i], rd_dot[:,i], rd_ddot[:,i] = path_pars(t,t_ctrl[-1],c,tilt,x_ctrl_end[:,0], shape)
        # rd[:,i], rd_dot[:,i] = x_end[:,i], x_end_dot[:,i]
        
    rd_full = np.hstack((rd[:,i], rd_dot[:,i]))
    rd_dot_full = np.hstack((rd_dot[:,i], rd_ddot[:,i]))
    error[:,i] = np.hstack((x_ctrl_end[:,i],x_ctrl_dot_end[:,i])) - rd_full
    
    W = neural_jacobian(map_net, x_ctrl[:num_joints,i])
    W_dot = neural_jacobian_dot(map_net, x_ctrl[:num_joints,i],x_ctrl[num_joints:,i])
    J_tilde = np.vstack((np.hstack((W,np.zeros_like(W))),np.hstack((W_dot,W))))
    
    u_ctrl[:,i] = np.dot(np.linalg.pinv(np.matmul(Bc,np.kron(z_ctrl[:,i],np.eye(num_inputs)).T)), -np.matmul(Ac,z_ctrl[:,i]) + np.matmul(np.linalg.pinv(np.matmul(J_tilde, Cc)), (rd_dot_full - np.matmul(gamma,error[:,i]))))
    
    # u_ctrl[:,i] = np.dot(np.linalg.pinv(np.matmul(J_tilde,np.matmul(Cc,Bc))), -np.matmul(np.matmul(J_tilde, Cc),np.matmul(Ac,z_ctrl[:,i])) + rd_dot_full - np.matmul(gamma,error[:,i]))
    # u_ctrl[:,i] = np.dot(np.linalg.pinv(np.matmul(Cc,Bc)), -np.matmul(np.matmul(Cc,Ac),z_ctrl[:,i]) + np.matmul(np.linalg.pinv(J_tilde), (rd_dot_full - np.matmul(gamma,error[:,i]))))
            
    
    z_ctrl[:,i+1] = np.matmul(z_ctrl[:,i],A.T) + np.matmul(np.kron(z_ctrl[:,i],u_ctrl[:,i]),B.T)
    x_ctrl[:,i+1] = np.matmul(z_ctrl[:,i+1],C.T)
    x_ctrl_end[:,i+1] = map_net.forward(torch.from_numpy(x_ctrl[:num_joints,i+1]).float()).detach().numpy()
    x_ctrl_dot_end[:,i+1] = np.matmul(neural_jacobian(map_net, x_ctrl[:num_joints,i+1]), x_ctrl[num_joints:,i+1])
    
                   
    # x_ctrl[0:3,i+1],x_ctrl[3:,i+1] = dynamics_3R(dt, u_ctrl[:,i], x_ctrl[0:3,i],x_ctrl[3:,i], robot_pars)
    # z_ctrl[:,i+1] = lift(x_ctrl[:,i+1],model_koop_dnn, net_params)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 5
#       2 t = t_ctrl[i]
#       3 if modality == '2D':
#       4     # rd[:,i], rd_dot[:,i],rd_ddot= path_pars_2D(t,t_ctrl[-1],c,tilt,x_ctrl_end[:,0], shape)
# ----> 5     rd[:,i], rd_dot[:,i] = x_end[:,i], x_end_dot[:,i]
#       6 else:
#       7     rd[:,i], rd_dot[:,i], rd_ddot[:,i] = path_pars(t,t_ctrl[-1],c,tilt,x_ctrl_end[:,0], shape)
#
# NameError: name 'x_end' is not defined

# %%
np.matmul(gamma,error[:,i])

# %%
np.matmul(np.matmul(J_tilde, Cc),A).mean()

# %%
u_ctrl[:,10]

# %%
np.matmul(J_tilde,Cc).shape

# %%
np.vstack((rd_dot[:,i], rd_ddot[:,i]))

# %%
if modality == '2D':
    plt.figure(figsize=(20,12))
    plt.plot(x_ctrl_end[0,:],x_ctrl_end[1,:],label = 'traced')
    plt.plot(rd[0,:-1],rd[1,:-1],label ='reference')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend()
    plt.axis('equal')
else:
    ax = plt.axes(projection='3d')
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.set_zlabel("z")
    
    ax.plot3D(x_ctrl_end[0,:],x_ctrl_end[1,:],x_ctrl_end[2,:],label = 'traced')
    ax.plot3D(rd[0,:-1],rd[1,:-1],rd[2,:-1],label ='reference')
    plt.legend()

    plt.axis('equal')

# %%
plt.figure(figsize=(20,12))
for i in range(int(num_states_cart)):
    plt.subplot(3,3,i+1)
    plt.plot(t_ctrl[:-1],rd[i,:],label ='reference')
    plt.plot(t_ctrl[:],x_ctrl_end[i,:],label = 'traced')
    plt.xlabel('t')
    plt.legend()

# %%
plt.figure(figsize=(20,12))
for i in range(int(num_states_cart)):
    plt.subplot(3,3,i+1)
    plt.plot(t_ctrl[:-1],error[i,:])
    plt.xlabel('t')
    plt.ylabel('error_' + str(i))

# %%
plt.figure(figsize=(20,12))
for i in range(int(num_joints)):
    plt.subplot(3,3,i+1)
    plt.plot(t_ctrl[:u_ctrl.shape[1]],u_ctrl[i,:])
    plt.xlabel('t')
    plt.ylabel('tau' + str(i))
