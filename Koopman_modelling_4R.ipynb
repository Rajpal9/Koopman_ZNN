# %% [markdown]
# ***Import Libraries***

# %%
"""This program bilinearizes 3R planar dyanmics using koopman theory and autoencoder to map"""
import numpy as np
import matplotlib.pyplot as plt
import sklearn.preprocessing
import itertools
import scipy.io
import torch

# bilinear Koopman
from core.koopman_core import KoopDNN, KoopmanNet, KoopmanNetCtrl
from models.koop_model import model_matricies,lift
from core.util import fit_standardizer
from sklearn import preprocessing

# forward map neural net
from core.neural_fwd_map import map_Net
from core.util import Output_Con
import control as ct

## bilinear ControlModel
from control_files.nmpc_osqp import NonlinearMPCController
from dynamics.learned_models_control.bilinear_dynamics import bilinear_Dynamics

## import paths
from paths.paths import path_pars

## extra libraries
import numpy as np
import scipy as sp
from scipy import sparse

# %%
## define paths
## define paths
robot = '4R'
nature = 'bilinear'
modality = '3D'

robot_type_load = robot +'/' + modality # for data load0
robot_type = robot +'/'+ nature +'/' + modality # for saving purposes

train = True
mass_var = False


if mass_var == True:
    file_data = 'dynamics/Dataset_MATLAB/' + robot_type_load +'/data_mass_var.mat'
else:
    file_data = 'dynamics/Dataset_MATLAB/' + robot_type_load +'/data.mat'

# %% [markdown]
# ### Load Data

# %%
data = scipy.io.loadmat(file_data)

X_end = np.array(data['X_end'], dtype = 'float64')
X_full = np.array(data['X'], dtype = 'float64')
U_full = np.array(data['tau'], dtype = 'float64')

print(X_end.shape, X_full.shape,U_full.shape)
# Out:
# (125, 1001, 3) (125, 1001, 8) (125, 1000, 4)

# %%
np.sum(np.sum(np.isnan(X_end))), np.sum(np.sum(np.isnan(U_full))), np.sum(np.sum(np.isnan(X_full)))
# Out:
# (0, 0, 0)

# %% [markdown]
# ***Simulation Parameters***

# %%
dt = float(data['dt']) #time step
num_snaps = int(data['num_snaps']) # no. of snapshots
num_traj = int(data['num_traj']) #no of trajectories
T = np.linspace(0,num_snaps*dt, num_snaps+1)
num_train = int(0.75*num_traj) # no. of training examples
num_val = num_traj-num_train # no of testing examples
num_traj = num_train+num_val #no of trajectories
num_states = X_full.shape[2] # no. of states
num_joints = num_states/2
num_inputs = U_full.shape[2] # no. of inputs

# %%
dt, num_snaps, num_traj, num_states, num_inputs
# Out:
# (0.005, 1000, 125, 8, 4)

# %% [markdown]
# ***Plotting the trajectories***

# %%
"""Training dataset visualization"""
#theta evolution
for i in range(int(num_joints)):
    plt.subplot(3,3,i+1)
    plt.xlabel("t")
    plt.ylabel("th"+str(i+1))
    for j in range(num_traj):
        plt.plot(T,X_full[j,:,i])

# %%
for i in range(int(num_joints)):
    plt.subplot(3,3,i+1)
    plt.xlabel("t")
    plt.ylabel("th"+str(i+1)+ ' dot')
    for j in range(num_traj):
        plt.plot(T,X_full[j,:,i+int(num_joints)])

# %%
#x and y positions of the end effector
# %matplotlib widget
# ax = plt.axes(projection='3d')
# ax.set_xlabel("x")
# ax.set_ylabel("y")
# ax.set_zlabel("z")
# for i in range(num_traj):
#     ax.plot3D(X_end[i,:,0],X_end[i,:,1],X_end[i,:,2])
    
# plt.axis('equal')

# %%
for i in range(num_traj):
    plt.plot(X_end[i,:,0],X_end[i,:,1])
    
plt.axis('equal')
# Out:
# (-1.3355178412743767,
#  1.3105550384783906,
#  -1.1721000240050983,
#  1.2592606291457253)

# %%
for i in range(num_inputs):
    plt.subplot(4,2,i+1)
    plt.xlabel("t")
    plt.ylabel("tau"+str(i))
    for j in range(num_traj):
        plt.plot(T[:-1],U_full[j,:,i])

# %% [markdown]
# ***Training and validation datasets***

# %%
# split training and vaidation datasets
xs_train, us_train = X_full[:num_train,:,:],U_full[:num_train,:,:]
xs_val, us_val = X_full[num_train:,:,:],U_full[num_train:,:,:]

# %%
# import scipy.io
# Data_set = {"x_end": X_end, "X_full": X_full}
# scipy.io.savemat("Data_set.mat",Data_set)

# %%
# import torch
# import torch.nn as nn
# import torch.nn.functional as F

# %% [markdown]
# ***Model Training***

# %%
net_params = {}
net_params['state_dim'] = num_states
net_params['ctrl_dim'] = num_inputs
net_params['encoder_hidden_width'] = 30 # 30
net_params['encoder_hidden_depth'] = 3  # 2
net_params['encoder_output_dim'] = 10 # 20
net_params['optimizer'] = 'adam'
net_params['activation_type'] = 'tanh'
net_params['lr'] = 5e-4 # 5e-4
net_params['epochs'] = 100
net_params['batch_size'] = 128
net_params['lifted_loss_penalty'] = 0.4 
net_params['l2_reg'] = 0.0        
net_params['l1_reg'] = 0.1
net_params['first_obs_const'] = True
net_params['override_C'] = True # this makes the state a part of lifetd state
net_params['dt'] = dt

# %%
if mass_var == True:
    file_koop = 'saved_models/'+robot_type+'/koop_arch_con_mass_var.pth'
else:
    file_koop = 'saved_models/'+robot_type+'/koop_arch_con.pth'

if train == True:
    
    standardizer_u_kdnn = fit_standardizer(us_train, preprocessing.StandardScaler(with_mean=False))
    # standardizer_x_kdnn = fit_standardizer(xs_train, preprocessing.StandardScaler(with_mean=False))
    net = KoopmanNetCtrl(net_params, standardizer_u=standardizer_u_kdnn)
    # net = KoopmanNetCtrl(net_params)
    model_koop_dnn = KoopDNN(net)
    model_koop_dnn.set_datasets(xs_train, u_train=us_train, x_val=xs_val, u_val=us_val)
    model_koop_dnn.model_pipeline(net_params)
    model_koop_dnn.construct_koopman_model()
    torch.save(model_koop_dnn,file_koop)
else:
    model_koop_dnn = torch.load(file_koop)
# Out:
# Epoch   1: train loss: 2.6704871655, validation loss: 0.6950154239
# Epoch   2: train loss: 0.6132184267, validation loss: 0.5949669366
# Epoch   3: train loss: 0.5600869656, validation loss: 0.5585889175
# Epoch   4: train loss: 0.5355876088, validation loss: 0.5396912644
# Epoch   5: train loss: 0.5217791200, validation loss: 0.5274031146
# Epoch   6: train loss: 0.5134508014, validation loss: 0.5201170559
# Epoch   7: train loss: 0.5075403452, validation loss: 0.5136517137
# Epoch   8: train loss: 0.5028005838, validation loss: 0.5099032393
# Epoch   9: train loss: 0.4994307756, validation loss: 0.5074780523
# Epoch  10: train loss: 0.4963594377, validation loss: 0.5053396686
# Epoch  11: train loss: 0.4938350320, validation loss: 0.5019566973
# Epoch  12: train loss: 0.4915530980, validation loss: 0.5002577883
# Epoch  13: train loss: 0.4895574152, validation loss: 0.4977125857
# Epoch  14: train loss: 0.4882686138, validation loss: 0.4967114967
# Epoch  15: train loss: 0.4866321683, validation loss: 0.4962057545
# Epoch  16: train loss: 0.4854232073, validation loss: 0.4929985765
# Epoch  17: train loss: 0.4841918945, validation loss: 0.4930238700
# Epoch  18: train loss: 0.4835100174, validation loss: 0.4981962435
# Epoch  19: train loss: 0.4829190969, validation loss: 0.4948643698
# Epoch  20: train loss: 0.4820552170, validation loss: 0.4900983140
# Epoch  21: train loss: 0.4813158214, validation loss: 0.4887013705
# Epoch  22: train loss: 0.4808294475, validation loss: 0.4938096832
# Epoch  23: train loss: 0.4806698561, validation loss: 0.4895166585
# Epoch  24: train loss: 0.4804501235, validation loss: 0.4877796640
# Epoch  25: train loss: 0.4799127281, validation loss: 0.4890096666
# Epoch  26: train loss: 0.4790360332, validation loss: 0.4887136629
# Epoch  27: train loss: 0.4794721305, validation loss: 0.4911879507
# Epoch  28: train loss: 0.4791179895, validation loss: 0.4886251915
# Epoch  29: train loss: 0.4783962071, validation loss: 0.4932717005
# Epoch  30: train loss: 0.4790541530, validation loss: 0.4884305423
# Epoch  31: train loss: 0.4786050916, validation loss: 0.4890027928
# Epoch  32: train loss: 0.4783756733, validation loss: 0.4870865350
# Epoch  33: train loss: 0.4782856703, validation loss: 0.4895349543
# Epoch  34: train loss: 0.4784238636, validation loss: 0.4872378299
# Epoch  35: train loss: 0.4783414304, validation loss: 0.4862166210
# Epoch  36: train loss: 0.4780719578, validation loss: 0.4892568574
# Epoch  37: train loss: 0.4778183401, validation loss: 0.4861628847
# Epoch  38: train loss: 0.4782853425, validation loss: 0.4923495996
# Epoch  39: train loss: 0.4776712954, validation loss: 0.4889910579
# Epoch  40: train loss: 0.4778779745, validation loss: 0.4887245315
# Epoch  41: train loss: 0.4780639410, validation loss: 0.4888173701
# Epoch  42: train loss: 0.4777118564, validation loss: 0.4874529039
# Epoch  43: train loss: 0.4778001904, validation loss: 0.4925234054
# Epoch  44: train loss: 0.4777373970, validation loss: 0.4895306422
# Epoch  45: train loss: 0.4776645303, validation loss: 0.4861158648
# Epoch  46: train loss: 0.4777963758, validation loss: 0.4897634207
# Epoch  47: train loss: 0.4778324366, validation loss: 0.4926031243
# Epoch  48: train loss: 0.4771089554, validation loss: 0.4901587136
# Epoch  49: train loss: 0.4781327546, validation loss: 0.4935866663
# Epoch  50: train loss: 0.4780220091, validation loss: 0.4870083500
# Epoch  51: train loss: 0.4775386453, validation loss: 0.4887165411
# Epoch  52: train loss: 0.4774516225, validation loss: 0.4911640027
# Epoch  53: train loss: 0.4775903523, validation loss: 0.4967604533
# Epoch  54: train loss: 0.4774658978, validation loss: 0.4882878151
# Epoch  55: train loss: 0.4775882661, validation loss: 0.4901112132
# Epoch  56: train loss: 0.4775224030, validation loss: 0.4921009418
# Epoch  57: train loss: 0.4772295356, validation loss: 0.4899673957
# Epoch  58: train loss: 0.4774998426, validation loss: 0.4914060740
# Epoch  59: train loss: 0.4771485031, validation loss: 0.4950748419
# Epoch  60: train loss: 0.4774596691, validation loss: 0.4932469084
# Epoch  61: train loss: 0.4771962762, validation loss: 0.4920944939
# Epoch  62: train loss: 0.4769926071, validation loss: 0.4928184047
# Epoch  63: train loss: 0.4776202440, validation loss: 0.4985477726
# Epoch  64: train loss: 0.4773491621, validation loss: 0.4976075839
# Epoch  65: train loss: 0.4771770537, validation loss: 0.4960330043
# Epoch  66: train loss: 0.4770764709, validation loss: 0.4989948198
# Epoch  67: train loss: 0.4768919349, validation loss: 0.5013925630
# Epoch  68: train loss: 0.4775341451, validation loss: 0.5046881469
# Epoch  69: train loss: 0.4772595763, validation loss: 0.5045782266
# Epoch  70: train loss: 0.4770129323, validation loss: 0.5173603491
# Epoch  71: train loss: 0.4769021869, validation loss: 0.5253738133
# Epoch  72: train loss: 0.4772344828, validation loss: 0.5162828313
# Epoch  73: train loss: 0.4772655666, validation loss: 0.5207743585
# Epoch  74: train loss: 0.4772777557, validation loss: 0.5240744102
# Epoch  75: train loss: 0.4775114954, validation loss: 0.5276863606
# Epoch  76: train loss: 0.4770445824, validation loss: 0.5350344775
# Epoch  77: train loss: 0.4772765636, validation loss: 0.5269888855
# Epoch  78: train loss: 0.4769233465, validation loss: 0.5383823301
# Epoch  79: train loss: 0.4770569801, validation loss: 0.5354118783
# Epoch  80: train loss: 0.4772311151, validation loss: 0.5396995227
# Epoch  81: train loss: 0.4777195156, validation loss: 0.5422167960
# Epoch  82: train loss: 0.4773023129, validation loss: 0.5405603973
# Epoch  83: train loss: 0.4772937596, validation loss: 0.5355936391
# Epoch  84: train loss: 0.4775519073, validation loss: 0.5428596886
# Epoch  85: train loss: 0.4770018756, validation loss: 0.5368455760
# Epoch  86: train loss: 0.4771683216, validation loss: 0.5395287353
# Epoch  87: train loss: 0.4771968126, validation loss: 0.5422832371
# Epoch  88: train loss: 0.4772345722, validation loss: 0.5512661866
# Epoch  89: train loss: 0.4772984087, validation loss: 0.5525679151
# Epoch  90: train loss: 0.4771694243, validation loss: 0.5502156549
# Epoch  91: train loss: 0.4773704708, validation loss: 0.5596100243
# Epoch  92: train loss: 0.4772310257, validation loss: 0.5664363831
# Epoch  93: train loss: 0.4768934846, validation loss: 0.5643044859
# Epoch  94: train loss: 0.4772163332, validation loss: 0.5554122634
# Epoch  95: train loss: 0.4770414233, validation loss: 0.5587217771
# Epoch  96: train loss: 0.4774475098, validation loss: 0.5683272223
# Epoch  97: train loss: 0.4770711362, validation loss: 0.5601048158
# Epoch  98: train loss: 0.4773286283, validation loss: 0.5661672004
# Epoch  99: train loss: 0.4768968523, validation loss: 0.5640600233
# Epoch 100: train loss: 0.4768911898, validation loss: 0.5635950177
# Finished Training

# %% [markdown]
# ***Learning Curves***

# %%
train_loss = [l[0] for l in model_koop_dnn.train_loss_hist]
train_pred_loss = [l[1] for l in model_koop_dnn.train_loss_hist]
train_lifted_loss = [l[2] for l in model_koop_dnn.train_loss_hist]
val_loss = [l[0] for l in model_koop_dnn.val_loss_hist]
val_pred_loss = [l[1] for l in model_koop_dnn.val_loss_hist]
val_lifted_loss = [l[2] for l in model_koop_dnn.val_loss_hist]
epochs = np.arange(0, net_params['epochs'])

plt.figure(figsize=(15,8))
plt.plot(epochs, train_loss, color='tab:orange', label='Training loss')
plt.plot(epochs, train_pred_loss, '--', color='tab:orange', label='Training prediction loss')
plt.plot(epochs, train_lifted_loss, ':', color='tab:orange', label='Training lifted loss')
plt.plot(epochs, val_loss, color='tab:blue', label='Validation loss')
plt.plot(epochs, val_pred_loss, '--', color='tab:blue', label='Validation prediction loss')
plt.plot(epochs, val_lifted_loss, ':', color='tab:blue', label='Validation lifted loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale('log')
plt.savefig("convergence plot for arch1")
plt.show()

# %%
map_net_params = {}
map_net_params["input_dim"] = int(num_joints) #number of joint angles
map_net_params["output_dim"] = X_end.shape[2] #x and y position of the end effector
map_net_params["hidden_width"] = 30 #20
map_net_params["hidden_depth"] = 4  #2
map_net_params["batch_size"] = 100  #100
map_net_params["epochs"] = 100   # 500
map_net_params["activation_type"] = 'tanh'
map_net_params["lr"] = 5e-4     #1e-3
map_net_params["optimizer"] = 'adam'
map_net_params['l2_reg'] = 0.0
map_net_params['l1_reg'] = 0.0

# %%
#dataset
# split training and vaidation datasets
xs_map_train, ys_map_train = X_full[:num_train,:,:int(num_joints)],X_end[:num_train,:,:num_inputs]
xs_map_val, ys_map_val = X_full[num_train:,:,:int(num_joints)],X_end[num_train:,:,:num_inputs]

# %%
ys_map_train.shape, ys_map_val.shape,xs_map_train.shape, xs_map_val.shape
# Out:
# ((93, 1001, 3), (32, 1001, 3), (93, 1001, 4), (32, 1001, 4))

# %%
#Initalize network
#Initalize network
if mass_var == True:
    file_fwd = 'saved_models/'+ robot_type +'/map_net_con_mass_var.pth' 
else:
    file_fwd = 'saved_models/'+ robot_type +'/map_net_con.pth'

if train == True:
    map_net = map_Net(map_net_params)
    map_net.set_dataset_map(xs_map_train,ys_map_train,xs_map_val,ys_map_val)
    map_net.data_pipeline()
    torch.save(map_net,file_fwd)
else:
    map_net = torch.load(file_fwd)
# Out:
# Epoch   1: train loss: 0.0436964988, validation loss: 0.0513391841
# Epoch   2: train loss: 0.0095905865, validation loss: 0.0315762242
# Epoch   3: train loss: 0.0054830813, validation loss: 0.0224845985
# Epoch   4: train loss: 0.0037925268, validation loss: 0.0181713944
# Epoch   5: train loss: 0.0029961897, validation loss: 0.0168977610
# Epoch   6: train loss: 0.0025416624, validation loss: 0.0150741983
# Epoch   7: train loss: 0.0021933859, validation loss: 0.0143956554
# Epoch   8: train loss: 0.0019359018, validation loss: 0.0138719681
# Epoch   9: train loss: 0.0017449662, validation loss: 0.0128976754
# Epoch  10: train loss: 0.0015562592, validation loss: 0.0121696220
# Epoch  11: train loss: 0.0014243874, validation loss: 0.0123186831
# Epoch  12: train loss: 0.0012935618, validation loss: 0.0121057430
# Epoch  13: train loss: 0.0012092833, validation loss: 0.0117607673
# Epoch  14: train loss: 0.0010955582, validation loss: 0.0115928447
# Epoch  15: train loss: 0.0010275302, validation loss: 0.0125515194
# Epoch  16: train loss: 0.0009476872, validation loss: 0.0113401509
# Epoch  17: train loss: 0.0008935925, validation loss: 0.0115427785
# Epoch  18: train loss: 0.0008321463, validation loss: 0.0114367314
# Epoch  19: train loss: 0.0007943037, validation loss: 0.0114319868
# Epoch  20: train loss: 0.0007384646, validation loss: 0.0114932004
# Epoch  21: train loss: 0.0006983796, validation loss: 0.0116533355
# Epoch  22: train loss: 0.0006754197, validation loss: 0.0113384496
# Epoch  23: train loss: 0.0006335476, validation loss: 0.0109631823
# Epoch  24: train loss: 0.0005987635, validation loss: 0.0110960149
# Epoch  25: train loss: 0.0005855514, validation loss: 0.0111467236
# Epoch  26: train loss: 0.0005740493, validation loss: 0.0109440745
# Epoch  27: train loss: 0.0005343718, validation loss: 0.0106956208
# Epoch  28: train loss: 0.0005182531, validation loss: 0.0105036333
# Epoch  29: train loss: 0.0004958636, validation loss: 0.0105001824
# Epoch  30: train loss: 0.0004853860, validation loss: 0.0101875244
# Epoch  31: train loss: 0.0004663302, validation loss: 0.0099020972
# Epoch  32: train loss: 0.0004496973, validation loss: 0.0098223056
# Epoch  33: train loss: 0.0004417728, validation loss: 0.0096467523
# Epoch  34: train loss: 0.0004200020, validation loss: 0.0095835378
# Epoch  35: train loss: 0.0004134276, validation loss: 0.0091265918
# Epoch  36: train loss: 0.0003996011, validation loss: 0.0089900541
# Epoch  37: train loss: 0.0003866673, validation loss: 0.0086302443
# Epoch  38: train loss: 0.0003718874, validation loss: 0.0089534468
# Epoch  39: train loss: 0.0003642518, validation loss: 0.0083399056
# Epoch  40: train loss: 0.0003461472, validation loss: 0.0081853276
# Epoch  41: train loss: 0.0003506596, validation loss: 0.0078061348
# Epoch  42: train loss: 0.0003231556, validation loss: 0.0077874350
# Epoch  43: train loss: 0.0003227589, validation loss: 0.0074806019
# Epoch  44: train loss: 0.0003100834, validation loss: 0.0075391555
# Epoch  45: train loss: 0.0003032462, validation loss: 0.0069675940
# Epoch  46: train loss: 0.0002967237, validation loss: 0.0069835767
# Epoch  47: train loss: 0.0002855705, validation loss: 0.0068001078
# Epoch  48: train loss: 0.0002821621, validation loss: 0.0066211140
# Epoch  49: train loss: 0.0002669098, validation loss: 0.0064794723
# Epoch  50: train loss: 0.0002674075, validation loss: 0.0063395197
# Epoch  51: train loss: 0.0002608381, validation loss: 0.0063355444
# Epoch  52: train loss: 0.0002579928, validation loss: 0.0058254634
# Epoch  53: train loss: 0.0002450169, validation loss: 0.0056896767
# Epoch  54: train loss: 0.0002399622, validation loss: 0.0058805417
# Epoch  55: train loss: 0.0002285527, validation loss: 0.0056600286
# Epoch  56: train loss: 0.0002289906, validation loss: 0.0054319328
# Epoch  57: train loss: 0.0002252182, validation loss: 0.0051931944
# Epoch  58: train loss: 0.0002157509, validation loss: 0.0051367053
# Epoch  59: train loss: 0.0002100438, validation loss: 0.0052065500
# Epoch  60: train loss: 0.0002009841, validation loss: 0.0047842070
# Epoch  61: train loss: 0.0001979398, validation loss: 0.0048187417
# Epoch  62: train loss: 0.0001941254, validation loss: 0.0047274171
# Epoch  63: train loss: 0.0001918159, validation loss: 0.0046343434
# Epoch  64: train loss: 0.0001877652, validation loss: 0.0046671260
# Epoch  65: train loss: 0.0001842429, validation loss: 0.0043862285
# Epoch  66: train loss: 0.0001810756, validation loss: 0.0045506442
# Epoch  67: train loss: 0.0001722254, validation loss: 0.0043533865
# Epoch  68: train loss: 0.0001690298, validation loss: 0.0043722979
# Epoch  69: train loss: 0.0001672633, validation loss: 0.0041569634
# Epoch  70: train loss: 0.0001614743, validation loss: 0.0041098711
# Epoch  71: train loss: 0.0001600778, validation loss: 0.0041575363
# Epoch  72: train loss: 0.0001571313, validation loss: 0.0040184514
# Epoch  73: train loss: 0.0001535078, validation loss: 0.0040081714
# Epoch  74: train loss: 0.0001510522, validation loss: 0.0037930816
# Epoch  75: train loss: 0.0001449348, validation loss: 0.0038592356
# Epoch  76: train loss: 0.0001461393, validation loss: 0.0039407285
# Epoch  77: train loss: 0.0001438023, validation loss: 0.0037545785
# Epoch  78: train loss: 0.0001411772, validation loss: 0.0038430929
# Epoch  79: train loss: 0.0001351921, validation loss: 0.0038676226
# Epoch  80: train loss: 0.0001316817, validation loss: 0.0036181270
# Epoch  81: train loss: 0.0001344021, validation loss: 0.0035304770
# Epoch  82: train loss: 0.0001280586, validation loss: 0.0034887556
# Epoch  83: train loss: 0.0001278903, validation loss: 0.0034741597
# Epoch  84: train loss: 0.0001224143, validation loss: 0.0034009627
# Epoch  85: train loss: 0.0001226889, validation loss: 0.0035390147
# Epoch  86: train loss: 0.0001185727, validation loss: 0.0033462082
# Epoch  87: train loss: 0.0001194797, validation loss: 0.0033884420
# Epoch  88: train loss: 0.0001130207, validation loss: 0.0033032612
# Epoch  89: train loss: 0.0001136045, validation loss: 0.0033840060
# Epoch  90: train loss: 0.0001140304, validation loss: 0.0033055681
# Epoch  91: train loss: 0.0001126688, validation loss: 0.0032385084
# Epoch  92: train loss: 0.0001073065, validation loss: 0.0033048265
# Epoch  93: train loss: 0.0001091183, validation loss: 0.0030654883
# Epoch  94: train loss: 0.0001063993, validation loss: 0.0032829382
# Epoch  95: train loss: 0.0001023650, validation loss: 0.0031857999
# Epoch  96: train loss: 0.0001047235, validation loss: 0.0032085428
# Epoch  97: train loss: 0.0000997985, validation loss: 0.0031532146
# Epoch  98: train loss: 0.0000978281, validation loss: 0.0030557451
# Epoch  99: train loss: 0.0001000659, validation loss: 0.0030161078
# Epoch 100: train loss: 0.0000975965, validation loss: 0.0030323630
# Finished training

# %%
epochs = np.arange(0, map_net_params['epochs'])
plt.figure(figsize=(15,8))
plt.plot(epochs, map_net.train_loss_hist, color='tab:orange', label='Training loss')
plt.plot(epochs, map_net.val_loss_hist, color='tab:blue', label='Validation loss')

plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale('log')
plt.savefig("convergence plot of map net for arch1[3,20,20,2]")
plt.show()

# %%
# import scipy.io
path_model = 'saved_models/'+ robot_type +'/matlab_files/' 

#save net parameters
scipy.io.savemat(path_model + "map_in_weights.mat", {"map_in_weights": map_net.map_net_in.weight.detach().numpy()})
scipy.io.savemat(path_model + "map_in_bias.mat", {"map_in_bias": map_net.map_net_in.bias.detach().numpy()})

scipy.io.savemat(path_model +"map_hidden_weights_1.mat",
                 {"map_hidden_weights_1": map_net.map_net_hid[0].weight.detach().numpy()})
scipy.io.savemat(path_model +"map_hidden_bias_1.mat",
                 {"map_hidden_bias_1": map_net.map_net_hid[0].bias.detach().numpy()})

scipy.io.savemat(path_model +"map_hidden_weights_2.mat",
                 {"map_hidden_weights_2": map_net.map_net_hid[1].weight.detach().numpy()})
scipy.io.savemat(path_model + "map_hidden_bias_2.mat",
                 {"map_hidden_bias_2": map_net.map_net_hid[1].bias.detach().numpy()})

scipy.io.savemat(path_model + "map_hidden_weights_3.mat",
                 {"map_hidden_weights_3": map_net.map_net_hid[2].weight.detach().numpy()})
scipy.io.savemat(path_model +"map_hidden_bias_3.mat",
                 {"map_hidden_bias_3": map_net.map_net_hid[2].bias.detach().numpy()})

scipy.io.savemat(path_model + "map_out_weights.mat", {"map_out_weights": map_net.map_net_out.weight.detach().numpy()})
scipy.io.savemat(path_model + "map_out_bias.mat", {"map_out_bias": map_net.map_net_out.bias.detach().numpy()})

# %%
map_net.map_net_hid
# Out:
# ModuleList(
#   (0-2): 3 x Linear(in_features=30, out_features=30, bias=True)
# )

# %% [markdown]
# ## Test Data Parameters

# %%
# test data parameters
num_snaps_val = num_snaps # no. of snapshots
T = np.linspace(0,num_snaps_val*dt, num_snaps_val+1)
num_traj_val = 1 # no. of training examples
first_obs_const = int(net_params['first_obs_const']) #only one state
override_C = net_params['override_C']
if override_C:
    n_obs = int(net_params['encoder_output_dim']) + num_states + first_obs_const 
else:
    n_obs = int(net_params['encoder_output_dim']) + first_obs_const

# %% [markdown]
# ***Koopman Bilinear Model***

# %%
A = np.array(model_koop_dnn.A)
#B = np.array(model_koop_dnn.B).reshape(-1,num_inputs*n_obs)
B = np.array(model_koop_dnn.B)
#B_tensor = np.empty((num_inputs,n_obs, n_obs))
#for ii, b in enumerate(B):
    #B_tensor[ii] = b
C = np.array(model_koop_dnn.C)

print(A.shape, B.shape, C.shape)
# Out:
# (19, 19) (19, 76) (8, 19)

# %% [markdown]
# ## Controlability

# %%
Ac = (A-np.eye(n_obs))/dt
Bc = B/dt
Cc = C
Cr = C[0:int(num_joints),:]

# %%
A.shape
# Out:
# (19, 19)

# %%
#check controllability
Con_lin = ct.ctrb(Ac, Bc)
rank_lin = np.linalg.matrix_rank(Con_lin)

print(rank_lin)
# Out:
# 18

# %%
out_con_mat, out_con_rank = Output_Con(Ac,Bc,Cc)


print(out_con_mat.shape)
print(out_con_rank)
# Out:
# (8, 1520)
# 8

# %%
# #SAVE MATRIX PARAMETERS AS MATLAB FILE
# import scipy.io

dyn_matrices = {"A": A, "B": B, "C": C}
scipy.io.savemat(path_model + "dyn_mat.mat", dyn_matrices)
#save encoder parameters
scipy.io.savemat(path_model + "in_weights.mat", {"encode_in_weights": model_koop_dnn.net.encoder_fc_in.weight.detach().numpy()})
scipy.io.savemat(path_model + "in_bias.mat", {"encode_in_bias": model_koop_dnn.net.encoder_fc_in.bias.detach().numpy()})

scipy.io.savemat(path_model + "hidden_weights_1.mat",
                 {"encode_hidden_weights_1": model_koop_dnn.net.encoder_fc_hid[0].weight.detach().numpy()})
scipy.io.savemat(path_model + "hidden_bias_1.mat",
                 {"encode_hidden_bias_1": model_koop_dnn.net.encoder_fc_hid[0].bias.detach().numpy()})

scipy.io.savemat(path_model + "hidden_weights_2.mat",
                 {"encode_hidden_weights_2": model_koop_dnn.net.encoder_fc_hid[1].weight.detach().numpy()})
scipy.io.savemat(path_model + "hidden_bias_2.mat",
                 {"encode_hidden_bias_2": model_koop_dnn.net.encoder_fc_hid[1].bias.detach().numpy()})

scipy.io.savemat(path_model + "out_weights.mat", {"encode_out_weights": model_koop_dnn.net.encoder_fc_out.weight.detach().numpy()})
scipy.io.savemat(path_model + "out_bias.mat", {"encode_out_bias": model_koop_dnn.net.encoder_fc_out.bias.detach().numpy()})

# %%
encode_out_bias = model_koop_dnn.net.encoder_fc_out.bias.detach().numpy()
encode_out_weights = model_koop_dnn.net.encoder_fc_out.weight.detach().numpy()

# %% [markdown]
# ***Test Data Generation***

# %%
# data_gen
j = 10
xs_end_test = X_end[j,:,:]
xs_test = X_full[j,:,:]
us_test = U_full[j,:,:]

# %%
print(xs_end_test.shape, xs_test.shape, us_test.shape)
# Out:
# (1001, 3) (1001, 8) (1000, 4)

# %%
print(model_koop_dnn.test_loss(xs_test.reshape(1,-1,num_states),u_test = us_test.reshape(1,-1,num_inputs)))
# Out:
# tensor(0.4798)

# %%
basis = model_koop_dnn.net.encode_forward_

# %%
X,_ = model_koop_dnn.net.process(xs_test.reshape(1,-1,num_states),data_u = us_test.reshape(1,-1,num_inputs))
print(X.shape)
# Out:
# (1000, 20)

# %%
x = X[:, :num_states]
u = X[:, num_states:num_states+num_inputs]
x_prime = X[:,num_states+num_inputs:]

print(x.shape, u.shape, x_prime.shape)
# Out:
# (1000, 8) (1000, 4) (1000, 8)

# %% [markdown]
# ***Initial Condition Lifting***

# %%
# initialize the matricies
z = np.empty((n_obs,num_snaps_val+1)).T
x_est = np.zeros((num_states,num_snaps_val+1)).T
x_end_est = np.zeros((X_end.shape[2],num_snaps_val)).T

# %%
z[0,:] = lift(x[0,:],model_koop_dnn, net_params)
x_est[0,:] = x[0,:]

# %% [markdown]
# ***Time Evolution***

# %%
for i in range(num_snaps_val):
  #bilinear
    z[i+1,:] = np.matmul(z[i,:],A.T)+np.matmul(np.kron(u[i,:],z[i,:]),B.T)
    x_est[i+1,:] = np.matmul(z[i+1,:],C.T)  
    x_end_est[i,:] = map_net.forward(torch.from_numpy(x_est[i,:int(num_joints)]).float()).detach().numpy()

# %% [markdown]
# ***Visualization***

# %% [markdown]
# # Joint Space

# %%
plt.figure(figsize=(20,12))
for i in range(int(num_joints)):
    plt.subplot(3,3,i+1)
    plt.plot(T[:-1],x[:,i],label ='Actual')
    plt.plot(T[:],x_est[:,i],label = 'estimated(bilinear)')
    plt.xlabel('t')
    plt.ylabel('theta_' + str(i))
    plt.title('theta_' + str(i) + ' Comparison')
    plt.legend()

# %%
plt.figure(figsize=(20,12))
for i in range(int(num_joints)):
    plt.subplot(3,3,i+1)
    plt.plot(T[:-1],x[:,int(num_joints)+i],label ='Actual')
    plt.plot(T[:],x_est[:,int(num_joints)+i],label = 'estimated(bilinear)')
    plt.xlabel('t')
    plt.ylabel('theta_dot_' + str(i))
    plt.title('theta_dot_' + str(i) + ' Comparison')
    plt.legend()

# %%
plt.figure(figsize=(20,12))
for i in range(int(num_joints)):
    plt.subplot(3,3,i+1)
    plt.plot(T[:-1],u[:,i])
    plt.xlabel('t')
    plt.ylabel('tau' + str(i))

# %%
plt.figure(figsize=(20,12))
for i in range(int(num_joints)):
    plt.subplot(3,3,i+1)
    plt.plot(T[:-1],us_test[:,i])
    plt.xlabel('t')
    plt.ylabel('tau' + str(i))

# %% [markdown]
# ## Cartesian Space

# %%
plt.figure(figsize=(20,6))
for i in range(X_end.shape[2]):
    plt.subplot(1,3,i+1)
    plt.plot(T[:],xs_end_test[:,i], label = 'Actual')
    plt.plot(T[:-1],x_end_est[:,i], label = 'Estimated')
    plt.legend()
plt.show()

# %%
error_joint_space = np.linalg.norm(xs_test-x_est,axis = 1)
error_cart_space = np.linalg.norm(xs_end_test[:-1]-x_end_est,axis = 1)

# %%
plt.figure(figsize =(20,6))
plt.subplot(1,2,1)
plt.plot(T[:],error_joint_space)
plt.title('Joint Space Error')

plt.subplot(1,2,2)
plt.plot(T[:-1],error_cart_space)
plt.title('Cartesian Space Error')
# Out:
# Text(0.5, 1.0, 'Cartesian Space Error')

# %%
xs_test[8,:]
# Out:
# array([-1.77072634e+00,  1.27176082e-01,  1.76420219e+00, -2.28697604e+00,
#         9.09717347e-03,  1.48297902e-02,  5.31363959e-03,  1.46378230e-03])

# %% [markdown]
# ## Controllers

# %% [markdown]
# ## Reference Trajectory

# %%
t_ctrl = np.arange(start=0, stop=5, step=dt)
num_snaps_ctrl = t_ctrl.shape[0]

# %%
## linear path
# x_ref = np.vstack((np.vstack((np.linspace(0,np.pi,num_snaps_ctrl),np.linspace(0,np.pi/2,num_snaps_ctrl))),np.linspace(0,np.pi,num_snaps_ctrl)))
# x_ref_dot = np.vstack((np.vstack(((np.pi/10)*np.ones(num_snaps_ctrl),(np.pi/20)*np.ones(num_snaps_ctrl))),(np.pi/10)*np.ones(num_snaps_ctrl)))
# x_ref_ddot = np.vstack((np.vstack((np.zeros(num_snaps_ctrl),np.zeros(num_snaps_ctrl))),np.zeros(num_snaps_ctrl)))

def gen_desired_path(num_states,num_snaps, t_end,shape):
    
    x_ref = np.empty((int(num_states),num_snaps))
    x_ref_dot = np.empty_like(x_ref)
    x_ref_ddot = np.empty_like(x_ref)
    
    arg = np.linspace(0,np.pi,num_snaps)
    
    for i in range(num_snaps):
        if shape == 'linear':
            x_ref[:,i] = np.array([arg[i], arg[i]/2, arg[i],arg[i]])
            x_ref_dot[:,i] = np.array([arg[-1]/t_end, arg[-1]/(2*t_end), arg[-1]/(t_end),arg[-1]/(t_end)])
            x_ref_ddot[:,i] = np.zeros(num_states,)
            
        elif shape == 'sinosoidal':
            x_ref[:,i] = 0.1*np.array([np.sin(2*arg[i]),np.sin(2*arg[i]) , np.sin(2*arg[i]),np.sin(2*arg[i])])
            x_ref_dot[:,i] = 0.1*np.array([(2*arg[-1]/t_end)*np.cos(2*arg[i]),(2*arg[-1]/t_end)*np.cos(2*arg[i]),
                                      (2*arg[-1]/t_end)*np.cos(2*arg[i]),(2*arg[-1]/t_end)*np.cos(2*arg[i])])
            x_ref_ddot[:,i] = 0.1* np.array([-((2*arg[-1]/t_end)**2)*np.cos(2*arg[i]),-((2*arg[-1]/t_end)**2)*np.sin(2*arg[i]),
                                      -((2*arg[-1]/t_end)**2)*np.sin(2*arg[i]),-((2*arg[-1]/t_end)**2)*np.sin(2*arg[i])])
        else:
            print('Shape is not defined')
            break
            
            
    return x_ref, x_ref_dot, x_ref_ddot

# %%
x_ref, x_ref_dot, x_ref_ddot = gen_desired_path(int(num_states/2),num_snaps_ctrl, t_ctrl[-1],'sinosoidal')
# x_ref = x[:,:3].T
# x_ref_dot = x[:,3:].T

# %% [markdown]
# ## ZNN

# %%
# gamma = 10

# %%
# ## specify the matricies
# z_ctrl = np.empty((n_obs,num_snaps_ctrl))
# x_ctrl = np.empty((num_states,num_snaps_ctrl))
# u_ctrl = np.empty((num_inputs,num_snaps_ctrl-1))
#
# ## initialize the matricies
# x_ctrl[:,0] = np.hstack((x_ref[:,0],x_ref_dot[:,0]))
# z_ctrl[:,0] = lift(x_ctrl[:,0],model_koop_dnn, net_params)

# %%
# x_ref_full = np.vstack((x_ref,x_ref_dot))
# x_ref_dot_full = np.vstack((x_ref_dot,x_ref_ddot))
# for i in range(2):
#     t = t_ctrl[i]
#     u_ctrl[:,i] = np.dot(np.linalg.pinv(np.matmul(C,np.matmul(Bc, np.kron(z_ctrl[:,i],np.eye(num_inputs)).T))), -np.matmul(C,np.matmul(Ac,z_ctrl[:,i])) + x_ref_dot_full[:,i] - gamma*(x_ctrl[:,i] - x_ref_full[:,i]))
#
#     z_ctrl[:,i+1] = np.matmul(z_ctrl[:,i],A.T)+np.matmul(np.kron(u_ctrl[:,i],z_ctrl[:,i]),B.T)
#     x_ctrl[:,i+1] = np.matmul(z_ctrl[:,i+1],C.T)
#     # x_ctrl[0:3,i+1],x_ctrl[3:,i+1] = dynamics_3R(dt, u_ctrl[:,i], x_ctrl[0:3,i],x_ctrl[3:,i], robot_pars)
#     # z_ctrl[:,i+1] = lift(x_ctrl[:,i+1],model_koop_dnn, net_params)
#

# %%
# plt.figure(figsize=(20,12))
# for i in range(int(num_joints)):
#     plt.subplot(3,3,i+1)
#     plt.plot(t_ctrl[:400],x_ref[i,:400],label ='reference')
#     plt.plot(t_ctrl[:400],x_ctrl[i,:400],label = 'traced')
#     plt.xlabel('t')
#     plt.ylabel('theta_' + str(i))
#     plt.title('theta_' + str(i) + ' Comparison')
#     plt.legend()

# %%
# plt.figure(figsize=(20,12))
# for i in range(int(num_joints)):
#     plt.subplot(3,3,i+1)
#     plt.plot(t_ctrl[:],x_ref_dot[i,:],label ='reference')
#     plt.plot(t_ctrl[:],x_ctrl[int(i+num_joints),:],label = 'traced')
#     plt.xlabel('t')
#     plt.ylabel('theta_dot ' + str(i))
#     plt.title('theta_dot ' + str(i) + ' Comparison')
#     plt.legend()

# %%
# plt.figure(figsize=(20,12))
# for i in range(int(num_joints)):
#     plt.subplot(3,3,i+1)
#     plt.plot(t_ctrl[:-1],u_ctrl2[i,:])
#     plt.xlabel('t')
#     plt.ylabel('tau' + str(i))

# %%
# np.linalg.pinv(np.matmul(C,np.matmul(Bc, np.kron(z_ctrl[:,i],np.eye(num_inputs)).T))).shape

# %%
# np.dot(np.linalg.pinv(np.matmul(C,np.matmul(Bc, np.kron(z_ctrl[:,i],np.eye(num_inputs)).T))), -np.matmul(C,np.matmul(Ac,z_ctrl[:,i])) + x_ref_dot_full[:,i] - gamma*(x_ctrl[:,i] - x_ref_full[:,i])).shape

# %%
# ZNN implementation with only reference joint angles
gamma2 = 5
num_theta = int(num_joints)
# num_snaps_ctrl = 2
## specify the matricies
z_ctrl2 = np.zeros((n_obs, num_snaps_ctrl))
x_ctrl2 = np.zeros((num_theta, num_snaps_ctrl))
u_ctrl2 = np.zeros((num_inputs, num_snaps_ctrl - 1))
error = np.zeros((num_theta, num_snaps_ctrl))

## initialize the matricies
x_ctrl2[:, 0] = x_ref[:, 0]
z_ctrl2[:, 0] = lift(np.hstack((x_ref[:, 0], x_ref_dot[:, 0])), model_koop_dnn, net_params)

for i in range(num_snaps_ctrl - 1):
    t = t_ctrl[i]
    error[:,i] = x_ctrl2[:,i] - x_ref[:,i]

    u_ctrl2[:,i] = np.linalg.pinv(Cr @ Bc @ np.kron(z_ctrl2[:, i], np.eye(num_inputs)).T) @ (-gamma2 * error[:,i] + x_ref_dot[:,i] - Cr @ Ac @ z_ctrl2[:,i])
    # u_ctrl2[:,i] = np.clip(u_ctrl2[:,i],-0.3,0.3)
    z_ctrl2[:, i + 1] = np.matmul(z_ctrl2[:, i], A.T) + np.matmul(np.kron(u_ctrl2[:, i], z_ctrl2[:, i]), B.T)
    x_ctrl2[:, i + 1] = np.matmul(z_ctrl2[:, i + 1], Cr.T)
    # x_ctrl[0:3,i+1],x_ctrl[3:,i+1] = dynamics_3R(dt, u_ctrl[:,i], x_ctrl[0:3,i],x_ctrl[3:,i], robot_pars)
    # z_ctrl[:,i+1] = lift(x_ctrl[:,i+1],model_koop_dnn, net_params)

# %%
plt.figure(figsize=(20,12))
for i in range(int(num_joints)):
    plt.subplot(3,3,i+1)
    plt.plot(t_ctrl[:600],x_ref[i,:600],label ='reference')
    plt.plot(t_ctrl[:600],x_ctrl2[i,:600],label = 'traced')
    plt.xlabel('t')
    plt.ylabel('theta_' + str(i))
    plt.title('theta_' + str(i) + ' Comparison')
    plt.legend()

# %%
plt.figure(figsize=(20,12))
for i in range(int(num_joints)):
    plt.subplot(3,3,i+1)
    plt.plot(t_ctrl[:-1],u_ctrl2[i,:])
    plt.xlabel('t')
    plt.ylabel('tau' + str(i))

# %%
plt.figure(figsize=(20,12))
for i in range(int(num_joints)):
    plt.subplot(3,3,i+1)
    plt.plot(t_ctrl,error[i,:])
    plt.xlabel('t')
    plt.ylabel('error' + str(i))

# %% [markdown]
# ## MPC

# %%
# Create Linear Model Instanse
bilinear_model = bilinear_Dynamics(sparse.csc_matrix(A),sparse.csc_matrix(B), C)
x_ref_full = np.vstack((x_ref,x_ref_dot))

# Model parameters
solver_settings = {}
solver_settings['gen_embedded_ctrl'] = False
solver_settings['warm_start'] = True
solver_settings['polish'] = True
solver_settings['polish_refine_iter'] = 3
solver_settings['scaling'] = True
solver_settings['adaptive_rho'] = False
solver_settings['check_termination'] = 25
solver_settings['max_iter'] = 1000
solver_settings['eps_abs'] = 1e-6
solver_settings['eps_rel'] = 1e-6
solver_settings['eps_prim_inf'] = 1e-4
solver_settings['eps_dual_inf'] = 1e-4
solver_settings['linsys_solver'] = 'qdldl'

## set limits
umax = 10*np.array([1, 1, 1])
umin = -umax

xmax =  10*np.array([1, 1, 1, 1, 1, 1])
xmin = -xmax

# %%
traj_length = num_snaps_ctrl
max_iter = 100
N = 10 #length of horizon
t_eval = dt * np.arange(traj_length+1)          # Simulation time points, closed loop
Q_mpc =  sparse.diags(1e2*np.array([1,1,1,0,0,0]))        # State penalty matrix, trajectory generation
QN_mpc = 1*sparse.eye(num_states)       # Final state penalty matrix, trajectory generation
R_mpc =  1*sparse.eye(num_inputs)         # Actuation penalty matrix, trajectory generation
R0_mpc = sparse.csc_matrix(np.zeros(num_inputs))

# Design trajectory:
x0 = x_ref_full[:,0]                        
# State constraints, trajectory generation
# Define initial solution for SQP algorithm:
x_init = np.linspace(x0, x0, N+1)
u_init = 1*np.ones((num_inputs, N)).T

# %%
z_init = np.empty((N+1, n_obs))
z0 = lift(x0, model_koop_dnn, net_params)
for i in range(N+1):
    z_init[i,:] = lift(x_init[i,:], model_koop_dnn, net_params)

# %%
controller_nmpc = NonlinearMPCController(bilinear_model, N, dt, umin, umax, xmin, xmax, Q_mpc, R_mpc, QN_mpc, solver_settings)
controller_nmpc.construct_controller(z_init, u_init,x_ref_full[:,0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 2
#       1 controller_nmpc = NonlinearMPCController(bilinear_model, N, dt, umin, umax, xmin, xmax, Q_mpc, R_mpc, QN_mpc, solver_settings)
# ----> 2 controller_nmpc.construct_controller(z_init, u_init,x_ref_full[:,0])
#
# File ~/Projects/Koopman_ZNN/control_files/nmpc_osqp.py:80, in NonlinearMPCController.construct_controller(self, z_init, u_init, x_ref)
#      77 r_lst = [np.ones(self.nz) for _ in range(self.N)]
#      78 self.r_vec = np.array(r_lst).flatten()
# ---> 80 self.construct_objective_(x_ref)
#      81 self.construct_constraint_vecs_(z0)
#      82 self.construct_constraint_matrix_(A_lst, B_lst)
#
# File ~/Projects/Koopman_ZNN/control_files/nmpc_osqp.py:232, in NonlinearMPCController.construct_objective_(self, xr)
#     226 """
#     227 Construct MPC objective function
#     228 :return:
#     229 """
#     230 # Quadratic objective:
# --> 232 self._osqp_P = sparse.block_diag([sparse.kron(sparse.eye(self.N), self.C.T @ self.Q @ self.C),
#     233                                   self.C.T @ self.QN @ self.C,
#     234                                   sparse.kron(sparse.eye(self.N), self.R)], format='csc')
#     237 # Linear objective:
#     238 self._osqp_q = np.hstack(
#     239     [(self.C.T @ self.Q @ (self.C @ self.z_init[:-1, :].T - xr.reshape(-1, 1))).flatten(order='F'),
#     240      self.C.T @ self.QN @ (self.C @ self.z_init[-1, :] - xr),
#     241      (self.R @ (self.u_init.T)).flatten(order='F')])
#
# File ~/.local/lib/python3.8/site-packages/scipy/sparse/_base.py:636, in spmatrix.__rmatmul__(self, other)
#     633 if isscalarlike(other):
#     634     raise ValueError("Scalar operands are not allowed, "
#     635                      "use '*' instead")
# --> 636 return self._rmul_dispatch(other)
#
# File ~/.local/lib/python3.8/site-packages/scipy/sparse/_base.py:614, in spmatrix._rmul_dispatch(self, other)
#     612 except AttributeError:
#     613     tr = np.asarray(other).transpose()
# --> 614 ret = self.transpose()._mul_dispatch(tr)
#     615 if ret is NotImplemented:
#     616     return NotImplemented
#
# File ~/.local/lib/python3.8/site-packages/scipy/sparse/_base.py:577, in spmatrix._mul_dispatch(self, other)
#     572 elif other.ndim == 2:
#     573     ##
#     574     # dense 2D array or matrix ("multivector")
#     576     if other.shape[0] != self.shape[1]:
# --> 577         raise ValueError('dimension mismatch')
#     579     result = self._mul_multivector(np.asarray(other))
#     581     if isinstance(other, np.matrix):
#
# ValueError: dimension mismatch

# %%
controller_nmpc.trajectory_tracking(x0, z0, x_ref_full.T, max_iter)

# %%
plt.figure(figsize=(18, 6)) 
plt.subplot(1,3,1)
plt.plot(t_ctrl[:],x_ref[0,:],label ='reference')
plt.plot(t_eval,controller_nmpc.x_traced[:,0],label = 'traced')
plt.xlabel('t')
plt.ylabel('theta_1')
plt.title('theta_1 Comparison')
plt.legend()

plt.subplot(1,3,2)
plt.plot(t_ctrl[:],x_ref[1,:],label ='reference')
plt.plot(t_eval,controller_nmpc.x_traced[:,1],label = 'traced')
plt.xlabel('t')
plt.ylabel('theta_2')
plt.title('theta_2 Comparison')
plt.legend()

plt.subplot(1,3,3)
plt.plot(t_ctrl[:],x_ref[2,:],label ='reference')
plt.plot(t_eval,controller_nmpc.x_traced[:,2],label = 'traced')
plt.xlabel('t')
plt.ylabel('theta_3')
plt.title('theta_3 Comparison')
plt.legend()

# %%
plt.figure(figsize=(18, 6)) 
plt.subplot(1,3,1)
plt.plot(t_eval[:-1],controller_nmpc.controls[:,0],label = 'traced')
plt.xlabel('t')
plt.ylabel('theta_1')
plt.title('theta_1 Comparison')
plt.legend()

plt.subplot(1,3,2)
plt.plot(t_eval[:-1],controller_nmpc.controls[:,1],label = 'traced')
plt.xlabel('t')
plt.ylabel('theta_2')
plt.title('theta_2 Comparison')
plt.legend()

plt.subplot(1,3,3)
plt.plot(t_eval[:-1],controller_nmpc.controls[:,2],label = 'traced')
plt.xlabel('t')
plt.ylabel('theta_3')
plt.title('theta_3 Comparison')
plt.legend()
