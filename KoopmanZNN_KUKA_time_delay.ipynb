# %% [markdown]
# ***Import Libraries***

# %%
"""This program bilinearizes 3R planar dyanmics using koopman theory and autoencoder to map"""
import numpy as np
import matplotlib.pyplot as plt
import sklearn.preprocessing
import itertools
import scipy.io
import torch

# bilinear Koopman
from core.koopman_time_delay import KoopDNN, KoopmanNet, KoopmanNetCtrl
from models.koop_model import model_matricies,lift, lift_delay
from core.util import fit_standardizer
from sklearn import preprocessing

# forward map neural net
from core.neural_fwd_map import map_Net


## import paths
from paths.paths import path_pars

# %% [markdown]
# ### Load Data

# %%
data = scipy.io.loadmat('dynamics/Dataset_MATLAB/2D/data.mat')

X_end = np.array(data['X_end'], dtype = 'float64')
X_full = np.array(data['X'], dtype = 'float64')
U_full = np.array(data['tau'], dtype = 'float64')

print(X_end.shape, X_full.shape,U_full.shape)
# Out:
# (500, 501, 3) (500, 501, 6) (500, 500, 7)

# %%
np.sum(np.sum(np.isnan(X_end))), np.sum(np.sum(np.isnan(U_full))), np.sum(np.sum(np.isnan(X_full)))
# Out:
# (0, 0, 0)

# %% [markdown]
# ***Simulation Parameters***

# %%
dt = float(data['dt']) #time step
num_snaps = int(data['num_snaps']) # no. of snapshots
num_traj = int(data['num_traj']) #no of trajectories
T = np.linspace(0,num_snaps*dt, num_snaps+1)
num_train = int(0.75*num_traj) # no. of training examples
num_val = num_traj-num_train # no of testing examples
num_traj = num_train+num_val #no of trajectories
num_states = X_full.shape[2] # no. of states
num_inputs = U_full.shape[2] # no. of inputs

# %%
dt, num_snaps, num_traj, num_states, num_inputs
# Out:
# (0.005, 500, 500, 6, 7)

# %% [markdown]
# ***Plotting the trajectories***

# %%
"""Training dataset visualization"""
#theta evolution
for i in range(int(num_states/2)):
    plt.subplot(3,3,i+1)
    plt.xlabel("t")
    plt.ylabel("th"+str(i+1))
    for j in range(num_traj):
        plt.plot(T,X_full[j,:,i])

# %%
for i in range(int(num_states/2)):
    plt.subplot(3,3,i+1)
    plt.xlabel("t")
    plt.ylabel("th"+str(i+1)+ ' dot')
    for j in range(num_traj):
        plt.plot(T,X_full[j,:,i+int(num_states/2)])

# %%
#x and y positions of the end effector
ax = plt.axes(projection='3d')
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
for i in range(num_traj):
    ax.plot3D(X_end[i,:,0],X_end[i,:,1],X_end[i,:,2])

plt.axis('equal')
# Out:
# (-1.0281885547005443,
#  1.0231498771372207,
#  -1.025669215915997,
#  1.025669215921768)

# %%
for i in range(num_inputs):
    plt.subplot(4,2,i+1)
    plt.xlabel("t")
    plt.ylabel("tau"+str(i))
    for j in range(num_traj):
        plt.plot(T[:-1],U_full[j,:,i])

# %% [markdown]
# ***Training and validation datasets***

# %%
# split training and vaidation datasets
xs_train, us_train = X_full[:num_train,:,:],U_full[:num_train,:,:]
xs_val, us_val = X_full[num_train:,:,:],U_full[num_train:,:,:]

# %%
# import scipy.io
# Data_set = {"x_end": X_end, "X_full": X_full}
# scipy.io.savemat("Data_set.mat",Data_set)

# %%
# import torch
# import torch.nn as nn
# import torch.nn.functional as F

# %% [markdown]
# ***Model Training***

# %%
net_params = {}
net_params['state_dim'] = num_states
net_params['ctrl_dim'] = num_inputs
net_params["output_dim"] = num_states
net_params['encoder_hidden_width'] = 30
net_params['encoder_hidden_depth'] = 2
net_params["num_delays"] = 10
net_params['encoder_output_dim'] = 20
net_params['optimizer'] = 'adam'
net_params['activation_type'] = 'tanh'
net_params['lr'] = 5e-5 # 5e-4
net_params['epochs'] = 500
net_params['batch_size'] = 128
net_params['lifted_loss_penalty'] = 0.4 
net_params['l2_reg'] = 0.0         
net_params['l1_reg'] = 0.0
net_params['first_obs_const'] = True
net_params['override_C'] = True # this makes the state a part of lifetd state
net_params['dt'] = dt

# %%
train = True

if train == True:
    file = 'saved_models/Kuka/2D/koop_arch_time_delay.pth'
    # standardizer_u_kdnn = fit_standardizer(us_train, preprocessing.StandardScaler(with_mean=False))
    # net = KoopmanNetCtrl(net_params, standardizer_u=standardizer_u_kdnn)
    net = KoopmanNetCtrl(net_params)
    model_koop_dnn = KoopDNN(net)
    model_koop_dnn.set_datasets(xs_train, u_train=us_train, x_val=xs_val, u_val=us_val)
    model_koop_dnn.model_pipeline(net_params)
    model_koop_dnn.construct_koopman_model()
    torch.save(model_koop_dnn,file)
else:
    file = 'saved_models/Kuka/2D/koop_arch_time_delay.pth'
    model_koop_dnn = torch.load(file)
# Out:
# Epoch   1: train loss: 0.8826053143, validation loss: 0.7231982621
# Epoch   2: train loss: 0.5963759422, validation loss: 0.5586805046
# Epoch   3: train loss: 0.4880595207, validation loss: 0.4578181138
# Epoch   4: train loss: 0.3771074414, validation loss: 0.3514663868
# Epoch   5: train loss: 0.3075481355, validation loss: 0.3062724992
# Epoch   6: train loss: 0.2780481875, validation loss: 0.2836045484
# Epoch   7: train loss: 0.2613737583, validation loss: 0.2692035035
# Epoch   8: train loss: 0.2499528229, validation loss: 0.2590300977
# Epoch   9: train loss: 0.2409396321, validation loss: 0.2507957127
# Epoch  10: train loss: 0.2335962057, validation loss: 0.2435128855
# Epoch  11: train loss: 0.2273741215, validation loss: 0.2373707400
# Epoch  12: train loss: 0.2219692916, validation loss: 0.2318073090
# Epoch  13: train loss: 0.2170502543, validation loss: 0.2271326514
# Epoch  14: train loss: 0.2123265117, validation loss: 0.2214904709
# Epoch  15: train loss: 0.2073892206, validation loss: 0.2161582374
# Epoch  16: train loss: 0.2026260495, validation loss: 0.2112948512
# Epoch  17: train loss: 0.1988744885, validation loss: 0.2078250748
# Epoch  18: train loss: 0.1959977150, validation loss: 0.2045233353
# Epoch  19: train loss: 0.1936678886, validation loss: 0.2023571340
# Epoch  20: train loss: 0.1917085946, validation loss: 0.2002714537
# Epoch  21: train loss: 0.1899819523, validation loss: 0.1982876421
# Epoch  22: train loss: 0.1884715855, validation loss: 0.1968714660
# Epoch  23: train loss: 0.1870933026, validation loss: 0.1953960507
# Epoch  24: train loss: 0.1858442873, validation loss: 0.1937276747
# Epoch  25: train loss: 0.1846883893, validation loss: 0.1927062813
# Epoch  26: train loss: 0.1836171001, validation loss: 0.1914054464
# Epoch  27: train loss: 0.1826098710, validation loss: 0.1903373729
# Epoch  28: train loss: 0.1816891879, validation loss: 0.1894109217
# Epoch  29: train loss: 0.1808484197, validation loss: 0.1884577350
# Epoch  30: train loss: 0.1800621450, validation loss: 0.1876076028
# Epoch  31: train loss: 0.1793300509, validation loss: 0.1869550234
# Epoch  32: train loss: 0.1786802113, validation loss: 0.1860216059
# Epoch  33: train loss: 0.1780725569, validation loss: 0.1854471623
# Epoch  34: train loss: 0.1774906218, validation loss: 0.1847945766
# Epoch  35: train loss: 0.1770003438, validation loss: 0.1844560132
# Epoch  36: train loss: 0.1765114814, validation loss: 0.1837465465
# Epoch  37: train loss: 0.1760936826, validation loss: 0.1833117738
# Epoch  38: train loss: 0.1757006198, validation loss: 0.1828191158
# Epoch  39: train loss: 0.1753187776, validation loss: 0.1824692025
# Epoch  40: train loss: 0.1749520302, validation loss: 0.1820940235
# Epoch  41: train loss: 0.1746234596, validation loss: 0.1816628612
# Epoch  42: train loss: 0.1743080914, validation loss: 0.1813846075
# Epoch  43: train loss: 0.1740335077, validation loss: 0.1809334943
# Epoch  44: train loss: 0.1737587452, validation loss: 0.1806378411
# Epoch  45: train loss: 0.1734789461, validation loss: 0.1806599729
# Epoch  46: train loss: 0.1732211411, validation loss: 0.1802846576
# Epoch  47: train loss: 0.1729695201, validation loss: 0.1798479300
# Epoch  48: train loss: 0.1727382690, validation loss: 0.1796440855
# Epoch  49: train loss: 0.1725069433, validation loss: 0.1794496414
# Epoch  50: train loss: 0.1722935736, validation loss: 0.1790675975
# Epoch  51: train loss: 0.1720819771, validation loss: 0.1788196584
# Epoch  52: train loss: 0.1718849540, validation loss: 0.1786927691
# Epoch  53: train loss: 0.1716788411, validation loss: 0.1784049987
# Epoch  54: train loss: 0.1715115011, validation loss: 0.1783532058
# Epoch  55: train loss: 0.1713300943, validation loss: 0.1780516524
# Epoch  56: train loss: 0.1711545587, validation loss: 0.1778400916
# Epoch  57: train loss: 0.1709607840, validation loss: 0.1776411854
# Epoch  58: train loss: 0.1708383411, validation loss: 0.1775000333
# Epoch  59: train loss: 0.1706681252, validation loss: 0.1774918786
# Epoch  60: train loss: 0.1705167592, validation loss: 0.1772038465
# Epoch  61: train loss: 0.1703945100, validation loss: 0.1769665044
# Epoch  62: train loss: 0.1702456772, validation loss: 0.1769144593
# Epoch  63: train loss: 0.1701115966, validation loss: 0.1767858335
# Epoch  64: train loss: 0.1699945629, validation loss: 0.1769006938
# Epoch  65: train loss: 0.1698498577, validation loss: 0.1766995716
# Epoch  66: train loss: 0.1697482020, validation loss: 0.1763569434
# Epoch  67: train loss: 0.1696253419, validation loss: 0.1762744470
# Epoch  68: train loss: 0.1695189029, validation loss: 0.1761749569
# Epoch  69: train loss: 0.1694414467, validation loss: 0.1760319605
# Epoch  70: train loss: 0.1693653613, validation loss: 0.1759009198
# Epoch  71: train loss: 0.1692327857, validation loss: 0.1758399455
# Epoch  72: train loss: 0.1691754013, validation loss: 0.1758077486
# Epoch  73: train loss: 0.1690782160, validation loss: 0.1756974401
# Epoch  74: train loss: 0.1689894050, validation loss: 0.1757172996
# Epoch  75: train loss: 0.1689172089, validation loss: 0.1755884342
# Epoch  76: train loss: 0.1688325852, validation loss: 0.1755680491
# Epoch  77: train loss: 0.1687683165, validation loss: 0.1754129570
# Epoch  78: train loss: 0.1686876714, validation loss: 0.1753056469
# Epoch  79: train loss: 0.1686178893, validation loss: 0.1753471877
# Epoch  80: train loss: 0.1685534567, validation loss: 0.1751592873
# Epoch  81: train loss: 0.1684982181, validation loss: 0.1751745217
# Epoch  82: train loss: 0.1684200168, validation loss: 0.1751707264
# Epoch  83: train loss: 0.1683898717, validation loss: 0.1749995481
# Epoch  84: train loss: 0.1683258712, validation loss: 0.1749581411
# Epoch  85: train loss: 0.1682816893, validation loss: 0.1749697211
# Epoch  86: train loss: 0.1682206392, validation loss: 0.1748570893
# Epoch  87: train loss: 0.1681796312, validation loss: 0.1748806383
# Epoch  88: train loss: 0.1681313664, validation loss: 0.1748400736
# Epoch  89: train loss: 0.1680748761, validation loss: 0.1748750735
# Epoch  90: train loss: 0.1680476665, validation loss: 0.1748713566
# Epoch  91: train loss: 0.1679659635, validation loss: 0.1747421065
# Epoch  92: train loss: 0.1679563075, validation loss: 0.1746794957
# Epoch  93: train loss: 0.1679017097, validation loss: 0.1745687737
# Epoch  94: train loss: 0.1678606570, validation loss: 0.1746364662
# Epoch  95: train loss: 0.1678446829, validation loss: 0.1745356898
# Epoch  96: train loss: 0.1677811444, validation loss: 0.1745867350
# Epoch  97: train loss: 0.1677583605, validation loss: 0.1745351365
# Epoch  98: train loss: 0.1677189767, validation loss: 0.1744018383
# Epoch  99: train loss: 0.1676876992, validation loss: 0.1743306153
# Epoch 100: train loss: 0.1676491797, validation loss: 0.1743828691
# Epoch 101: train loss: 0.1676255018, validation loss: 0.1742990457
# Epoch 102: train loss: 0.1676161438, validation loss: 0.1743151155
# Epoch 103: train loss: 0.1675614268, validation loss: 0.1743681242
# Epoch 104: train loss: 0.1675166190, validation loss: 0.1742182261
# Epoch 105: train loss: 0.1674951911, validation loss: 0.1741643104
# Epoch 106: train loss: 0.1674538553, validation loss: 0.1742931728
# Epoch 107: train loss: 0.1674547493, validation loss: 0.1742288930
# Epoch 108: train loss: 0.1674132794, validation loss: 0.1740870758
# Epoch 109: train loss: 0.1673904657, validation loss: 0.1740918526
# Epoch 110: train loss: 0.1673721224, validation loss: 0.1743133510
# Epoch 111: train loss: 0.1673348397, validation loss: 0.1741173678
# Epoch 112: train loss: 0.1673221290, validation loss: 0.1741049813
# Epoch 113: train loss: 0.1672827750, validation loss: 0.1739538349
# Epoch 114: train loss: 0.1672731936, validation loss: 0.1740490612
# Epoch 115: train loss: 0.1672473103, validation loss: 0.1739266522
# Epoch 116: train loss: 0.1672185659, validation loss: 0.1739370870
# Epoch 117: train loss: 0.1671926826, validation loss: 0.1739339657
# Epoch 118: train loss: 0.1671483964, validation loss: 0.1739076921
# Epoch 119: train loss: 0.1671177894, validation loss: 0.1739743491
# Epoch 120: train loss: 0.1671107113, validation loss: 0.1737904223
# Epoch 121: train loss: 0.1670928001, validation loss: 0.1737749031
# Epoch 122: train loss: 0.1670613140, validation loss: 0.1737605015
# Epoch 123: train loss: 0.1670333147, validation loss: 0.1737441432
# Epoch 124: train loss: 0.1670350581, validation loss: 0.1737610700
# Epoch 125: train loss: 0.1670195907, validation loss: 0.1737286671
# Epoch 126: train loss: 0.1669905037, validation loss: 0.1738459531
# Epoch 127: train loss: 0.1669549644, validation loss: 0.1736483640
# Epoch 128: train loss: 0.1669336110, validation loss: 0.1737064435
# Epoch 129: train loss: 0.1669180989, validation loss: 0.1737379825
# Epoch 130: train loss: 0.1669027358, validation loss: 0.1736104505
# Epoch 131: train loss: 0.1668935120, validation loss: 0.1736163317
# Epoch 132: train loss: 0.1668691784, validation loss: 0.1735849235
# Epoch 133: train loss: 0.1668386012, validation loss: 0.1734936624
# Epoch 134: train loss: 0.1668083668, validation loss: 0.1734557612
# Epoch 135: train loss: 0.1667890102, validation loss: 0.1735380208
# Epoch 136: train loss: 0.1667670757, validation loss: 0.1735307353
# Epoch 137: train loss: 0.1667615771, validation loss: 0.1734741454
# Epoch 138: train loss: 0.1667243689, validation loss: 0.1734413081
# Epoch 139: train loss: 0.1667035073, validation loss: 0.1733455902
# Epoch 140: train loss: 0.1667004526, validation loss: 0.1733608551
# Epoch 141: train loss: 0.1666458696, validation loss: 0.1733234008
# Epoch 142: train loss: 0.1666260362, validation loss: 0.1734421770
# Epoch 143: train loss: 0.1666039526, validation loss: 0.1732656568
# Epoch 144: train loss: 0.1665903330, validation loss: 0.1733641073
# Epoch 145: train loss: 0.1665489078, validation loss: 0.1733001008
# Epoch 146: train loss: 0.1665420681, validation loss: 0.1731768737
# Epoch 147: train loss: 0.1665135175, validation loss: 0.1730772681
# Epoch 148: train loss: 0.1664703041, validation loss: 0.1733057428
# Epoch 149: train loss: 0.1664450616, validation loss: 0.1730631603
# Epoch 150: train loss: 0.1664345860, validation loss: 0.1730865533
# Epoch 151: train loss: 0.1663952619, validation loss: 0.1731786147
# Epoch 152: train loss: 0.1663795859, validation loss: 0.1730150784
# Epoch 153: train loss: 0.1663435549, validation loss: 0.1729214379
# Epoch 154: train loss: 0.1662908643, validation loss: 0.1728303162
# Epoch 155: train loss: 0.1662653983, validation loss: 0.1727993558
# Epoch 156: train loss: 0.1662342250, validation loss: 0.1728849680
# Epoch 157: train loss: 0.1662021279, validation loss: 0.1727327498
# Epoch 158: train loss: 0.1661920846, validation loss: 0.1727556276
# Epoch 159: train loss: 0.1661376059, validation loss: 0.1728656033
# Epoch 160: train loss: 0.1660881191, validation loss: 0.1726393432
# Epoch 161: train loss: 0.1660590172, validation loss: 0.1726411752
# Epoch 162: train loss: 0.1660073996, validation loss: 0.1725858932
# Epoch 163: train loss: 0.1659580171, validation loss: 0.1725070670
# Epoch 164: train loss: 0.1659096777, validation loss: 0.1724404862
# Epoch 165: train loss: 0.1658813059, validation loss: 0.1722807486
# Epoch 166: train loss: 0.1658457816, validation loss: 0.1723439108
# Epoch 167: train loss: 0.1657688767, validation loss: 0.1723565549
# Epoch 168: train loss: 0.1657048762, validation loss: 0.1721935066
# Epoch 169: train loss: 0.1656626612, validation loss: 0.1720851594
# Epoch 170: train loss: 0.1655883789, validation loss: 0.1721722636
# Epoch 171: train loss: 0.1655444801, validation loss: 0.1721266036
# Epoch 172: train loss: 0.1654760689, validation loss: 0.1718482167
# Epoch 173: train loss: 0.1654275656, validation loss: 0.1718763135
# Epoch 174: train loss: 0.1653516591, validation loss: 0.1719360549
# Epoch 175: train loss: 0.1652634293, validation loss: 0.1716436144
# Epoch 176: train loss: 0.1652101576, validation loss: 0.1716253334
# Epoch 177: train loss: 0.1651551276, validation loss: 0.1715121198
# Epoch 178: train loss: 0.1650948972, validation loss: 0.1714670138
# Epoch 179: train loss: 0.1650174111, validation loss: 0.1716009199
# Epoch 180: train loss: 0.1649173200, validation loss: 0.1713384031
# Epoch 181: train loss: 0.1648605019, validation loss: 0.1715623722
# Epoch 182: train loss: 0.1648261398, validation loss: 0.1711796609
# Epoch 183: train loss: 0.1647450477, validation loss: 0.1710785561
# Epoch 184: train loss: 0.1646366864, validation loss: 0.1711973459
# Epoch 185: train loss: 0.1645870507, validation loss: 0.1709258809
# Epoch 186: train loss: 0.1645097435, validation loss: 0.1709507705
# Epoch 187: train loss: 0.1644569337, validation loss: 0.1707927853
# Epoch 188: train loss: 0.1643596143, validation loss: 0.1707348661
# Epoch 189: train loss: 0.1643232107, validation loss: 0.1707367729
# Epoch 190: train loss: 0.1642485261, validation loss: 0.1705764050
# Epoch 191: train loss: 0.1641739905, validation loss: 0.1704674465
# Epoch 192: train loss: 0.1641114801, validation loss: 0.1704089878
# Epoch 193: train loss: 0.1640462875, validation loss: 0.1703561146
# Epoch 194: train loss: 0.1639682204, validation loss: 0.1703074092
# Epoch 195: train loss: 0.1638935506, validation loss: 0.1701880149
# Epoch 196: train loss: 0.1638061702, validation loss: 0.1701982238
# Epoch 197: train loss: 0.1637513340, validation loss: 0.1701098084
# Epoch 198: train loss: 0.1636865586, validation loss: 0.1702502107
# Epoch 199: train loss: 0.1636490524, validation loss: 0.1699850089
# Epoch 200: train loss: 0.1635268629, validation loss: 0.1698863767
# Epoch 201: train loss: 0.1634877473, validation loss: 0.1697523196
# Epoch 202: train loss: 0.1634278744, validation loss: 0.1698275276
# Epoch 203: train loss: 0.1633245796, validation loss: 0.1696903441
# Epoch 204: train loss: 0.1632470489, validation loss: 0.1697644032
# Epoch 205: train loss: 0.1632225960, validation loss: 0.1696802405
# Epoch 206: train loss: 0.1631190181, validation loss: 0.1694209925
# Epoch 207: train loss: 0.1630912125, validation loss: 0.1692889846
# Epoch 208: train loss: 0.1630275846, validation loss: 0.1692139159
# Epoch 209: train loss: 0.1629475504, validation loss: 0.1692129186
# Epoch 210: train loss: 0.1628931910, validation loss: 0.1691239602
# Epoch 211: train loss: 0.1627937555, validation loss: 0.1691333427
# Epoch 212: train loss: 0.1627572924, validation loss: 0.1689754562
# Epoch 213: train loss: 0.1626920104, validation loss: 0.1689307369
# Epoch 214: train loss: 0.1626310796, validation loss: 0.1688056193
# Epoch 215: train loss: 0.1625756770, validation loss: 0.1687236994
# Epoch 216: train loss: 0.1624954492, validation loss: 0.1686706055
# Epoch 217: train loss: 0.1624143869, validation loss: 0.1686407175
# Epoch 218: train loss: 0.1623533815, validation loss: 0.1686623680
# Epoch 219: train loss: 0.1623056233, validation loss: 0.1685677439
# Epoch 220: train loss: 0.1622744203, validation loss: 0.1684122357
# Epoch 221: train loss: 0.1621598154, validation loss: 0.1684048625
# Epoch 222: train loss: 0.1621111333, validation loss: 0.1684073086
# Epoch 223: train loss: 0.1620778292, validation loss: 0.1683756416
# Epoch 224: train loss: 0.1620279700, validation loss: 0.1683869602
# Epoch 225: train loss: 0.1619583219, validation loss: 0.1683101145
# Epoch 226: train loss: 0.1618773043, validation loss: 0.1680912402
# Epoch 227: train loss: 0.1618105918, validation loss: 0.1680358342
# Epoch 228: train loss: 0.1617776453, validation loss: 0.1679858991
# Epoch 229: train loss: 0.1616948098, validation loss: 0.1679185490
# Epoch 230: train loss: 0.1616532207, validation loss: 0.1678867422
# Epoch 231: train loss: 0.1616000533, validation loss: 0.1679571505
# Epoch 232: train loss: 0.1615233272, validation loss: 0.1677021613
# Epoch 233: train loss: 0.1614945233, validation loss: 0.1676978189
# Epoch 234: train loss: 0.1614499986, validation loss: 0.1676797152
# Epoch 235: train loss: 0.1613905281, validation loss: 0.1677333922
# Epoch 236: train loss: 0.1613300145, validation loss: 0.1675686041
# Epoch 237: train loss: 0.1612964123, validation loss: 0.1674700542
# Epoch 238: train loss: 0.1612271518, validation loss: 0.1672995813
# Epoch 239: train loss: 0.1611531675, validation loss: 0.1672396766
# Epoch 240: train loss: 0.1611030847, validation loss: 0.1673144249
# Epoch 241: train loss: 0.1610790789, validation loss: 0.1671053706
# Epoch 242: train loss: 0.1610268801, validation loss: 0.1672591221
# Epoch 243: train loss: 0.1610010117, validation loss: 0.1670889683
# Epoch 244: train loss: 0.1609309465, validation loss: 0.1670990922
# Epoch 245: train loss: 0.1608603746, validation loss: 0.1670464992
# Epoch 246: train loss: 0.1608125418, validation loss: 0.1669915807
# Epoch 247: train loss: 0.1607891023, validation loss: 0.1668593548
# Epoch 248: train loss: 0.1607118994, validation loss: 0.1667457848
# Epoch 249: train loss: 0.1606829166, validation loss: 0.1668049769
# Epoch 250: train loss: 0.1606086344, validation loss: 0.1667439220
# Epoch 251: train loss: 0.1606292874, validation loss: 0.1669383629
# Epoch 252: train loss: 0.1605338752, validation loss: 0.1666803917
# Epoch 253: train loss: 0.1604762971, validation loss: 0.1665238327
# Epoch 254: train loss: 0.1604445726, validation loss: 0.1665356470
# Epoch 255: train loss: 0.1603577435, validation loss: 0.1664630380
# Epoch 256: train loss: 0.1603724062, validation loss: 0.1663640661
# Epoch 257: train loss: 0.1603060365, validation loss: 0.1664348247
# Epoch 258: train loss: 0.1602330208, validation loss: 0.1665577732
# Epoch 259: train loss: 0.1602119654, validation loss: 0.1665478647
# Epoch 260: train loss: 0.1601866782, validation loss: 0.1662631330
# Epoch 261: train loss: 0.1601503342, validation loss: 0.1663030724
# Epoch 262: train loss: 0.1600932628, validation loss: 0.1660739237
# Epoch 263: train loss: 0.1600422412, validation loss: 0.1662148163
# Epoch 264: train loss: 0.1599905342, validation loss: 0.1661171987
# Epoch 265: train loss: 0.1599730998, validation loss: 0.1663969160
# Epoch 266: train loss: 0.1599366069, validation loss: 0.1660589385
# Epoch 267: train loss: 0.1598966122, validation loss: 0.1661881515
# Epoch 268: train loss: 0.1598408669, validation loss: 0.1659246379
# Epoch 269: train loss: 0.1597746313, validation loss: 0.1659606145
# Epoch 270: train loss: 0.1597873867, validation loss: 0.1659863702
# Epoch 271: train loss: 0.1596999317, validation loss: 0.1660664276
# Epoch 272: train loss: 0.1596635431, validation loss: 0.1658752010
# Epoch 273: train loss: 0.1596538872, validation loss: 0.1657796265
# Epoch 274: train loss: 0.1596339941, validation loss: 0.1655473176
# Epoch 275: train loss: 0.1595503241, validation loss: 0.1655262082
# Epoch 276: train loss: 0.1594981253, validation loss: 0.1658867393
# Epoch 277: train loss: 0.1594792008, validation loss: 0.1656404442
# Epoch 278: train loss: 0.1594495773, validation loss: 0.1654793928
# Epoch 279: train loss: 0.1593781114, validation loss: 0.1657683409
# Epoch 280: train loss: 0.1593872011, validation loss: 0.1653710072
# Epoch 281: train loss: 0.1593577713, validation loss: 0.1654399257
# Epoch 282: train loss: 0.1592741758, validation loss: 0.1653672566
# Epoch 283: train loss: 0.1592721790, validation loss: 0.1653685239
# Epoch 284: train loss: 0.1592330635, validation loss: 0.1652124129
# Epoch 285: train loss: 0.1592292935, validation loss: 0.1653543361
# Epoch 286: train loss: 0.1591555923, validation loss: 0.1651949044
# Epoch 287: train loss: 0.1591179520, validation loss: 0.1652045495
# Epoch 288: train loss: 0.1590556055, validation loss: 0.1654142015
# Epoch 289: train loss: 0.1590518802, validation loss: 0.1658734675
# Epoch 290: train loss: 0.1590373963, validation loss: 0.1653463547
# Epoch 291: train loss: 0.1589880437, validation loss: 0.1651632448
# Epoch 292: train loss: 0.1589749902, validation loss: 0.1650333187
# Epoch 293: train loss: 0.1589161307, validation loss: 0.1650516440
# Epoch 294: train loss: 0.1588854939, validation loss: 0.1652182775
# Epoch 295: train loss: 0.1588365734, validation loss: 0.1649015150
# Epoch 296: train loss: 0.1588117182, validation loss: 0.1654679569
# Epoch 297: train loss: 0.1587922722, validation loss: 0.1648517471
# Epoch 298: train loss: 0.1587561816, validation loss: 0.1648929541
# Epoch 299: train loss: 0.1587210596, validation loss: 0.1648359691
# Epoch 300: train loss: 0.1587036401, validation loss: 0.1646219634
# Epoch 301: train loss: 0.1586436480, validation loss: 0.1648068939
# Epoch 302: train loss: 0.1586214006, validation loss: 0.1649986756
# Epoch 303: train loss: 0.1585821509, validation loss: 0.1647575441
# Epoch 304: train loss: 0.1585623026, validation loss: 0.1646474580
# Epoch 305: train loss: 0.1585160643, validation loss: 0.1648047761
# Epoch 306: train loss: 0.1584832519, validation loss: 0.1645745747
# Epoch 307: train loss: 0.1584592015, validation loss: 0.1644482139
# Epoch 308: train loss: 0.1584401429, validation loss: 0.1644228556
# Epoch 309: train loss: 0.1584324688, validation loss: 0.1644395498
# Epoch 310: train loss: 0.1583874673, validation loss: 0.1644301960
# Epoch 311: train loss: 0.1583428681, validation loss: 0.1645378670
# Epoch 312: train loss: 0.1583069563, validation loss: 0.1645613321
# Epoch 313: train loss: 0.1582859755, validation loss: 0.1643612954
# Epoch 314: train loss: 0.1582376659, validation loss: 0.1642095615
# Epoch 315: train loss: 0.1582486928, validation loss: 0.1642195913
# Epoch 316: train loss: 0.1582134068, validation loss: 0.1643277381
# Epoch 317: train loss: 0.1581395864, validation loss: 0.1650297984
# Epoch 318: train loss: 0.1581610441, validation loss: 0.1641236630
# Epoch 319: train loss: 0.1580968946, validation loss: 0.1641851884
# Epoch 320: train loss: 0.1580852121, validation loss: 0.1642313343
# Epoch 321: train loss: 0.1580158025, validation loss: 0.1639795800
# Epoch 322: train loss: 0.1580212861, validation loss: 0.1641704603
# Epoch 323: train loss: 0.1580012292, validation loss: 0.1640338394
# Epoch 324: train loss: 0.1579821110, validation loss: 0.1642008961
# Epoch 325: train loss: 0.1579747498, validation loss: 0.1640020844
# Epoch 326: train loss: 0.1579063386, validation loss: 0.1638526987
# Epoch 327: train loss: 0.1578546464, validation loss: 0.1643328749
# Epoch 328: train loss: 0.1578329951, validation loss: 0.1638014356
# Epoch 329: train loss: 0.1578199714, validation loss: 0.1639729775
# Epoch 330: train loss: 0.1578139216, validation loss: 0.1640793336
# Epoch 331: train loss: 0.1577151120, validation loss: 0.1638226976
# Epoch 332: train loss: 0.1577635407, validation loss: 0.1643095095
# Epoch 333: train loss: 0.1577253789, validation loss: 0.1636522831
# Epoch 334: train loss: 0.1576707214, validation loss: 0.1639605855
# Epoch 335: train loss: 0.1576328278, validation loss: 0.1641851562
# Epoch 336: train loss: 0.1576499343, validation loss: 0.1639332823
# Epoch 337: train loss: 0.1576050818, validation loss: 0.1640007077
# Epoch 338: train loss: 0.1576029360, validation loss: 0.1636088920
# Epoch 339: train loss: 0.1575887203, validation loss: 0.1636236344
# Epoch 340: train loss: 0.1575251669, validation loss: 0.1654010081
# Epoch 341: train loss: 0.1575263143, validation loss: 0.1636724941
# Epoch 342: train loss: 0.1574496776, validation loss: 0.1638775386
# Epoch 343: train loss: 0.1574842334, validation loss: 0.1636577235
# Epoch 344: train loss: 0.1574474275, validation loss: 0.1644987008
# Epoch 345: train loss: 0.1574137062, validation loss: 0.1634618150
# Epoch 346: train loss: 0.1573709399, validation loss: 0.1636271400
# Epoch 347: train loss: 0.1573224813, validation loss: 0.1636794590
# Epoch 348: train loss: 0.1573533565, validation loss: 0.1634003762
# Epoch 349: train loss: 0.1573293358, validation loss: 0.1636926135
# Epoch 350: train loss: 0.1573072225, validation loss: 0.1634154428
# Epoch 351: train loss: 0.1572629511, validation loss: 0.1633143352
# Epoch 352: train loss: 0.1572778374, validation loss: 0.1633587100
# Epoch 353: train loss: 0.1572361588, validation loss: 0.1634249372
# Epoch 354: train loss: 0.1572186649, validation loss: 0.1634448782
# Epoch 355: train loss: 0.1571189314, validation loss: 0.1633147768
# Epoch 356: train loss: 0.1571538597, validation loss: 0.1631973615
# Epoch 357: train loss: 0.1571292877, validation loss: 0.1634309924
# Epoch 358: train loss: 0.1570781469, validation loss: 0.1632675280
# Epoch 359: train loss: 0.1570790112, validation loss: 0.1635239960
# Epoch 360: train loss: 0.1569960713, validation loss: 0.1630958448
# Epoch 361: train loss: 0.1570752710, validation loss: 0.1632954468
# Epoch 362: train loss: 0.1569715142, validation loss: 0.1630407189
# Epoch 363: train loss: 0.1569645554, validation loss: 0.1632828875
# Epoch 364: train loss: 0.1569616348, validation loss: 0.1632926328
# Epoch 365: train loss: 0.1569528133, validation loss: 0.1629954070
# Epoch 366: train loss: 0.1568938047, validation loss: 0.1632007296
# Epoch 367: train loss: 0.1568795890, validation loss: 0.1632329613
# Epoch 368: train loss: 0.1568839997, validation loss: 0.1630246484
# Epoch 369: train loss: 0.1568306088, validation loss: 0.1630369038
# Epoch 370: train loss: 0.1567971110, validation loss: 0.1629222872
# Epoch 371: train loss: 0.1567814499, validation loss: 0.1629580043
# Epoch 372: train loss: 0.1568025500, validation loss: 0.1630219085
# Epoch 373: train loss: 0.1567355692, validation loss: 0.1630702159
# Epoch 374: train loss: 0.1567379981, validation loss: 0.1631704002
# Epoch 375: train loss: 0.1566995233, validation loss: 0.1628268901
# Epoch 376: train loss: 0.1566992402, validation loss: 0.1631438860
# Epoch 377: train loss: 0.1566220671, validation loss: 0.1628436490
# Epoch 378: train loss: 0.1566489637, validation loss: 0.1629455017
# Epoch 379: train loss: 0.1565827727, validation loss: 0.1628195952
# Epoch 380: train loss: 0.1565812379, validation loss: 0.1630145586
# Epoch 381: train loss: 0.1565734744, validation loss: 0.1626968299
# Epoch 382: train loss: 0.1565286815, validation loss: 0.1630297900
# Epoch 383: train loss: 0.1565492749, validation loss: 0.1626928393
# Epoch 384: train loss: 0.1564937085, validation loss: 0.1629634159
# Epoch 385: train loss: 0.1564638615, validation loss: 0.1625968028
# Epoch 386: train loss: 0.1564315557, validation loss: 0.1631554078
# Epoch 387: train loss: 0.1564218998, validation loss: 0.1633500967
# Epoch 388: train loss: 0.1564153433, validation loss: 0.1627303223
# Epoch 389: train loss: 0.1564226449, validation loss: 0.1626668385
# Epoch 390: train loss: 0.1563655734, validation loss: 0.1625803003
# Epoch 391: train loss: 0.1563458145, validation loss: 0.1625106110
# Epoch 392: train loss: 0.1563723981, validation loss: 0.1626709901
# Epoch 393: train loss: 0.1562980115, validation loss: 0.1623956161
# Epoch 394: train loss: 0.1562856436, validation loss: 0.1627985100
# Epoch 395: train loss: 0.1562745124, validation loss: 0.1624951528
# Epoch 396: train loss: 0.1562087238, validation loss: 0.1625485194
# Epoch 397: train loss: 0.1562104672, validation loss: 0.1625626988
# Epoch 398: train loss: 0.1561840177, validation loss: 0.1624294637
# Epoch 399: train loss: 0.1561823785, validation loss: 0.1626582779
# Epoch 400: train loss: 0.1561918557, validation loss: 0.1624754788
# Epoch 401: train loss: 0.1561000198, validation loss: 0.1626268865
# Epoch 402: train loss: 0.1561359167, validation loss: 0.1623955967
# Epoch 403: train loss: 0.1560953557, validation loss: 0.1622135827
# Epoch 404: train loss: 0.1560741663, validation loss: 0.1625029180
# Epoch 405: train loss: 0.1560813338, validation loss: 0.1633043619
# Epoch 406: train loss: 0.1560652405, validation loss: 0.1629882903
# Epoch 407: train loss: 0.1560361087, validation loss: 0.1622826109
# Epoch 408: train loss: 0.1559942365, validation loss: 0.1633282716
# Epoch 409: train loss: 0.1559904367, validation loss: 0.1623352435
# Epoch 410: train loss: 0.1559862792, validation loss: 0.1627427578
# Epoch 411: train loss: 0.1559302211, validation loss: 0.1626717344
# Epoch 412: train loss: 0.1559426337, validation loss: 0.1620691404
# Epoch 413: train loss: 0.1559113115, validation loss: 0.1620879133
# Epoch 414: train loss: 0.1558767706, validation loss: 0.1626052312
# Epoch 415: train loss: 0.1558883935, validation loss: 0.1623263495
# Epoch 416: train loss: 0.1558605134, validation loss: 0.1620089312
# Epoch 417: train loss: 0.1558409780, validation loss: 0.1623086389
# Epoch 418: train loss: 0.1558301598, validation loss: 0.1627237898
# Epoch 419: train loss: 0.1558114439, validation loss: 0.1627841426
# Epoch 420: train loss: 0.1558241397, validation loss: 0.1622631780
# Epoch 421: train loss: 0.1557884961, validation loss: 0.1622922947
# Epoch 422: train loss: 0.1557383239, validation loss: 0.1618668788
# Epoch 423: train loss: 0.1557391137, validation loss: 0.1622005463
# Epoch 424: train loss: 0.1556925923, validation loss: 0.1619141330
# Epoch 425: train loss: 0.1556907892, validation loss: 0.1620817553
# Epoch 426: train loss: 0.1556379944, validation loss: 0.1620430981
# Epoch 427: train loss: 0.1556484103, validation loss: 0.1617558449
# Epoch 428: train loss: 0.1556379497, validation loss: 0.1619423471
# Epoch 429: train loss: 0.1556471884, validation loss: 0.1618899842
# Epoch 430: train loss: 0.1555744261, validation loss: 0.1619649170
# Epoch 431: train loss: 0.1556051821, validation loss: 0.1621498651
# Epoch 432: train loss: 0.1555736512, validation loss: 0.1620412911
# Epoch 433: train loss: 0.1555439234, validation loss: 0.1617744713
# Epoch 434: train loss: 0.1555344611, validation loss: 0.1621174355
# Epoch 435: train loss: 0.1555226147, validation loss: 0.1620106696
# Epoch 436: train loss: 0.1555004269, validation loss: 0.1617544237
# Epoch 437: train loss: 0.1555193365, validation loss: 0.1620284348
# Epoch 438: train loss: 0.1554501951, validation loss: 0.1620414269
# Epoch 439: train loss: 0.1554440111, validation loss: 0.1616456597
# Epoch 440: train loss: 0.1554383337, validation loss: 0.1623298343
# Epoch 441: train loss: 0.1553934813, validation loss: 0.1617103100
# Epoch 442: train loss: 0.1554102600, validation loss: 0.1619419398
# Epoch 443: train loss: 0.1553607136, validation loss: 0.1617512375
# Epoch 444: train loss: 0.1553385109, validation loss: 0.1616974645
# Epoch 445: train loss: 0.1553214192, validation loss: 0.1622378540
# Epoch 446: train loss: 0.1552930921, validation loss: 0.1620040995
# Epoch 447: train loss: 0.1552861184, validation loss: 0.1615167765
# Epoch 448: train loss: 0.1553118229, validation loss: 0.1616537258
# Epoch 449: train loss: 0.1552824229, validation loss: 0.1619793507

# %% [markdown]
# ***Learning Curves***

# %%
train_loss = [l[0] for l in model_koop_dnn.train_loss_hist]
train_pred_loss = [l[1] for l in model_koop_dnn.train_loss_hist]
train_lifted_loss = [l[2] for l in model_koop_dnn.train_loss_hist]
val_loss = [l[0] for l in model_koop_dnn.val_loss_hist]
val_pred_loss = [l[1] for l in model_koop_dnn.val_loss_hist]
val_lifted_loss = [l[2] for l in model_koop_dnn.val_loss_hist]
epochs = np.arange(0, net_params['epochs'])

plt.figure(figsize=(15,8))
plt.plot(epochs, train_loss, color='tab:orange', label='Training loss')
plt.plot(epochs, train_pred_loss, '--', color='tab:orange', label='Training prediction loss')
plt.plot(epochs, train_lifted_loss, ':', color='tab:orange', label='Training lifted loss')
plt.plot(epochs, val_loss, color='tab:blue', label='Validation loss')
plt.plot(epochs, val_pred_loss, '--', color='tab:blue', label='Validation prediction loss')
plt.plot(epochs, val_lifted_loss, ':', color='tab:blue', label='Validation lifted loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale('log')
plt.savefig("convergence plot for arch1")
plt.show()

# %%
map_net_params = {}
map_net_params["input_dim"] = int(num_states/2) #number of joint angles
map_net_params["output_dim"] = X_end.shape[2] #x and y position of the end effector
map_net_params["hidden_width"] = 20
map_net_params["hidden_depth"] = 2
map_net_params["batch_size"] = 100
map_net_params["epochs"] = 500
map_net_params["activation_type"] = 'tanh'
map_net_params["lr"] = 1e-3
map_net_params["optimizer"] = 'adam'
map_net_params['l2_reg'] = 0.0
map_net_params['l1_reg'] = 0.0

# %%
#dataset
# split training and vaidation datasets
xs_map_train, ys_map_train = X_full[:num_train,:,:int(num_states/2)],X_end[:num_train,:,:num_inputs]
xs_map_val, ys_map_val = X_full[num_train:,:,:int(num_states/2)],X_end[num_train:,:,:num_inputs]

# %%
ys_map_train.shape, ys_map_val.shape,xs_map_train.shape, xs_map_val.shape

# %%
#Initalize network
#Initalize network
train = True

if train==True:
    file = "saved_models/Kuka/2D/map_net_time_delay.pth"
    map_net = map_Net(map_net_params)
    map_net.set_dataset_map(xs_map_train,ys_map_train,xs_map_val,ys_map_val)
    map_net.data_pipeline()
    torch.save(map_net,file)
else:
    file = "saved_models/Kuka/2D/map_net_time_delay.pth"
    map_net = torch.load(file)

# %%
epochs = np.arange(0, map_net_params['epochs'])
plt.figure(figsize=(15,8))
plt.plot(epochs, map_net.train_loss_hist, color='tab:orange', label='Training loss')
plt.plot(epochs, map_net.val_loss_hist, color='tab:blue', label='Validation loss')

plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale('log')
plt.savefig("convergence plot of map net for arch1[3,20,20,2]")
plt.show()

# %%
# import scipy.io

# #save net parameters
# scipy.io.savemat("map_in_weights.mat", {"map_in_weights": map_net.map_net_in.weight.detach().numpy()})
# scipy.io.savemat("map_in_bias.mat", {"map_in_bias": map_net.map_net_in.bias.detach().numpy()})

# scipy.io.savemat("map_hidden_weights_1.mat",
#                  {"map_hidden_weights_1": map_net.map_net_hid[0].weight.detach().numpy()})
# scipy.io.savemat("map_hidden_bias_1.mat",
#                  {"map_hidden_bias_1": map_net.map_net_hid[0].bias.detach().numpy()})

# scipy.io.savemat("map_hidden_weights_2.mat",
#                  {"map_hidden_weights_2": map_net.map_net_hid[1].weight.detach().numpy()})
# scipy.io.savemat("map_hidden_bias_2.mat",
#                  {"map_hidden_bias_2": map_net.map_net_hid[1].bias.detach().numpy()})

# scipy.io.savemat("map_hidden_weights_3.mat",
#                  {"map_hidden_weights_3": map_net.map_net_hid[2].weight.detach().numpy()})
# scipy.io.savemat("map_hidden_bias_3.mat",
#                  {"map_hidden_bias_3": map_net.map_net_hid[2].bias.detach().numpy()})

# scipy.io.savemat("map_out_weights.mat", {"map_out_weights": map_net.map_net_out.weight.detach().numpy()})
# scipy.io.savemat("map_out_bias.mat", {"map_out_bias": map_net.map_net_out.bias.detach().numpy()})

# %% [markdown]
# ## Test Data Parameters

# %%
# test data parameters
num_snaps_val = num_snaps # no. of snapshots
T = np.linspace(0,num_snaps_val*dt, num_snaps_val+1)
num_traj_val = 1 # no. of training examples
first_obs_const = int(net_params['first_obs_const']) #only one state
override_C = net_params['override_C']
if override_C:
    n_obs = int(net_params['encoder_output_dim']) + num_states + first_obs_const 
else:
    n_obs = int(net_params['encoder_output_dim']) + first_obs_const

# %% [markdown]
# ***Koopman Bilinear Model***

# %%
A = np.array(model_koop_dnn.A)
#B = np.array(model_koop_dnn.B).reshape(-1,num_inputs*n_obs)
B = np.array(model_koop_dnn.B)
#B_tensor = np.empty((num_inputs,n_obs, n_obs))
#for ii, b in enumerate(B):
    #B_tensor[ii] = b
C = np.array(model_koop_dnn.C)

print(A.shape, B.shape, C.shape)

# %%
# #SAVE MATRIX PARAMETERS AS MATLAB FILE
# import scipy.io

# dyn_matrices = {"A": A, "B": B, "C": C}
# scipy.io.savemat("dyn_mat.mat", dyn_matrices)
# #save encoder parameters
# scipy.io.savemat("in_weights.mat", {"encode_in_weights": model_koop_dnn.net.encoder_fc_in.weight.detach().numpy()})
# scipy.io.savemat("in_bias.mat", {"encode_in_bias": model_koop_dnn.net.encoder_fc_in.bias.detach().numpy()})

# scipy.io.savemat("hidden_weights_1.mat",
#                  {"encode_hidden_weights_1": model_koop_dnn.net.encoder_fc_hid[0].weight.detach().numpy()})
# scipy.io.savemat("hidden_bias_1.mat",
#                  {"encode_hidden_bias_1": model_koop_dnn.net.encoder_fc_hid[0].bias.detach().numpy()})

# scipy.io.savemat("hidden_weights_2.mat",
#                  {"encode_hidden_weights_2": model_koop_dnn.net.encoder_fc_hid[1].weight.detach().numpy()})
# scipy.io.savemat("hidden_bias_2.mat",
#                  {"encode_hidden_bias_2": model_koop_dnn.net.encoder_fc_hid[1].bias.detach().numpy()})

# scipy.io.savemat("out_weights.mat", {"encode_out_weights": model_koop_dnn.net.encoder_fc_out.weight.detach().numpy()})
# scipy.io.savemat("out_bias.mat", {"encode_out_bias": model_koop_dnn.net.encoder_fc_out.bias.detach().numpy()})

# %%
encode_out_bias = model_koop_dnn.net.encoder_fc_out.bias.detach().numpy()
encode_out_weights = model_koop_dnn.net.encoder_fc_out.weight.detach().numpy()

# %% [markdown]
# ***Test Data Generation***

# %%
# data_gen
j = 70
xs_end_test = X_end[j,:,:]
xs_test = X_full[j,:,:]
us_test = U_full[j,:,:]

# %%
print(xs_end_test.shape, xs_test.shape, us_test.shape)

# %%
print(model_koop_dnn.test_loss(xs_test.reshape(1,-1,num_states),u_test = us_test.reshape(1,-1,num_inputs)))

# %% [markdown]
# ***Initial Condition Lifting***

# %%
# initialize the matricies
z = np.empty((n_obs,num_snaps_val+1)).T
x_est = np.zeros((num_states,num_snaps_val+1)).T
x_end_est = np.zeros((X_end.shape[2],num_snaps_val)).T

# %%
num_outputs = num_states

# %%
x_out_test = xs_test[:num_snaps_val+1,:]
x_out_Test = x_out_test.reshape((num_snaps_val+1,num_outputs))
u_Test = us_test.reshape((num_snaps_val,num_inputs))
x0 = x_out_Test[:net_params["num_delays"]+1,:]
X0 = x0.reshape((1,num_outputs*(net_params["num_delays"]+1)))
print(X0.shape)
z[0,:] = lift_delay(X0[0,:],model_koop_dnn, net_params)
x_est[0,:] = x_out_test[0,:]

# %% [markdown]
# ***Time Evolution***

# %%
for i in range(num_snaps_val):
  #bilinear
    z[i+1,:] = np.matmul(z[i,:],A.T)+np.matmul(np.kron(u_Test[i,:],z[i,:]),B.T)
    x_est[i+1,:] = np.matmul(z[i+1,:],C.T)  
    x_end_est[i,:] = map_net.forward(torch.from_numpy(x_est[i,:int(num_states/2)]).float()).detach().numpy()

# %% [markdown]
# ***Visualization***

# %% [markdown]
# # Joint Space

# %%
plt.figure()
plt.plot(T[:],x_out_Test[:,0],label ='Actual')
plt.plot(T[:],x_est[:,0],label = 'estimated(bilinear)')
plt.xlabel('t')
plt.ylabel('theta_1')
plt.title('theta_1 Comparison')
plt.legend()

# %%
plt.figure()
plt.plot(T,x_out_Test[:,1],label ='Actual')
plt.plot(T,x_est[:,1],label = 'estimated(bilinear)')
plt.title('Theta_2')
plt.xlabel('t')
plt.ylabel('Theta_2_comparison')
plt.legend()

# %%
plt.figure()
plt.plot(T,x_out_Test[:,2],label ='Actual')
plt.plot(T,x_est[:,2],label = 'estimated(bilinear)')
plt.title('Theta_3')
plt.xlabel('t')
plt.ylabel('theta_3')
plt.legend()

# %%
plt.figure()
plt.plot(T,x_out_Test[:,3],label ='Actual')
plt.plot(T,x_est[:,3],label = 'estimated(bilinear)')
plt.title('Theta_4')
plt.xlabel('t')
plt.ylabel('theta_4')
plt.legend()

# %%
plt.figure()
plt.plot(T,x_out_Test[:,4],label ='Actual')
plt.plot(T,x_est[:,4],label = 'estimated(bilinear)')
plt.title('Theta_5')
plt.xlabel('t')
plt.ylabel('theta_5')
plt.legend()

# %%
plt.figure()
plt.plot(T,x_out_Test[:,5],label ='Actual')
plt.plot(T,x_est[:,5],label = 'estimated(bilinear)')
plt.title('Theta_6')
plt.xlabel('t')
plt.ylabel('theta_6')
plt.legend()

# %%
plt.figure()
plt.plot(T,x_out_Test[:,6],label ='Actual')
plt.plot(T,x_est[:,6],label = 'estimated(bilinear)')
plt.title('Theta_6')
plt.xlabel('t')
plt.ylabel('theta_6')
plt.legend()

# %%
plt.figure()
plt.plot(T,x_out_Test[:,7],label ='Actual')
plt.plot(T,x_est[:,7],label = 'estimated(bilinear)')
plt.xlabel('t')
plt.ylabel('theta_1_dot')
plt.title('theta_1_dot Comparison')
plt.legend()

# %%
plt.figure()
plt.plot(T,x_out_Test[:,8],label ='Actual')
plt.plot(T,x_est[:,8],label = 'estimated(bilinear)')
plt.title('Theta_2_dot')
plt.xlabel('t')
plt.ylabel('Theta_2_dot_comparison')
plt.legend()

# %%
plt.figure()
plt.plot(T,x_out_Test[:,9],label ='Actual')
plt.plot(T,x_est[:,9],label = 'estimated(bilinear)')
plt.title('Theta_3_dot')
plt.xlabel('t')
plt.ylabel('theta_3_dot')
plt.legend()

# %%
plt.figure()
plt.plot(T,x_out_Test[:,10],label ='Actual')
plt.plot(T,x_est[:,10],label = 'estimated(bilinear)')
plt.title('Theta_4_dot')
plt.xlabel('t')
plt.ylabel('theta_4_dot')
plt.legend()

# %%
plt.figure()
plt.plot(T,x_out_Test[:,11],label ='Actual')
plt.plot(T,x_est[:,11],label = 'estimated(bilinear)')
plt.title('Theta_5_dot')
plt.xlabel('t')
plt.ylabel('theta_5_dot')
plt.legend()

# %%
plt.figure()
plt.plot(T,x_out_Test[:,12],label ='Actual')
plt.plot(T,x_est[:,12],label = 'estimated(bilinear)')
plt.title('Theta_6_dot')
plt.xlabel('t')
plt.ylabel('theta_6_dot')
plt.legend()

# %%
plt.figure()
plt.plot(T,x_out_Test[:,13],label ='Actual')
plt.plot(T,x_est[:,13],label = 'estimated(bilinear)')
plt.title('Theta_7_dot')
plt.xlabel('t')
plt.ylabel('theta_7_dot')
plt.legend()

# %% [markdown]
# ## Cartesian Space

# %%
plt.figure()
plt.plot(T,xs_end_test[:,0], label = 'Actual')
plt.plot(T[:-1],x_end_est[:,0], label = 'Estimated')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(T,xs_end_test[:,1], label = 'Actual')
plt.plot(T[:-1],x_end_est[:,1], label = 'Estimated')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(T,xs_end_test[:,2], label = 'Actual')
plt.plot(T[:-1],x_end_est[:,2], label = 'Estimated')
plt.legend()
plt.show()
