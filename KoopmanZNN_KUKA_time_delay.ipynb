# %% [markdown]
# ***Import Libraries***

# %%
"""This program bilinearizes 3R planar dyanmics using koopman theory and autoencoder to map"""
import numpy as np
import matplotlib.pyplot as plt
import sklearn.preprocessing
import itertools
import scipy.io
import torch

# bilinear Koopman
from core.koopman_time_delay import KoopDNN, KoopmanNet, KoopmanNetCtrl
from models.koop_model import model_matricies,lift, lift_delay
from core.util import fit_standardizer
from sklearn import preprocessing

# forward map neural net
from core.neural_fwd_map import map_Net


## import paths
from paths.paths import path_pars

# %% [markdown]
# ### Load Data

# %%
data = scipy.io.loadmat('dynamics/Dataset_MATLAB/2D/data.mat')

X_end = np.array(data['X_end'], dtype = 'float64')
X_full = np.array(data['X'], dtype = 'float64')
U_full = np.array(data['tau_red'], dtype = 'float64')

print(X_end.shape, X_full.shape,U_full.shape)
# Out:
# (100, 1001, 3) (100, 1001, 14) (100, 1000, 3)

# %%
np.sum(np.sum(np.isnan(X_end))), np.sum(np.sum(np.isnan(U_full))), np.sum(np.sum(np.isnan(X_full)))
# Out:
# (0, 0, 0)

# %% [markdown]
# ***Simulation Parameters***

# %%
dt = float(data['dt']) #time step
num_snaps = int(data['num_snaps']) # no. of snapshots
num_traj = int(data['num_traj']) #no of trajectories
T = np.linspace(0,num_snaps*dt, num_snaps+1)
num_train = int(0.75*num_traj) # no. of training examples
num_val = num_traj-num_train # no of testing examples
num_traj = num_train+num_val #no of trajectories
num_states = X_full.shape[2] # no. of states
num_inputs = U_full.shape[2] # no. of inputs

# %%
dt, num_snaps, num_traj, num_states, num_inputs
# Out:
# (0.005, 1000, 100, 14, 3)

# %% [markdown]
# ***Plotting the trajectories***

# %%
"""Training dataset visualization"""
#theta evolution
for i in range(int(num_states/2)):
    plt.subplot(3,3,i+1)
    plt.xlabel("t")
    plt.ylabel("th"+str(i+1))
    for j in range(num_traj):
        plt.plot(T,X_full[j,:,i])

# %%
for i in range(int(num_states/2)):
    plt.subplot(3,3,i+1)
    plt.xlabel("t")
    plt.ylabel("th"+str(i+1)+ ' dot')
    for j in range(num_traj):
        plt.plot(T,X_full[j,:,i+int(num_states/2)])

# %%
#x and y positions of the end effector
ax = plt.axes(projection='3d')
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
for i in range(num_traj):
    ax.plot3D(X_end[i,:,0],X_end[i,:,1],X_end[i,:,2])

# %%
for i in range(num_inputs):
    plt.subplot(4,2,i+1)
    plt.xlabel("t")
    plt.ylabel("tau"+str(i))
    for j in range(num_traj):
        plt.plot(T[:-1],U_full[j,:,i])

# %% [markdown]
# ***Training and validation datasets***

# %%
# split training and vaidation datasets
xs_train, us_train = X_full[:num_train,:,:],U_full[:num_train,:,:]
xs_val, us_val = X_full[num_train:,:,:],U_full[num_train:,:,:]

# %%
# import scipy.io
# Data_set = {"x_end": X_end, "X_full": X_full}
# scipy.io.savemat("Data_set.mat",Data_set)

# %%
# import torch
# import torch.nn as nn
# import torch.nn.functional as F

# %% [markdown]
# ***Model Training***

# %%
net_params = {}
net_params['state_dim'] = num_states
net_params['ctrl_dim'] = num_inputs
net_params["output_dim"] = num_states
net_params['encoder_hidden_width'] = 30
net_params['encoder_hidden_depth'] = 2
net_params["num_delays"] = 10
net_params['encoder_output_dim'] = 20
net_params['optimizer'] = 'adam'
net_params['activation_type'] = 'tanh'
net_params['lr'] = 5e-5 # 5e-4
net_params['epochs'] = 500
net_params['batch_size'] = 128
net_params['lifted_loss_penalty'] = 0.4 
net_params['l2_reg'] = 0.0         
net_params['l1_reg'] = 0.0
net_params['first_obs_const'] = True
net_params['override_C'] = True # this makes the state a part of lifetd state
net_params['dt'] = dt

# %%
train = True

if train == True:
    file = 'saved_models/Kuka/2D/koop_arch_time_delay.pth'
    standardizer_u_kdnn = fit_standardizer(us_train, preprocessing.StandardScaler(with_mean=False))
    net = KoopmanNetCtrl(net_params, standardizer_u=standardizer_u_kdnn)
    # net = KoopmanNetCtrl(net_params)
    model_koop_dnn = KoopDNN(net)
    model_koop_dnn.set_datasets(xs_train, u_train=us_train, x_val=xs_val, u_val=us_val)
    model_koop_dnn.model_pipeline(net_params)
    model_koop_dnn.construct_koopman_model()
    torch.save(model_koop_dnn,file)
else:
    file = 'saved_models/Kuka/2D/koop_arch_time_delay.pth'
    model_koop_dnn = torch.load(file)
# Out:
# Epoch   1: train loss: 105.8494644165, validation loss: 89.0659038965
# Epoch   2: train loss: 40.7857894897, validation loss: 42.2394636670
# Epoch   3: train loss: 18.3843040466, validation loss: 24.5620009713
# Epoch   4: train loss: 10.1009998322, validation loss: 15.4204999220
# Epoch   5: train loss: 5.9013667107, validation loss: 10.3222901692
# Epoch   6: train loss: 3.4977948666, validation loss: 7.0028184497
# Epoch   7: train loss: 2.2400989532, validation loss: 5.1804207301
# Epoch   8: train loss: 1.6081376076, validation loss: 4.3889540832
# Epoch   9: train loss: 1.2563728094, validation loss: 3.5388774265
# Epoch  10: train loss: 1.0363615751, validation loss: 2.7707291826
# Epoch  11: train loss: 0.8941981196, validation loss: 2.2136423159
# Epoch  12: train loss: 0.8064633608, validation loss: 1.9290372197
# Epoch  13: train loss: 0.7350344062, validation loss: 1.9579606524
# Epoch  14: train loss: 0.6670361757, validation loss: 1.6499848308
# Epoch  15: train loss: 0.6241844296, validation loss: 1.4243774346
# Epoch  16: train loss: 0.5913909078, validation loss: 1.3606778092
# Epoch  17: train loss: 0.5648266077, validation loss: 1.2614382138
# Epoch  18: train loss: 0.5458010435, validation loss: 1.0870928079
# Epoch  19: train loss: 0.5267575383, validation loss: 1.1174044238
# Epoch  20: train loss: 0.5109924078, validation loss: 1.0204707941
# Epoch  21: train loss: 0.4990263879, validation loss: 1.0506017866
# Epoch  22: train loss: 0.4891712070, validation loss: 0.9674034181
# Epoch  23: train loss: 0.4766835272, validation loss: 0.8910451034
# Epoch  24: train loss: 0.4669450521, validation loss: 0.8866699557
# Epoch  25: train loss: 0.4590335786, validation loss: 0.8308628446
# Epoch  26: train loss: 0.4521701932, validation loss: 0.8757138942
# Epoch  27: train loss: 0.4443018436, validation loss: 0.8439131632
# Epoch  28: train loss: 0.4376330376, validation loss: 0.8394687508
# Epoch  29: train loss: 0.4282172322, validation loss: 0.8151980993
# Epoch  30: train loss: 0.4196767509, validation loss: 0.7893483136
# Epoch  31: train loss: 0.4135403633, validation loss: 0.8031905746
# Epoch  32: train loss: 0.4069197178, validation loss: 0.7988910052
# Epoch  33: train loss: 0.4038625360, validation loss: 0.7693157931
# Epoch  34: train loss: 0.3944814503, validation loss: 0.7582665430
# Epoch  35: train loss: 0.3885385990, validation loss: 0.7437744525
# Epoch  36: train loss: 0.3819826245, validation loss: 0.7529177797
# Epoch  37: train loss: 0.3815874457, validation loss: 0.7546836744
# Epoch  38: train loss: 0.3713365197, validation loss: 0.6975316167
# Epoch  39: train loss: 0.3715907633, validation loss: 0.6702717419
# Epoch  40: train loss: 0.3647575080, validation loss: 0.6914531914
# Epoch  41: train loss: 0.3585099876, validation loss: 0.6944252656
# Epoch  42: train loss: 0.3553675711, validation loss: 0.6986648860
# Epoch  43: train loss: 0.3512823284, validation loss: 0.6734818923
# Epoch  44: train loss: 0.3479201794, validation loss: 0.6881456544
# Epoch  45: train loss: 0.3430159092, validation loss: 0.6723956877
# Epoch  46: train loss: 0.3394058347, validation loss: 0.6413056289
# Epoch  47: train loss: 0.3386991322, validation loss: 0.6882359789
# Epoch  48: train loss: 0.3338957131, validation loss: 0.6485222541
# Epoch  49: train loss: 0.3286781013, validation loss: 0.6754042405
# Epoch  50: train loss: 0.3260945678, validation loss: 0.6439407504
# Epoch  51: train loss: 0.3228523731, validation loss: 0.6601916119
# Epoch  52: train loss: 0.3203000128, validation loss: 0.6417471414
# Epoch  53: train loss: 0.3177902699, validation loss: 0.6330908613
# Epoch  54: train loss: 0.3134799898, validation loss: 0.6604370267
# Epoch  55: train loss: 0.3107508123, validation loss: 0.6356180686
# Epoch  56: train loss: 0.3079799712, validation loss: 0.6646867904
# Epoch  57: train loss: 0.3047255278, validation loss: 0.6280782982
# Epoch  58: train loss: 0.3017663360, validation loss: 0.6291340997
# Epoch  59: train loss: 0.2986174226, validation loss: 0.6309599132
# Epoch  60: train loss: 0.2962853312, validation loss: 0.6502755838
# Epoch  61: train loss: 0.2909968197, validation loss: 0.6414403359
# Epoch  62: train loss: 0.2904444039, validation loss: 0.6199699502
# Epoch  63: train loss: 0.2868235707, validation loss: 0.6239576855
# Epoch  64: train loss: 0.2861353159, validation loss: 0.6136604294
# Epoch  65: train loss: 0.2809528112, validation loss: 0.6075348422
# Epoch  66: train loss: 0.2774244249, validation loss: 0.6347498291
# Epoch  67: train loss: 0.2772646546, validation loss: 0.6230625059
# Epoch  68: train loss: 0.2726161182, validation loss: 0.6159431915
# Epoch  69: train loss: 0.2706935704, validation loss: 0.5938431885
# Epoch  70: train loss: 0.2682442665, validation loss: 0.5901910278
# Epoch  71: train loss: 0.2648883462, validation loss: 0.5939704867
# Epoch  72: train loss: 0.2612000704, validation loss: 0.6014853931
# Epoch  73: train loss: 0.2588371634, validation loss: 0.6149230823
# Epoch  74: train loss: 0.2565524578, validation loss: 0.6040869692
# Epoch  75: train loss: 0.2531106472, validation loss: 0.5864579469
# Epoch  76: train loss: 0.2503445446, validation loss: 0.5853206299
# Epoch  77: train loss: 0.2483484000, validation loss: 0.5827443738
# Epoch  78: train loss: 0.2447567880, validation loss: 0.5746677494
# Epoch  79: train loss: 0.2433776110, validation loss: 0.6045225328
# Epoch  80: train loss: 0.2395897508, validation loss: 0.5793112077
# Epoch  81: train loss: 0.2377946526, validation loss: 0.5856982735
# Epoch  82: train loss: 0.2358044088, validation loss: 0.5916282766
# Epoch  83: train loss: 0.2335615605, validation loss: 0.5898162985
# Epoch  84: train loss: 0.2300217003, validation loss: 0.5893984482
# Epoch  85: train loss: 0.2286418676, validation loss: 0.5800214195
# Epoch  86: train loss: 0.2263331264, validation loss: 0.5686034275
# Epoch  87: train loss: 0.2245192081, validation loss: 0.5736082875
# Epoch  88: train loss: 0.2218481898, validation loss: 0.5506887245
# Epoch  89: train loss: 0.2198866159, validation loss: 0.5607608370
# Epoch  90: train loss: 0.2164368033, validation loss: 0.5477883079
# Epoch  91: train loss: 0.2159215659, validation loss: 0.5581826839
# Epoch  92: train loss: 0.2112199515, validation loss: 0.5400511843
# Epoch  93: train loss: 0.2102951258, validation loss: 0.5902944895
# Epoch  94: train loss: 0.2082166374, validation loss: 0.5275502587
# Epoch  95: train loss: 0.2076548189, validation loss: 0.5394128499
# Epoch  96: train loss: 0.2039894611, validation loss: 0.5312592282
# Epoch  97: train loss: 0.2019204348, validation loss: 0.5147352641
# Epoch  98: train loss: 0.1990222633, validation loss: 0.5257918104
# Epoch  99: train loss: 0.1973725110, validation loss: 0.5299829505
# Epoch 100: train loss: 0.1967927366, validation loss: 0.5159971260
# Epoch 101: train loss: 0.1938854754, validation loss: 0.5072902416
# Epoch 102: train loss: 0.1936848313, validation loss: 0.5212830024
# Epoch 103: train loss: 0.1912932396, validation loss: 0.5068742243
# Epoch 104: train loss: 0.1907557100, validation loss: 0.5305988345
# Epoch 105: train loss: 0.1889193058, validation loss: 0.4893929719
# Epoch 106: train loss: 0.1859708428, validation loss: 0.4997623719
# Epoch 107: train loss: 0.1849036068, validation loss: 0.4974561991
# Epoch 108: train loss: 0.1824668050, validation loss: 0.4986261313
# Epoch 109: train loss: 0.1829755604, validation loss: 0.4915617028
# Epoch 110: train loss: 0.1800390631, validation loss: 0.4884355584
# Epoch 111: train loss: 0.1772690117, validation loss: 0.4839610944
# Epoch 112: train loss: 0.1766044945, validation loss: 0.4834411535
# Epoch 113: train loss: 0.1756952703, validation loss: 0.4741735872
# Epoch 114: train loss: 0.1738443822, validation loss: 0.4792844724
# Epoch 115: train loss: 0.1718631387, validation loss: 0.4940129247
# Epoch 116: train loss: 0.1703263670, validation loss: 0.4810601865
# Epoch 117: train loss: 0.1701015681, validation loss: 0.4724226026
# Epoch 118: train loss: 0.1672300100, validation loss: 0.4699364386
# Epoch 119: train loss: 0.1678254753, validation loss: 0.4746300856
# Epoch 120: train loss: 0.1658974886, validation loss: 0.4667896442
# Epoch 121: train loss: 0.1657401919, validation loss: 0.4561617924
# Epoch 122: train loss: 0.1637504846, validation loss: 0.4785970655
# Epoch 123: train loss: 0.1611677706, validation loss: 0.4747664361
# Epoch 124: train loss: 0.1608928144, validation loss: 0.4715870116
# Epoch 125: train loss: 0.1608565450, validation loss: 0.4598454069
# Epoch 126: train loss: 0.1577379853, validation loss: 0.4531632047
# Epoch 127: train loss: 0.1567524970, validation loss: 0.4699012781
# Epoch 128: train loss: 0.1563920230, validation loss: 0.4496818858
# Epoch 129: train loss: 0.1542169899, validation loss: 0.4702202120
# Epoch 130: train loss: 0.1535956562, validation loss: 0.4620654049
# Epoch 131: train loss: 0.1523570418, validation loss: 0.4419985417
# Epoch 132: train loss: 0.1519858837, validation loss: 0.4561123946
# Epoch 133: train loss: 0.1507563740, validation loss: 0.4493086430
# Epoch 134: train loss: 0.1499206126, validation loss: 0.4609078802
# Epoch 135: train loss: 0.1483995467, validation loss: 0.4501991574
# Epoch 136: train loss: 0.1478095651, validation loss: 0.4452519306
# Epoch 137: train loss: 0.1471267194, validation loss: 0.4521708814
# Epoch 138: train loss: 0.1456359178, validation loss: 0.4394674195
# Epoch 139: train loss: 0.1440356225, validation loss: 0.4443820826
# Epoch 140: train loss: 0.1433954686, validation loss: 0.4547769027
# Epoch 141: train loss: 0.1434448361, validation loss: 0.4326077588
# Epoch 142: train loss: 0.1411533803, validation loss: 0.4445764883
# Epoch 143: train loss: 0.1406226605, validation loss: 0.4267153742
# Epoch 144: train loss: 0.1407376230, validation loss: 0.4226104413
# Epoch 145: train loss: 0.1401275396, validation loss: 0.4310502427
# Epoch 146: train loss: 0.1390723586, validation loss: 0.4321779413
# Epoch 147: train loss: 0.1384642720, validation loss: 0.4258482620
# Epoch 148: train loss: 0.1360636652, validation loss: 0.4337285470
# Epoch 149: train loss: 0.1356720328, validation loss: 0.4294648250
# Epoch 150: train loss: 0.1357277781, validation loss: 0.4262598277
# Epoch 151: train loss: 0.1343315840, validation loss: 0.4192118784
# Epoch 152: train loss: 0.1338142455, validation loss: 0.4151789976
# Epoch 153: train loss: 0.1328093112, validation loss: 0.4114502897
# Epoch 154: train loss: 0.1325909048, validation loss: 0.4268066193
# Epoch 155: train loss: 0.1317699850, validation loss: 0.4183716176
# Epoch 156: train loss: 0.1301375329, validation loss: 0.4175492917
# Epoch 157: train loss: 0.1287742108, validation loss: 0.4188097984
# Epoch 158: train loss: 0.1293496639, validation loss: 0.4254526133
# Epoch 159: train loss: 0.1294916123, validation loss: 0.4032884188
# Epoch 160: train loss: 0.1269723028, validation loss: 0.4139925198
# Epoch 161: train loss: 0.1273607314, validation loss: 0.4134470470
# Epoch 162: train loss: 0.1272122264, validation loss: 0.4064512698
# Epoch 163: train loss: 0.1263614297, validation loss: 0.4142659086
# Epoch 164: train loss: 0.1246159449, validation loss: 0.4041611334
# Epoch 165: train loss: 0.1249773204, validation loss: 0.4027098054
# Epoch 166: train loss: 0.1229271814, validation loss: 0.4075120051
# Epoch 167: train loss: 0.1223876774, validation loss: 0.4012432989
# Epoch 168: train loss: 0.1208731532, validation loss: 0.3997530961
# Epoch 169: train loss: 0.1214767843, validation loss: 0.3946518732
# Epoch 170: train loss: 0.1222744510, validation loss: 0.3956969715
# Epoch 171: train loss: 0.1202336252, validation loss: 0.3990752451
# Epoch 172: train loss: 0.1195571944, validation loss: 0.3928389153
# Epoch 173: train loss: 0.1196273863, validation loss: 0.4018133496
# Epoch 174: train loss: 0.1196011752, validation loss: 0.4304653077
# Epoch 175: train loss: 0.1201280057, validation loss: 0.3879911772
# Epoch 176: train loss: 0.1163683832, validation loss: 0.3911362214
# Epoch 177: train loss: 0.1157321110, validation loss: 0.3973452072
# Epoch 178: train loss: 0.1154328957, validation loss: 0.3884816360
# Epoch 179: train loss: 0.1156595051, validation loss: 0.3832095628
# Epoch 180: train loss: 0.1146908104, validation loss: 0.3828896646
# Epoch 181: train loss: 0.1121738032, validation loss: 0.3795490812
# Epoch 182: train loss: 0.1134589612, validation loss: 0.3840186349
# Epoch 183: train loss: 0.1134266034, validation loss: 0.3756857896
# Epoch 184: train loss: 0.1148728654, validation loss: 0.4107733327
# Epoch 185: train loss: 0.1134888083, validation loss: 0.3794409641
# Epoch 186: train loss: 0.1099135652, validation loss: 0.3776201940
# Epoch 187: train loss: 0.1090044454, validation loss: 0.3754279423
# Epoch 188: train loss: 0.1092239022, validation loss: 0.3840867291
# Epoch 189: train loss: 0.1081742644, validation loss: 0.3881601212
# Epoch 190: train loss: 0.1087618321, validation loss: 0.3803384413
# Epoch 191: train loss: 0.1087866426, validation loss: 0.3959815274
# Epoch 192: train loss: 0.1072474867, validation loss: 0.3718928492
# Epoch 193: train loss: 0.1063061208, validation loss: 0.3712368110
# Epoch 194: train loss: 0.1060019508, validation loss: 0.3724276407
# Epoch 195: train loss: 0.1043801010, validation loss: 0.3729331522
# Epoch 196: train loss: 0.1054930463, validation loss: 0.3811890285
# Epoch 197: train loss: 0.1043978035, validation loss: 0.3697541303
# Epoch 198: train loss: 0.1034628749, validation loss: 0.3728990195
# Epoch 199: train loss: 0.1039347276, validation loss: 0.3657820320
# Epoch 200: train loss: 0.1029979885, validation loss: 0.3668207444
# Epoch 201: train loss: 0.1023090407, validation loss: 0.3698570584
# Epoch 202: train loss: 0.1003663391, validation loss: 0.3674066073
# Epoch 203: train loss: 0.1006308123, validation loss: 0.3680599528
# Epoch 204: train loss: 0.1010034233, validation loss: 0.3731223397
# Epoch 205: train loss: 0.1009170115, validation loss: 0.3656948734
# Epoch 206: train loss: 0.0987519473, validation loss: 0.3658287420
# Epoch 207: train loss: 0.0997992009, validation loss: 0.3736201442
# Epoch 208: train loss: 0.0989708900, validation loss: 0.3599698685
# Epoch 209: train loss: 0.0975942537, validation loss: 0.3718376585
# Epoch 210: train loss: 0.0974796936, validation loss: 0.3622221715
# Epoch 211: train loss: 0.0977185145, validation loss: 0.3729272294
# Epoch 212: train loss: 0.0980919376, validation loss: 0.3889257384
# Epoch 213: train loss: 0.0979035124, validation loss: 0.3603857493
# Epoch 214: train loss: 0.0969035923, validation loss: 0.3712197272
# Epoch 215: train loss: 0.0951634198, validation loss: 0.3549656244
# Epoch 216: train loss: 0.0949524790, validation loss: 0.3578592684
# Epoch 217: train loss: 0.0947927386, validation loss: 0.3597937757
# Epoch 218: train loss: 0.0950120613, validation loss: 0.4852913838
# Epoch 219: train loss: 0.0984585136, validation loss: 0.3490152968
# Epoch 220: train loss: 0.0927139148, validation loss: 0.3521483402
# Epoch 221: train loss: 0.0936829448, validation loss: 0.3556919749
# Epoch 222: train loss: 0.0930693001, validation loss: 0.3539692183
# Epoch 223: train loss: 0.0920469537, validation loss: 0.3679820457
# Epoch 224: train loss: 0.0929162428, validation loss: 0.3465900598
# Epoch 225: train loss: 0.0919560716, validation loss: 0.3517539135
# Epoch 226: train loss: 0.0915873498, validation loss: 0.3495642590
# Epoch 227: train loss: 0.0913736448, validation loss: 0.3635037989
# Epoch 228: train loss: 0.0908981189, validation loss: 0.3509674342
# Epoch 229: train loss: 0.0896676779, validation loss: 0.3461576642
# Epoch 230: train loss: 0.0906406045, validation loss: 0.3873618016
# Epoch 231: train loss: 0.0897499695, validation loss: 0.3495224758
# Epoch 232: train loss: 0.0895377174, validation loss: 0.3454191942
# Epoch 233: train loss: 0.0891354159, validation loss: 0.3423627585
# Epoch 234: train loss: 0.0891403779, validation loss: 0.3495774291
# Epoch 235: train loss: 0.0881875306, validation loss: 0.3407867841
# Epoch 236: train loss: 0.0876963660, validation loss: 0.3411409421
# Epoch 237: train loss: 0.0871208161, validation loss: 0.3385918779
# Epoch 238: train loss: 0.0871748626, validation loss: 0.3447923502
# Epoch 239: train loss: 0.0861793607, validation loss: 0.3353876045
# Epoch 240: train loss: 0.0875140429, validation loss: 0.3340782826
# Epoch 241: train loss: 0.0869550258, validation loss: 0.3535206964
# Epoch 242: train loss: 0.0869475976, validation loss: 0.3452778024
# Epoch 243: train loss: 0.0854833946, validation loss: 0.3529721799
# Epoch 244: train loss: 0.0862035304, validation loss: 0.3379590410
# Epoch 245: train loss: 0.0856666267, validation loss: 0.3352061315
# Epoch 246: train loss: 0.0845070481, validation loss: 0.3406870917
# Epoch 247: train loss: 0.0860017464, validation loss: 0.3413155762
# Epoch 248: train loss: 0.0854080394, validation loss: 0.3346209076
# Epoch 249: train loss: 0.0830550566, validation loss: 0.3432285472
# Epoch 250: train loss: 0.0846790969, validation loss: 0.3361872821
# Epoch 251: train loss: 0.0832882524, validation loss: 0.3491962946
# Epoch 252: train loss: 0.0848937035, validation loss: 0.3322288956
# Epoch 253: train loss: 0.0820291415, validation loss: 0.3260480938
# Epoch 254: train loss: 0.0816553384, validation loss: 0.3502903553
# Epoch 255: train loss: 0.0825294033, validation loss: 0.3283928020
# Epoch 256: train loss: 0.0828774124, validation loss: 0.3491332886
# Epoch 257: train loss: 0.0819779783, validation loss: 0.3310372421
# Epoch 258: train loss: 0.0821112990, validation loss: 0.3294387468
# Epoch 259: train loss: 0.0805240497, validation loss: 0.3263592383
# Epoch 260: train loss: 0.0811568275, validation loss: 0.3255634672
# Epoch 261: train loss: 0.0810648352, validation loss: 0.3276907685
# Epoch 262: train loss: 0.0799338818, validation loss: 0.3275158958
# Epoch 263: train loss: 0.0803440362, validation loss: 0.3394330649
# Epoch 264: train loss: 0.0799326077, validation loss: 0.3322857546
# Epoch 265: train loss: 0.0809961334, validation loss: 0.3211087426
# Epoch 266: train loss: 0.0803433433, validation loss: 0.3223608557
# Epoch 267: train loss: 0.0790739730, validation loss: 0.3257245011
# Epoch 268: train loss: 0.0799361765, validation loss: 0.3191619924
# Epoch 269: train loss: 0.0802114829, validation loss: 0.3285707085
# Epoch 270: train loss: 0.0786161721, validation loss: 0.3315232382
# Epoch 271: train loss: 0.0842756182, validation loss: 0.4726472905
# Epoch 272: train loss: 0.0910971686, validation loss: 0.3239993721
# Epoch 273: train loss: 0.0769238248, validation loss: 0.3267893583
# Epoch 274: train loss: 0.0776600093, validation loss: 0.3229444750
# Epoch 275: train loss: 0.0778630376, validation loss: 0.3234331518
# Epoch 276: train loss: 0.0764939860, validation loss: 0.3171661840
# Epoch 277: train loss: 0.0768681988, validation loss: 0.3498105854
# Epoch 278: train loss: 0.0777835324, validation loss: 0.3158923719
# Epoch 279: train loss: 0.0773212612, validation loss: 0.3167850845
# Epoch 280: train loss: 0.0764610916, validation loss: 0.3238611267
# Epoch 281: train loss: 0.0764817297, validation loss: 0.3228446733
# Epoch 282: train loss: 0.0765627250, validation loss: 0.3179897990
# Epoch 283: train loss: 0.0765439123, validation loss: 0.3199636406
# Epoch 284: train loss: 0.0762085691, validation loss: 0.3213077235
# Epoch 285: train loss: 0.0759175196, validation loss: 0.3190116147
# Epoch 286: train loss: 0.0748175606, validation loss: 0.3495083809
# Epoch 287: train loss: 0.0755490512, validation loss: 0.3158569118
# Epoch 288: train loss: 0.0751523301, validation loss: 0.3236815368
# Epoch 289: train loss: 0.0756994709, validation loss: 0.3239994018
# Epoch 290: train loss: 0.0755476058, validation loss: 0.3097260876
# Epoch 291: train loss: 0.0752234831, validation loss: 0.3205647937
# Epoch 292: train loss: 0.0749363825, validation loss: 0.3100649753
# Epoch 293: train loss: 0.0755690113, validation loss: 0.3152542426
# Epoch 294: train loss: 0.0738623887, validation loss: 0.3188348029
# Epoch 295: train loss: 0.0741043091, validation loss: 0.3118568120
# Epoch 296: train loss: 0.0736305490, validation loss: 0.3077042030
# Epoch 297: train loss: 0.0752915069, validation loss: 0.3177528675
# Epoch 298: train loss: 0.0724824145, validation loss: 0.3359792026
# Epoch 299: train loss: 0.0745423958, validation loss: 0.3157992693
# Epoch 300: train loss: 0.0735913590, validation loss: 0.3107886481
# Epoch 301: train loss: 0.0730980262, validation loss: 0.3192106252
# Epoch 302: train loss: 0.0726939440, validation loss: 0.3224017539
# Epoch 303: train loss: 0.0733067542, validation loss: 0.3129105282
# Epoch 304: train loss: 0.0735161826, validation loss: 0.3132941424
# Epoch 305: train loss: 0.0727382377, validation loss: 0.3187175040
# Epoch 306: train loss: 0.0722440332, validation loss: 0.3072682554
# Epoch 307: train loss: 0.0734811127, validation loss: 0.3585846458
# Epoch 308: train loss: 0.0734756142, validation loss: 0.3136775258
# Epoch 309: train loss: 0.0712803528, validation loss: 0.3066563994
# Epoch 310: train loss: 0.0712477267, validation loss: 0.3089887957
# Epoch 311: train loss: 0.0714746863, validation loss: 0.3104231301
# Epoch 312: train loss: 0.0713073462, validation loss: 0.3023108297
# Epoch 313: train loss: 0.0714217201, validation loss: 0.3202758076
# Epoch 314: train loss: 0.0713992193, validation loss: 0.3104072571
# Epoch 315: train loss: 0.0719925314, validation loss: 0.3517586143
# Epoch 316: train loss: 0.0718984902, validation loss: 0.3362408046
# Epoch 317: train loss: 0.0715792179, validation loss: 0.3224166403
# Epoch 318: train loss: 0.0700863153, validation loss: 0.3146773270
# Epoch 319: train loss: 0.0695357248, validation loss: 0.3070099910
# Epoch 320: train loss: 0.0702518672, validation loss: 0.3072113116
# Epoch 321: train loss: 0.0697768033, validation loss: 0.3321817270
# Epoch 322: train loss: 0.0713806301, validation loss: 0.3076758515
# Epoch 323: train loss: 0.0704814941, validation loss: 0.3098649351
# Epoch 324: train loss: 0.0696486011, validation loss: 0.3063787761
# Epoch 325: train loss: 0.0689606890, validation loss: 0.3140873517
# Epoch 326: train loss: 0.0701232925, validation loss: 0.3090092801
# Epoch 327: train loss: 0.0694913939, validation loss: 0.3065472348
# Epoch 328: train loss: 0.0698634014, validation loss: 0.3227668120
# Epoch 329: train loss: 0.0691097379, validation loss: 0.3007006981
# Epoch 330: train loss: 0.0683424026, validation loss: 0.3071635383
# Epoch 331: train loss: 0.0690137148, validation loss: 0.2993917598
# Epoch 332: train loss: 0.0685080439, validation loss: 0.3194561214
# Epoch 333: train loss: 0.0679063573, validation loss: 0.3092743468
# Epoch 334: train loss: 0.0680169761, validation loss: 0.2989386380
# Epoch 335: train loss: 0.0686164424, validation loss: 0.3046155342
# Epoch 336: train loss: 0.0686073601, validation loss: 0.3010661320
# Epoch 337: train loss: 0.0678478181, validation loss: 0.3069911904
# Epoch 338: train loss: 0.0678315237, validation loss: 0.3003589109
# Epoch 339: train loss: 0.0672976822, validation loss: 0.2991221430
# Epoch 340: train loss: 0.0675878301, validation loss: 0.3065671586
# Epoch 341: train loss: 0.0676872954, validation loss: 0.3083411893
# Epoch 342: train loss: 0.0667776540, validation loss: 0.3038518819
# Epoch 343: train loss: 0.0667644516, validation loss: 0.3068213390
# Epoch 344: train loss: 0.0663374290, validation loss: 0.3041802095
# Epoch 345: train loss: 0.0660509020, validation loss: 0.2955082043
# Epoch 346: train loss: 0.0665925443, validation loss: 0.3137358624
# Epoch 347: train loss: 0.0668291301, validation loss: 0.3118816150
# Epoch 348: train loss: 0.0658829361, validation loss: 0.3097256842
# Epoch 349: train loss: 0.0665836185, validation loss: 0.3000631658
# Epoch 350: train loss: 0.0651266500, validation loss: 0.3040250635
# Epoch 351: train loss: 0.0662673488, validation loss: 0.2930293438
# Epoch 352: train loss: 0.0663422346, validation loss: 0.3008370495
# Epoch 353: train loss: 0.0648055524, validation loss: 0.2935023377
# Epoch 354: train loss: 0.0654762834, validation loss: 0.3043939209
# Epoch 355: train loss: 0.0653211474, validation loss: 0.3100783685
# Epoch 356: train loss: 0.0665774941, validation loss: 0.2932635228
# Epoch 357: train loss: 0.0640198663, validation loss: 0.2930198541
# Epoch 358: train loss: 0.0659373403, validation loss: 0.2966938766
# Epoch 359: train loss: 0.0644789413, validation loss: 0.2931564256
# Epoch 360: train loss: 0.0648951977, validation loss: 0.3098122879
# Epoch 361: train loss: 0.0645888448, validation loss: 0.3014824884
# Epoch 362: train loss: 0.0641910285, validation loss: 0.2983048557
# Epoch 363: train loss: 0.0648696348, validation loss: 0.3045215011
# Epoch 364: train loss: 0.0649210513, validation loss: 0.2900788252
# Epoch 365: train loss: 0.0641688257, validation loss: 0.2939508130
# Epoch 366: train loss: 0.0638777688, validation loss: 0.2876604250
# Epoch 367: train loss: 0.0641058385, validation loss: 0.2968945153
# Epoch 368: train loss: 0.0636757240, validation loss: 0.2880572248
# Epoch 369: train loss: 0.0625327080, validation loss: 0.2955937342
# Epoch 370: train loss: 0.0639666393, validation loss: 0.2939620421
# Epoch 371: train loss: 0.0631411076, validation loss: 0.2881937908
# Epoch 372: train loss: 0.0631513894, validation loss: 0.2902790334
# Epoch 373: train loss: 0.0632838905, validation loss: 0.3158415225
# Epoch 374: train loss: 0.0624789819, validation loss: 0.2910898812
# Epoch 375: train loss: 0.0624776967, validation loss: 0.2908499836
# Epoch 376: train loss: 0.0621197112, validation loss: 0.2871788623
# Epoch 377: train loss: 0.0626270697, validation loss: 0.3027258536
# Epoch 378: train loss: 0.0635045469, validation loss: 0.2843549976
# Epoch 379: train loss: 0.0611048266, validation loss: 0.2924818454
# Epoch 380: train loss: 0.0618836917, validation loss: 0.2896618553
# Epoch 381: train loss: 0.0621150769, validation loss: 0.2914817869
# Epoch 382: train loss: 0.0625247657, validation loss: 0.3771237852
# Epoch 383: train loss: 0.0635415837, validation loss: 0.2925405147
# Epoch 384: train loss: 0.0621759072, validation loss: 0.3473039261
# Epoch 385: train loss: 0.0634468719, validation loss: 0.2986165600
# Epoch 386: train loss: 0.0607991554, validation loss: 0.2886759954
# Epoch 387: train loss: 0.0613892153, validation loss: 0.2843833522
# Epoch 388: train loss: 0.0610804856, validation loss: 0.2863861612
# Epoch 389: train loss: 0.0622966513, validation loss: 0.4071135457
# Epoch 390: train loss: 0.0694981217, validation loss: 0.2892739536
# Epoch 391: train loss: 0.0597201698, validation loss: 0.2963848431
# Epoch 392: train loss: 0.0600594990, validation loss: 0.2874053248
# Epoch 393: train loss: 0.0599536188, validation loss: 0.2896082722
# Epoch 394: train loss: 0.0594951361, validation loss: 0.2913407413
# Epoch 395: train loss: 0.0608045422, validation loss: 0.2905458227
# Epoch 396: train loss: 0.0602257252, validation loss: 0.2810953720
# Epoch 397: train loss: 0.0600588769, validation loss: 0.2879462999
# Epoch 398: train loss: 0.0599982925, validation loss: 0.2828240637
# Epoch 399: train loss: 0.0597546138, validation loss: 0.2825060290
# Epoch 400: train loss: 0.0594150312, validation loss: 0.2866796964
# Epoch 401: train loss: 0.0586297512, validation loss: 0.2952100720
# Epoch 402: train loss: 0.0596510768, validation loss: 0.2831466625
# Epoch 403: train loss: 0.0588229522, validation loss: 0.2807309363
# Epoch 404: train loss: 0.0598832034, validation loss: 0.2808197246
# Epoch 405: train loss: 0.0590280145, validation loss: 0.2865463588
# Epoch 406: train loss: 0.0599741042, validation loss: 0.2763472938
# Epoch 407: train loss: 0.0588408858, validation loss: 0.2857546094
# Epoch 408: train loss: 0.0588838831, validation loss: 0.2905351738
# Epoch 409: train loss: 0.0580991320, validation loss: 0.2855761168
# Epoch 410: train loss: 0.0577410124, validation loss: 0.2841954886
# Epoch 411: train loss: 0.0588527098, validation loss: 0.2781553872
# Epoch 412: train loss: 0.0579766892, validation loss: 0.3001360323
# Epoch 413: train loss: 0.0585848279, validation loss: 0.2887086256
# Epoch 414: train loss: 0.0581417382, validation loss: 0.2799744440
# Epoch 415: train loss: 0.0576588884, validation loss: 0.3137296309
# Epoch 416: train loss: 0.0587364882, validation loss: 0.2762875966
# Epoch 417: train loss: 0.0578020588, validation loss: 0.2930994127
# Epoch 418: train loss: 0.0570380315, validation loss: 0.2743398755
# Epoch 419: train loss: 0.0589142889, validation loss: 0.2916452257
# Epoch 420: train loss: 0.0572177656, validation loss: 0.2771626187
# Epoch 421: train loss: 0.0561072752, validation loss: 0.2769265701
# Epoch 422: train loss: 0.0566261336, validation loss: 0.3004254419
# Epoch 423: train loss: 0.0583777577, validation loss: 0.2738128634
# Epoch 424: train loss: 0.0568556264, validation loss: 0.2840487476
# Epoch 425: train loss: 0.0560458079, validation loss: 0.2755374957
# Epoch 426: train loss: 0.0561083592, validation loss: 0.3028156589
# Epoch 427: train loss: 0.0575468801, validation loss: 0.2771910757
# Epoch 428: train loss: 0.0580068380, validation loss: 0.3161634010
# Epoch 429: train loss: 0.0565577261, validation loss: 0.2795484144
# Epoch 430: train loss: 0.0561051704, validation loss: 0.2831489575
# Epoch 431: train loss: 0.0565742590, validation loss: 0.2756617427
# Epoch 432: train loss: 0.0557361357, validation loss: 0.2829046912
# Epoch 433: train loss: 0.0550050735, validation loss: 0.2897817424
# Epoch 434: train loss: 0.0561607070, validation loss: 0.3220356000
# Epoch 435: train loss: 0.0564506724, validation loss: 0.2746863192
# Epoch 436: train loss: 0.0559191741, validation loss: 0.2953269351
# Epoch 437: train loss: 0.0561827309, validation loss: 0.2703295479
# Epoch 438: train loss: 0.0542540289, validation loss: 0.2732626046
# Epoch 439: train loss: 0.0550269298, validation loss: 0.3139610614
# Epoch 440: train loss: 0.0562301539, validation loss: 0.2848588749
# Epoch 441: train loss: 0.0546954498, validation loss: 0.2773858586
# Epoch 442: train loss: 0.0552010722, validation loss: 0.2713562103
# Epoch 443: train loss: 0.0541971400, validation loss: 0.2714564962
# Epoch 444: train loss: 0.0538645126, validation loss: 0.2736801017
# Epoch 445: train loss: 0.0548244305, validation loss: 0.2697208602
# Epoch 446: train loss: 0.0546933189, validation loss: 0.2790256813
# Epoch 447: train loss: 0.0551403984, validation loss: 0.2750448000
# Epoch 448: train loss: 0.0526315793, validation loss: 0.2676969147
# Epoch 449: train loss: 0.0534008630, validation loss: 0.2714680699
# Epoch 450: train loss: 0.0543763340, validation loss: 0.2743847731
# Epoch 451: train loss: 0.0540153421, validation loss: 0.2696412366
# Epoch 452: train loss: 0.0537299030, validation loss: 0.2803272052
# Epoch 453: train loss: 0.0535308272, validation loss: 0.2672133851
# Epoch 454: train loss: 0.0535063297, validation loss: 0.2650475012
# Epoch 455: train loss: 0.0536098965, validation loss: 0.2738156764
# Epoch 456: train loss: 0.0526114069, validation loss: 0.2866011884
# Epoch 457: train loss: 0.0539677218, validation loss: 0.2784050049
# Epoch 458: train loss: 0.0533976965, validation loss: 0.2657739966
# Epoch 459: train loss: 0.0524212234, validation loss: 0.2678909142
# Epoch 460: train loss: 0.0533563197, validation loss: 0.2690677882
# Epoch 461: train loss: 0.0534258671, validation loss: 0.2746684949
# Epoch 462: train loss: 0.0527187809, validation loss: 0.2687643204
# Epoch 463: train loss: 0.0524650402, validation loss: 0.2684807233
# Epoch 464: train loss: 0.0526241884, validation loss: 0.2895453307
# Epoch 465: train loss: 0.0536913536, validation loss: 0.2653292477
# Epoch 466: train loss: 0.0516807884, validation loss: 0.2604165029
# Epoch 467: train loss: 0.0526511818, validation loss: 0.2683692909
# Epoch 468: train loss: 0.0519472025, validation loss: 0.2724253400
# Epoch 469: train loss: 0.0511250868, validation loss: 0.2654767444
# Epoch 470: train loss: 0.0511894375, validation loss: 0.2642412132
# Epoch 471: train loss: 0.0524095297, validation loss: 0.2633632550
# Epoch 472: train loss: 0.0518074334, validation loss: 0.2719585495
# Epoch 473: train loss: 0.0518280938, validation loss: 0.2724530792
# Epoch 474: train loss: 0.0514080077, validation loss: 0.2775498139
# Epoch 475: train loss: 0.0516351461, validation loss: 0.2663466996
# Epoch 476: train loss: 0.0520834103, validation loss: 0.2653892089
# Epoch 477: train loss: 0.0513566583, validation loss: 0.2662422118
# Epoch 478: train loss: 0.0505203158, validation loss: 0.2596372201
# Epoch 479: train loss: 0.0506183505, validation loss: 0.2647176884
# Epoch 480: train loss: 0.0507962182, validation loss: 0.2592727264
# Epoch 481: train loss: 0.0513814166, validation loss: 0.2690637612
# Epoch 482: train loss: 0.0519444905, validation loss: 0.2814405021
# Epoch 483: train loss: 0.0506152324, validation loss: 0.2637317675
# Epoch 484: train loss: 0.0503716618, validation loss: 0.2617498388
# Epoch 485: train loss: 0.0496365950, validation loss: 0.2603414756
# Epoch 486: train loss: 0.0506444573, validation loss: 0.2602076646
# Epoch 487: train loss: 0.0505750701, validation loss: 0.2549802658
# Epoch 488: train loss: 0.0510203987, validation loss: 0.2618857906
# Epoch 489: train loss: 0.0492915362, validation loss: 0.2637242835
# Epoch 490: train loss: 0.0499116257, validation loss: 0.2699959558
# Epoch 491: train loss: 0.0498161651, validation loss: 0.2728740045
# Epoch 492: train loss: 0.0503367856, validation loss: 0.2613536094
# Epoch 493: train loss: 0.0498315133, validation loss: 0.2687093339
# Epoch 494: train loss: 0.0492844284, validation loss: 0.2640385880
# Epoch 495: train loss: 0.0494224019, validation loss: 0.2634414884
# Epoch 496: train loss: 0.0493950769, validation loss: 0.2619925998
# Epoch 497: train loss: 0.0499165505, validation loss: 0.2900138970
# Epoch 498: train loss: 0.0499770641, validation loss: 0.2647396301
# Epoch 499: train loss: 0.0487994589, validation loss: 0.2549668349
# Epoch 500: train loss: 0.0484722294, validation loss: 0.2586248104
# Finished Training

# %% [markdown]
# ***Learning Curves***

# %%
train_loss = [l[0] for l in model_koop_dnn.train_loss_hist]
train_pred_loss = [l[1] for l in model_koop_dnn.train_loss_hist]
train_lifted_loss = [l[2] for l in model_koop_dnn.train_loss_hist]
val_loss = [l[0] for l in model_koop_dnn.val_loss_hist]
val_pred_loss = [l[1] for l in model_koop_dnn.val_loss_hist]
val_lifted_loss = [l[2] for l in model_koop_dnn.val_loss_hist]
epochs = np.arange(0, net_params['epochs'])

plt.figure(figsize=(15,8))
plt.plot(epochs, train_loss, color='tab:orange', label='Training loss')
plt.plot(epochs, train_pred_loss, '--', color='tab:orange', label='Training prediction loss')
plt.plot(epochs, train_lifted_loss, ':', color='tab:orange', label='Training lifted loss')
plt.plot(epochs, val_loss, color='tab:blue', label='Validation loss')
plt.plot(epochs, val_pred_loss, '--', color='tab:blue', label='Validation prediction loss')
plt.plot(epochs, val_lifted_loss, ':', color='tab:blue', label='Validation lifted loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale('log')
plt.savefig("convergence plot for arch1")
plt.show()

# %%
map_net_params = {}
map_net_params["input_dim"] = int(num_states/2) #number of joint angles
map_net_params["output_dim"] = X_end.shape[2] #x and y position of the end effector
map_net_params["hidden_width"] = 20
map_net_params["hidden_depth"] = 2
map_net_params["batch_size"] = 100
map_net_params["epochs"] = 500
map_net_params["activation_type"] = 'tanh'
map_net_params["lr"] = 1e-3
map_net_params["optimizer"] = 'adam'
map_net_params['l2_reg'] = 0.0
map_net_params['l1_reg'] = 0.0

# %%
#dataset
# split training and vaidation datasets
xs_map_train, ys_map_train = X_full[:num_train,:,:7],X_end[:num_train,:,:3]
xs_map_val, ys_map_val = X_full[num_train:,:,:7],X_end[num_train:,:,:3]

# %%
ys_map_train.shape, ys_map_val.shape,xs_map_train.shape, xs_map_val.shape
# Out:
# ((75, 1001, 3), (25, 1001, 3), (75, 1001, 7), (25, 1001, 7))

# %%
#Initalize network
#Initalize network
train = False

if train==True:
    file = "saved_models/Kuka/2D/map_net_time_delay.pth"
    map_net = map_Net(map_net_params)
    map_net.set_dataset_map(xs_map_train,ys_map_train,xs_map_val,ys_map_val)
    map_net.data_pipeline()
    torch.save(map_net,file)
else:
    file = "saved_models/Kuka/2D/map_net_time_delay.pth"
    map_net = torch.load(file)

# %%
epochs = np.arange(0, map_net_params['epochs'])
plt.figure(figsize=(15,8))
plt.plot(epochs, map_net.train_loss_hist, color='tab:orange', label='Training loss')
plt.plot(epochs, map_net.val_loss_hist, color='tab:blue', label='Validation loss')

plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale('log')
plt.savefig("convergence plot of map net for arch1[3,20,20,2]")
plt.show()

# %%
# import scipy.io

# #save net parameters
# scipy.io.savemat("map_in_weights.mat", {"map_in_weights": map_net.map_net_in.weight.detach().numpy()})
# scipy.io.savemat("map_in_bias.mat", {"map_in_bias": map_net.map_net_in.bias.detach().numpy()})

# scipy.io.savemat("map_hidden_weights_1.mat",
#                  {"map_hidden_weights_1": map_net.map_net_hid[0].weight.detach().numpy()})
# scipy.io.savemat("map_hidden_bias_1.mat",
#                  {"map_hidden_bias_1": map_net.map_net_hid[0].bias.detach().numpy()})

# scipy.io.savemat("map_hidden_weights_2.mat",
#                  {"map_hidden_weights_2": map_net.map_net_hid[1].weight.detach().numpy()})
# scipy.io.savemat("map_hidden_bias_2.mat",
#                  {"map_hidden_bias_2": map_net.map_net_hid[1].bias.detach().numpy()})

# scipy.io.savemat("map_hidden_weights_3.mat",
#                  {"map_hidden_weights_3": map_net.map_net_hid[2].weight.detach().numpy()})
# scipy.io.savemat("map_hidden_bias_3.mat",
#                  {"map_hidden_bias_3": map_net.map_net_hid[2].bias.detach().numpy()})

# scipy.io.savemat("map_out_weights.mat", {"map_out_weights": map_net.map_net_out.weight.detach().numpy()})
# scipy.io.savemat("map_out_bias.mat", {"map_out_bias": map_net.map_net_out.bias.detach().numpy()})

# %% [markdown]
# ## Test Data Parameters

# %%
# test data parameters
num_snaps_val = 1000 # no. of snapshots
T = np.linspace(0,num_snaps_val*dt, num_snaps_val+1)
num_traj_val = 1 # no. of training examples
first_obs_const = int(net_params['first_obs_const']) #only one state
override_C = net_params['override_C']
if override_C:
    n_obs = int(net_params['encoder_output_dim']) + num_states + first_obs_const 
else:
    n_obs = int(net_params['encoder_output_dim']) + first_obs_const

# %% [markdown]
# ***Koopman Bilinear Model***

# %%
A = np.array(model_koop_dnn.A)
#B = np.array(model_koop_dnn.B).reshape(-1,num_inputs*n_obs)
B = np.array(model_koop_dnn.B)
#B_tensor = np.empty((num_inputs,n_obs, n_obs))
#for ii, b in enumerate(B):
    #B_tensor[ii] = b
C = np.array(model_koop_dnn.C)

print(A.shape, B.shape, C.shape)
# Out:
# (35, 35) (35, 105) (14, 35)

# %%
# #SAVE MATRIX PARAMETERS AS MATLAB FILE
# import scipy.io

# dyn_matrices = {"A": A, "B": B, "C": C}
# scipy.io.savemat("dyn_mat.mat", dyn_matrices)
# #save encoder parameters
# scipy.io.savemat("in_weights.mat", {"encode_in_weights": model_koop_dnn.net.encoder_fc_in.weight.detach().numpy()})
# scipy.io.savemat("in_bias.mat", {"encode_in_bias": model_koop_dnn.net.encoder_fc_in.bias.detach().numpy()})

# scipy.io.savemat("hidden_weights_1.mat",
#                  {"encode_hidden_weights_1": model_koop_dnn.net.encoder_fc_hid[0].weight.detach().numpy()})
# scipy.io.savemat("hidden_bias_1.mat",
#                  {"encode_hidden_bias_1": model_koop_dnn.net.encoder_fc_hid[0].bias.detach().numpy()})

# scipy.io.savemat("hidden_weights_2.mat",
#                  {"encode_hidden_weights_2": model_koop_dnn.net.encoder_fc_hid[1].weight.detach().numpy()})
# scipy.io.savemat("hidden_bias_2.mat",
#                  {"encode_hidden_bias_2": model_koop_dnn.net.encoder_fc_hid[1].bias.detach().numpy()})

# scipy.io.savemat("out_weights.mat", {"encode_out_weights": model_koop_dnn.net.encoder_fc_out.weight.detach().numpy()})
# scipy.io.savemat("out_bias.mat", {"encode_out_bias": model_koop_dnn.net.encoder_fc_out.bias.detach().numpy()})

# %%
encode_out_bias = model_koop_dnn.net.encoder_fc_out.bias.detach().numpy()
encode_out_weights = model_koop_dnn.net.encoder_fc_out.weight.detach().numpy()

# %% [markdown]
# ***Test Data Generation***

# %%
# data_gen
j = 60
xs_end_test = X_end[j,:,:]
xs_test = X_full[j,:,:]
us_test = U_full[j,:,:]

# %%
print(xs_end_test.shape, xs_test.shape, us_test.shape)
# Out:
# (1001, 3) (1001, 14) (1000, 3)

# %%
print(model_koop_dnn.test_loss(xs_test.reshape(1,-1,num_states),u_test = us_test.reshape(1,-1,num_inputs)))
# Out:
# tensor(0.0231)

# %% [markdown]
# ***Initial Condition Lifting***

# %%
# initialize the matricies
z = np.empty((n_obs,num_snaps_val+1)).T
x_est = np.zeros((num_states,num_snaps_val+1)).T
x_end_est = np.zeros((X_end.shape[2],num_snaps_val)).T

# %%
num_outputs = num_states

# %%
x_out_test = xs_test[:num_snaps_val+1,:]
x_out_Test = x_out_test.reshape((num_snaps_val+1,num_outputs))
u_Test = us_test.reshape((num_snaps_val,num_inputs))
x0 = x_out_Test[:net_params["num_delays"]+1,:]
X0 = x0.reshape((1,num_outputs*(net_params["num_delays"]+1)))
print(X0.shape)
z[0,:] = lift_delay(X0[0,:],model_koop_dnn, net_params)
x_est[0,:] = x_out_test[0,:]
# Out:
# (1, 154)

# %% [markdown]
# ***Time Evolution***

# %%
for i in range(num_snaps_val):
  #bilinear
    z[i+1,:] = np.matmul(z[i,:],A.T)+np.matmul(np.kron(u_Test[i,:],z[i,:]),B.T)
    x_est[i+1,:] = np.matmul(z[i+1,:],C.T)  
    x_end_est[i,:] = map_net.forward(torch.from_numpy(x_est[i,:int(num_states/2)]).float()).detach().numpy()

# %% [markdown]
# ***Visualization***

# %% [markdown]
# # Joint Space

# %%
plt.figure()
plt.plot(T[:200],x_out_Test[:200,0],label ='Actual')
plt.plot(T[:200],x_est[:200,0],label = 'estimated(bilinear)')
plt.xlabel('t')
plt.ylabel('theta_1')
plt.title('theta_1 Comparison')
plt.legend()

# %%
plt.figure()
plt.plot(T,x_out_Test[:,1],label ='Actual')
plt.plot(T,x_est[:,1],label = 'estimated(bilinear)')
plt.title('Theta_2')
plt.xlabel('t')
plt.ylabel('Theta_2_comparison')
plt.legend()

# %%
plt.figure()
plt.plot(T,x_out_Test[:,2],label ='Actual')
plt.plot(T,x_est[:,2],label = 'estimated(bilinear)')
plt.title('Theta_3')
plt.xlabel('t')
plt.ylabel('theta_3')
plt.legend()

# %%
plt.figure()
plt.plot(T,x_out_Test[:,3],label ='Actual')
plt.plot(T,x_est[:,3],label = 'estimated(bilinear)')
plt.title('Theta_4')
plt.xlabel('t')
plt.ylabel('theta_4')
plt.legend()

# %%
plt.figure()
plt.plot(T,x_out_Test[:,4],label ='Actual')
plt.plot(T,x_est[:,4],label = 'estimated(bilinear)')
plt.title('Theta_5')
plt.xlabel('t')
plt.ylabel('theta_5')
plt.legend()

# %%
plt.figure()
plt.plot(T,x_out_Test[:,5],label ='Actual')
plt.plot(T,x_est[:,5],label = 'estimated(bilinear)')
plt.title('Theta_6')
plt.xlabel('t')
plt.ylabel('theta_6')
plt.legend()

# %%
plt.figure()
plt.plot(T,x_out_Test[:,6],label ='Actual')
plt.plot(T,x_est[:,6],label = 'estimated(bilinear)')
plt.title('Theta_6')
plt.xlabel('t')
plt.ylabel('theta_6')
plt.legend()

# %%
plt.figure()
plt.plot(T,x_out_Test[:,7],label ='Actual')
plt.plot(T,x_est[:,7],label = 'estimated(bilinear)')
plt.xlabel('t')
plt.ylabel('theta_1_dot')
plt.title('theta_1_dot Comparison')
plt.legend()

# %%
plt.figure()
plt.plot(T,x_out_Test[:,8],label ='Actual')
plt.plot(T,x_est[:,8],label = 'estimated(bilinear)')
plt.title('Theta_2_dot')
plt.xlabel('t')
plt.ylabel('Theta_2_dot_comparison')
plt.legend()

# %%
plt.figure()
plt.plot(T,x_out_Test[:,9],label ='Actual')
plt.plot(T,x_est[:,9],label = 'estimated(bilinear)')
plt.title('Theta_3_dot')
plt.xlabel('t')
plt.ylabel('theta_3_dot')
plt.legend()

# %%
plt.figure()
plt.plot(T,x_out_Test[:,10],label ='Actual')
plt.plot(T,x_est[:,10],label = 'estimated(bilinear)')
plt.title('Theta_4_dot')
plt.xlabel('t')
plt.ylabel('theta_4_dot')
plt.legend()

# %%
plt.figure()
plt.plot(T,x_out_Test[:,11],label ='Actual')
plt.plot(T,x_est[:,11],label = 'estimated(bilinear)')
plt.title('Theta_5_dot')
plt.xlabel('t')
plt.ylabel('theta_5_dot')
plt.legend()

# %%
plt.figure()
plt.plot(T,x_out_Test[:,12],label ='Actual')
plt.plot(T,x_est[:,12],label = 'estimated(bilinear)')
plt.title('Theta_6_dot')
plt.xlabel('t')
plt.ylabel('theta_6_dot')
plt.legend()

# %%
plt.figure()
plt.plot(T,x_out_Test[:,13],label ='Actual')
plt.plot(T,x_est[:,13],label = 'estimated(bilinear)')
plt.title('Theta_7_dot')
plt.xlabel('t')
plt.ylabel('theta_7_dot')
plt.legend()

# %% [markdown]
# ## Cartesian Space

# %%
plt.figure()
plt.plot(T,xs_end_test[:,0], label = 'Actual')
plt.plot(T[:-1],x_end_est[:,0], label = 'Estimated')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(T,xs_end_test[:,1], label = 'Actual')
plt.plot(T[:-1],x_end_est[:,1], label = 'Estimated')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(T,xs_end_test[:,2], label = 'Actual')
plt.plot(T[:-1],x_end_est[:,2], label = 'Estimated')
plt.legend()
plt.show()
