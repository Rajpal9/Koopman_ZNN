# %% [markdown]
# ***Import Libraries***

# %%
"""This program linearizes 3R planar dyanmics using koopman theory and autoencoder to map"""
import numpy as np
import matplotlib.pyplot as plt
import sklearn.preprocessing
import itertools
import scipy.io
import torch

# bilinear Koopman
from core.koopman_core_linear import KoopDNN, KoopmanNet, KoopmanNetCtrl
from models.koop_model import model_matricies,lift
from core.util import fit_standardizer
from sklearn import preprocessing

# forward map neural net
from core.neural_fwd_map import map_Net
from models.neural_jacob_map import neural_jacobian, neural_jacobian_dot
# controllability
from core.util import Output_Con
import control as ct


## import paths
from paths.paths import path_pars, path_pars_2D

## extra libraries
import numpy as np
import scipy as sp
from scipy import sparse

# %%
## define paths
robot = '5R'
nature = 'linear'
modality = '3D'

robot_type_load = robot +'/' + modality # for data load0
robot_type = robot +'/'+ nature +'/' + modality # for saving purposes

train = True
mass_var = False
standardize = True


if mass_var == True:
    file_data = 'dynamics/Dataset_MATLAB/' + robot_type_load +'/data_mass_var.mat'
else:
    file_data = 'dynamics/Dataset_MATLAB/' + robot_type_load +'/data.mat'
    

    
file_data_fwd = 'dynamics/Dataset_MATLAB/' + robot_type_load +'/data_fw.mat'

# %%
file_data
# Out:
# 'dynamics/Dataset_MATLAB/5R/3D/data.mat'

# %% [markdown]
# ### Load Data

# %%
data = scipy.io.loadmat(file_data)
data_fw = scipy.io.loadmat(file_data_fwd)

X_end = np.array(data['X_end'], dtype = 'float64')
X_full = np.array(data['X'], dtype = 'float64')
U_full = np.array(data['tau'], dtype = 'float64')

X_end_fw = np.array(data_fw['X_end_fw'], dtype = 'float64')
X_fw = np.array(data_fw['X_fw'], dtype = 'float64')

print(X_end.shape, X_full.shape,U_full.shape)
# Out:
# (200, 1001, 3) (200, 1001, 10) (200, 1000, 5)

# %%
np.sum(np.sum(np.isnan(X_end))), np.sum(np.sum(np.isnan(U_full))), np.sum(np.sum(np.isnan(X_full)))
# Out:
# (0, 0, 0)

# %% [markdown]
# ***Simulation Parameters***

# %%
dt = float(data['dt']) #time step
num_snaps = int(data['num_snaps']) # no. of snapshots
num_traj = int(data['num_traj']) #no of trajectories
T = np.linspace(0,num_snaps*dt, num_snaps+1)
num_train = int(0.75*num_traj) # no. of training examples
num_val = num_traj-num_train # no of testing examples
num_traj = num_train+num_val #no of trajectories
num_states = X_full.shape[2] # no. of states
num_joints = int(num_states/2)
num_inputs = U_full.shape[2] # no. of inputs
num_states_cart = int(X_end.shape[2])

# %%
dt, num_snaps, num_traj, num_states, num_inputs
# Out:
# (0.005, 1000, 200, 10, 5)

# %% [markdown]
# ***Plotting the trajectories***

# %%
"""Training dataset visualization"""
#theta evolution
for i in range(int(num_joints)):
    plt.subplot(3,3,i+1)
    plt.xlabel("t")
    plt.ylabel("th"+str(i+1))
    for j in range(num_traj):
        plt.plot(T,X_full[j,:,i])

# %%
for i in range(int(num_joints)):
    plt.subplot(3,3,i+1)
    plt.xlabel("t")
    plt.ylabel("th"+str(i+1)+ ' dot')
    for j in range(num_traj):
        plt.plot(T,X_full[j,:,i+int(num_joints)])

# %%
#x and y positions of the end effector
# %matplotlib widget
# ax = plt.axes(projection='3d')
# ax.set_xlabel("x")
# ax.set_ylabel("y")
# ax.set_zlabel("z")
# for i in range(num_traj):
#     ax.plot3D(X_end[i,:,0],X_end[i,:,1],X_end[i,:,2])
    
# plt.axis('equal')

# %%
for i in range(num_traj):
    plt.plot(X_end[i,:,0],X_end[i,:,1])
    
plt.axis('equal')
# Out:
# (-1.4082256410463365,
#  1.2162615275538926,
#  -1.2879232904449895,
#  1.3425861283208387)

# %%
for i in range(num_inputs):
    plt.subplot(4,2,i+1)
    plt.xlabel("t")
    plt.ylabel("tau"+str(i))
    for j in range(num_traj):
        plt.plot(T[:-1],U_full[j,:,i])

# %% [markdown]
# ***Training and validation datasets***

# %%
# split training and vaidation datasets
xs_train, us_train = X_full[:num_train,:,:],U_full[:num_train,:,:]
xs_val, us_val = X_full[num_train:,:,:],U_full[num_train:,:,:]

# %%
# import scipy.io
# Data_set = {"x_end": X_end, "X_full": X_full}
# scipy.io.savemat("Data_set.mat",Data_set)

# %%
# import torch
# import torch.nn as nn
# import torch.nn.functional as F

# %% [markdown]
# ***Model Training***

# %%
net_params = {}
net_params['state_dim'] = num_states
net_params['ctrl_dim'] = num_inputs
net_params['encoder_hidden_width'] = 30 # 30
net_params['encoder_hidden_depth'] = 3  # 2
net_params['encoder_output_dim'] = 20   # 20
net_params['optimizer'] = 'adam'
net_params['activation_type'] = 'tanh'
net_params['lr'] = 5e-4 # 5e-4
net_params['epochs'] = 100
net_params['batch_size'] = 128
net_params['lifted_loss_penalty'] = 0.4 
net_params['l2_reg'] = 0.00       
net_params['l1_reg'] = 0.00
net_params['first_obs_const'] = True
net_params['override_C'] = True # this makes the state a part of lifetd state
net_params['dt'] = dt

# %%
                                                    
if mass_var == True:
    file_koop = 'saved_models/'+robot_type+'/koop_arch_con_mass_var.pth'
else:
    file_koop = 'saved_models/'+robot_type+'/koop_arch_con.pth'
    
standardizer_u_kdnn = fit_standardizer(us_train, preprocessing.StandardScaler(with_mean = True))
# standardizer_x_kdnn = fit_standardizer(xs_train, preprocessing.StandardScaler(with_mean=False))

if train == True:
    
    if standardize:
        net = KoopmanNetCtrl(net_params, standardizer_u=standardizer_u_kdnn)
    else:
        net = KoopmanNetCtrl(net_params)
    model_koop_dnn = KoopDNN(net)
    model_koop_dnn.set_datasets(xs_train, u_train=us_train, x_val=xs_val, u_val=us_val)
    model_koop_dnn.model_pipeline(net_params)
    model_koop_dnn.construct_koopman_model()
    torch.save(model_koop_dnn,file_koop)
else:
    model_koop_dnn = torch.load(file_koop)
# Out:
# /home/rajpal/.local/lib/python3.8/site-packages/torch/autograd/__init__.py:200: UserWarning: CUDA initialization: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:109.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Epoch   1: train loss: 0.9300329089, validation loss: 0.7452509548
# Epoch   2: train loss: 0.6132062078, validation loss: 0.5310039068
# Epoch   3: train loss: 0.4673799276, validation loss: 0.4493666023
# Epoch   4: train loss: 0.4053437412, validation loss: 0.3911471894
# Epoch   5: train loss: 0.3464981318, validation loss: 0.3290537641
# Epoch   6: train loss: 0.2856293917, validation loss: 0.2680686285
# Epoch   7: train loss: 0.2287907302, validation loss: 0.2132438119
# Epoch   8: train loss: 0.1821269989, validation loss: 0.1702369592
# Epoch   9: train loss: 0.1470591575, validation loss: 0.1393447129
# Epoch  10: train loss: 0.1219984815, validation loss: 0.1166537711
# Epoch  11: train loss: 0.1045675501, validation loss: 0.1012974025
# Epoch  12: train loss: 0.0925669819, validation loss: 0.0905668245
# Epoch  13: train loss: 0.0841355622, validation loss: 0.0830653398
# Epoch  14: train loss: 0.0779268518, validation loss: 0.0770282957
# Epoch  15: train loss: 0.0731043667, validation loss: 0.0723023493
# Epoch  16: train loss: 0.0692200214, validation loss: 0.0683419416
# Epoch  17: train loss: 0.0660984218, validation loss: 0.0655314507
# Epoch  18: train loss: 0.0636200756, validation loss: 0.0629761134
# Epoch  19: train loss: 0.0616185963, validation loss: 0.0612355857
# Epoch  20: train loss: 0.0600345582, validation loss: 0.0595310217
# Epoch  21: train loss: 0.0588074364, validation loss: 0.0584189141
# Epoch  22: train loss: 0.0578251407, validation loss: 0.0575635533
# Epoch  23: train loss: 0.0570683330, validation loss: 0.0565147760
# Epoch  24: train loss: 0.0564542338, validation loss: 0.0558341623
# Epoch  25: train loss: 0.0559558608, validation loss: 0.0553987646
# Epoch  26: train loss: 0.0555628575, validation loss: 0.0550701729
# Epoch  27: train loss: 0.0552436262, validation loss: 0.0548758057
# Epoch  28: train loss: 0.0549718961, validation loss: 0.0545568216
# Epoch  29: train loss: 0.0547627918, validation loss: 0.0543650590
# Epoch  30: train loss: 0.0545718484, validation loss: 0.0541645630
# Epoch  31: train loss: 0.0544185415, validation loss: 0.0540392031
# Epoch  32: train loss: 0.0542770773, validation loss: 0.0539062604
# Epoch  33: train loss: 0.0541706793, validation loss: 0.0536497160
# Epoch  34: train loss: 0.0540627390, validation loss: 0.0536701010
# Epoch  35: train loss: 0.0539870858, validation loss: 0.0535873897
# Epoch  36: train loss: 0.0539099500, validation loss: 0.0535107945
# Epoch  37: train loss: 0.0538502112, validation loss: 0.0534801674
# Epoch  38: train loss: 0.0538026728, validation loss: 0.0534110184
# Epoch  39: train loss: 0.0537622236, validation loss: 0.0534859561
# Epoch  40: train loss: 0.0537210107, validation loss: 0.0532279535
# Epoch  41: train loss: 0.0536996871, validation loss: 0.0534220964
# Epoch  42: train loss: 0.0536813624, validation loss: 0.0534770991
# Epoch  43: train loss: 0.0536658652, validation loss: 0.0532886188
# Epoch  44: train loss: 0.0536536239, validation loss: 0.0533760073
# Epoch  45: train loss: 0.0536434352, validation loss: 0.0531949837
# Epoch  46: train loss: 0.0536357947, validation loss: 0.0531410027
# Epoch  47: train loss: 0.0536239557, validation loss: 0.0530958666
# Epoch  48: train loss: 0.0536225922, validation loss: 0.0531253858
# Epoch  49: train loss: 0.0536119454, validation loss: 0.0533263664
# Epoch  50: train loss: 0.0536096394, validation loss: 0.0531065416
# Epoch  51: train loss: 0.0536053814, validation loss: 0.0532424570
# Epoch  52: train loss: 0.0535998493, validation loss: 0.0532868442
# Epoch  53: train loss: 0.0536009260, validation loss: 0.0532233706
# Epoch  54: train loss: 0.0535960607, validation loss: 0.0532555356
# Epoch  55: train loss: 0.0535960160, validation loss: 0.0532346403
# Epoch  56: train loss: 0.0535892919, validation loss: 0.0533050090
# Epoch  57: train loss: 0.0535906404, validation loss: 0.0532096831
# Epoch  58: train loss: 0.0535904467, validation loss: 0.0532169599
# Epoch  59: train loss: 0.0535886586, validation loss: 0.0532500740
# Epoch  60: train loss: 0.0535860546, validation loss: 0.0532774274
# Epoch  61: train loss: 0.0535856783, validation loss: 0.0532664574
# Epoch  62: train loss: 0.0535843372, validation loss: 0.0530657368
# Epoch  63: train loss: 0.0535763130, validation loss: 0.0534030517
# Epoch  64: train loss: 0.0535865091, validation loss: 0.0532744721
# Epoch  65: train loss: 0.0535831861, validation loss: 0.0532011568
# Epoch  66: train loss: 0.0535826683, validation loss: 0.0532425607
# Epoch  67: train loss: 0.0535908639, validation loss: 0.0531718059
# Epoch  68: train loss: 0.0535799824, validation loss: 0.0530907019
# Epoch  69: train loss: 0.0535775721, validation loss: 0.0531354993
# Epoch  70: train loss: 0.0535769612, validation loss: 0.0532887106
# Epoch  71: train loss: 0.0535803288, validation loss: 0.0531109320
# Epoch  72: train loss: 0.0535776988, validation loss: 0.0532563836
# Epoch  73: train loss: 0.0535752065, validation loss: 0.0534344934
# Epoch  74: train loss: 0.0535770431, validation loss: 0.0533277321
# Epoch  75: train loss: 0.0535779744, validation loss: 0.0530940065
# Epoch  76: train loss: 0.0535767563, validation loss: 0.0531853309
# Epoch  77: train loss: 0.0535731018, validation loss: 0.0532995575
# Epoch  78: train loss: 0.0535766557, validation loss: 0.0532069014
# Epoch  79: train loss: 0.0535671562, validation loss: 0.0532801189
# Epoch  80: train loss: 0.0535730086, validation loss: 0.0532458433
# Epoch  81: train loss: 0.0535681061, validation loss: 0.0531792933
# Epoch  82: train loss: 0.0535724126, validation loss: 0.0531730894
# Epoch  83: train loss: 0.0535714924, validation loss: 0.0531214365
# Epoch  84: train loss: 0.0535766184, validation loss: 0.0532172038
# Epoch  85: train loss: 0.0535764992, validation loss: 0.0531963551
# Epoch  86: train loss: 0.0535676405, validation loss: 0.0530988553
# Epoch  87: train loss: 0.0535734631, validation loss: 0.0531347730
# Epoch  88: train loss: 0.0535677522, validation loss: 0.0533167145
# Epoch  89: train loss: 0.0535694174, validation loss: 0.0531285672
# Epoch  90: train loss: 0.0535635427, validation loss: 0.0529799983
# Epoch  91: train loss: 0.0535615757, validation loss: 0.0532177835
# Epoch  92: train loss: 0.0535733625, validation loss: 0.0531007261
# Epoch  93: train loss: 0.0535692349, validation loss: 0.0531748720
# Epoch  94: train loss: 0.0535702705, validation loss: 0.0530767738
# Epoch  95: train loss: 0.0535682254, validation loss: 0.0533807537
# Epoch  96: train loss: 0.0535696447, validation loss: 0.0533604940
# Epoch  97: train loss: 0.0535630584, validation loss: 0.0531820642
# Epoch  98: train loss: 0.0535622053, validation loss: 0.0533709287
# Epoch  99: train loss: 0.0535708927, validation loss: 0.0531654357
# Epoch 100: train loss: 0.0535620525, validation loss: 0.0532682690
# Finished Training

# %% [markdown]
# ***Learning Curves***

# %%
train_loss = [l[0] for l in model_koop_dnn.train_loss_hist]
train_pred_loss = [l[1] for l in model_koop_dnn.train_loss_hist]
train_lifted_loss = [l[2] for l in model_koop_dnn.train_loss_hist]
val_loss = [l[0] for l in model_koop_dnn.val_loss_hist]
val_pred_loss = [l[1] for l in model_koop_dnn.val_loss_hist]
val_lifted_loss = [l[2] for l in model_koop_dnn.val_loss_hist]
epochs = np.arange(0, net_params['epochs'])

plt.figure(figsize=(15,8))
plt.plot(epochs, train_loss, color='tab:orange', label='Training loss')
plt.plot(epochs, train_pred_loss, '--', color='tab:orange', label='Training prediction loss')
plt.plot(epochs, train_lifted_loss, ':', color='tab:orange', label='Training lifted loss')
plt.plot(epochs, val_loss, color='tab:blue', label='Validation loss')
plt.plot(epochs, val_pred_loss, '--', color='tab:blue', label='Validation prediction loss')
plt.plot(epochs, val_lifted_loss, ':', color='tab:blue', label='Validation lifted loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale('log')
plt.savefig("convergence plot for arch1")
plt.show()

# %%
map_net_params = {}
map_net_params["input_dim"] = int(num_joints) #number of joint angles
map_net_params["output_dim"] = X_end.shape[2] #x and y position of the end effector
map_net_params["hidden_width"] = 20 #20
map_net_params["hidden_depth"] = 4  #2
map_net_params["batch_size"] = 128  #100
map_net_params["epochs"] = 200     # 500
map_net_params["activation_type"] = 'tanh'
map_net_params["lr"] = 1e-3     #1e-3
map_net_params["optimizer"] = 'adam'
map_net_params['l2_reg'] = 0.0
map_net_params['l1_reg'] = 0.0

# %%
#dataset
# split training and vaidation datasets
xs_map_train, ys_map_train = X_fw[:num_train,:,:int(num_joints)],X_end_fw[:num_train,:,:num_inputs]
xs_map_val, ys_map_val = X_fw[num_train:,:,:int(num_joints)],X_end_fw[num_train:,:,:num_inputs]

# %%
ys_map_train.shape, ys_map_val.shape,xs_map_train.shape, xs_map_val.shape
# Out:
# ((150, 1000, 3), (50, 1000, 3), (150, 1000, 5), (50, 1000, 5))

# %%
#Initalize network
#Initalize network
if mass_var == True:
    file_fwd = 'saved_models/'+ robot_type +'/map_net_con_mass_var.pth' 
else:
    file_fwd = 'saved_models/'+ robot_type +'/map_net_con.pth'

if train == True:
    map_net = map_Net(map_net_params)
    map_net.set_dataset_map(xs_map_train,ys_map_train,xs_map_val,ys_map_val)
    map_net.data_pipeline()
    torch.save(map_net,file_fwd)
else:
    map_net = torch.load(file_fwd)
# Out:
# Epoch   1: train loss: 0.0781698737, validation loss: 0.0420102542
# Epoch   2: train loss: 0.0364307087, validation loss: 0.0317775320
# Epoch   3: train loss: 0.0288018133, validation loss: 0.0251056588
# Epoch   4: train loss: 0.0230745800, validation loss: 0.0212904631
# Epoch   5: train loss: 0.0194479039, validation loss: 0.0179933491
# Epoch   6: train loss: 0.0170161154, validation loss: 0.0157595491
# Epoch   7: train loss: 0.0150895061, validation loss: 0.0141692690
# Epoch   8: train loss: 0.0135886658, validation loss: 0.0129419639
# Epoch   9: train loss: 0.0123303891, validation loss: 0.0116526955
# Epoch  10: train loss: 0.0113061101, validation loss: 0.0107786919
# Epoch  11: train loss: 0.0103971490, validation loss: 0.0102791679
# Epoch  12: train loss: 0.0096515835, validation loss: 0.0089743279
# Epoch  13: train loss: 0.0090667152, validation loss: 0.0088800197
# Epoch  14: train loss: 0.0085245811, validation loss: 0.0081027389
# Epoch  15: train loss: 0.0080313020, validation loss: 0.0081746274
# Epoch  16: train loss: 0.0076351796, validation loss: 0.0077071784
# Epoch  17: train loss: 0.0072236639, validation loss: 0.0070363554
# Epoch  18: train loss: 0.0068675269, validation loss: 0.0066790034
# Epoch  19: train loss: 0.0065344387, validation loss: 0.0062717992
# Epoch  20: train loss: 0.0061792847, validation loss: 0.0061934862
# Epoch  21: train loss: 0.0058527378, validation loss: 0.0054850793
# Epoch  22: train loss: 0.0056119808, validation loss: 0.0056758078
# Epoch  23: train loss: 0.0053637591, validation loss: 0.0055453504
# Epoch  24: train loss: 0.0051507302, validation loss: 0.0048048493
# Epoch  25: train loss: 0.0049669733, validation loss: 0.0051759997
# Epoch  26: train loss: 0.0047862974, validation loss: 0.0046527176
# Epoch  27: train loss: 0.0045960832, validation loss: 0.0044496049
# Epoch  28: train loss: 0.0045283085, validation loss: 0.0044650868
# Epoch  29: train loss: 0.0043538724, validation loss: 0.0042185480
# Epoch  30: train loss: 0.0041962303, validation loss: 0.0040972159
# Epoch  31: train loss: 0.0041180073, validation loss: 0.0040597905
# Epoch  32: train loss: 0.0039686089, validation loss: 0.0039698234
# Epoch  33: train loss: 0.0039209631, validation loss: 0.0035084065
# Epoch  34: train loss: 0.0037902117, validation loss: 0.0034907491
# Epoch  35: train loss: 0.0037151834, validation loss: 0.0044168978
# Epoch  36: train loss: 0.0035729234, validation loss: 0.0033736043
# Epoch  37: train loss: 0.0035600469, validation loss: 0.0034217677
# Epoch  38: train loss: 0.0034715078, validation loss: 0.0031259359
# Epoch  39: train loss: 0.0033879024, validation loss: 0.0035755026
# Epoch  40: train loss: 0.0033646054, validation loss: 0.0034245473
# Epoch  41: train loss: 0.0032575181, validation loss: 0.0032366867
# Epoch  42: train loss: 0.0032073962, validation loss: 0.0036410801
# Epoch  43: train loss: 0.0031587866, validation loss: 0.0030763854
# Epoch  44: train loss: 0.0030906797, validation loss: 0.0027830533
# Epoch  45: train loss: 0.0030528281, validation loss: 0.0033900378
# Epoch  46: train loss: 0.0030091247, validation loss: 0.0028480612
# Epoch  47: train loss: 0.0029288192, validation loss: 0.0026634512
# Epoch  48: train loss: 0.0028994900, validation loss: 0.0028480332
# Epoch  49: train loss: 0.0028416978, validation loss: 0.0027563712
# Epoch  50: train loss: 0.0028142590, validation loss: 0.0034618561
# Epoch  51: train loss: 0.0027768886, validation loss: 0.0025535222
# Epoch  52: train loss: 0.0026979357, validation loss: 0.0026365004
# Epoch  53: train loss: 0.0026801366, validation loss: 0.0023034925
# Epoch  54: train loss: 0.0026129031, validation loss: 0.0025134958
# Epoch  55: train loss: 0.0026275332, validation loss: 0.0025833327
# Epoch  56: train loss: 0.0025384515, validation loss: 0.0025132635
# Epoch  57: train loss: 0.0025152832, validation loss: 0.0025620589
# Epoch  58: train loss: 0.0024706046, validation loss: 0.0026558361
# Epoch  59: train loss: 0.0024186214, validation loss: 0.0022389874
# Epoch  60: train loss: 0.0023901377, validation loss: 0.0023669685
# Epoch  61: train loss: 0.0023517341, validation loss: 0.0020894915
# Epoch  62: train loss: 0.0023231065, validation loss: 0.0022142909
# Epoch  63: train loss: 0.0022784418, validation loss: 0.0021800182
# Epoch  64: train loss: 0.0022323861, validation loss: 0.0024075306
# Epoch  65: train loss: 0.0022083199, validation loss: 0.0020897983
# Epoch  66: train loss: 0.0021688628, validation loss: 0.0019350059
# Epoch  67: train loss: 0.0021432542, validation loss: 0.0021071402
# Epoch  68: train loss: 0.0020845670, validation loss: 0.0020308020
# Epoch  69: train loss: 0.0020697521, validation loss: 0.0019635873
# Epoch  70: train loss: 0.0020447763, validation loss: 0.0019544818
# Epoch  71: train loss: 0.0020046825, validation loss: 0.0018790710
# Epoch  72: train loss: 0.0019831604, validation loss: 0.0020597829
# Epoch  73: train loss: 0.0019589906, validation loss: 0.0018885382
# Epoch  74: train loss: 0.0019175056, validation loss: 0.0017356803
# Epoch  75: train loss: 0.0019070045, validation loss: 0.0019188958
# Epoch  76: train loss: 0.0018722791, validation loss: 0.0018084317
# Epoch  77: train loss: 0.0018495921, validation loss: 0.0019186811
# Epoch  78: train loss: 0.0018040924, validation loss: 0.0016784021
# Epoch  79: train loss: 0.0018023751, validation loss: 0.0019910815
# Epoch  80: train loss: 0.0017728228, validation loss: 0.0017637647
# Epoch  81: train loss: 0.0017854238, validation loss: 0.0019789284
# Epoch  82: train loss: 0.0017442096, validation loss: 0.0016289087
# Epoch  83: train loss: 0.0017094018, validation loss: 0.0016122665
# Epoch  84: train loss: 0.0017033607, validation loss: 0.0017191379
# Epoch  85: train loss: 0.0016768452, validation loss: 0.0016042710
# Epoch  86: train loss: 0.0016582690, validation loss: 0.0017005843
# Epoch  87: train loss: 0.0016480600, validation loss: 0.0017126386
# Epoch  88: train loss: 0.0016516583, validation loss: 0.0017325808
# Epoch  89: train loss: 0.0016030987, validation loss: 0.0015649205
# Epoch  90: train loss: 0.0016193661, validation loss: 0.0015466708
# Epoch  91: train loss: 0.0015802698, validation loss: 0.0018665365
# Epoch  92: train loss: 0.0015779215, validation loss: 0.0014156154
# Epoch  93: train loss: 0.0015503971, validation loss: 0.0013582616
# Epoch  94: train loss: 0.0015561252, validation loss: 0.0014109373
# Epoch  95: train loss: 0.0015267684, validation loss: 0.0015986058
# Epoch  96: train loss: 0.0014962550, validation loss: 0.0014018987
# Epoch  97: train loss: 0.0015189864, validation loss: 0.0014625601
# Epoch  98: train loss: 0.0014985231, validation loss: 0.0014697311
# Epoch  99: train loss: 0.0014839783, validation loss: 0.0015371501
# Epoch 100: train loss: 0.0014533316, validation loss: 0.0015357047
# Epoch 101: train loss: 0.0014454739, validation loss: 0.0013104416
# Epoch 102: train loss: 0.0014374228, validation loss: 0.0014815524
# Epoch 103: train loss: 0.0014299335, validation loss: 0.0013889540
# Epoch 104: train loss: 0.0013990158, validation loss: 0.0014085269
# Epoch 105: train loss: 0.0014019086, validation loss: 0.0016701957
# Epoch 106: train loss: 0.0013962247, validation loss: 0.0012167848
# Epoch 107: train loss: 0.0013750129, validation loss: 0.0013248707
# Epoch 108: train loss: 0.0013569130, validation loss: 0.0014415058
# Epoch 109: train loss: 0.0013561764, validation loss: 0.0013368166
# Epoch 110: train loss: 0.0013513018, validation loss: 0.0013266415
# Epoch 111: train loss: 0.0013609711, validation loss: 0.0014369705
# Epoch 112: train loss: 0.0013270265, validation loss: 0.0011905016
# Epoch 113: train loss: 0.0013132794, validation loss: 0.0013473612
# Epoch 114: train loss: 0.0013117870, validation loss: 0.0012593996
# Epoch 115: train loss: 0.0013271877, validation loss: 0.0014756071
# Epoch 116: train loss: 0.0012901326, validation loss: 0.0012857132
# Epoch 117: train loss: 0.0012823865, validation loss: 0.0015122646
# Epoch 118: train loss: 0.0012814051, validation loss: 0.0012860227
# Epoch 119: train loss: 0.0012548355, validation loss: 0.0012961837
# Epoch 120: train loss: 0.0012501859, validation loss: 0.0012386234
# Epoch 121: train loss: 0.0012619168, validation loss: 0.0011826034
# Epoch 122: train loss: 0.0012285407, validation loss: 0.0010943053
# Epoch 123: train loss: 0.0012383032, validation loss: 0.0013098079
# Epoch 124: train loss: 0.0012347190, validation loss: 0.0011372826
# Epoch 125: train loss: 0.0012046580, validation loss: 0.0012444914
# Epoch 126: train loss: 0.0012020140, validation loss: 0.0011269416
# Epoch 127: train loss: 0.0012138578, validation loss: 0.0010554683
# Epoch 128: train loss: 0.0011943249, validation loss: 0.0011919750
# Epoch 129: train loss: 0.0011907444, validation loss: 0.0010936693
# Epoch 130: train loss: 0.0011803889, validation loss: 0.0012574893
# Epoch 131: train loss: 0.0011867594, validation loss: 0.0013105325
# Epoch 132: train loss: 0.0011616786, validation loss: 0.0011756760
# Epoch 133: train loss: 0.0011532015, validation loss: 0.0010635920
# Epoch 134: train loss: 0.0011545728, validation loss: 0.0012834026
# Epoch 135: train loss: 0.0011550506, validation loss: 0.0012763366
# Epoch 136: train loss: 0.0011446125, validation loss: 0.0009877038
# Epoch 137: train loss: 0.0011369161, validation loss: 0.0011480104
# Epoch 138: train loss: 0.0011383069, validation loss: 0.0010477131
# Epoch 139: train loss: 0.0011354467, validation loss: 0.0010649738
# Epoch 140: train loss: 0.0011129294, validation loss: 0.0009757111
# Epoch 141: train loss: 0.0011044129, validation loss: 0.0010839609
# Epoch 142: train loss: 0.0011034403, validation loss: 0.0011369037
# Epoch 143: train loss: 0.0011221203, validation loss: 0.0009969761
# Epoch 144: train loss: 0.0011109006, validation loss: 0.0010820139
# Epoch 145: train loss: 0.0010837617, validation loss: 0.0011424020
# Epoch 146: train loss: 0.0010885300, validation loss: 0.0010579615
# Epoch 147: train loss: 0.0010822238, validation loss: 0.0012659374
# Epoch 148: train loss: 0.0010693803, validation loss: 0.0010132097
# Epoch 149: train loss: 0.0010774361, validation loss: 0.0009882767
# Epoch 150: train loss: 0.0010575564, validation loss: 0.0009355641
# Epoch 151: train loss: 0.0010691440, validation loss: 0.0011488914
# Epoch 152: train loss: 0.0010477619, validation loss: 0.0011197563
# Epoch 153: train loss: 0.0010518967, validation loss: 0.0009291583
# Epoch 154: train loss: 0.0010441803, validation loss: 0.0012305976
# Epoch 155: train loss: 0.0010343241, validation loss: 0.0010612012
# Epoch 156: train loss: 0.0010455247, validation loss: 0.0010462087
# Epoch 157: train loss: 0.0010385152, validation loss: 0.0010660493
# Epoch 158: train loss: 0.0010274614, validation loss: 0.0010053548
# Epoch 159: train loss: 0.0010163245, validation loss: 0.0010069020
# Epoch 160: train loss: 0.0010277922, validation loss: 0.0010458112
# Epoch 161: train loss: 0.0010215530, validation loss: 0.0012321912
# Epoch 162: train loss: 0.0010050307, validation loss: 0.0009241732
# Epoch 163: train loss: 0.0010077120, validation loss: 0.0009692928
# Epoch 164: train loss: 0.0009951547, validation loss: 0.0009476631
# Epoch 165: train loss: 0.0009955419, validation loss: 0.0009363605
# Epoch 166: train loss: 0.0009998910, validation loss: 0.0009923341
# Epoch 167: train loss: 0.0009941508, validation loss: 0.0009753681
# Epoch 168: train loss: 0.0009791444, validation loss: 0.0010740314
# Epoch 169: train loss: 0.0009835921, validation loss: 0.0008816026
# Epoch 170: train loss: 0.0009745264, validation loss: 0.0010070888
# Epoch 171: train loss: 0.0009666670, validation loss: 0.0009184421
# Epoch 172: train loss: 0.0009720930, validation loss: 0.0009100199
# Epoch 173: train loss: 0.0009809552, validation loss: 0.0010353852
# Epoch 174: train loss: 0.0009635015, validation loss: 0.0010063051
# Epoch 175: train loss: 0.0009457371, validation loss: 0.0010186539
# Epoch 176: train loss: 0.0009630287, validation loss: 0.0009048233
# Epoch 177: train loss: 0.0009451841, validation loss: 0.0009550013
# Epoch 178: train loss: 0.0009731379, validation loss: 0.0007860032
# Epoch 179: train loss: 0.0009244056, validation loss: 0.0010940196
# Epoch 180: train loss: 0.0009416656, validation loss: 0.0009960494
# Epoch 181: train loss: 0.0009313680, validation loss: 0.0009005667
# Epoch 182: train loss: 0.0009467638, validation loss: 0.0008817123
# Epoch 183: train loss: 0.0009320845, validation loss: 0.0010240688
# Epoch 184: train loss: 0.0009296969, validation loss: 0.0007967815
# Epoch 185: train loss: 0.0009241179, validation loss: 0.0008844374
# Epoch 186: train loss: 0.0009145206, validation loss: 0.0009822508
# Epoch 187: train loss: 0.0009292170, validation loss: 0.0008601083
# Epoch 188: train loss: 0.0009200388, validation loss: 0.0009167787
# Epoch 189: train loss: 0.0009098686, validation loss: 0.0009160377
# Epoch 190: train loss: 0.0009083362, validation loss: 0.0010504077
# Epoch 191: train loss: 0.0009094896, validation loss: 0.0007808069
# Epoch 192: train loss: 0.0009213261, validation loss: 0.0009029762
# Epoch 193: train loss: 0.0008962653, validation loss: 0.0008932238
# Epoch 194: train loss: 0.0008966488, validation loss: 0.0009839175
# Epoch 195: train loss: 0.0008920641, validation loss: 0.0007856546
# Epoch 196: train loss: 0.0008928151, validation loss: 0.0008770638
# Epoch 197: train loss: 0.0008869242, validation loss: 0.0008777234
# Epoch 198: train loss: 0.0008897256, validation loss: 0.0011566768
# Epoch 199: train loss: 0.0008758850, validation loss: 0.0010318518
# Epoch 200: train loss: 0.0008932116, validation loss: 0.0008198022
# Finished training

# %%
epochs = np.arange(0, map_net_params['epochs'])
plt.figure(figsize=(15,8))
plt.plot(epochs, map_net.train_loss_hist, color='tab:orange', label='Training loss')
plt.plot(epochs, map_net.val_loss_hist, color='tab:blue', label='Validation loss')

plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale('log')
plt.savefig("convergence plot of map net for arch1[3,20,20,2]")
plt.show()

# %%
# # import scipy.io
# path_model = 'saved_models/'+ robot_type +'/matlab_files/' 

# #save net parameters
# scipy.io.savemat(path_model + "map_in_weights.mat", {"map_in_weights": map_net.map_net_in.weight.detach().numpy()})
# scipy.io.savemat(path_model + "map_in_bias.mat", {"map_in_bias": map_net.map_net_in.bias.detach().numpy()})

# scipy.io.savemat(path_model +"map_hidden_weights_1.mat",
#                  {"map_hidden_weights_1": map_net.map_net_hid[0].weight.detach().numpy()})
# scipy.io.savemat(path_model +"map_hidden_bias_1.mat",
#                  {"map_hidden_bias_1": map_net.map_net_hid[0].bias.detach().numpy()})

# scipy.io.savemat(path_model +"map_hidden_weights_2.mat",
#                  {"map_hidden_weights_2": map_net.map_net_hid[1].weight.detach().numpy()})
# scipy.io.savemat(path_model + "map_hidden_bias_2.mat",
#                  {"map_hidden_bias_2": map_net.map_net_hid[1].bias.detach().numpy()})

# scipy.io.savemat(path_model + "map_hidden_weights_3.mat",
#                  {"map_hidden_weights_3": map_net.map_net_hid[2].weight.detach().numpy()})
# scipy.io.savemat(path_model +"map_hidden_bias_3.mat",
#                  {"map_hidden_bias_3": map_net.map_net_hid[2].bias.detach().numpy()})

# scipy.io.savemat(path_model + "map_out_weights.mat", {"map_out_weights": map_net.map_net_out.weight.detach().numpy()})
# scipy.io.savemat(path_model + "map_out_bias.mat", {"map_out_bias": map_net.map_net_out.bias.detach().numpy()})

# %%
map_net.map_net_hid
# Out:
# ModuleList(
#   (0-2): 3 x Linear(in_features=20, out_features=20, bias=True)
# )

# %% [markdown]
# ## Test Data Parameters

# %%
# test data parameters
first_obs_const = int(net_params['first_obs_const']) #only one state
override_C = net_params['override_C']
if override_C:
    n_obs = int(net_params['encoder_output_dim']) + num_states + first_obs_const 
else:
    n_obs = int(net_params['encoder_output_dim']) + first_obs_const

# %% [markdown]
# ***Koopman Bilinear Model***

# %%
A = np.array(model_koop_dnn.A)
#B = np.array(model_koop_dnn.B).reshape(-1,num_inputs*n_obs)
B = np.array(model_koop_dnn.B)
#B_tensor = np.empty((num_inputs,n_obs, n_obs))
#for ii, b in enumerate(B):
    #B_tensor[ii] = b
C = np.array(model_koop_dnn.C)

print(A.shape, B.shape, C.shape)
# Out:
# (31, 31) (31, 5) (10, 31)

# %% [markdown]
# ## Controlability

# %%
Ac = (A-np.eye(n_obs))/dt
Bc = B/dt
Cc = C
Cr = C[0:3,:]

Cr_v = C[num_joints:2*num_joints,:]

# %%
A.shape, B.shape
# Out:
# ((31, 31), (31, 5))

# %%
#check controllability
Con_lin = ct.ctrb(Ac, Bc)
rank_lin = np.linalg.matrix_rank(Con_lin)

print(rank_lin)
# Out:
# 30

# %%
out_con_mat, out_con_rank = Output_Con(Ac,Bc,Cc)


print(out_con_mat.shape)
print(out_con_rank)
# Out:
# (10, 160)
# 10

# %%
# continiouts
print('mean full',np.linalg.pinv(Bc).mean())
print('rank full',np.linalg.matrix_rank(Bc))

print('mean full',np.linalg.pinv(Ac).mean())
print('rank full',np.linalg.matrix_rank(Ac))
# Out:
# mean full 0.09487738
# rank full 5
# mean full 2.1364933942295754
# rank full 30

# %%
# continiouts
print('mean full',np.linalg.pinv(np.matmul(C,Bc)).mean(),np.linalg.pinv(np.matmul(C,Ac)).mean())
print('rank full',np.linalg.matrix_rank(np.matmul(C,Bc)), np.linalg.matrix_rank(np.matmul(C,Ac)))

print('mean reduced',np.linalg.pinv(np.matmul(Cr,Bc)).mean(),np.linalg.pinv(np.matmul(Cr,Ac)).mean())
print('rank reduced',np.linalg.matrix_rank(np.matmul(Cr,Bc)),np.linalg.matrix_rank(np.matmul(Cr,Ac)))
# Out:
# mean full 0.39400232 0.013567408809807056
# rank full 5 10
# mean reduced -2029.291 0.02798928666161002
# rank reduced 3 3

# %%
# discreate
print('mean full',np.linalg.pinv(np.matmul(C,B)).mean(),np.linalg.pinv(np.matmul(C,A)).mean())
print('rank full',np.linalg.matrix_rank(np.matmul(C,B)), np.linalg.matrix_rank(np.matmul(C,A)))

print('mean reduced',np.linalg.pinv(np.matmul(Cr,B)).mean(),np.linalg.pinv(np.matmul(Cr,A)).mean())
print('rank reduced',np.linalg.matrix_rank(np.matmul(Cr,B)),np.linalg.matrix_rank(np.matmul(Cr,A)))
# Out:
# mean full 78.80046 0.032223906
# rank full 5 10
# mean reduced -405858.22 0.032386176
# rank reduced 3 3

# %%
print('mean full',np.linalg.pinv(np.matmul(C,B)).mean(),np.linalg.pinv(np.matmul(C,A)).mean())
print('rank full',np.linalg.matrix_rank(np.matmul(C,B)), np.linalg.matrix_rank(np.matmul(C,A)))

print('mean reduced',np.linalg.pinv(np.matmul(Cr_v,B)).mean(),np.linalg.pinv(np.matmul(Cr_v,A)).mean())
print('rank reduced',np.linalg.matrix_rank(np.matmul(Cr_v,B)),np.linalg.matrix_rank(np.matmul(Cr_v,A)))
# Out:
# mean full 78.80046 0.032223906
# rank full 5 10
# mean reduced 157.61963 0.032258324
# rank reduced 5 5

# %%
# # #SAVE MATRIX PARAMETERS AS MATLAB FILE
# # import scipy.io

# dyn_matrices = {"A": A, "B": B, "C": C}
# scipy.io.savemat(path_model + "dyn_mat.mat", dyn_matrices)
# #save encoder parameters

# scipy.io.savemat(path_model + "in_weights.mat", {"encode_in_weights": model_koop_dnn.net.encoder_fc_in.weight.detach().numpy()})
# scipy.io.savemat(path_model + "in_bias.mat", {"encode_in_bias": model_koop_dnn.net.encoder_fc_in.bias.detach().numpy()})

# scipy.io.savemat(path_model + "hidden_weights_1.mat",
#                  {"encode_hidden_weights_1": model_koop_dnn.net.encoder_fc_hid[0].weight.detach().numpy()})
# scipy.io.savemat(path_model + "hidden_bias_1.mat",
#                  {"encode_hidden_bias_1": model_koop_dnn.net.encoder_fc_hid[0].bias.detach().numpy()})

# scipy.io.savemat(path_model + "hidden_weights_2.mat",
#                  {"encode_hidden_weights_2": model_koop_dnn.net.encoder_fc_hid[1].weight.detach().numpy()})
# scipy.io.savemat(path_model + "hidden_bias_2.mat",
#                  {"encode_hidden_bias_2": model_koop_dnn.net.encoder_fc_hid[1].bias.detach().numpy()})

# scipy.io.savemat(path_model + "out_weights.mat", {"encode_out_weights": model_koop_dnn.net.encoder_fc_out.weight.detach().numpy()})
# scipy.io.savemat(path_model + "out_bias.mat", {"encode_out_bias": model_koop_dnn.net.encoder_fc_out.bias.detach().numpy()})

# if standardize:
#     scipy.io.savemat(path_model + "std.mat", {"standardize": standardize, 'mean': standardizer_u_kdnn.mean_, 'scale':standardizer_u_kdnn.scale_})
    
# else:
#     scipy.io.savemat(path_model + "std.mat", {"standardize": standardize})

# %% [markdown]
# ## Save Data

# %%
# #SAVE MATRIX PARAMETERS AS MATLAB FILE
# import scipy.io

path_model = 'saved_models/'+ robot_type +'/matlab_files/' 

dyn_matrices = {"A": A, "B": B, "C": C}
scipy.io.savemat(path_model + "dyn_mat.mat", dyn_matrices)
#save encoder parameters

encoder_dict = {}

encoder_dict["encoder_in_weights"] =  model_koop_dnn.net.encoder_fc_in.weight.detach().numpy()
encoder_dict["encoder_in_bias"] = model_koop_dnn.net.encoder_fc_in.bias.detach().numpy()
encoder_dict["encoder_hidden_depth"] = int(net_params["encoder_hidden_depth"]-1) 

encoder_dict["encoder_hidden_weights"] = np.empty((net_params["encoder_hidden_width"],net_params["encoder_hidden_width"],net_params["encoder_hidden_depth"]-1))
encoder_dict["encoder_hidden_bias"] = np.empty((1,net_params["encoder_hidden_width"],net_params["encoder_hidden_depth"]-1))


for i in range(net_params["encoder_hidden_depth"]-1):
    
    encoder_dict["encoder_hidden_weights"][:,:,i] = model_koop_dnn.net.encoder_fc_hid[i].weight.detach().numpy()
    encoder_dict["encoder_hidden_bias"][:,:,i] = model_koop_dnn.net.encoder_fc_hid[i].bias.detach().numpy()

encoder_dict["encoder_out_weights"] = model_koop_dnn.net.encoder_fc_out.weight.detach().numpy()
encoder_dict["encoder_out_bias"] = model_koop_dnn.net.encoder_fc_out.bias.detach().numpy()

scipy.io.savemat(path_model + "encoder.mat", encoder_dict)

if standardize:
    scipy.io.savemat(path_model + "std.mat", {"standardize": standardize, 'mean': standardizer_u_kdnn.mean_, 'scale':standardizer_u_kdnn.scale_})
    
else:
    scipy.io.savemat(path_model + "std.mat", {"standardize": standardize})

# %%
# save forward map
forward_map_dict = {}

forward_map_dict["map_in_weights"] = map_net.map_net_in.weight.detach().numpy()
forward_map_dict["map_in_bias"] = map_net.map_net_in.bias.detach().numpy()
forward_map_dict["map_hidden_depth"] = int(map_net_params["hidden_depth"]-1)

forward_map_dict["map_hidden_weights"] = np.empty((map_net_params["hidden_width"],map_net_params["hidden_width"],map_net_params["hidden_depth"]-1))
forward_map_dict["map_hidden_bias"] = np.empty((1,map_net_params["hidden_width"],map_net_params["hidden_depth"]-1))

for i in range(map_net_params["hidden_depth"]-1):
    
    forward_map_dict["map_hidden_weights"][:,:,i] = map_net.map_net_hid[i].weight.detach().numpy()
    forward_map_dict["map_hidden_bias"][:,:,i] = map_net.map_net_hid[i].bias.detach().numpy()

forward_map_dict["map_out_weights"] = map_net.map_net_out.weight.detach().numpy()
forward_map_dict["map_out_bias"] = map_net.map_net_out.bias.detach().numpy()


path_model = 'saved_models/'+ robot_type +'/matlab_files/' 
#save net parameters


scipy.io.savemat(path_model + "forward_map.mat", forward_map_dict)

# %%
net_params['encoder_hidden_depth']
# Out:
# 3

# %%
path_model
# Out:
# 'saved_models/5R/linear/3D/matlab_files/'

# %%
encode_out_bias = model_koop_dnn.net.encoder_fc_out.bias.detach().numpy()
encode_out_weights = model_koop_dnn.net.encoder_fc_out.weight.detach().numpy()

# %% [markdown]
# ***Test Data Generation***

# %%
test_data = 'dynamics/Dataset_MATLAB/' + robot_type_load +'/data_test.mat'
data_test = scipy.io.loadmat(test_data)

# %%
X_end_test = np.array(data_test['X_end'], dtype = 'float64')
X_test = np.array(data_test['X'], dtype = 'float64')
U_test = np.array(data_test['tau'], dtype = 'float64')
num_snaps_test = int(data_test['num_snaps'])
num_traj_test = int(data_test['num_traj'])
# test data parameters
T = np.linspace(0,num_snaps_test*dt, num_snaps_test+1)

# %%
# data_gen
j = random.choice(range(num_traj_test))
xs_end_test = X_end_test[j,:,:]
xs_test = X_test[j,:,:]
us_test = U_test[j,:,:]

# %%
print(xs_end_test.shape, xs_test.shape, us_test.shape)
# Out:
# (1001, 3) (1001, 10) (1000, 5)

# %%
print(model_koop_dnn.test_loss(xs_test.reshape(1,-1,num_states),u_test = us_test.reshape(1,-1,num_inputs)))
# Out:
# tensor(0.0433)

# %%
basis = model_koop_dnn.net.encode_forward_

# %%
X,_ = model_koop_dnn.net.process(xs_test.reshape(1,-1,num_states),data_u = us_test.reshape(1,-1,num_inputs))
print(X.shape)
# Out:
# (1000, 25)

# %%
x = X[:, :num_states]
u = X[:, num_states:num_states+num_inputs]
x_prime = X[:,num_states+num_inputs:]

print(x.shape, u.shape, x_prime.shape)
# Out:
# (1000, 10) (1000, 5) (1000, 10)

# %% [markdown]
# ***Initial Condition Lifting***

# %%
# initialize the matricies
z = np.empty((n_obs,num_snaps_test+1)).T
x_est = np.zeros((num_states,num_snaps_test+1)).T
x_end_est = np.zeros((X_end.shape[2],num_snaps_test)).T

# %%
z[0,:] = lift(x[0,:],model_koop_dnn, net_params)
x_est[0,:] = x[0,:]

# %% [markdown]
# ***Time Evolution***

# %%
for i in range(num_snaps_test):
  #bilinear
    z[i+1,:] = np.matmul(z[i,:],A.T)+np.matmul(u[i,:],B.T)
    x_est[i+1,:] = np.matmul(z[i+1,:],C.T)  
    x_end_est[i,:] = map_net.forward(torch.from_numpy(x_est[i,:int(num_joints)]).float()).detach().numpy()

# %% [markdown]
# ***Visualization***

# %% [markdown]
# # Joint Space

# %%
plt.figure(figsize=(20,12))
for i in range(int(num_joints)):
    plt.subplot(3,3,i+1)
    plt.plot(T[:-1],x[:,i],label ='Actual')
    plt.plot(T[:],x_est[:,i],label = 'estimated(bilinear)')
    plt.xlabel('t')
    plt.ylabel('theta_' + str(i))
    plt.title('theta_' + str(i) + ' Comparison')
    plt.legend()

# %%
plt.figure(figsize=(20,12))
for i in range(int(num_joints)):
    plt.subplot(3,3,i+1)
    plt.plot(T[:-1],x[:,int(num_joints)+i],label ='Actual')
    plt.plot(T[:],x_est[:,int(num_joints)+i],label = 'estimated(bilinear)')
    plt.xlabel('t')
    plt.ylabel('theta_dot_' + str(i))
    plt.title('theta_dot_' + str(i) + ' Comparison')
    plt.legend()

# %%
plt.figure(figsize=(20,12))
for i in range(int(num_joints)):
    plt.subplot(3,3,i+1)
    plt.plot(T[:-1],u[:,i])
    plt.xlabel('t')
    plt.ylabel('tau' + str(i))

# %%
plt.figure(figsize=(20,12))
for i in range(int(num_joints)):
    plt.subplot(3,3,i+1)
    plt.plot(T[:-1],us_test[:,i])
    plt.xlabel('t')
    plt.ylabel('tau' + str(i))

# %%
if standardize:
    u_unscaled = np.array([standardizer_u_kdnn.inverse_transform(d.reshape(1,-1)) for d in u]).reshape(num_snaps_test,num_inputs)
    plt.figure(figsize=(20,12))
    for i in range(int(num_joints)):
        plt.subplot(3,3,i+1)
        plt.plot(T[:-1],us_test[:,i], label= 'original')
        plt.plot(T[:-1],u_unscaled[:,i], label= 'unscaled')
        plt.xlabel('t')
        plt.ylabel('tau' + str(i))
        
    print(u.shape)
    print(u_unscaled.shape)

# %%
# the mean error for the whole test dataset
# the mean error for the whole test dataset
error_ang_traj =  np.empty((num_snaps_test))
error_vel_traj =  np.empty((num_snaps_test))

error_ang_total  = np.empty((num_traj_test))
error_vel_total  = np.empty((num_traj_test))
for j in range(num_traj_test):
    xs_test = X_test[j,:,:]
    us_test = U_test[j,:,:]
    X,_ = model_koop_dnn.net.process(xs_test.reshape(1,-1,num_states),data_u = us_test.reshape(1,-1,num_inputs))
    x = X[:, :num_states]
    u = X[:, num_states:num_states+num_inputs]
    x_prime = X[:,num_states+num_inputs:]
    z[0,:] = lift(x[0,:],model_koop_dnn, net_params)
    x_est[0,:] = x[0,:]
    
    for i in range(num_snaps_test):
        #bilinear
        z[i+1,:] = np.matmul(z[i,:],A.T)+np.matmul(u[i,:],B.T)
        x_est[i+1,:] = np.matmul(z[i+1,:],C.T)  
        error_ang_traj[i] = np.mean(abs(x_est[i,:num_joints] - x[i,:num_joints]))
        error_vel_traj[i] = np.mean(abs(x_est[i,num_joints:] - x[i,num_joints:]))
        
    error_ang_total[j] = np.mean(error_ang_traj)
    error_vel_total[j] = np.mean(error_vel_traj)

# %%
print("Mean Absolute Error for joint angles for testing data :", np.mean(error_ang_total))
print("Mean Absolute Error for joint velocity for testing data :", np.mean(error_vel_total))

# %% [markdown]
# ## Cartesian Space

# %%
plt.figure(figsize=(20,6))
for i in range(X_end.shape[2]):
    plt.subplot(1,3,i+1)
    plt.plot(T[:],xs_end_test[:,i], label = 'Actual')
    plt.plot(T[:-1],x_end_est[:,i], label = 'Estimated')
    plt.legend()
plt.show()

# %%
error_joint_space = np.linalg.norm(xs_test-x_est,axis = 1)
error_cart_space = np.linalg.norm(xs_end_test[:-1]-x_end_est,axis = 1)

# %%
plt.figure(figsize =(20,6))
plt.subplot(1,2,1)
plt.plot(T[:],error_joint_space)
plt.title('Joint Space Error')

plt.subplot(1,2,2)
plt.plot(T[:-1],error_cart_space)
plt.title('Cartesian Space Error')

# %%
xs_test[8,:]

# %% [markdown]
# ## Controllers

# %% [markdown]
# ## ZNN full state

# %%
t_ctrl = np.arange(start=0, stop=5, step=dt)
num_snaps_ctrl = t_ctrl.shape[0]

# %%
gamma = np.diag([10,10,10,50,50,50])
shape = 'cardioid'
c = 0.02
tilt = np.pi/6

# %%
## specify the matricies
z_ctrl = np.zeros((n_obs,num_snaps_ctrl))
z_dot = np.zeros((n_obs,num_snaps_ctrl-1))
x_ctrl = np.zeros((num_states,num_snaps_ctrl))
x_ctrl_end = np.zeros((num_states_cart,num_snaps_ctrl))
x_ctrl_dot_end = np.zeros((num_states_cart,num_snaps_ctrl))
x_ctrl_dot = np.zeros((num_states_cart,num_snaps_ctrl))
rd = np.zeros((num_states_cart,num_snaps_ctrl-1))
rd_dot = np.zeros((num_states_cart,num_snaps_ctrl-1))
rd_ddot = np.zeros((num_states_cart,num_snaps_ctrl-1))
error = np.zeros((2*(num_states_cart),num_snaps_ctrl-1))

u_ctrl = np.zeros((num_inputs,num_snaps_ctrl))

## initialize the matricies
# x_ctrl[:,0] = np.hstack((x_ref[:,0],x_ref_dot[:,0]))
x_ctrl[:,0] = np.hstack((np.ones((num_joints,)), np.zeros((num_joints,))))
z_ctrl[:,0] = lift(x_ctrl[:,0],model_koop_dnn, net_params)
x_ctrl_end[:,0] = map_net.forward(torch.from_numpy(x_ctrl[:num_joints,0]).float()).detach().numpy()

# %%
for i in range(num_snaps_ctrl-1):
    t = t_ctrl[i]
    if modality == '2D':
        # rd[:,i], rd_dot[:,i],rd_ddot= path_pars_2D(t,t_ctrl[-1],c,tilt,x_ctrl_end[:,0], shape)
        rd[:,i], rd_dot[:,i] = x_end[:,i], x_end_dot[:,i]
    else:
        rd[:,i], rd_dot[:,i], rd_ddot[:,i] = path_pars(t,t_ctrl[-1],c,tilt,x_ctrl_end[:,0], shape)
        # rd[:,i], rd_dot[:,i] = x_end[:,i], x_end_dot[:,i]
        
    rd_full = np.hstack((rd[:,i], rd_dot[:,i]))
    rd_dot_full = np.hstack((rd_dot[:,i], rd_ddot[:,i]))
    error[:,i] = np.hstack((x_ctrl_end[:,i],x_ctrl_dot_end[:,i])) - rd_full
    
    W = neural_jacobian(map_net, x_ctrl[:num_joints,i])
    W_dot = neural_jacobian_dot(map_net, x_ctrl[:num_joints,i],x_ctrl[num_joints:,i])
    J_tilde = np.vstack((np.hstack((W,np.zeros_like(W))),np.hstack((W_dot,W))))
    
    u_ctrl[:,i] = np.dot(np.linalg.pinv(Bc), -np.matmul(Ac,z_ctrl[:,i]) + np.matmul(np.linalg.pinv(np.matmul(J_tilde, Cc)), (rd_dot_full - np.matmul(gamma,error[:,i]))))
    
    # u_ctrl[:,i] = np.dot(np.linalg.pinv(np.matmul(J_tilde,np.matmul(Cc,Bc))), -np.matmul(np.matmul(J_tilde, Cc),np.matmul(Ac,z_ctrl[:,i])) + rd_dot_full - np.matmul(gamma,error[:,i]))
    # u_ctrl[:,i] = np.dot(np.linalg.pinv(np.matmul(Cc,Bc)), -np.matmul(np.matmul(Cc,Ac),z_ctrl[:,i]) + np.matmul(np.linalg.pinv(J_tilde), (rd_dot_full - np.matmul(gamma,error[:,i]))))
            
    
    z_ctrl[:,i+1] = np.matmul(z_ctrl[:,i],A.T)+np.matmul(u_ctrl[:,i],B.T)
    x_ctrl[:,i+1] = np.matmul(z_ctrl[:,i+1],C.T)
    x_ctrl_end[:,i+1] = map_net.forward(torch.from_numpy(x_ctrl[:num_joints,i+1]).float()).detach().numpy()
    x_ctrl_dot_end[:,i+1] = np.matmul(neural_jacobian(map_net, x_ctrl[:num_joints,i+1]), x_ctrl[num_joints:,i+1])
    
                   
    # x_ctrl[0:3,i+1],x_ctrl[3:,i+1] = dynamics_3R(dt, u_ctrl[:,i], x_ctrl[0:3,i],x_ctrl[3:,i], robot_pars)
    # z_ctrl[:,i+1] = lift(x_ctrl[:,i+1],model_koop_dnn, net_params)

# %%
np.matmul(gamma,error[:,i])

# %%
np.matmul(np.matmul(J_tilde, Cc),A).mean()

# %%
u_ctrl[:,10]

# %%
np.matmul(J_tilde,Cc).shape

# %%
np.vstack((rd_dot[:,i], rd_ddot[:,i]))

# %%
if modality == '2D':
    plt.figure(figsize=(20,12))
    plt.plot(x_ctrl_end[0,:],x_ctrl_end[1,:],label = 'traced')
    plt.plot(rd[0,:-1],rd[1,:-1],label ='reference')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend()
    plt.axis('equal')
else:
    ax = plt.axes(projection='3d')
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.set_zlabel("z")
    
    ax.plot3D(x_ctrl_end[0,:],x_ctrl_end[1,:],x_ctrl_end[2,:],label = 'traced')
    ax.plot3D(rd[0,:-1],rd[1,:-1],rd[2,:-1],label ='reference')
    plt.legend()

    plt.axis('equal')

# %%
plt.figure(figsize=(20,12))
for i in range(int(num_states_cart)):
    plt.subplot(3,3,i+1)
    plt.plot(t_ctrl[:-1],rd[i,:],label ='reference')
    plt.plot(t_ctrl[:],x_ctrl_end[i,:],label = 'traced')
    plt.xlabel('t')
    plt.legend()

# %%
plt.figure(figsize=(20,12))
for i in range(int(num_states_cart)):
    plt.subplot(3,3,i+1)
    plt.plot(t_ctrl[:-1],error[i,:])
    plt.xlabel('t')
    plt.ylabel('error_' + str(i))

# %%
plt.figure(figsize=(20,12))
for i in range(int(num_joints)):
    plt.subplot(3,3,i+1)
    plt.plot(t_ctrl[:u_ctrl.shape[1]],u_ctrl[i,:])
    plt.xlabel('t')
    plt.ylabel('tau' + str(i))

# %%
if standardize:
    u_znn_unscaled = np.array([standardizer_u_kdnn.inverse_transform(d.reshape(1,-1)) for d in u_ctrl.T]).reshape(u_ctrl.shape[1],num_inputs)
    plt.figure(figsize=(20,12))
    for i in range(int(num_joints)):
        plt.subplot(3,3,i+1)
        plt.plot(T[:u_ctrl.shape[1]],u_znn_unscaled[:,i], label= 'unscaled')
        plt.xlabel('t')
        plt.ylabel('tau' + str(i))
