# %% [markdown]
# ***Import Libraries***

# %%
"""This program bilinearizes 3R planar dyanmics using koopman theory and autoencoder to map"""
import numpy as np
import matplotlib.pyplot as plt
import sklearn.preprocessing
import itertools
import scipy.io
import torch

# bilinear Koopman
from core.koopman_time_delay import KoopDNN, KoopmanNet, KoopmanNetCtrl
from models.koop_model import model_matricies,lift, lift_delay
from core.util import fit_standardizer
from sklearn import preprocessing

# forward map neural net
from core.neural_fwd_map import map_Net


## import paths
from paths.paths import path_pars

# %% [markdown]
# ### Load Data

# %%
data = scipy.io.loadmat('dynamics/Dataset_MATLAB/2D/data.mat')

X_end = np.array(data['X_end'], dtype = 'float64')
X_full = np.array(data['X'], dtype = 'float64')
U_full = np.array(data['tau_red'], dtype = 'float64')

print(X_end.shape, X_full.shape,U_full.shape)
# Out:
# (100, 1001, 3) (100, 1001, 14) (100, 1000, 3)

# %%
np.sum(np.sum(np.isnan(X_end))), np.sum(np.sum(np.isnan(U_full))), np.sum(np.sum(np.isnan(X_full)))
# Out:
# (0, 0, 0)

# %% [markdown]
# ***Simulation Parameters***

# %%
dt = float(data['dt']) #time step
num_snaps = int(data['num_snaps']) # no. of snapshots
num_traj = int(data['num_traj']) #no of trajectories
T = np.linspace(0,num_snaps*dt, num_snaps+1)
num_train = int(0.75*num_traj) # no. of training examples
num_val = num_traj-num_train # no of testing examples
num_traj = num_train+num_val #no of trajectories
num_states = X_full.shape[2] # no. of states
num_inputs = U_full.shape[2] # no. of inputs

# %%
dt, num_snaps, num_traj, num_states, num_inputs
# Out:
# (0.005, 1000, 100, 14, 3)

# %% [markdown]
# ***Plotting the trajectories***

# %%
"""Training dataset visualization"""
#theta evolution
for i in range(int(num_states/2)):
    plt.subplot(3,3,i+1)
    plt.xlabel("t")
    plt.ylabel("th"+str(i+1))
    for j in range(num_traj):
        plt.plot(T,X_full[j,:,i])

# %%
for i in range(int(num_states/2)):
    plt.subplot(3,3,i+1)
    plt.xlabel("t")
    plt.ylabel("th"+str(i+1)+ ' dot')
    for j in range(num_traj):
        plt.plot(T,X_full[j,:,i+int(num_states/2)])

# %%
#x and y positions of the end effector
ax = plt.axes(projection='3d')
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
for i in range(num_traj):
    ax.plot3D(X_end[i,:,0],X_end[i,:,1],X_end[i,:,2])

# %%
for i in range(num_inputs):
    plt.subplot(4,2,i+1)
    plt.xlabel("t")
    plt.ylabel("tau"+str(i))
    for j in range(num_traj):
        plt.plot(T[:-1],U_full[j,:,i])

# %% [markdown]
# ***Training and validation datasets***

# %%
# split training and vaidation datasets
xs_train, us_train = X_full[:num_train,:,:],U_full[:num_train,:,:]
xs_val, us_val = X_full[num_train:,:,:],U_full[num_train:,:,:]

# %%
# import scipy.io
# Data_set = {"x_end": X_end, "X_full": X_full}
# scipy.io.savemat("Data_set.mat",Data_set)

# %%
# import torch
# import torch.nn as nn
# import torch.nn.functional as F

# %% [markdown]
# ***Model Training***

# %%
net_params = {}
net_params['state_dim'] = num_states
net_params['ctrl_dim'] = num_inputs
net_params["output_dim"] = num_states
net_params['encoder_hidden_width'] = 30
net_params['encoder_hidden_depth'] = 2
net_params["num_delays"] = 10
net_params['encoder_output_dim'] = 20
net_params['optimizer'] = 'adam'
net_params['activation_type'] = 'tanh'
net_params['lr'] = 5e-5 # 5e-4
net_params['epochs'] = 500
net_params['batch_size'] = 128
net_params['lifted_loss_penalty'] = 0.4 
net_params['l2_reg'] = 0.0         
net_params['l1_reg'] = 0.0
net_params['first_obs_const'] = False
net_params['override_C'] = True # this makes the state a part of lifetd state
net_params['dt'] = dt

# %%
train = False

if train == True:
    file = 'saved_models/Kuka/2D/koop_arch_time_delay.pth'
    standardizer_u_kdnn = fit_standardizer(us_train, preprocessing.StandardScaler(with_mean=False))
    net = KoopmanNetCtrl(net_params, standardizer_u=standardizer_u_kdnn)
    # net = KoopmanNetCtrl(net_params)
    model_koop_dnn = KoopDNN(net)
    model_koop_dnn.set_datasets(xs_train, u_train=us_train, x_val=xs_val, u_val=us_val)
    model_koop_dnn.model_pipeline(net_params)
    model_koop_dnn.construct_koopman_model()
    torch.save(model_koop_dnn,file)
else:
    file = 'saved_models/Kuka/2D/koop_arch_time_delay.pth'
    model_koop_dnn = torch.load(file)
# Out:
# /home/rajpal/.local/lib/python3.8/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator StandardScaler from version 0.24.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %% [markdown]
# ***Learning Curves***

# %%
train_loss = [l[0] for l in model_koop_dnn.train_loss_hist]
train_pred_loss = [l[1] for l in model_koop_dnn.train_loss_hist]
train_lifted_loss = [l[2] for l in model_koop_dnn.train_loss_hist]
val_loss = [l[0] for l in model_koop_dnn.val_loss_hist]
val_pred_loss = [l[1] for l in model_koop_dnn.val_loss_hist]
val_lifted_loss = [l[2] for l in model_koop_dnn.val_loss_hist]
epochs = np.arange(0, net_params['epochs'])

plt.figure(figsize=(15,8))
plt.plot(epochs, train_loss, color='tab:orange', label='Training loss')
plt.plot(epochs, train_pred_loss, '--', color='tab:orange', label='Training prediction loss')
plt.plot(epochs, train_lifted_loss, ':', color='tab:orange', label='Training lifted loss')
plt.plot(epochs, val_loss, color='tab:blue', label='Validation loss')
plt.plot(epochs, val_pred_loss, '--', color='tab:blue', label='Validation prediction loss')
plt.plot(epochs, val_lifted_loss, ':', color='tab:blue', label='Validation lifted loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale('log')
plt.savefig("convergence plot for arch1")
plt.show()

# %%
map_net_params = {}
map_net_params["input_dim"] = int(num_states/2) #number of joint angles
map_net_params["output_dim"] = X_end.shape[2] #x and y position of the end effector
map_net_params["hidden_width"] = 20
map_net_params["hidden_depth"] = 2
map_net_params["batch_size"] = 100
map_net_params["epochs"] = 500
map_net_params["activation_type"] = 'tanh'
map_net_params["lr"] = 1e-3
map_net_params["optimizer"] = 'adam'
map_net_params['l2_reg'] = 0.0
map_net_params['l1_reg'] = 0.0

# %%
#dataset
# split training and vaidation datasets
xs_map_train, ys_map_train = X_full[:num_train,:,:7],X_end[:num_train,:,:3]
xs_map_val, ys_map_val = X_full[num_train:,:,:7],X_end[num_train:,:,:3]

# %%
ys_map_train.shape, ys_map_val.shape,xs_map_train.shape, xs_map_val.shape
# Out:
# ((75, 1001, 3), (25, 1001, 3), (75, 1001, 7), (25, 1001, 7))

# %%
#Initalize network
#Initalize network
train = True

if train==True:
    file = "saved_models/Kuka/2D/map_net_time_delay.pth"
    map_net = map_Net(map_net_params)
    map_net.set_dataset_map(xs_map_train,ys_map_train,xs_map_val,ys_map_val)
    map_net.data_pipeline()
    map_net.plot_loss()
    torch.save(map_net,file)
else:
    file = "saved_models/Kuka/2D/map_net_time_delay.pth"
    map_net = torch.load(file)
# Out:
# Epoch   1: train loss: 0.0292896537, validation loss: 0.0200960968
# Epoch   2: train loss: 0.0080437975, validation loss: 0.0132757672
# Epoch   3: train loss: 0.0059495252, validation loss: 0.0109221440
# Epoch   4: train loss: 0.0049418228, validation loss: 0.0087828408
# Epoch   5: train loss: 0.0044310915, validation loss: 0.0081144415
# Epoch   6: train loss: 0.0040896274, validation loss: 0.0076846600
# Epoch   7: train loss: 0.0038893868, validation loss: 0.0067418804
# Epoch   8: train loss: 0.0037594691, validation loss: 0.0066283444
# Epoch   9: train loss: 0.0036448625, validation loss: 0.0061860410
# Epoch  10: train loss: 0.0035962029, validation loss: 0.0067048565
# Epoch  11: train loss: 0.0035131598, validation loss: 0.0059440030
# Epoch  12: train loss: 0.0034671050, validation loss: 0.0063252516
# Epoch  13: train loss: 0.0034378832, validation loss: 0.0062033991
# Epoch  14: train loss: 0.0033758119, validation loss: 0.0057318587
# Epoch  15: train loss: 0.0033383113, validation loss: 0.0061522357
# Epoch  16: train loss: 0.0033156195, validation loss: 0.0059073786
# Epoch  17: train loss: 0.0032760418, validation loss: 0.0059339820
# Epoch  18: train loss: 0.0032447675, validation loss: 0.0056377672
# Epoch  19: train loss: 0.0032143059, validation loss: 0.0059634741
# Epoch  20: train loss: 0.0031793393, validation loss: 0.0056139219
# Epoch  21: train loss: 0.0031693477, validation loss: 0.0056293275
# Epoch  22: train loss: 0.0031487309, validation loss: 0.0056915670
# Epoch  23: train loss: 0.0031252015, validation loss: 0.0057758469
# Epoch  24: train loss: 0.0031138611, validation loss: 0.0057633187
# Epoch  25: train loss: 0.0030639422, validation loss: 0.0057877613
# Epoch  26: train loss: 0.0030519525, validation loss: 0.0059600803
# Epoch  27: train loss: 0.0030442384, validation loss: 0.0058900492
# Epoch  28: train loss: 0.0030086327, validation loss: 0.0059565890
# Epoch  29: train loss: 0.0029802513, validation loss: 0.0057224759
# Epoch  30: train loss: 0.0029618969, validation loss: 0.0059459800
# Epoch  31: train loss: 0.0029467642, validation loss: 0.0058119566
# Epoch  32: train loss: 0.0029200657, validation loss: 0.0059173638
# Epoch  33: train loss: 0.0029076482, validation loss: 0.0059308158
# Epoch  34: train loss: 0.0028963368, validation loss: 0.0060886630
# Epoch  35: train loss: 0.0028666737, validation loss: 0.0059406944
# Epoch  36: train loss: 0.0028485366, validation loss: 0.0056560380
# Epoch  37: train loss: 0.0028242428, validation loss: 0.0056140362
# Epoch  38: train loss: 0.0028158647, validation loss: 0.0059242844
# Epoch  39: train loss: 0.0027976476, validation loss: 0.0054511791
# Epoch  40: train loss: 0.0027795901, validation loss: 0.0057003193
# Epoch  41: train loss: 0.0027720915, validation loss: 0.0058273019
# Epoch  42: train loss: 0.0027646081, validation loss: 0.0056791052
# Epoch  43: train loss: 0.0027443437, validation loss: 0.0053021926
# Epoch  44: train loss: 0.0027089895, validation loss: 0.0054514298
# Epoch  45: train loss: 0.0027076022, validation loss: 0.0059308050
# Epoch  46: train loss: 0.0026935641, validation loss: 0.0051347919
# Epoch  47: train loss: 0.0026866466, validation loss: 0.0058397020
# Epoch  48: train loss: 0.0026801332, validation loss: 0.0054992130
# Epoch  49: train loss: 0.0026548865, validation loss: 0.0053798136
# Epoch  50: train loss: 0.0026313792, validation loss: 0.0057850844
# Epoch  51: train loss: 0.0026211521, validation loss: 0.0053610098
# Epoch  52: train loss: 0.0026032259, validation loss: 0.0054047639
# Epoch  53: train loss: 0.0025984775, validation loss: 0.0054247647
# Epoch  54: train loss: 0.0025739426, validation loss: 0.0055054132
# Epoch  55: train loss: 0.0025740591, validation loss: 0.0051333958
# Epoch  56: train loss: 0.0025549372, validation loss: 0.0052474443
# Epoch  57: train loss: 0.0025354864, validation loss: 0.0057648897
# Epoch  58: train loss: 0.0025247418, validation loss: 0.0053785876
# Epoch  59: train loss: 0.0025252436, validation loss: 0.0058255082
# Epoch  60: train loss: 0.0025257328, validation loss: 0.0057828891
# Epoch  61: train loss: 0.0025076522, validation loss: 0.0051189879
# Epoch  62: train loss: 0.0024864891, validation loss: 0.0060264088
# Epoch  63: train loss: 0.0024799406, validation loss: 0.0059841891
# Epoch  64: train loss: 0.0024780830, validation loss: 0.0052622379
# Epoch  65: train loss: 0.0024650113, validation loss: 0.0054878554
# Epoch  66: train loss: 0.0024483477, validation loss: 0.0055611930
# Epoch  67: train loss: 0.0024568981, validation loss: 0.0057251772
# Epoch  68: train loss: 0.0024331164, validation loss: 0.0054839555
# Epoch  69: train loss: 0.0024314986, validation loss: 0.0056657594
# Epoch  70: train loss: 0.0024047686, validation loss: 0.0061056439
# Epoch  71: train loss: 0.0024065421, validation loss: 0.0056054664
# Epoch  72: train loss: 0.0023975890, validation loss: 0.0058349417
# Epoch  73: train loss: 0.0023852646, validation loss: 0.0058908466
# Epoch  74: train loss: 0.0023899098, validation loss: 0.0059039632
# Epoch  75: train loss: 0.0023890208, validation loss: 0.0056367195
# Epoch  76: train loss: 0.0023698068, validation loss: 0.0057285187
# Epoch  77: train loss: 0.0023600918, validation loss: 0.0058908497
# Epoch  78: train loss: 0.0023630776, validation loss: 0.0058479959
# Epoch  79: train loss: 0.0023397732, validation loss: 0.0056899596
# Epoch  80: train loss: 0.0023487905, validation loss: 0.0059222660
# Epoch  81: train loss: 0.0023296430, validation loss: 0.0060556694
# Epoch  82: train loss: 0.0023325678, validation loss: 0.0056587805
# Epoch  83: train loss: 0.0023171275, validation loss: 0.0057058004
# Epoch  84: train loss: 0.0022970620, validation loss: 0.0058417462
# Epoch  85: train loss: 0.0023073921, validation loss: 0.0056224625
# Epoch  86: train loss: 0.0023014725, validation loss: 0.0057252431
# Epoch  87: train loss: 0.0022940220, validation loss: 0.0056173177
# Epoch  88: train loss: 0.0022880708, validation loss: 0.0060370857
# Epoch  89: train loss: 0.0022666984, validation loss: 0.0059230205
# Epoch  90: train loss: 0.0022785972, validation loss: 0.0059143300
# Epoch  91: train loss: 0.0022686790, validation loss: 0.0059007778
# Epoch  92: train loss: 0.0022584104, validation loss: 0.0055266185
# Epoch  93: train loss: 0.0022495130, validation loss: 0.0054915107
# Epoch  94: train loss: 0.0022457943, validation loss: 0.0057306181
# Epoch  95: train loss: 0.0022581373, validation loss: 0.0059053988
# Epoch  96: train loss: 0.0022481675, validation loss: 0.0055316870
# Epoch  97: train loss: 0.0022279608, validation loss: 0.0059345887
# Epoch  98: train loss: 0.0022314596, validation loss: 0.0058043612
# Epoch  99: train loss: 0.0022225920, validation loss: 0.0058246649
# Epoch 100: train loss: 0.0022188522, validation loss: 0.0056436665
# Epoch 101: train loss: 0.0021987724, validation loss: 0.0057213007
# Epoch 102: train loss: 0.0022176409, validation loss: 0.0058066260
# Epoch 103: train loss: 0.0021961604, validation loss: 0.0057379874
# Epoch 104: train loss: 0.0021948880, validation loss: 0.0057017585
# Epoch 105: train loss: 0.0021852013, validation loss: 0.0057971512
# Epoch 106: train loss: 0.0021812307, validation loss: 0.0055544768
# Epoch 107: train loss: 0.0021806146, validation loss: 0.0055098595
# Epoch 108: train loss: 0.0021729301, validation loss: 0.0057028347
# Epoch 109: train loss: 0.0021723939, validation loss: 0.0056601198
# Epoch 110: train loss: 0.0021633356, validation loss: 0.0058379464
# Epoch 111: train loss: 0.0021615907, validation loss: 0.0060131900
# Epoch 112: train loss: 0.0021481969, validation loss: 0.0059062435
# Epoch 113: train loss: 0.0021484349, validation loss: 0.0059722209
# Epoch 114: train loss: 0.0021506337, validation loss: 0.0058330481
# Epoch 115: train loss: 0.0021373246, validation loss: 0.0059784550
# Epoch 116: train loss: 0.0021346505, validation loss: 0.0056813727
# Epoch 117: train loss: 0.0021338645, validation loss: 0.0055778015
# Epoch 118: train loss: 0.0021178998, validation loss: 0.0057702219
# Epoch 119: train loss: 0.0021170468, validation loss: 0.0057875512
# Epoch 120: train loss: 0.0021003877, validation loss: 0.0055283994
# Epoch 121: train loss: 0.0021042605, validation loss: 0.0056188796
# Epoch 122: train loss: 0.0020951729, validation loss: 0.0056447255
# Epoch 123: train loss: 0.0020887001, validation loss: 0.0058695315
# Epoch 124: train loss: 0.0020800312, validation loss: 0.0056641910
# Epoch 125: train loss: 0.0020792346, validation loss: 0.0055214453
# Epoch 126: train loss: 0.0020636556, validation loss: 0.0056873022
# Epoch 127: train loss: 0.0020563522, validation loss: 0.0055210046
# Epoch 128: train loss: 0.0020507937, validation loss: 0.0061053883
# Epoch 129: train loss: 0.0020483343, validation loss: 0.0059826955
# Epoch 130: train loss: 0.0020321557, validation loss: 0.0058143820
# Epoch 131: train loss: 0.0020186852, validation loss: 0.0059613484
# Epoch 132: train loss: 0.0020084327, validation loss: 0.0061005116
# Epoch 133: train loss: 0.0020015314, validation loss: 0.0056181930
# Epoch 134: train loss: 0.0020066733, validation loss: 0.0059666611
# Epoch 135: train loss: 0.0019831290, validation loss: 0.0057061521
# Epoch 136: train loss: 0.0019829313, validation loss: 0.0058895129
# Epoch 137: train loss: 0.0019823189, validation loss: 0.0059313075
# Epoch 138: train loss: 0.0019633033, validation loss: 0.0061174363
# Epoch 139: train loss: 0.0019519238, validation loss: 0.0060591595
# Epoch 140: train loss: 0.0019484868, validation loss: 0.0056861364
# Epoch 141: train loss: 0.0019326588, validation loss: 0.0062005645
# Epoch 142: train loss: 0.0019203861, validation loss: 0.0058415984
# Epoch 143: train loss: 0.0019042679, validation loss: 0.0061503155
# Epoch 144: train loss: 0.0018938159, validation loss: 0.0056862642
# Epoch 145: train loss: 0.0018897446, validation loss: 0.0058403644
# Epoch 146: train loss: 0.0018699795, validation loss: 0.0057620371
# Epoch 147: train loss: 0.0018701302, validation loss: 0.0058977727
# Epoch 148: train loss: 0.0018673397, validation loss: 0.0059522925
# Epoch 149: train loss: 0.0018583662, validation loss: 0.0055714078
# Epoch 150: train loss: 0.0018570996, validation loss: 0.0057936226
# Epoch 151: train loss: 0.0018505649, validation loss: 0.0057975797
# Epoch 152: train loss: 0.0018416025, validation loss: 0.0060576836
# Epoch 153: train loss: 0.0018414493, validation loss: 0.0058586262
# Epoch 154: train loss: 0.0018384418, validation loss: 0.0058096297
# Epoch 155: train loss: 0.0018237406, validation loss: 0.0060805342
# Epoch 156: train loss: 0.0018277261, validation loss: 0.0057895554
# Epoch 157: train loss: 0.0018253834, validation loss: 0.0060062243
# Epoch 158: train loss: 0.0018225139, validation loss: 0.0057812983
# Epoch 159: train loss: 0.0018188670, validation loss: 0.0056993201
# Epoch 160: train loss: 0.0018199848, validation loss: 0.0057380262
# Epoch 161: train loss: 0.0017995871, validation loss: 0.0060541857
# Epoch 162: train loss: 0.0018095778, validation loss: 0.0056752575
# Epoch 163: train loss: 0.0017934707, validation loss: 0.0059013735
# Epoch 164: train loss: 0.0017985413, validation loss: 0.0057012395
# Epoch 165: train loss: 0.0018010913, validation loss: 0.0058771940
# Epoch 166: train loss: 0.0017882984, validation loss: 0.0058195041
# Epoch 167: train loss: 0.0017865887, validation loss: 0.0056944511
# Epoch 168: train loss: 0.0017788990, validation loss: 0.0060827400
# Epoch 169: train loss: 0.0017748446, validation loss: 0.0054997860
# Epoch 170: train loss: 0.0017826033, validation loss: 0.0058758018
# Epoch 171: train loss: 0.0017796085, validation loss: 0.0057135278
# Epoch 172: train loss: 0.0017683033, validation loss: 0.0055724832
# Epoch 173: train loss: 0.0017682826, validation loss: 0.0056260323
# Epoch 174: train loss: 0.0017724300, validation loss: 0.0056155999
# Epoch 175: train loss: 0.0017588116, validation loss: 0.0057371173
# Epoch 176: train loss: 0.0017590848, validation loss: 0.0055833229
# Epoch 177: train loss: 0.0017498249, validation loss: 0.0053466017
# Epoch 178: train loss: 0.0017445085, validation loss: 0.0058139444
# Epoch 179: train loss: 0.0017512286, validation loss: 0.0055693132
# Epoch 180: train loss: 0.0017470499, validation loss: 0.0055736416
# Epoch 181: train loss: 0.0017416477, validation loss: 0.0053524005
# Epoch 182: train loss: 0.0017339995, validation loss: 0.0055188480
# Epoch 183: train loss: 0.0017379764, validation loss: 0.0054096220
# Epoch 184: train loss: 0.0017255653, validation loss: 0.0053850925
# Epoch 185: train loss: 0.0017235535, validation loss: 0.0054865376
# Epoch 186: train loss: 0.0017263538, validation loss: 0.0056375277
# Epoch 187: train loss: 0.0017164573, validation loss: 0.0052890145
# Epoch 188: train loss: 0.0017188078, validation loss: 0.0054745153
# Epoch 189: train loss: 0.0017135466, validation loss: 0.0053871078
# Epoch 190: train loss: 0.0017099222, validation loss: 0.0052282812
# Epoch 191: train loss: 0.0017038373, validation loss: 0.0052647642
# Epoch 192: train loss: 0.0016980270, validation loss: 0.0052364793
# Epoch 193: train loss: 0.0016959893, validation loss: 0.0052983431
# Epoch 194: train loss: 0.0016926321, validation loss: 0.0054933337
# Epoch 195: train loss: 0.0016862477, validation loss: 0.0057470614
# Epoch 196: train loss: 0.0016759494, validation loss: 0.0055027531
# Epoch 197: train loss: 0.0016759380, validation loss: 0.0053683303
# Epoch 198: train loss: 0.0016734361, validation loss: 0.0053649078
# Epoch 199: train loss: 0.0016696113, validation loss: 0.0052939621
# Epoch 200: train loss: 0.0016585477, validation loss: 0.0056706385
# Epoch 201: train loss: 0.0016534368, validation loss: 0.0056757885
# Epoch 202: train loss: 0.0016556647, validation loss: 0.0054149845
# Epoch 203: train loss: 0.0016492674, validation loss: 0.0057044706
# Epoch 204: train loss: 0.0016434753, validation loss: 0.0056197006
# Epoch 205: train loss: 0.0016447516, validation loss: 0.0053970807
# Epoch 206: train loss: 0.0016381596, validation loss: 0.0055854132
# Epoch 207: train loss: 0.0016544773, validation loss: 0.0062251491
# Epoch 208: train loss: 0.0016329335, validation loss: 0.0055292086
# Epoch 209: train loss: 0.0016359178, validation loss: 0.0056848685
# Epoch 210: train loss: 0.0016243731, validation loss: 0.0053906948
# Epoch 211: train loss: 0.0016207756, validation loss: 0.0060822880
# Epoch 212: train loss: 0.0016296291, validation loss: 0.0056178789
# Epoch 213: train loss: 0.0016182921, validation loss: 0.0056689112
# Epoch 214: train loss: 0.0016255596, validation loss: 0.0054552504
# Epoch 215: train loss: 0.0016145933, validation loss: 0.0059560389
# Epoch 216: train loss: 0.0016067510, validation loss: 0.0057496328
# Epoch 217: train loss: 0.0016157944, validation loss: 0.0061770812
# Epoch 218: train loss: 0.0016027530, validation loss: 0.0056336709
# Epoch 219: train loss: 0.0016045986, validation loss: 0.0058490543
# Epoch 220: train loss: 0.0015934556, validation loss: 0.0055903952
# Epoch 221: train loss: 0.0015941189, validation loss: 0.0059040890
# Epoch 222: train loss: 0.0015991542, validation loss: 0.0059363205
# Epoch 223: train loss: 0.0015864758, validation loss: 0.0059423188
# Epoch 224: train loss: 0.0015839226, validation loss: 0.0060086902
# Epoch 225: train loss: 0.0015802805, validation loss: 0.0057497086
# Epoch 226: train loss: 0.0015859494, validation loss: 0.0059149972
# Epoch 227: train loss: 0.0015768719, validation loss: 0.0060293282
# Epoch 228: train loss: 0.0015840545, validation loss: 0.0059663043
# Epoch 229: train loss: 0.0015735635, validation loss: 0.0058569484
# Epoch 230: train loss: 0.0015773760, validation loss: 0.0064961983
# Epoch 231: train loss: 0.0015763863, validation loss: 0.0056133336
# Epoch 232: train loss: 0.0015716382, validation loss: 0.0059145429
# Epoch 233: train loss: 0.0015697381, validation loss: 0.0061347204
# Epoch 234: train loss: 0.0015610764, validation loss: 0.0059556392
# Epoch 235: train loss: 0.0015584696, validation loss: 0.0061860707
# Epoch 236: train loss: 0.0015632417, validation loss: 0.0064942320
# Epoch 237: train loss: 0.0015578251, validation loss: 0.0063210095
# Epoch 238: train loss: 0.0015472437, validation loss: 0.0060649354
# Epoch 239: train loss: 0.0015540947, validation loss: 0.0063918260
# Epoch 240: train loss: 0.0015545524, validation loss: 0.0061949865
# Epoch 241: train loss: 0.0015370536, validation loss: 0.0060312437
# Epoch 242: train loss: 0.0015401083, validation loss: 0.0059060719
# Epoch 243: train loss: 0.0015401268, validation loss: 0.0062568531
# Epoch 244: train loss: 0.0015377712, validation loss: 0.0063823495
# Epoch 245: train loss: 0.0015296205, validation loss: 0.0061154471
# Epoch 246: train loss: 0.0015345163, validation loss: 0.0061652150
# Epoch 247: train loss: 0.0015256696, validation loss: 0.0060289566
# Epoch 248: train loss: 0.0015186284, validation loss: 0.0063501737
# Epoch 249: train loss: 0.0015181391, validation loss: 0.0061330937
# Epoch 250: train loss: 0.0015246906, validation loss: 0.0062982761
# Epoch 251: train loss: 0.0015097819, validation loss: 0.0061694366
# Epoch 252: train loss: 0.0015052519, validation loss: 0.0061078686
# Epoch 253: train loss: 0.0015051385, validation loss: 0.0061728759
# Epoch 254: train loss: 0.0015098575, validation loss: 0.0063509661
# Epoch 255: train loss: 0.0015004040, validation loss: 0.0062624735
# Epoch 256: train loss: 0.0014984514, validation loss: 0.0062820445
# Epoch 257: train loss: 0.0014988685, validation loss: 0.0063750729
# Epoch 258: train loss: 0.0014952772, validation loss: 0.0062058616
# Epoch 259: train loss: 0.0014928999, validation loss: 0.0063707557
# Epoch 260: train loss: 0.0014867450, validation loss: 0.0062133103
# Epoch 261: train loss: 0.0014927412, validation loss: 0.0062769719
# Epoch 262: train loss: 0.0014796262, validation loss: 0.0064961825
# Epoch 263: train loss: 0.0014794239, validation loss: 0.0065037053
# Epoch 264: train loss: 0.0014739892, validation loss: 0.0065980059
# Epoch 265: train loss: 0.0014717992, validation loss: 0.0063701629
# Epoch 266: train loss: 0.0014692800, validation loss: 0.0066409304
# Epoch 267: train loss: 0.0014752903, validation loss: 0.0065728280
# Epoch 268: train loss: 0.0014666019, validation loss: 0.0066449295
# Epoch 269: train loss: 0.0014612347, validation loss: 0.0066212548
# Epoch 270: train loss: 0.0014549877, validation loss: 0.0069336511
# Epoch 271: train loss: 0.0014532949, validation loss: 0.0063300509
# Epoch 272: train loss: 0.0014492660, validation loss: 0.0066441778
# Epoch 273: train loss: 0.0014545247, validation loss: 0.0065161472
# Epoch 274: train loss: 0.0014465919, validation loss: 0.0063167659
# Epoch 275: train loss: 0.0014420360, validation loss: 0.0068807822
# Epoch 276: train loss: 0.0014354935, validation loss: 0.0066463309
# Epoch 277: train loss: 0.0014416478, validation loss: 0.0068029989
# Epoch 278: train loss: 0.0014363411, validation loss: 0.0069418745
# Epoch 279: train loss: 0.0014292936, validation loss: 0.0065788358
# Epoch 280: train loss: 0.0014288625, validation loss: 0.0068250094
# Epoch 281: train loss: 0.0014274088, validation loss: 0.0064246807
# Epoch 282: train loss: 0.0014230650, validation loss: 0.0066429925
# Epoch 283: train loss: 0.0014156841, validation loss: 0.0065037166
# Epoch 284: train loss: 0.0014195257, validation loss: 0.0070017498
# Epoch 285: train loss: 0.0014141730, validation loss: 0.0066091307
# Epoch 286: train loss: 0.0014070604, validation loss: 0.0070684232
# Epoch 287: train loss: 0.0014080076, validation loss: 0.0064683181
# Epoch 288: train loss: 0.0014022219, validation loss: 0.0066743158
# Epoch 289: train loss: 0.0014041210, validation loss: 0.0065708228
# Epoch 290: train loss: 0.0014009218, validation loss: 0.0068370125
# Epoch 291: train loss: 0.0014012016, validation loss: 0.0067355476
# Epoch 292: train loss: 0.0013935440, validation loss: 0.0068783429
# Epoch 293: train loss: 0.0013922281, validation loss: 0.0067051940
# Epoch 294: train loss: 0.0013953401, validation loss: 0.0067940603
# Epoch 295: train loss: 0.0013914585, validation loss: 0.0068622836
# Epoch 296: train loss: 0.0013804490, validation loss: 0.0066725201
# Epoch 297: train loss: 0.0013797457, validation loss: 0.0069666023
# Epoch 298: train loss: 0.0013773914, validation loss: 0.0070510326
# Epoch 299: train loss: 0.0013803557, validation loss: 0.0066724396
# Epoch 300: train loss: 0.0013774722, validation loss: 0.0068440049
# Epoch 301: train loss: 0.0013776085, validation loss: 0.0069379660
# Epoch 302: train loss: 0.0013808022, validation loss: 0.0071268583
# Epoch 303: train loss: 0.0013663794, validation loss: 0.0066603142
# Epoch 304: train loss: 0.0013719933, validation loss: 0.0065406769
# Epoch 305: train loss: 0.0013613266, validation loss: 0.0073110659
# Epoch 306: train loss: 0.0013623429, validation loss: 0.0067068226
# Epoch 307: train loss: 0.0013673448, validation loss: 0.0070844422
# Epoch 308: train loss: 0.0013618455, validation loss: 0.0071088601
# Epoch 309: train loss: 0.0013583511, validation loss: 0.0068850033
# Epoch 310: train loss: 0.0013554317, validation loss: 0.0068384656
# Epoch 311: train loss: 0.0013543231, validation loss: 0.0068160161
# Epoch 312: train loss: 0.0013533253, validation loss: 0.0070082046
# Epoch 313: train loss: 0.0013482296, validation loss: 0.0066290671
# Epoch 314: train loss: 0.0013481802, validation loss: 0.0068541261
# Epoch 315: train loss: 0.0013554855, validation loss: 0.0069064932
# Epoch 316: train loss: 0.0013449757, validation loss: 0.0068929763
# Epoch 317: train loss: 0.0013492546, validation loss: 0.0069156195
# Epoch 318: train loss: 0.0013447308, validation loss: 0.0069935436
# Epoch 319: train loss: 0.0013434982, validation loss: 0.0069526319
# Epoch 320: train loss: 0.0013445292, validation loss: 0.0070414423
# Epoch 321: train loss: 0.0013388449, validation loss: 0.0071133375
# Epoch 322: train loss: 0.0013414939, validation loss: 0.0068353545
# Epoch 323: train loss: 0.0013412287, validation loss: 0.0073706651
# Epoch 324: train loss: 0.0013441330, validation loss: 0.0069648322
# Epoch 325: train loss: 0.0013374390, validation loss: 0.0072290007
# Epoch 326: train loss: 0.0013382577, validation loss: 0.0069515282
# Epoch 327: train loss: 0.0013256029, validation loss: 0.0068617384
# Epoch 328: train loss: 0.0013278145, validation loss: 0.0069906252
# Epoch 329: train loss: 0.0013264807, validation loss: 0.0071936878
# Epoch 330: train loss: 0.0013334480, validation loss: 0.0073522023
# Epoch 331: train loss: 0.0013266693, validation loss: 0.0072835925
# Epoch 332: train loss: 0.0013219068, validation loss: 0.0070219091
# Epoch 333: train loss: 0.0013241766, validation loss: 0.0069137868
# Epoch 334: train loss: 0.0013200513, validation loss: 0.0072708387
# Epoch 335: train loss: 0.0013128839, validation loss: 0.0074172170
# Epoch 336: train loss: 0.0013137530, validation loss: 0.0073536099
# Epoch 337: train loss: 0.0013175595, validation loss: 0.0075030706
# Epoch 338: train loss: 0.0013114114, validation loss: 0.0074710522
# Epoch 339: train loss: 0.0013097930, validation loss: 0.0068754244
# Epoch 340: train loss: 0.0013111350, validation loss: 0.0072191807
# Epoch 341: train loss: 0.0013076460, validation loss: 0.0074463940
# Epoch 342: train loss: 0.0012988724, validation loss: 0.0073645763
# Epoch 343: train loss: 0.0012957840, validation loss: 0.0075031245
# Epoch 344: train loss: 0.0012936294, validation loss: 0.0071142787
# Epoch 345: train loss: 0.0012880817, validation loss: 0.0072332609
# Epoch 346: train loss: 0.0012911229, validation loss: 0.0071196950
# Epoch 347: train loss: 0.0012924476, validation loss: 0.0071755327
# Epoch 348: train loss: 0.0012802033, validation loss: 0.0068980777
# Epoch 349: train loss: 0.0012890761, validation loss: 0.0074412561
# Epoch 350: train loss: 0.0012849245, validation loss: 0.0071030812
# Epoch 351: train loss: 0.0012767810, validation loss: 0.0075059804
# Epoch 352: train loss: 0.0012755558, validation loss: 0.0074986949
# Epoch 353: train loss: 0.0012841805, validation loss: 0.0078329688
# Epoch 354: train loss: 0.0012759083, validation loss: 0.0071723625
# Epoch 355: train loss: 0.0012753553, validation loss: 0.0075109414
# Epoch 356: train loss: 0.0012744525, validation loss: 0.0070612209
# Epoch 357: train loss: 0.0012677976, validation loss: 0.0072098680
# Epoch 358: train loss: 0.0012733771, validation loss: 0.0072646160
# Epoch 359: train loss: 0.0012662287, validation loss: 0.0071314621
# Epoch 360: train loss: 0.0012738398, validation loss: 0.0076804698
# Epoch 361: train loss: 0.0012618820, validation loss: 0.0069361630
# Epoch 362: train loss: 0.0012606335, validation loss: 0.0071420074
# Epoch 363: train loss: 0.0012640660, validation loss: 0.0078177636
# Epoch 364: train loss: 0.0012667471, validation loss: 0.0073744000
# Epoch 365: train loss: 0.0012603451, validation loss: 0.0075783442
# Epoch 366: train loss: 0.0012588796, validation loss: 0.0073564243
# Epoch 367: train loss: 0.0012552896, validation loss: 0.0077898978
# Epoch 368: train loss: 0.0012558747, validation loss: 0.0075247571
# Epoch 369: train loss: 0.0012615403, validation loss: 0.0077643745
# Epoch 370: train loss: 0.0012532136, validation loss: 0.0075736007
# Epoch 371: train loss: 0.0012499510, validation loss: 0.0074852880
# Epoch 372: train loss: 0.0012525371, validation loss: 0.0074417956
# Epoch 373: train loss: 0.0012506568, validation loss: 0.0073428169
# Epoch 374: train loss: 0.0012462157, validation loss: 0.0080347702
# Epoch 375: train loss: 0.0012453982, validation loss: 0.0081036266
# Epoch 376: train loss: 0.0012498790, validation loss: 0.0078963258
# Epoch 377: train loss: 0.0012539237, validation loss: 0.0078584280
# Epoch 378: train loss: 0.0012489194, validation loss: 0.0080805810
# Epoch 379: train loss: 0.0012436144, validation loss: 0.0074723733
# Epoch 380: train loss: 0.0012461731, validation loss: 0.0076281691
# Epoch 381: train loss: 0.0012394978, validation loss: 0.0075905939
# Epoch 382: train loss: 0.0012351483, validation loss: 0.0071817940
# Epoch 383: train loss: 0.0012414804, validation loss: 0.0071910341
# Epoch 384: train loss: 0.0012408791, validation loss: 0.0075901797
# Epoch 385: train loss: 0.0012467592, validation loss: 0.0075553694
# Epoch 386: train loss: 0.0012319268, validation loss: 0.0075832831
# Epoch 387: train loss: 0.0012376401, validation loss: 0.0074517530
# Epoch 388: train loss: 0.0012402067, validation loss: 0.0071243993
# Epoch 389: train loss: 0.0012368822, validation loss: 0.0074043574
# Epoch 390: train loss: 0.0012362032, validation loss: 0.0074271693
# Epoch 391: train loss: 0.0012375356, validation loss: 0.0076722702
# Epoch 392: train loss: 0.0012372565, validation loss: 0.0076262296
# Epoch 393: train loss: 0.0012273991, validation loss: 0.0075988492
# Epoch 394: train loss: 0.0012346335, validation loss: 0.0075363634
# Epoch 395: train loss: 0.0012326940, validation loss: 0.0078619001
# Epoch 396: train loss: 0.0012267045, validation loss: 0.0079581594
# Epoch 397: train loss: 0.0012330977, validation loss: 0.0075572289
# Epoch 398: train loss: 0.0012456005, validation loss: 0.0075325478
# Epoch 399: train loss: 0.0012297354, validation loss: 0.0073956593
# Epoch 400: train loss: 0.0012326544, validation loss: 0.0074024232
# Epoch 401: train loss: 0.0012274191, validation loss: 0.0077538954
# Epoch 402: train loss: 0.0012240306, validation loss: 0.0079092440
# Epoch 403: train loss: 0.0012323770, validation loss: 0.0074944321
# Epoch 404: train loss: 0.0012268806, validation loss: 0.0072445738
# Epoch 405: train loss: 0.0012339423, validation loss: 0.0075126181
# Epoch 406: train loss: 0.0012247644, validation loss: 0.0076025833
# Epoch 407: train loss: 0.0012245869, validation loss: 0.0074758746
# Epoch 408: train loss: 0.0012208174, validation loss: 0.0076275341
# Epoch 409: train loss: 0.0012284891, validation loss: 0.0074019032
# Epoch 410: train loss: 0.0012227543, validation loss: 0.0074220556
# Epoch 411: train loss: 0.0012275580, validation loss: 0.0076222649
# Epoch 412: train loss: 0.0012225847, validation loss: 0.0075181326
# Epoch 413: train loss: 0.0012260981, validation loss: 0.0076166076
# Epoch 414: train loss: 0.0012207751, validation loss: 0.0079065152
# Epoch 415: train loss: 0.0012240593, validation loss: 0.0075111910
# Epoch 416: train loss: 0.0012188776, validation loss: 0.0076358869
# Epoch 417: train loss: 0.0012169788, validation loss: 0.0075476533
# Epoch 418: train loss: 0.0012240598, validation loss: 0.0078349507
# Epoch 419: train loss: 0.0012174187, validation loss: 0.0074508184
# Epoch 420: train loss: 0.0012249756, validation loss: 0.0077422211
# Epoch 421: train loss: 0.0012196242, validation loss: 0.0073862215
# Epoch 422: train loss: 0.0012186667, validation loss: 0.0077681230
# Epoch 423: train loss: 0.0012184804, validation loss: 0.0078769744
# Epoch 424: train loss: 0.0012181757, validation loss: 0.0077844949
# Epoch 425: train loss: 0.0012162745, validation loss: 0.0074966600
# Epoch 426: train loss: 0.0012204239, validation loss: 0.0074903391
# Epoch 427: train loss: 0.0012128703, validation loss: 0.0077484406
# Epoch 428: train loss: 0.0012181870, validation loss: 0.0074365857
# Epoch 429: train loss: 0.0012168666, validation loss: 0.0079367900
# Epoch 430: train loss: 0.0012192708, validation loss: 0.0074424334
# Epoch 431: train loss: 0.0012145770, validation loss: 0.0074073747
# Epoch 432: train loss: 0.0012158425, validation loss: 0.0075449760
# Epoch 433: train loss: 0.0012136891, validation loss: 0.0072200436
# Epoch 434: train loss: 0.0012127231, validation loss: 0.0080046024
# Epoch 435: train loss: 0.0012149092, validation loss: 0.0074045835
# Epoch 436: train loss: 0.0012153176, validation loss: 0.0079001540
# Epoch 437: train loss: 0.0012146983, validation loss: 0.0075918348
# Epoch 438: train loss: 0.0012116673, validation loss: 0.0074663746
# Epoch 439: train loss: 0.0012164975, validation loss: 0.0077911224
# Epoch 440: train loss: 0.0012064544, validation loss: 0.0077971743
# Epoch 441: train loss: 0.0012098980, validation loss: 0.0071624185
# Epoch 442: train loss: 0.0012122069, validation loss: 0.0074946362
# Epoch 443: train loss: 0.0012110913, validation loss: 0.0081440708
# Epoch 444: train loss: 0.0012111110, validation loss: 0.0070958550
# Epoch 445: train loss: 0.0012133762, validation loss: 0.0077927953
# Epoch 446: train loss: 0.0012098886, validation loss: 0.0073248752
# Epoch 447: train loss: 0.0012132884, validation loss: 0.0075152351
# Epoch 448: train loss: 0.0012067871, validation loss: 0.0075173656
# Epoch 449: train loss: 0.0012072000, validation loss: 0.0077127296
# Epoch 450: train loss: 0.0012097683, validation loss: 0.0077015771
# Epoch 451: train loss: 0.0012151578, validation loss: 0.0068234517
# Epoch 452: train loss: 0.0012005516, validation loss: 0.0071912597
# Epoch 453: train loss: 0.0012065692, validation loss: 0.0073763894
# Epoch 454: train loss: 0.0011996647, validation loss: 0.0078926149
# Epoch 455: train loss: 0.0012088655, validation loss: 0.0072113854
# Epoch 456: train loss: 0.0012046077, validation loss: 0.0071747580
# Epoch 457: train loss: 0.0012083429, validation loss: 0.0074857013
# Epoch 458: train loss: 0.0012060588, validation loss: 0.0075413520
# Epoch 459: train loss: 0.0012053794, validation loss: 0.0072134116
# Epoch 460: train loss: 0.0012060800, validation loss: 0.0070996163
# Epoch 461: train loss: 0.0012038249, validation loss: 0.0072397320
# Epoch 462: train loss: 0.0012016113, validation loss: 0.0075461869
# Epoch 463: train loss: 0.0012059610, validation loss: 0.0073462651
# Epoch 464: train loss: 0.0012023813, validation loss: 0.0071403640
# Epoch 465: train loss: 0.0012063784, validation loss: 0.0072965509
# Epoch 466: train loss: 0.0011984974, validation loss: 0.0071825175
# Epoch 467: train loss: 0.0012020899, validation loss: 0.0072086913
# Epoch 468: train loss: 0.0012096345, validation loss: 0.0070358153
# Epoch 469: train loss: 0.0012061998, validation loss: 0.0066791868
# Epoch 470: train loss: 0.0012036250, validation loss: 0.0070882938
# Epoch 471: train loss: 0.0012037807, validation loss: 0.0072309385
# Epoch 472: train loss: 0.0012031924, validation loss: 0.0072829852
# Epoch 473: train loss: 0.0012013588, validation loss: 0.0076107459
# Epoch 474: train loss: 0.0011999931, validation loss: 0.0076230538
# Epoch 475: train loss: 0.0012053443, validation loss: 0.0072558717
# Epoch 476: train loss: 0.0012090905, validation loss: 0.0073556879
# Epoch 477: train loss: 0.0011975867, validation loss: 0.0075311761
# Epoch 478: train loss: 0.0012020615, validation loss: 0.0076320648
# Epoch 479: train loss: 0.0012056145, validation loss: 0.0077215975
# Epoch 480: train loss: 0.0012012499, validation loss: 0.0073849574
# Epoch 481: train loss: 0.0011989114, validation loss: 0.0072845070
# Epoch 482: train loss: 0.0011923682, validation loss: 0.0072829940
# Epoch 483: train loss: 0.0012030824, validation loss: 0.0070990058
# Epoch 484: train loss: 0.0012008542, validation loss: 0.0068871116
# Epoch 485: train loss: 0.0011994621, validation loss: 0.0071969044
# Epoch 486: train loss: 0.0011961068, validation loss: 0.0074808243
# Epoch 487: train loss: 0.0012044170, validation loss: 0.0073480954
# Epoch 488: train loss: 0.0011996156, validation loss: 0.0071375468
# Epoch 489: train loss: 0.0011974295, validation loss: 0.0069658199
# Epoch 490: train loss: 0.0011963583, validation loss: 0.0077952736
# Epoch 491: train loss: 0.0011988481, validation loss: 0.0070423644
# Epoch 492: train loss: 0.0011999855, validation loss: 0.0076033419
# Epoch 493: train loss: 0.0012042324, validation loss: 0.0067551441
# Epoch 494: train loss: 0.0011931080, validation loss: 0.0068703085
# Epoch 495: train loss: 0.0011968879, validation loss: 0.0074381782
# Epoch 496: train loss: 0.0011956886, validation loss: 0.0070529018
# Epoch 497: train loss: 0.0011977801, validation loss: 0.0072935583
# Epoch 498: train loss: 0.0011967721, validation loss: 0.0072414425
# Epoch 499: train loss: 0.0011925344, validation loss: 0.0073737297
# Epoch 500: train loss: 0.0011953221, validation loss: 0.0073930836
# Finished training

# %%
epochs = np.arange(0, map_net_params['epochs'])
plt.figure(figsize=(15,8))
plt.plot(epochs, map_net.train_loss_hist, color='tab:orange', label='Training loss')
plt.plot(epochs, map_net.val_loss_hist, color='tab:blue', label='Validation loss')

plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale('log')
plt.savefig("convergence plot of map net for arch1[3,20,20,2]")
plt.show()

# %%
# import scipy.io

# #save net parameters
# scipy.io.savemat("map_in_weights.mat", {"map_in_weights": map_net.map_net_in.weight.detach().numpy()})
# scipy.io.savemat("map_in_bias.mat", {"map_in_bias": map_net.map_net_in.bias.detach().numpy()})

# scipy.io.savemat("map_hidden_weights_1.mat",
#                  {"map_hidden_weights_1": map_net.map_net_hid[0].weight.detach().numpy()})
# scipy.io.savemat("map_hidden_bias_1.mat",
#                  {"map_hidden_bias_1": map_net.map_net_hid[0].bias.detach().numpy()})

# scipy.io.savemat("map_hidden_weights_2.mat",
#                  {"map_hidden_weights_2": map_net.map_net_hid[1].weight.detach().numpy()})
# scipy.io.savemat("map_hidden_bias_2.mat",
#                  {"map_hidden_bias_2": map_net.map_net_hid[1].bias.detach().numpy()})

# scipy.io.savemat("map_hidden_weights_3.mat",
#                  {"map_hidden_weights_3": map_net.map_net_hid[2].weight.detach().numpy()})
# scipy.io.savemat("map_hidden_bias_3.mat",
#                  {"map_hidden_bias_3": map_net.map_net_hid[2].bias.detach().numpy()})

# scipy.io.savemat("map_out_weights.mat", {"map_out_weights": map_net.map_net_out.weight.detach().numpy()})
# scipy.io.savemat("map_out_bias.mat", {"map_out_bias": map_net.map_net_out.bias.detach().numpy()})

# %% [markdown]
# ## Test Data Parameters

# %%
# test data parameters
num_snaps_val = 1000 # no. of snapshots
T = np.linspace(0,num_snaps_val*dt, num_snaps_val+1)
num_traj_val = 1 # no. of training examples
first_obs_const = int(net_params['first_obs_const']) #only one state
override_C = net_params['override_C']
if override_C:
    n_obs = int(net_params['encoder_output_dim']) + num_states + first_obs_const 
else:
    n_obs = int(net_params['encoder_output_dim']) + first_obs_const

# %% [markdown]
# ***Koopman Bilinear Model***

# %%
A = np.array(model_koop_dnn.A)
#B = np.array(model_koop_dnn.B).reshape(-1,num_inputs*n_obs)
B = np.array(model_koop_dnn.B)
#B_tensor = np.empty((num_inputs,n_obs, n_obs))
#for ii, b in enumerate(B):
    #B_tensor[ii] = b
C = np.array(model_koop_dnn.C)

print(A.shape, B.shape, C.shape)
# Out:
# (34, 34) (34, 102) (14, 34)

# %%
# #SAVE MATRIX PARAMETERS AS MATLAB FILE
# import scipy.io

# dyn_matrices = {"A": A, "B": B, "C": C}
# scipy.io.savemat("dyn_mat.mat", dyn_matrices)
# #save encoder parameters
# scipy.io.savemat("in_weights.mat", {"encode_in_weights": model_koop_dnn.net.encoder_fc_in.weight.detach().numpy()})
# scipy.io.savemat("in_bias.mat", {"encode_in_bias": model_koop_dnn.net.encoder_fc_in.bias.detach().numpy()})

# scipy.io.savemat("hidden_weights_1.mat",
#                  {"encode_hidden_weights_1": model_koop_dnn.net.encoder_fc_hid[0].weight.detach().numpy()})
# scipy.io.savemat("hidden_bias_1.mat",
#                  {"encode_hidden_bias_1": model_koop_dnn.net.encoder_fc_hid[0].bias.detach().numpy()})

# scipy.io.savemat("hidden_weights_2.mat",
#                  {"encode_hidden_weights_2": model_koop_dnn.net.encoder_fc_hid[1].weight.detach().numpy()})
# scipy.io.savemat("hidden_bias_2.mat",
#                  {"encode_hidden_bias_2": model_koop_dnn.net.encoder_fc_hid[1].bias.detach().numpy()})

# scipy.io.savemat("out_weights.mat", {"encode_out_weights": model_koop_dnn.net.encoder_fc_out.weight.detach().numpy()})
# scipy.io.savemat("out_bias.mat", {"encode_out_bias": model_koop_dnn.net.encoder_fc_out.bias.detach().numpy()})

# %%
encode_out_bias = model_koop_dnn.net.encoder_fc_out.bias.detach().numpy()
encode_out_weights = model_koop_dnn.net.encoder_fc_out.weight.detach().numpy()

# %% [markdown]
# ***Test Data Generation***

# %%
# data_gen
j = 60
xs_end_test = X_end[j,:,:]
xs_test = X_full[j,:,:]
us_test = U_full[j,:,:]

# %%
print(xs_end_test.shape, xs_test.shape, us_test.shape)
# Out:
# (1001, 3) (1001, 14) (1000, 3)

# %%
print(model_koop_dnn.test_loss(xs_test.reshape(1,-1,num_states),u_test = us_test.reshape(1,-1,num_inputs)))
# Out:
# tensor(0.8510)

# %% [markdown]
# ***Initial Condition Lifting***

# %%
# initialize the matricies
z = np.empty((n_obs,num_snaps_val+1)).T
x_est = np.zeros((num_states,num_snaps_val+1)).T
x_end_est = np.zeros((X_end.shape[2],num_snaps_val)).T

# %%
num_outputs = num_states

# %%
x_out_test = xs_test[:num_snaps_val+1,:]
x_out_Test = x_out_test.reshape((num_snaps_val+1,num_outputs))
u_Test = us_test.reshape((num_snaps_val,num_inputs))
x0 = x_out_Test[:net_params["num_delays"]+1,:]
X0 = x0.reshape((1,num_outputs*(net_params["num_delays"]+1)))
print(X0.shape)
z[0,:] = lift_delay(X0[0,:],model_koop_dnn, net_params)
x_est[0,:] = x_out_test[0,:]
# Out:
# (1, 154)

# %% [markdown]
# ***Time Evolution***

# %%
for i in range(num_snaps_val):
  #bilinear
    z[i+1,:] = np.matmul(z[i,:],A.T)+np.matmul(np.kron(u_Test[i,:],z[i,:]),B.T)
    x_est[i+1,:] = np.matmul(z[i+1,:],C.T)

# %% [markdown]
# ***Visualization***

# %% [markdown]
# # Joint Space

# %%
plt.figure()
plt.plot(T,x_out_Test[:,0],label ='Actual')
plt.plot(T,x_est[:,0],label = 'estimated(bilinear)')
plt.xlabel('t')
plt.ylabel('theta_1')
plt.title('theta_1 Comparison')
plt.legend()

# %%
plt.figure()
plt.plot(T,x_out_Test[:,1],label ='Actual')
plt.plot(T,x_est[:,1],label = 'estimated(bilinear)')
plt.title('Theta_2')
plt.xlabel('t')
plt.ylabel('Theta_2_comparison')
plt.legend()

# %%
plt.figure()
plt.plot(T,x_out_Test[:,2],label ='Actual')
plt.plot(T,x_est[:,2],label = 'estimated(bilinear)')
plt.title('Theta_3')
plt.xlabel('t')
plt.ylabel('theta_3')
plt.legend()

# %%
plt.figure()
plt.plot(T,x_out_Test[:,3],label ='Actual')
plt.plot(T,x_est[:,3],label = 'estimated(bilinear)')
plt.title('Theta_4')
plt.xlabel('t')
plt.ylabel('theta_4')
plt.legend()

# %%
plt.figure()
plt.plot(T,x_out_Test[:,4],label ='Actual')
plt.plot(T,x_est[:,4],label = 'estimated(bilinear)')
plt.title('Theta_5')
plt.xlabel('t')
plt.ylabel('theta_5')
plt.legend()

# %%
plt.figure()
plt.plot(T,x_out_Test[:,5],label ='Actual')
plt.plot(T,x_est[:,5],label = 'estimated(bilinear)')
plt.title('Theta_6')
plt.xlabel('t')
plt.ylabel('theta_6')
plt.legend()

# %%
plt.figure()
plt.plot(T,x_out_Test[:,6],label ='Actual')
plt.plot(T,x_est[:,6],label = 'estimated(bilinear)')
plt.title('Theta_6')
plt.xlabel('t')
plt.ylabel('theta_6')
plt.legend()

# %%
plt.figure()
plt.plot(T,x_out_Test[:,7],label ='Actual')
plt.plot(T,x_est[:,7],label = 'estimated(bilinear)')
plt.xlabel('t')
plt.ylabel('theta_1_dot')
plt.title('theta_1_dot Comparison')
plt.legend()

# %%
plt.figure()
plt.plot(T,x_out_Test[:,8],label ='Actual')
plt.plot(T,x_est[:,8],label = 'estimated(bilinear)')
plt.title('Theta_2_dot')
plt.xlabel('t')
plt.ylabel('Theta_2_dot_comparison')
plt.legend()

# %%
plt.figure()
plt.plot(T,x_out_Test[:,9],label ='Actual')
plt.plot(T,x_est[:,9],label = 'estimated(bilinear)')
plt.title('Theta_3_dot')
plt.xlabel('t')
plt.ylabel('theta_3_dot')
plt.legend()

# %%
plt.figure()
plt.plot(T,x_out_Test[:,10],label ='Actual')
plt.plot(T,x_est[:,10],label = 'estimated(bilinear)')
plt.title('Theta_4_dot')
plt.xlabel('t')
plt.ylabel('theta_4_dot')
plt.legend()

# %%
plt.figure()
plt.plot(T,x_out_Test[:,11],label ='Actual')
plt.plot(T,x_est[:,11],label = 'estimated(bilinear)')
plt.title('Theta_5_dot')
plt.xlabel('t')
plt.ylabel('theta_5_dot')
plt.legend()

# %%
plt.figure()
plt.plot(T,x_out_Test[:,12],label ='Actual')
plt.plot(T,x_est[:,12],label = 'estimated(bilinear)')
plt.title('Theta_6_dot')
plt.xlabel('t')
plt.ylabel('theta_6_dot')
plt.legend()

# %%
plt.figure()
plt.plot(T,x_out_Test[:,13],label ='Actual')
plt.plot(T,x_est[:,13],label = 'estimated(bilinear)')
plt.title('Theta_7_dot')
plt.xlabel('t')
plt.ylabel('theta_7_dot')
plt.legend()

# %% [markdown]
# ## Cartesian Space

# %%
plt.figure()
plt.plot(T,xs_end_test[:,0], label = 'Actual')
plt.plot(T[:-1],x_end_est[:,0], label = 'Estimated')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(T,xs_end_test[:,1], label = 'Actual')
plt.plot(T[:-1],x_end_est[:,1], label = 'Estimated')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(T,xs_end_test[:,2], label = 'Actual')
plt.plot(T[:-1],x_end_est[:,2], label = 'Estimated')
plt.legend()
plt.show()
