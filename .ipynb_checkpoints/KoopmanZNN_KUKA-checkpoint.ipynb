# %% [markdown]
# ***Import Libraries***

# %%
"""This program bilinearizes 3R planar dyanmics using koopman theory and autoencoder to map"""
import numpy as np
import matplotlib.pyplot as plt
import sklearn.preprocessing
import itertools
import scipy.io
import torch

# bilinear Koopman
from core.koopman_core import KoopDNN, KoopmanNet, KoopmanNetCtrl
from models.koop_model import model_matricies,lift

# forward map neural net
from core.neural_fwd_map import map_Net

# 2R dynamics and kinetics
from dynamics.robot_3R import dynamics_3R_data_gen, dynamics_3R, forward_kinematics_3R, forward_map_3R, Jacobian_3R


## import paths
from paths.paths import path_pars

# %% [markdown]
# ### Load Data

# %%
data = scipy.io.loadmat('dynamics/Dataset_MATLAB/2D/data.mat')

X_end = np.array(data['X_end'], dtype = 'float64')
X_full = np.array(data['X'], dtype = 'float64')
U_full = np.array(data['tau'], dtype = 'float64')

print(X_end.shape, X_full.shape,U_full.shape)

# %%
np.sum(np.sum(X.isnan()))

# %% [markdown]
# ***Simulation Parameters***

# %%
dt = float(data['dt']) #time step
num_snaps = int(data['num_snaps']) # no. of snapshots
num_traj = int(data['num_traj']) #no of trajectories
T = np.linspace(0,num_snaps*dt, num_snaps+1)
num_train = int(0.75*num_traj) # no. of training examples
num_val = num_traj-num_train # no of testing examples
num_traj = num_train+num_val #no of trajectories
num_states = X_full.shape[2] # no. of states
num_inputs = U_full.shape[2] # no. of inputs

# %%
dt, num_snaps, num_traj, num_states, num_inputs

# %% [markdown]
# ***Plotting the trajectories***

# %%
"""Training dataset visualization"""
#theta evolution
for i in range(int(num_states/2)):
    plt.subplot(3,3,i+1)
    plt.xlabel("t")
    plt.ylabel("th"+str(i))
    for j in range(num_traj):
        plt.plot(T,X_full[j,:,i])

# %%
for i in range(int(num_states/2)):
    plt.subplot(3,3,i+1)
    plt.xlabel("t")
    plt.ylabel("th"+str(i)+ ' dot')
    for j in range(num_traj):
        plt.plot(T,X_full[j,:,i+int(num_states/2)])

# %%
#x and y positions of the end effector
ax = plt.axes(projection='3d')
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
for i in range(num_traj):
    ax.plot3D(X_end[i,:,0],X_end[i,:,1],X_end[i,:,2])

# %%
for i in range(num_inputs):
    plt.subplot(4,2,i+1)
    plt.xlabel("t")
    plt.ylabel("tau"+str(i))
    for j in range(num_traj):
        plt.plot(T[:-1],U_full[j,:,i])

# %% [markdown]
# ***Training and validation datasets***

# %%
# split training and vaidation datasets
xs_train, us_train = X_full[:num_train,:,:],U_full[:num_train,:,:]
xs_val, us_val = X_full[num_train:,:,:],U_full[num_train:,:,:]

# %%
# import scipy.io
# Data_set = {"x_end": X_end, "X_full": X_full}
# scipy.io.savemat("Data_set.mat",Data_set)

# %%
# import torch
# import torch.nn as nn
# import torch.nn.functional as F

# %% [markdown]
# ***Model Training***

# %%
net_params = {}
net_params['state_dim'] = num_states
net_params['ctrl_dim'] = num_inputs
net_params['encoder_hidden_width'] = 80
net_params['encoder_hidden_depth'] = 2
net_params['encoder_output_dim'] = 30
net_params['optimizer'] = 'adam'
net_params['activation_type'] = 'tanh'
net_params['lr'] = 4e-4 # 5e-4
net_params['epochs'] = 500
net_params['batch_size'] = 128
net_params['lifted_loss_penalty'] = 0.4 
net_params['l2_reg'] = 0.0         
net_params['l1_reg'] = 0.0
net_params['first_obs_const'] = True
net_params['override_C'] = True # this makes the state a part of lifetd state
net_params['dt'] = dt

# %%
train = True

if train == True:
    file = 'saved_models/Kuka/2D/koop_arch.pth'
    net = KoopmanNetCtrl(net_params)
    model_koop_dnn = KoopDNN(net)
    model_koop_dnn.set_datasets(xs_train, u_train=us_train, x_val=xs_val, u_val=us_val)
    model_koop_dnn.model_pipeline(net_params)
    model_koop_dnn.construct_koopman_model()
    torch.save(model_koop_dnn,file)
else:
    file = 'saved_models/Kuka/2D/koop_arch.pth'
    model_koop_dnn = torch.load(file)

# %% [markdown]
# ***Learning Curves***

# %%
train_loss = [l[0] for l in model_koop_dnn.train_loss_hist]
train_pred_loss = [l[1] for l in model_koop_dnn.train_loss_hist]
train_lifted_loss = [l[2] for l in model_koop_dnn.train_loss_hist]
val_loss = [l[0] for l in model_koop_dnn.val_loss_hist]
val_pred_loss = [l[1] for l in model_koop_dnn.val_loss_hist]
val_lifted_loss = [l[2] for l in model_koop_dnn.val_loss_hist]
epochs = np.arange(0, net_params['epochs'])

plt.figure(figsize=(15,8))
plt.plot(epochs, train_loss, color='tab:orange', label='Training loss')
plt.plot(epochs, train_pred_loss, '--', color='tab:orange', label='Training prediction loss')
plt.plot(epochs, train_lifted_loss, ':', color='tab:orange', label='Training lifted loss')
plt.plot(epochs, val_loss, color='tab:blue', label='Validation loss')
plt.plot(epochs, val_pred_loss, '--', color='tab:blue', label='Validation prediction loss')
plt.plot(epochs, val_lifted_loss, ':', color='tab:blue', label='Validation lifted loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale('log')
plt.savefig("convergence plot for arch1")
plt.show()

# %%
map_net_params = {}
map_net_params["input_dim"] = 7 #number of joint angles
map_net_params["output_dim"] = 3 #x and y position of the end effector
map_net_params["hidden_width"] = 20
map_net_params["hidden_depth"] = 2
map_net_params["batch_size"] = 100
map_net_params["epochs"] = 500
map_net_params["activation_type"] = 'tanh'
map_net_params["lr"] = 1e-3
map_net_params["optimizer"] = 'adam'
map_net_params['l2_reg'] = 0.0
map_net_params['l1_reg'] = 0.0

# %%
#dataset
# split training and vaidation datasets
xs_map_train, ys_map_train = X_full[:num_train,:,:7],X_end[:num_train,:,:3]
xs_map_val, ys_map_val = X_full[num_train:,:,:7],X_end[num_train:,:,:3]

# %%
ys_map_train.shape, ys_map_val.shape,xs_map_train.shape, xs_map_val.shape
# Out:
# ((75, 1001, 3), (25, 1001, 3), (75, 1001, 7), (25, 1001, 7))

# %%
#Initalize network
#Initalize network
train = True

if train==True:
    file = "saved_models/Kuka/2D/map_net.pth"
    map_net = map_Net(map_net_params)
    map_net.set_dataset_map(xs_map_train,ys_map_train,xs_map_val,ys_map_val)
    map_net.data_pipeline()
    map_net.plot_loss()
    torch.save(map_net.state_dict(),file)
else:
    file = "saved_models/Kuka/2D/map_net.pth"
    map_net = map_Net(map_net_params)
    map_net.load_state_dict(torch.load(file))
# Out:
# Epoch   1: train loss: 0.0962451593, validation loss: 0.0760354180
# Epoch   2: train loss: 0.0337701498, validation loss: 0.0626574862
# Epoch   3: train loss: 0.0220221268, validation loss: 0.0610305981
# Epoch   4: train loss: 0.0160409435, validation loss: 0.0580074658
# Epoch   5: train loss: 0.0128947471, validation loss: 0.0577173758
# Epoch   6: train loss: 0.0110132343, validation loss: 0.0559232222
# Epoch   7: train loss: 0.0096315676, validation loss: 0.0573772749
# Epoch   8: train loss: 0.0086338599, validation loss: 0.0586474868
# Epoch   9: train loss: 0.0079018891, validation loss: 0.0576214232
# Epoch  10: train loss: 0.0073315776, validation loss: 0.0592607087
# Epoch  11: train loss: 0.0068614193, validation loss: 0.0600660136
# Epoch  12: train loss: 0.0065100702, validation loss: 0.0612221489
# Epoch  13: train loss: 0.0061765543, validation loss: 0.0633820482
# Epoch  14: train loss: 0.0059328646, validation loss: 0.0636069470
# Epoch  15: train loss: 0.0056879573, validation loss: 0.0647919631
# Epoch  16: train loss: 0.0054705460, validation loss: 0.0657600881
# Epoch  17: train loss: 0.0052953294, validation loss: 0.0654233438
# Epoch  18: train loss: 0.0051257187, validation loss: 0.0668689280
# Epoch  19: train loss: 0.0049418801, validation loss: 0.0667016404
# Epoch  20: train loss: 0.0047840361, validation loss: 0.0674786505
# Epoch  21: train loss: 0.0046488104, validation loss: 0.0678126346
# Epoch  22: train loss: 0.0045235224, validation loss: 0.0705955986
# Epoch  23: train loss: 0.0043858356, validation loss: 0.0702847890
# Epoch  24: train loss: 0.0042777895, validation loss: 0.0714339350
# Epoch  25: train loss: 0.0041932963, validation loss: 0.0740169098
# Epoch  26: train loss: 0.0041064595, validation loss: 0.0737700859
# Epoch  27: train loss: 0.0040375254, validation loss: 0.0720236886
# Epoch  28: train loss: 0.0039445581, validation loss: 0.0745482153
# Epoch  29: train loss: 0.0038906371, validation loss: 0.0752442889
# Epoch  30: train loss: 0.0038443989, validation loss: 0.0752489095
# Epoch  31: train loss: 0.0037901498, validation loss: 0.0765452717
# Epoch  32: train loss: 0.0037361207, validation loss: 0.0769013435
# Epoch  33: train loss: 0.0036978417, validation loss: 0.0772914724
# Epoch  34: train loss: 0.0036649836, validation loss: 0.0784951879
# Epoch  35: train loss: 0.0036206758, validation loss: 0.0787157374
# Epoch  36: train loss: 0.0035850573, validation loss: 0.0763605506
# Epoch  37: train loss: 0.0035471543, validation loss: 0.0788149017
# Epoch  38: train loss: 0.0035138883, validation loss: 0.0787998861
# Epoch  39: train loss: 0.0034862872, validation loss: 0.0798442301
# Epoch  40: train loss: 0.0034573799, validation loss: 0.0770855913
# Epoch  41: train loss: 0.0034069704, validation loss: 0.0797443375
# Epoch  42: train loss: 0.0034015376, validation loss: 0.0781826526
# Epoch  43: train loss: 0.0033634221, validation loss: 0.0811307334
# Epoch  44: train loss: 0.0033327869, validation loss: 0.0795163800
# Epoch  45: train loss: 0.0033086460, validation loss: 0.0793504890
# Epoch  46: train loss: 0.0032707429, validation loss: 0.0819480109
# Epoch  47: train loss: 0.0032508771, validation loss: 0.0809720248
# Epoch  48: train loss: 0.0032247850, validation loss: 0.0825013338
# Epoch  49: train loss: 0.0031861858, validation loss: 0.0809364642
# Epoch  50: train loss: 0.0031752929, validation loss: 0.0812324180
# Epoch  51: train loss: 0.0031370111, validation loss: 0.0810847338
# Epoch  52: train loss: 0.0031155765, validation loss: 0.0826007773
# Epoch  53: train loss: 0.0031022625, validation loss: 0.0844648185
# Epoch  54: train loss: 0.0030664069, validation loss: 0.0839406660
# Epoch  55: train loss: 0.0030322794, validation loss: 0.0835852876
# Epoch  56: train loss: 0.0030174414, validation loss: 0.0836572414
# Epoch  57: train loss: 0.0029949256, validation loss: 0.0851637911
# Epoch  58: train loss: 0.0029785424, validation loss: 0.0840957875
# Epoch  59: train loss: 0.0029399985, validation loss: 0.0855875117
# Epoch  60: train loss: 0.0029215209, validation loss: 0.0852044380
# Epoch  61: train loss: 0.0029145473, validation loss: 0.0858489336
# Epoch  62: train loss: 0.0028856226, validation loss: 0.0861146527
# Epoch  63: train loss: 0.0028631289, validation loss: 0.0873161971
# Epoch  64: train loss: 0.0028611213, validation loss: 0.0874111764
# Epoch  65: train loss: 0.0028279387, validation loss: 0.0851186669
# Epoch  66: train loss: 0.0028043631, validation loss: 0.0868968027
# Epoch  67: train loss: 0.0028000627, validation loss: 0.0875051912
# Epoch  68: train loss: 0.0027718298, validation loss: 0.0860598994
# Epoch  69: train loss: 0.0027732087, validation loss: 0.0859738941
# Epoch  70: train loss: 0.0027378324, validation loss: 0.0879098446
# Epoch  71: train loss: 0.0027363901, validation loss: 0.0878550751
# Epoch  72: train loss: 0.0027160086, validation loss: 0.0870058285
# Epoch  73: train loss: 0.0027133828, validation loss: 0.0861399705
# Epoch  74: train loss: 0.0026962640, validation loss: 0.0884687458
# Epoch  75: train loss: 0.0026692687, validation loss: 0.0876100868
# Epoch  76: train loss: 0.0026671188, validation loss: 0.0867228540
# Epoch  77: train loss: 0.0026467092, validation loss: 0.0878538184
# Epoch  78: train loss: 0.0026514198, validation loss: 0.0891263073
# Epoch  79: train loss: 0.0026357806, validation loss: 0.0860372948
# Epoch  80: train loss: 0.0026183082, validation loss: 0.0889991015
# Epoch  81: train loss: 0.0026001656, validation loss: 0.0888452160
# Epoch  82: train loss: 0.0025974081, validation loss: 0.0874743846
# Epoch  83: train loss: 0.0025752756, validation loss: 0.0878975837
# Epoch  84: train loss: 0.0025796943, validation loss: 0.0883083974
# Epoch  85: train loss: 0.0025606019, validation loss: 0.0877699179
# Epoch  86: train loss: 0.0025481282, validation loss: 0.0869143845
# Epoch  87: train loss: 0.0025344969, validation loss: 0.0868452277
# Epoch  88: train loss: 0.0025309978, validation loss: 0.0886015010
# Epoch  89: train loss: 0.0025235029, validation loss: 0.0889751519
# Epoch  90: train loss: 0.0025097128, validation loss: 0.0876487933
# Epoch  91: train loss: 0.0025070921, validation loss: 0.0875117242
# Epoch  92: train loss: 0.0024852205, validation loss: 0.0884914440
# Epoch  93: train loss: 0.0024876395, validation loss: 0.0864754641
# Epoch  94: train loss: 0.0024828136, validation loss: 0.0868052619
# Epoch  95: train loss: 0.0024781849, validation loss: 0.0881799840
# Epoch  96: train loss: 0.0024686054, validation loss: 0.0866399165
# Epoch  97: train loss: 0.0024454299, validation loss: 0.0869401091
# Epoch  98: train loss: 0.0024427501, validation loss: 0.0860964653
# Epoch  99: train loss: 0.0024463544, validation loss: 0.0872222938
# Epoch 100: train loss: 0.0024264442, validation loss: 0.0870820746
# Epoch 101: train loss: 0.0024340593, validation loss: 0.0878187068
# Epoch 102: train loss: 0.0024175074, validation loss: 0.0863380606
# Epoch 103: train loss: 0.0024133515, validation loss: 0.0873212775
# Epoch 104: train loss: 0.0024114673, validation loss: 0.0874592934
# Epoch 105: train loss: 0.0023940404, validation loss: 0.0872678159
# Epoch 106: train loss: 0.0023809570, validation loss: 0.0869647868
# Epoch 107: train loss: 0.0023877023, validation loss: 0.0877711621
# Epoch 108: train loss: 0.0023745129, validation loss: 0.0868085636
# Epoch 109: train loss: 0.0023749646, validation loss: 0.0881544437
# Epoch 110: train loss: 0.0023665252, validation loss: 0.0880291700
# Epoch 111: train loss: 0.0023625371, validation loss: 0.0874502776
# Epoch 112: train loss: 0.0023573208, validation loss: 0.0881846505
# Epoch 113: train loss: 0.0023565396, validation loss: 0.0883535374
# Epoch 114: train loss: 0.0023339023, validation loss: 0.0878545403
# Epoch 115: train loss: 0.0023422804, validation loss: 0.0879256834
# Epoch 116: train loss: 0.0023313320, validation loss: 0.0887120357
# Epoch 117: train loss: 0.0023419155, validation loss: 0.0898526220
# Epoch 118: train loss: 0.0023314369, validation loss: 0.0901418589
# Epoch 119: train loss: 0.0023212232, validation loss: 0.0891012939
# Epoch 120: train loss: 0.0023219235, validation loss: 0.0882052065
# Epoch 121: train loss: 0.0023140396, validation loss: 0.0905286462
# Epoch 122: train loss: 0.0023087357, validation loss: 0.0870897156
# Epoch 123: train loss: 0.0022990498, validation loss: 0.0893014155
# Epoch 124: train loss: 0.0022953849, validation loss: 0.0874358834
# Epoch 125: train loss: 0.0022918328, validation loss: 0.0892449289
# Epoch 126: train loss: 0.0022961126, validation loss: 0.0874829459
# Epoch 127: train loss: 0.0022849733, validation loss: 0.0894615100
# Epoch 128: train loss: 0.0022689441, validation loss: 0.0891770887
# Epoch 129: train loss: 0.0022844593, validation loss: 0.0884712618
# Epoch 130: train loss: 0.0022833200, validation loss: 0.0893872716
# Epoch 131: train loss: 0.0022663034, validation loss: 0.0901196160
# Epoch 132: train loss: 0.0022626793, validation loss: 0.0907116824
# Epoch 133: train loss: 0.0022547987, validation loss: 0.0892664625
# Epoch 134: train loss: 0.0022592996, validation loss: 0.0887902231
# Epoch 135: train loss: 0.0022491608, validation loss: 0.0892420422
# Epoch 136: train loss: 0.0022443010, validation loss: 0.0885951899
# Epoch 137: train loss: 0.0022459513, validation loss: 0.0900114019
# Epoch 138: train loss: 0.0022360061, validation loss: 0.0890994043
# Epoch 139: train loss: 0.0022345309, validation loss: 0.0906251706
# Epoch 140: train loss: 0.0022457032, validation loss: 0.0890821574
# Epoch 141: train loss: 0.0022343701, validation loss: 0.0889207787
# Epoch 142: train loss: 0.0022268985, validation loss: 0.0891920946
# Epoch 143: train loss: 0.0022226206, validation loss: 0.0907353409
# Epoch 144: train loss: 0.0022228722, validation loss: 0.0914371588
# Epoch 145: train loss: 0.0022232026, validation loss: 0.0906277748
# Epoch 146: train loss: 0.0022176434, validation loss: 0.0897513987
# Epoch 147: train loss: 0.0022150088, validation loss: 0.0914078242
# Epoch 148: train loss: 0.0022075996, validation loss: 0.0892634320
# Epoch 149: train loss: 0.0022025518, validation loss: 0.0897251418
# Epoch 150: train loss: 0.0022023760, validation loss: 0.0914034534
# Epoch 151: train loss: 0.0021966063, validation loss: 0.0889587298
# Epoch 152: train loss: 0.0021974441, validation loss: 0.0906606664
# Epoch 153: train loss: 0.0021922526, validation loss: 0.0904778497
# Epoch 154: train loss: 0.0021874189, validation loss: 0.0908633827
# Epoch 155: train loss: 0.0021789256, validation loss: 0.0925891718
# Epoch 156: train loss: 0.0021901154, validation loss: 0.0911337787
# Epoch 157: train loss: 0.0021760395, validation loss: 0.0900893109
# Epoch 158: train loss: 0.0021672078, validation loss: 0.0899629400
# Epoch 159: train loss: 0.0021691846, validation loss: 0.0895120104
# Epoch 160: train loss: 0.0021685435, validation loss: 0.0895303385
# Epoch 161: train loss: 0.0021601432, validation loss: 0.0908477541
# Epoch 162: train loss: 0.0021715615, validation loss: 0.0912627044
# Epoch 163: train loss: 0.0021484780, validation loss: 0.0933131782
# Epoch 164: train loss: 0.0021505877, validation loss: 0.0911345975
# Epoch 165: train loss: 0.0021447394, validation loss: 0.0917117722
# Epoch 166: train loss: 0.0021574647, validation loss: 0.0902048989
# Epoch 167: train loss: 0.0021392620, validation loss: 0.0908215921
# Epoch 168: train loss: 0.0021605070, validation loss: 0.0919831098
# Epoch 169: train loss: 0.0021448531, validation loss: 0.0915085077
# Epoch 170: train loss: 0.0021412423, validation loss: 0.0906339830
# Epoch 171: train loss: 0.0021342749, validation loss: 0.0905786087
# Epoch 172: train loss: 0.0021272680, validation loss: 0.0919956659
# Epoch 173: train loss: 0.0021268934, validation loss: 0.0901746566
# Epoch 174: train loss: 0.0021422206, validation loss: 0.0925485125
# Epoch 175: train loss: 0.0021180520, validation loss: 0.0910862484
# Epoch 176: train loss: 0.0021157753, validation loss: 0.0895057266
# Epoch 177: train loss: 0.0021126193, validation loss: 0.0920119489
# Epoch 178: train loss: 0.0021098099, validation loss: 0.0910564702
# Epoch 179: train loss: 0.0021208178, validation loss: 0.0906617092
# Epoch 180: train loss: 0.0021075021, validation loss: 0.0918773191
# Epoch 181: train loss: 0.0021014019, validation loss: 0.0923087716
# Epoch 182: train loss: 0.0021007696, validation loss: 0.0916157737
# Epoch 183: train loss: 0.0021098349, validation loss: 0.0918042923
# Epoch 184: train loss: 0.0020964107, validation loss: 0.0913845500
# Epoch 185: train loss: 0.0020931568, validation loss: 0.0913185181
# Epoch 186: train loss: 0.0020955432, validation loss: 0.0912715648
# Epoch 187: train loss: 0.0020959888, validation loss: 0.0912283037
# Epoch 188: train loss: 0.0020819377, validation loss: 0.0927197303
# Epoch 189: train loss: 0.0020929641, validation loss: 0.0915402491
# Epoch 190: train loss: 0.0020836108, validation loss: 0.0923445409
# Epoch 191: train loss: 0.0020740598, validation loss: 0.0909901598
# Epoch 192: train loss: 0.0020783295, validation loss: 0.0917538231
# Epoch 193: train loss: 0.0020725543, validation loss: 0.0920144731
# Epoch 194: train loss: 0.0020681487, validation loss: 0.0909591623
# Epoch 195: train loss: 0.0020664757, validation loss: 0.0936891808
# Epoch 196: train loss: 0.0020646055, validation loss: 0.0912295334
# Epoch 197: train loss: 0.0020658569, validation loss: 0.0922700362
# Epoch 198: train loss: 0.0020592935, validation loss: 0.0924932653
# Epoch 199: train loss: 0.0020581811, validation loss: 0.0927395985
# Epoch 200: train loss: 0.0020585843, validation loss: 0.0934904211
# Epoch 201: train loss: 0.0020618006, validation loss: 0.0921256551
# Epoch 202: train loss: 0.0020492243, validation loss: 0.0931896068
# Epoch 203: train loss: 0.0020471003, validation loss: 0.0923136360
# Epoch 204: train loss: 0.0020600826, validation loss: 0.0925243072
# Epoch 205: train loss: 0.0020404067, validation loss: 0.0930226739
# Epoch 206: train loss: 0.0020478905, validation loss: 0.0930324675
# Epoch 207: train loss: 0.0020450383, validation loss: 0.0925716521
# Epoch 208: train loss: 0.0020552185, validation loss: 0.0926147088
# Epoch 209: train loss: 0.0020339034, validation loss: 0.0914827141
# Epoch 210: train loss: 0.0020299816, validation loss: 0.0921917983
# Epoch 211: train loss: 0.0020295185, validation loss: 0.0939249222
# Epoch 212: train loss: 0.0020418982, validation loss: 0.0936531613
# Epoch 213: train loss: 0.0020318414, validation loss: 0.0923121531
# Epoch 214: train loss: 0.0020262901, validation loss: 0.0921304709
# Epoch 215: train loss: 0.0020148402, validation loss: 0.0932117790
# Epoch 216: train loss: 0.0020244922, validation loss: 0.0951421954
# Epoch 217: train loss: 0.0020141323, validation loss: 0.0935551941
# Epoch 218: train loss: 0.0020103592, validation loss: 0.0926746977
# Epoch 219: train loss: 0.0020152357, validation loss: 0.0908888460
# Epoch 220: train loss: 0.0020125153, validation loss: 0.0928558534
# Epoch 221: train loss: 0.0020114621, validation loss: 0.0921049735
# Epoch 222: train loss: 0.0019975103, validation loss: 0.0943330295
# Epoch 223: train loss: 0.0020105043, validation loss: 0.0933419253
# Epoch 224: train loss: 0.0020182131, validation loss: 0.0923638483
# Epoch 225: train loss: 0.0020013810, validation loss: 0.0928549836
# Epoch 226: train loss: 0.0020038252, validation loss: 0.0938595032
# Epoch 227: train loss: 0.0020020068, validation loss: 0.0931969829
# Epoch 228: train loss: 0.0020047315, validation loss: 0.0937385308
# Epoch 229: train loss: 0.0019992157, validation loss: 0.0939618700
# Epoch 230: train loss: 0.0019972629, validation loss: 0.0940865154
# Epoch 231: train loss: 0.0019824727, validation loss: 0.0934452512
# Epoch 232: train loss: 0.0019890815, validation loss: 0.0950751854
# Epoch 233: train loss: 0.0019798685, validation loss: 0.0921458284
# Epoch 234: train loss: 0.0019841061, validation loss: 0.0954773043
# Epoch 235: train loss: 0.0019896618, validation loss: 0.0929510684
# Epoch 236: train loss: 0.0019907797, validation loss: 0.0947480199
# Epoch 237: train loss: 0.0019791726, validation loss: 0.0943257870
# Epoch 238: train loss: 0.0019845660, validation loss: 0.0924171652
# Epoch 239: train loss: 0.0019739695, validation loss: 0.0943142023
# Epoch 240: train loss: 0.0019753959, validation loss: 0.0934992445
# Epoch 241: train loss: 0.0019797736, validation loss: 0.0953124684
# Epoch 242: train loss: 0.0019770101, validation loss: 0.0944238873
# Epoch 243: train loss: 0.0019781869, validation loss: 0.0939332682
# Epoch 244: train loss: 0.0019770592, validation loss: 0.0950993709
# Epoch 245: train loss: 0.0019748032, validation loss: 0.0952275971
# Epoch 246: train loss: 0.0019663180, validation loss: 0.0926179853
# Epoch 247: train loss: 0.0019648321, validation loss: 0.0971120195
# Epoch 248: train loss: 0.0019617722, validation loss: 0.0949529293
# Epoch 249: train loss: 0.0019744952, validation loss: 0.0936685512
# Epoch 250: train loss: 0.0019473211, validation loss: 0.0945899488
# Epoch 251: train loss: 0.0019660787, validation loss: 0.0942933846
# Epoch 252: train loss: 0.0019516765, validation loss: 0.0937051515
# Epoch 253: train loss: 0.0019609951, validation loss: 0.0961741931
# Epoch 254: train loss: 0.0019573153, validation loss: 0.0941915764
# Epoch 255: train loss: 0.0019529828, validation loss: 0.0944927823
# Epoch 256: train loss: 0.0019598616, validation loss: 0.0968790113
# Epoch 257: train loss: 0.0019419106, validation loss: 0.0948362470
# Epoch 258: train loss: 0.0019553712, validation loss: 0.0945619421
# Epoch 259: train loss: 0.0019407273, validation loss: 0.0951047785
# Epoch 260: train loss: 0.0019540801, validation loss: 0.0963079947
# Epoch 261: train loss: 0.0019475603, validation loss: 0.0957834792
# Epoch 262: train loss: 0.0019482922, validation loss: 0.0945570585
# Epoch 263: train loss: 0.0019446972, validation loss: 0.0937093074
# Epoch 264: train loss: 0.0019437274, validation loss: 0.0959403566
# Epoch 265: train loss: 0.0019416598, validation loss: 0.0944405634
# Epoch 266: train loss: 0.0019422518, validation loss: 0.0926421367
# Epoch 267: train loss: 0.0019484629, validation loss: 0.0956385798
# Epoch 268: train loss: 0.0019379094, validation loss: 0.0945378035
# Epoch 269: train loss: 0.0019255309, validation loss: 0.0963985640
# Epoch 270: train loss: 0.0019304062, validation loss: 0.0961148325
# Epoch 271: train loss: 0.0019388970, validation loss: 0.0964254186
# Epoch 272: train loss: 0.0019357315, validation loss: 0.0955000024
# Epoch 273: train loss: 0.0019273423, validation loss: 0.0977549166
# Epoch 274: train loss: 0.0019302343, validation loss: 0.0973043112
# Epoch 275: train loss: 0.0019358085, validation loss: 0.0951113572
# Epoch 276: train loss: 0.0019256660, validation loss: 0.0963266037
# Epoch 277: train loss: 0.0019303377, validation loss: 0.0958366724
# Epoch 278: train loss: 0.0019199368, validation loss: 0.0964841922
# Epoch 279: train loss: 0.0019201070, validation loss: 0.0964321815
# Epoch 280: train loss: 0.0019267677, validation loss: 0.0956696705
# Epoch 281: train loss: 0.0019215814, validation loss: 0.0962366953
# Epoch 282: train loss: 0.0019181721, validation loss: 0.0983563703
# Epoch 283: train loss: 0.0019277365, validation loss: 0.0968645967
# Epoch 284: train loss: 0.0019268905, validation loss: 0.0954749411
# Epoch 285: train loss: 0.0019201574, validation loss: 0.0953059816
# Epoch 286: train loss: 0.0019138468, validation loss: 0.0958837206
# Epoch 287: train loss: 0.0019178667, validation loss: 0.0963046764
# Epoch 288: train loss: 0.0019090987, validation loss: 0.0971159381
# Epoch 289: train loss: 0.0019097268, validation loss: 0.0961116545
# Epoch 290: train loss: 0.0019107722, validation loss: 0.0968561742
# Epoch 291: train loss: 0.0019122224, validation loss: 0.0983750251
# Epoch 292: train loss: 0.0019074699, validation loss: 0.0966418549
# Epoch 293: train loss: 0.0019115005, validation loss: 0.0974368986
# Epoch 294: train loss: 0.0018975172, validation loss: 0.0979407483
# Epoch 295: train loss: 0.0019097140, validation loss: 0.0980895396
# Epoch 296: train loss: 0.0019067396, validation loss: 0.0970972061
# Epoch 297: train loss: 0.0018998512, validation loss: 0.0976292780
# Epoch 298: train loss: 0.0018899195, validation loss: 0.0963396860
# Epoch 299: train loss: 0.0019075138, validation loss: 0.0985290741
# Epoch 300: train loss: 0.0019023338, validation loss: 0.0976041832
# Epoch 301: train loss: 0.0019027510, validation loss: 0.0966870124
# Epoch 302: train loss: 0.0019100878, validation loss: 0.0975262085
# Epoch 303: train loss: 0.0019050097, validation loss: 0.0971136584
# Epoch 304: train loss: 0.0018892378, validation loss: 0.0967510560
# Epoch 305: train loss: 0.0018917404, validation loss: 0.0976097714
# Epoch 306: train loss: 0.0018933524, validation loss: 0.0971884164
# Epoch 307: train loss: 0.0018986577, validation loss: 0.0995143256
# Epoch 308: train loss: 0.0019005654, validation loss: 0.0980470355
# Epoch 309: train loss: 0.0018928009, validation loss: 0.0976694576
# Epoch 310: train loss: 0.0019023960, validation loss: 0.0983861667
# Epoch 311: train loss: 0.0018889818, validation loss: 0.0972356989
# Epoch 312: train loss: 0.0018905390, validation loss: 0.0992009209
# Epoch 313: train loss: 0.0018827746, validation loss: 0.0983720212
# Epoch 314: train loss: 0.0018853781, validation loss: 0.0983543002
# Epoch 315: train loss: 0.0018865837, validation loss: 0.0974798198
# Epoch 316: train loss: 0.0018921809, validation loss: 0.0980651309
# Epoch 317: train loss: 0.0018742058, validation loss: 0.0995387782
# Epoch 318: train loss: 0.0018685163, validation loss: 0.0988202893
# Epoch 319: train loss: 0.0018776020, validation loss: 0.0997224564
# Epoch 320: train loss: 0.0018887426, validation loss: 0.0992993337
# Epoch 321: train loss: 0.0018904683, validation loss: 0.1004691782
# Epoch 322: train loss: 0.0018900320, validation loss: 0.0997640468
# Epoch 323: train loss: 0.0018716401, validation loss: 0.0983471198
# Epoch 324: train loss: 0.0018823986, validation loss: 0.0985180909
# Epoch 325: train loss: 0.0018914654, validation loss: 0.0970939228
# Epoch 326: train loss: 0.0018690367, validation loss: 0.0988313924
# Epoch 327: train loss: 0.0018737359, validation loss: 0.0993389257
# Epoch 328: train loss: 0.0018744756, validation loss: 0.0986753288
# Epoch 329: train loss: 0.0018737880, validation loss: 0.0981209976
# Epoch 330: train loss: 0.0018667696, validation loss: 0.0999073397
# Epoch 331: train loss: 0.0018781297, validation loss: 0.0997872928
# Epoch 332: train loss: 0.0018654391, validation loss: 0.0983550264
# Epoch 333: train loss: 0.0018664222, validation loss: 0.0994763859
# Epoch 334: train loss: 0.0018679607, validation loss: 0.0982038604
# Epoch 335: train loss: 0.0018674226, validation loss: 0.0992820067
# Epoch 336: train loss: 0.0018708512, validation loss: 0.0998982928
# Epoch 337: train loss: 0.0018657489, validation loss: 0.1002018832
# Epoch 338: train loss: 0.0018564359, validation loss: 0.1002607553
# Epoch 339: train loss: 0.0018572098, validation loss: 0.0993645971
# Epoch 340: train loss: 0.0018641012, validation loss: 0.0998338436
# Epoch 341: train loss: 0.0018635482, validation loss: 0.0992744024
# Epoch 342: train loss: 0.0018562337, validation loss: 0.1003998582
# Epoch 343: train loss: 0.0018519209, validation loss: 0.1001545933
# Epoch 344: train loss: 0.0018625161, validation loss: 0.1005922779
# Epoch 345: train loss: 0.0018602718, validation loss: 0.0989713737
# Epoch 346: train loss: 0.0018566364, validation loss: 0.1010692597
# Epoch 347: train loss: 0.0018529000, validation loss: 0.1002543110
# Epoch 348: train loss: 0.0018511833, validation loss: 0.1008566560
# Epoch 349: train loss: 0.0018443342, validation loss: 0.0992804563
# Epoch 350: train loss: 0.0018468195, validation loss: 0.1000033803
# Epoch 351: train loss: 0.0018510180, validation loss: 0.1021953255
# Epoch 352: train loss: 0.0018442317, validation loss: 0.1006503889
# Epoch 353: train loss: 0.0018482562, validation loss: 0.0992693814
# Epoch 354: train loss: 0.0018459949, validation loss: 0.1005352395
# Epoch 355: train loss: 0.0018498716, validation loss: 0.1015075847
# Epoch 356: train loss: 0.0018258159, validation loss: 0.1018419159
# Epoch 357: train loss: 0.0018446648, validation loss: 0.1007889860
# Epoch 358: train loss: 0.0018340114, validation loss: 0.1009159946
# Epoch 359: train loss: 0.0018383259, validation loss: 0.1011746756
# Epoch 360: train loss: 0.0018404847, validation loss: 0.0998891531
# Epoch 361: train loss: 0.0018362166, validation loss: 0.1006217473
# Epoch 362: train loss: 0.0018357855, validation loss: 0.1009792656
# Epoch 363: train loss: 0.0018308217, validation loss: 0.1007141581
# Epoch 364: train loss: 0.0018338154, validation loss: 0.1013185067
# Epoch 365: train loss: 0.0018322843, validation loss: 0.1028303473
# Epoch 366: train loss: 0.0018300250, validation loss: 0.1006178226
# Epoch 367: train loss: 0.0018341931, validation loss: 0.1015256720
# Epoch 368: train loss: 0.0018228580, validation loss: 0.1012701419
# Epoch 369: train loss: 0.0018243128, validation loss: 0.1024306859
# Epoch 370: train loss: 0.0018317629, validation loss: 0.1033701874
# Epoch 371: train loss: 0.0018278473, validation loss: 0.1017948586
# Epoch 372: train loss: 0.0018223434, validation loss: 0.1022684773
# Epoch 373: train loss: 0.0018222361, validation loss: 0.0992562546
# Epoch 374: train loss: 0.0018248950, validation loss: 0.1014077186
# Epoch 375: train loss: 0.0018269031, validation loss: 0.1019391110
# Epoch 376: train loss: 0.0018191065, validation loss: 0.1003521931
# Epoch 377: train loss: 0.0018292553, validation loss: 0.1010484826
# Epoch 378: train loss: 0.0018170883, validation loss: 0.0996313937
# Epoch 379: train loss: 0.0018157434, validation loss: 0.1030392046
# Epoch 380: train loss: 0.0018154209, validation loss: 0.1011460495
# Epoch 381: train loss: 0.0018245024, validation loss: 0.1014259386
# Epoch 382: train loss: 0.0018204360, validation loss: 0.1025021706
# Epoch 383: train loss: 0.0018076423, validation loss: 0.1034702976
# Epoch 384: train loss: 0.0018008608, validation loss: 0.1014622290
# Epoch 385: train loss: 0.0018166362, validation loss: 0.1020875156
# Epoch 386: train loss: 0.0018086901, validation loss: 0.1020899117
# Epoch 387: train loss: 0.0018040655, validation loss: 0.1024748156
# Epoch 388: train loss: 0.0018046475, validation loss: 0.1026554272
# Epoch 389: train loss: 0.0018115804, validation loss: 0.1009272935
# Epoch 390: train loss: 0.0018016504, validation loss: 0.1014899370
# Epoch 391: train loss: 0.0018066372, validation loss: 0.1031234978
# Epoch 392: train loss: 0.0017992544, validation loss: 0.1034058605
# Epoch 393: train loss: 0.0018041664, validation loss: 0.1029404515
# Epoch 394: train loss: 0.0017916793, validation loss: 0.1019425631
# Epoch 395: train loss: 0.0017981550, validation loss: 0.1023339574
# Epoch 396: train loss: 0.0017987401, validation loss: 0.1033482664
# Epoch 397: train loss: 0.0017885712, validation loss: 0.1028228226
# Epoch 398: train loss: 0.0017922230, validation loss: 0.1039392897
# Epoch 399: train loss: 0.0017913012, validation loss: 0.1040130619
# Epoch 400: train loss: 0.0017850023, validation loss: 0.1026109487
# Epoch 401: train loss: 0.0017996496, validation loss: 0.1020193314
# Epoch 402: train loss: 0.0017932708, validation loss: 0.1007523880
# Epoch 403: train loss: 0.0017892959, validation loss: 0.1048104355
# Epoch 404: train loss: 0.0017777194, validation loss: 0.1030250074
# Epoch 405: train loss: 0.0017908408, validation loss: 0.1015888088
# Epoch 406: train loss: 0.0017882475, validation loss: 0.1024180369
# Epoch 407: train loss: 0.0017763301, validation loss: 0.1019703520
# Epoch 408: train loss: 0.0017756859, validation loss: 0.1029194457
# Epoch 409: train loss: 0.0017799787, validation loss: 0.1023507383
# Epoch 410: train loss: 0.0017800870, validation loss: 0.1028294445
# Epoch 411: train loss: 0.0017697577, validation loss: 0.1041183217
# Epoch 412: train loss: 0.0017738810, validation loss: 0.1014036185
# Epoch 413: train loss: 0.0017675923, validation loss: 0.1021716848
# Epoch 414: train loss: 0.0017721980, validation loss: 0.1040036161
# Epoch 415: train loss: 0.0017700538, validation loss: 0.1020713660
# Epoch 416: train loss: 0.0017733776, validation loss: 0.1032557046
# Epoch 417: train loss: 0.0017669783, validation loss: 0.1028177850
# Epoch 418: train loss: 0.0017648760, validation loss: 0.1041324984
# Epoch 419: train loss: 0.0017747860, validation loss: 0.1020739794
# Epoch 420: train loss: 0.0017680251, validation loss: 0.1039427316
# Epoch 421: train loss: 0.0017623659, validation loss: 0.1020756786
# Epoch 422: train loss: 0.0017463015, validation loss: 0.1036389156
# Epoch 423: train loss: 0.0017587778, validation loss: 0.1038251538
# Epoch 424: train loss: 0.0017567548, validation loss: 0.1043234753
# Epoch 425: train loss: 0.0017569447, validation loss: 0.1038513155
# Epoch 426: train loss: 0.0017497626, validation loss: 0.1054574638
# Epoch 427: train loss: 0.0017641987, validation loss: 0.1044605143
# Epoch 428: train loss: 0.0017516726, validation loss: 0.1052669760
# Epoch 429: train loss: 0.0017476957, validation loss: 0.1027633534
# Epoch 430: train loss: 0.0017570046, validation loss: 0.1039640263
# Epoch 431: train loss: 0.0017480715, validation loss: 0.1044885666
# Epoch 432: train loss: 0.0017410842, validation loss: 0.1023886809
# Epoch 433: train loss: 0.0017615273, validation loss: 0.1047644902
# Epoch 434: train loss: 0.0017400810, validation loss: 0.1043878074
# Epoch 435: train loss: 0.0017470951, validation loss: 0.1050876435
# Epoch 436: train loss: 0.0017510193, validation loss: 0.1031539079
# Epoch 437: train loss: 0.0017296549, validation loss: 0.1040652774
# Epoch 438: train loss: 0.0017360367, validation loss: 0.1060222416
# Epoch 439: train loss: 0.0017381942, validation loss: 0.1069727821
# Epoch 440: train loss: 0.0017323121, validation loss: 0.1036327690
# Epoch 441: train loss: 0.0017307648, validation loss: 0.1040330657
# Epoch 442: train loss: 0.0017391786, validation loss: 0.1055437482
# Epoch 443: train loss: 0.0017378750, validation loss: 0.1059626709
# Epoch 444: train loss: 0.0017318522, validation loss: 0.1031397809
# Epoch 445: train loss: 0.0017317825, validation loss: 0.1051920449
# Epoch 446: train loss: 0.0017262354, validation loss: 0.1035522065
# Epoch 447: train loss: 0.0017362643, validation loss: 0.1045308395
# Epoch 448: train loss: 0.0017270921, validation loss: 0.1054906889
# Epoch 449: train loss: 0.0017313260, validation loss: 0.1076671350
# Epoch 450: train loss: 0.0017221615, validation loss: 0.1058596405
# Epoch 451: train loss: 0.0017294668, validation loss: 0.1062099146
# Epoch 452: train loss: 0.0017210390, validation loss: 0.1049334125
# Epoch 453: train loss: 0.0017179579, validation loss: 0.1047209179
# Epoch 454: train loss: 0.0017248814, validation loss: 0.1049492463
# Epoch 455: train loss: 0.0017177950, validation loss: 0.1057376965
# Epoch 456: train loss: 0.0017171996, validation loss: 0.1059310155
# Epoch 457: train loss: 0.0017226932, validation loss: 0.1054207984
# Epoch 458: train loss: 0.0017238424, validation loss: 0.1041169996
# Epoch 459: train loss: 0.0017184960, validation loss: 0.1066544965
# Epoch 460: train loss: 0.0017189014, validation loss: 0.1069618503
# Epoch 461: train loss: 0.0017264824, validation loss: 0.1064930183
# Epoch 462: train loss: 0.0017080371, validation loss: 0.1068908823
# Epoch 463: train loss: 0.0017036712, validation loss: 0.1054971568
# Epoch 464: train loss: 0.0017170355, validation loss: 0.1038500066
# Epoch 465: train loss: 0.0017182356, validation loss: 0.1073661220
# Epoch 466: train loss: 0.0017134865, validation loss: 0.1050884234
# Epoch 467: train loss: 0.0016992860, validation loss: 0.1054711517
# Epoch 468: train loss: 0.0017134593, validation loss: 0.1057132083
# Epoch 469: train loss: 0.0017124213, validation loss: 0.1055643850
# Epoch 470: train loss: 0.0017012373, validation loss: 0.1068368003
# Epoch 471: train loss: 0.0017123495, validation loss: 0.1055762965
# Epoch 472: train loss: 0.0016950644, validation loss: 0.1062396833
# Epoch 473: train loss: 0.0017014979, validation loss: 0.1054532273
# Epoch 474: train loss: 0.0017016387, validation loss: 0.1063531718
# Epoch 475: train loss: 0.0017112520, validation loss: 0.1065290199
# Epoch 476: train loss: 0.0017041951, validation loss: 0.1062315227
# Epoch 477: train loss: 0.0017043025, validation loss: 0.1081690799
# Epoch 478: train loss: 0.0016999237, validation loss: 0.1055106311
# Epoch 479: train loss: 0.0017031866, validation loss: 0.1071328329
# Epoch 480: train loss: 0.0016943972, validation loss: 0.1069048369
# Epoch 481: train loss: 0.0016980504, validation loss: 0.1075571402
# Epoch 482: train loss: 0.0016903346, validation loss: 0.1058285749
# Epoch 483: train loss: 0.0017068460, validation loss: 0.1055349713
# Epoch 484: train loss: 0.0016878774, validation loss: 0.1073112702
# Epoch 485: train loss: 0.0016995859, validation loss: 0.1068796183
# Epoch 486: train loss: 0.0016997345, validation loss: 0.1073512265
# Epoch 487: train loss: 0.0016881940, validation loss: 0.1062380367
# Epoch 488: train loss: 0.0016929145, validation loss: 0.1064807683
# Epoch 489: train loss: 0.0016958761, validation loss: 0.1101686076
# Epoch 490: train loss: 0.0016899725, validation loss: 0.1067896926
# Epoch 491: train loss: 0.0016880109, validation loss: 0.1068010892
# Epoch 492: train loss: 0.0016873332, validation loss: 0.1077865979
# Epoch 493: train loss: 0.0016754478, validation loss: 0.1073121468
# Epoch 494: train loss: 0.0016938655, validation loss: 0.1076977516
# Epoch 495: train loss: 0.0016916265, validation loss: 0.1072088629
# Epoch 496: train loss: 0.0016938133, validation loss: 0.1086455055
# Epoch 497: train loss: 0.0016858447, validation loss: 0.1069785903
# Epoch 498: train loss: 0.0016758962, validation loss: 0.1081057933
# Epoch 499: train loss: 0.0016892129, validation loss: 0.1083783516
# Epoch 500: train loss: 0.0016872279, validation loss: 0.1082287574
# Finished training

# %%
epochs = np.arange(0, map_net_params['epochs'])
plt.figure(figsize=(15,8))
plt.plot(epochs, map_net.train_loss_hist, color='tab:orange', label='Training loss')
plt.plot(epochs, map_net.val_loss_hist, color='tab:blue', label='Validation loss')

plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale('log')
plt.savefig("convergence plot of map net for arch1[3,20,20,2]")
plt.show()

# %%
# import scipy.io

# #save net parameters
# scipy.io.savemat("map_in_weights.mat", {"map_in_weights": map_net.map_net_in.weight.detach().numpy()})
# scipy.io.savemat("map_in_bias.mat", {"map_in_bias": map_net.map_net_in.bias.detach().numpy()})

# scipy.io.savemat("map_hidden_weights_1.mat",
#                  {"map_hidden_weights_1": map_net.map_net_hid[0].weight.detach().numpy()})
# scipy.io.savemat("map_hidden_bias_1.mat",
#                  {"map_hidden_bias_1": map_net.map_net_hid[0].bias.detach().numpy()})

# scipy.io.savemat("map_hidden_weights_2.mat",
#                  {"map_hidden_weights_2": map_net.map_net_hid[1].weight.detach().numpy()})
# scipy.io.savemat("map_hidden_bias_2.mat",
#                  {"map_hidden_bias_2": map_net.map_net_hid[1].bias.detach().numpy()})

# scipy.io.savemat("map_hidden_weights_3.mat",
#                  {"map_hidden_weights_3": map_net.map_net_hid[2].weight.detach().numpy()})
# scipy.io.savemat("map_hidden_bias_3.mat",
#                  {"map_hidden_bias_3": map_net.map_net_hid[2].bias.detach().numpy()})

# scipy.io.savemat("map_out_weights.mat", {"map_out_weights": map_net.map_net_out.weight.detach().numpy()})
# scipy.io.savemat("map_out_bias.mat", {"map_out_bias": map_net.map_net_out.bias.detach().numpy()})

# %% [markdown]
# ## Test Data Parameters

# %%
# test data parameters
num_snaps_val = 1000 # no. of snapshots
T = np.linspace(0,num_snaps_val*dt, num_snaps_val+1)
num_traj_val = 1 # no. of training examples
first_obs_const = int(net_params['first_obs_const']) #only one state
override_C = net_params['override_C']
if override_C:
    n_obs = int(net_params['encoder_output_dim']) + num_states + first_obs_const 
else:
    n_obs = int(net_params['encoder_output_dim']) + first_obs_const

# %% [markdown]
# ***Koopman Bilinear Model***

# %%
A = np.array(model_koop_dnn.A)
#B = np.array(model_koop_dnn.B).reshape(-1,num_inputs*n_obs)
B = np.array(model_koop_dnn.B)
#B_tensor = np.empty((num_inputs,n_obs, n_obs))
#for ii, b in enumerate(B):
    #B_tensor[ii] = b
C = np.array(model_koop_dnn.C)

print(A.shape, B.shape, C.shape)
# Out:
# (45, 45) (45, 315) (14, 45)

# %%
# #SAVE MATRIX PARAMETERS AS MATLAB FILE
# import scipy.io

# dyn_matrices = {"A": A, "B": B, "C": C}
# scipy.io.savemat("dyn_mat.mat", dyn_matrices)
# #save encoder parameters
# scipy.io.savemat("in_weights.mat", {"encode_in_weights": model_koop_dnn.net.encoder_fc_in.weight.detach().numpy()})
# scipy.io.savemat("in_bias.mat", {"encode_in_bias": model_koop_dnn.net.encoder_fc_in.bias.detach().numpy()})

# scipy.io.savemat("hidden_weights_1.mat",
#                  {"encode_hidden_weights_1": model_koop_dnn.net.encoder_fc_hid[0].weight.detach().numpy()})
# scipy.io.savemat("hidden_bias_1.mat",
#                  {"encode_hidden_bias_1": model_koop_dnn.net.encoder_fc_hid[0].bias.detach().numpy()})

# scipy.io.savemat("hidden_weights_2.mat",
#                  {"encode_hidden_weights_2": model_koop_dnn.net.encoder_fc_hid[1].weight.detach().numpy()})
# scipy.io.savemat("hidden_bias_2.mat",
#                  {"encode_hidden_bias_2": model_koop_dnn.net.encoder_fc_hid[1].bias.detach().numpy()})

# scipy.io.savemat("out_weights.mat", {"encode_out_weights": model_koop_dnn.net.encoder_fc_out.weight.detach().numpy()})
# scipy.io.savemat("out_bias.mat", {"encode_out_bias": model_koop_dnn.net.encoder_fc_out.bias.detach().numpy()})

# %%
encode_out_bias = model_koop_dnn.net.encoder_fc_out.bias.detach().numpy()
encode_out_weights = model_koop_dnn.net.encoder_fc_out.weight.detach().numpy()

# %% [markdown]
# ***Test Data Generation***

# %%
# data_gen
j = 60
xs_end_test = X_end[j,:,:]
xs_test = X_full[j,:,:]
us_test = U_full[j,:,:]

# %%
print(model_koop_dnn.test_loss(xs_test.reshape(1,-1,14),u_test = us_test.reshape(1,-1,7)))
# Out:
# tensor(0.0384)

# %%
basis = model_koop_dnn.net.encode_forward_

# %%
X,_ = model_koop_dnn.net.process(xs_test.reshape(1,-1,14),data_u = us_test.reshape(1,-1,7))
print(X.shape)
# Out:
# (1000, 35)

# %%
x = X[:, :num_states]
u = X[:, num_states:num_states+num_inputs]
x_prime = X[:,num_states+num_inputs:]

print(x.shape, u.shape, x_prime.shape)
# Out:
# (1000, 14) (1000, 7) (1000, 14)

# %% [markdown]
# ***Initial Condition Lifting***

# %%
# initialize the matricies
z = np.empty((n_obs,num_snaps_val+1)).T
x_est = np.zeros((num_states,num_snaps_val+1)).T

# %%
z[0,:] = lift(x[0,:],model_koop_dnn, net_params)
x_est[0,:] = x[0,:]

# %% [markdown]
# ***Time Evolution***

# %%
for i in range(num_snaps_val):
  #bilinear
    z[i+1,:] = np.matmul(z[i,:],A.T)+np.matmul(np.kron(u[i,:],z[i,:]),B.T)
    x_est[i+1,:] = np.matmul(z[i+1,:],C.T)

# %% [markdown]
# ***Visualization***

# %% [markdown]
# # Joint Space

# %%
plt.figure()
plt.plot(T[:-1],x[:,0],label ='Actual')
plt.plot(T,x_est[:,0],label = 'estimated(bilinear)')
plt.xlabel('t')
plt.ylabel('theta_1')
plt.title('theta_1 Comparison')
plt.legend()

# %%
plt.figure()
plt.plot(T[:-1],x[:,1],label ='Actual')
plt.plot(T,x_est[:,1],label = 'estimated(bilinear)')
plt.title('Theta_2')
plt.xlabel('t')
plt.ylabel('Theta_2_comparison')
plt.legend()

# %%
plt.figure()
plt.plot(T[:-1],x[:,2],label ='Actual')
plt.plot(T,x_est[:,2],label = 'estimated(bilinear)')
plt.title('Theta_3')
plt.xlabel('t')
plt.ylabel('theta_3')
plt.legend()

# %%
plt.figure()
plt.plot(T[:-1],x[:,3],label ='Actual')
plt.plot(T,x_est[:,3],label = 'estimated(bilinear)')
plt.title('Theta_4')
plt.xlabel('t')
plt.ylabel('theta_4')
plt.legend()

# %%
plt.figure()
plt.plot(T[:-1],x[:,4],label ='Actual')
plt.plot(T,x_est[:,4],label = 'estimated(bilinear)')
plt.title('Theta_5')
plt.xlabel('t')
plt.ylabel('theta_5')
plt.legend()

# %%
plt.figure()
plt.plot(T[:-1],x[:,5],label ='Actual')
plt.plot(T,x_est[:,5],label = 'estimated(bilinear)')
plt.title('Theta_6')
plt.xlabel('t')
plt.ylabel('theta_6')
plt.legend()

# %%
plt.figure()
plt.plot(T[:-1],x[:,6],label ='Actual')
plt.plot(T,x_est[:,6],label = 'estimated(bilinear)')
plt.title('Theta_6')
plt.xlabel('t')
plt.ylabel('theta_6')
plt.legend()

# %%
plt.figure()
plt.plot(T[:-1],x[:,7],label ='Actual')
plt.plot(T,x_est[:,7],label = 'estimated(bilinear)')
plt.xlabel('t')
plt.ylabel('theta_1_dot')
plt.title('theta_1_dot Comparison')
plt.legend()

# %%
plt.figure()
plt.plot(T[:-1],x[:,8],label ='Actual')
plt.plot(T,x_est[:,8],label = 'estimated(bilinear)')
plt.title('Theta_2_dot')
plt.xlabel('t')
plt.ylabel('Theta_2_dot_comparison')
plt.legend()

# %%
plt.figure()
plt.plot(T[:-1],x[:,9],label ='Actual')
plt.plot(T,x_est[:,9],label = 'estimated(bilinear)')
plt.title('Theta_3_dot')
plt.xlabel('t')
plt.ylabel('theta_3_dot')
plt.legend()

# %%
plt.figure()
plt.plot(T[:-1],x[:,10],label ='Actual')
plt.plot(T,x_est[:,10],label = 'estimated(bilinear)')
plt.title('Theta_4_dot')
plt.xlabel('t')
plt.ylabel('theta_4_dot')
plt.legend()

# %%
plt.figure()
plt.plot(T[:-1],x[:,11],label ='Actual')
plt.plot(T,x_est[:,11],label = 'estimated(bilinear)')
plt.title('Theta_5_dot')
plt.xlabel('t')
plt.ylabel('theta_5_dot')
plt.legend()

# %%
plt.figure()
plt.plot(T[:-1],x[:,12],label ='Actual')
plt.plot(T,x_est[:,12],label = 'estimated(bilinear)')
plt.title('Theta_6_dot')
plt.xlabel('t')
plt.ylabel('theta_6_dot')
plt.legend()

# %%
plt.figure()
plt.plot(T[:-1],x[:,13],label ='Actual')
plt.plot(T,x_est[:,13],label = 'estimated(bilinear)')
plt.title('Theta_7_dot')
plt.xlabel('t')
plt.ylabel('theta_7_dot')
plt.legend()
