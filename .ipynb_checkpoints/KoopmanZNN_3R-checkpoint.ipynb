# %% [markdown]
# ***Import Libraries***

# %%
"""This program bilinearizes 3R planar dyanmics using koopman theory and autoencoder to map"""
import numpy as np
import matplotlib.pyplot as plt
import sklearn.preprocessing
import itertools

import torch

# bilinear Koopman
from core.koopman_core import KoopDNN, KoopmanNet, KoopmanNetCtrl
from models.koop_model import model_matricies,lift

# forward map neural net
from core.neural_fwd_map import map_Net

# 2R dynamics and kinetics
from dynamics.robot_3R import dynamics_3R_data_gen, dynamics_3R, forward_kinematics_3R, forward_map_3R, Jacobian_3R

## import paths
from paths.paths import path_pars

# %% [markdown]
# ***Simulation Parameters***

# %%
dt = 0.005 #time step
num_snaps = 1000 # no. of snapshots
T = np.linspace(0,num_snaps*dt, num_snaps+1)
num_train = 100 # no. of training examples
num_val = int(0.25*num_train) # no of testing examples
num_traj = num_train+num_val #no of trajectories
num_states = 6 # no. of states
num_inputs = 3 # no. of inputs

# %% [markdown]
# ***Robot Parameters***

# %%
robot_pars = {}
# link lengths
robot_pars['a1'] = 0.33
robot_pars['a2'] = 0.33
robot_pars['a3'] = 0.33

#link masses
robot_pars['m1'] = 0.1
robot_pars['m2'] = 0.1
robot_pars['m3'] = 0.1

# link inertias
robot_pars['I1'] = 1
robot_pars['I2'] = 1
robot_pars['I3'] = 1

#position of CM
robot_pars['l1'] = 0.33/2
robot_pars['l2'] = 0.33/2
robot_pars['l3'] = 0.33/2

#dynamic friction coefficient
robot_pars['fd'] = 0.1

# %% [markdown]
# ***Data Generation for 3R***

# %%
# Trajectories
X_end,X_full, U_full = dynamics_3R_data_gen(dt,num_traj, num_snaps,num_states,num_inputs,robot_pars)
print(X_end.shape, X_full.shape,U_full.shape)
# Out:
# (125, 1001, 2) (125, 1001, 6) (125, 1000, 3)

# %%
X_full.T.shape, X_full.dtype
# Out:
# ((6, 1001, 125), dtype('float64'))

# %% [markdown]
# ***Plotting the trajectories***

# %%
"""Training dataset visualization"""
#theta1 theta2 plot
plt.subplot(2,3,1)
plt.title("Trajectory Plot")
plt.xlabel("th1")
plt.ylabel("th2")
for i in range(num_traj):
  plt.plot(X_full[i,:,0],X_full[i,:,1])

#theta2 theta3 plot
plt.subplot(2,3,2)
plt.xlabel("th2")
plt.ylabel("th3")
for i in range(num_traj):
    plt.plot(X_full[i,:,1],X_full[i,:,2])

#theta1 theta3 plot
plt.subplot(2,3,3)
plt.xlabel("th1")
plt.ylabel("th3")
for i in range(num_traj):
    plt.plot(X_full[i,:,0],X_full[i,:,2])

#theta1_dot theta2_dot plot
plt.subplot(2,3,4)
plt.xlabel("th1_dot")
plt.ylabel("th2_dot")
for i in range(num_traj):
    plt.plot(X_full[i,:,3],X_full[i,:,4])

#theta2_dot theta3_dot plot
plt.subplot(2,3,5)
plt.xlabel("th2_dot")
plt.ylabel("th3_dot")
for i in range(num_traj):
    plt.plot(X_full[i,:,4],X_full[i,:,5])

#theta1_dot theta3_dot plot
plt.subplot(2,3,6)
plt.xlabel("th1_dot")
plt.ylabel("th3_dot")
for i in range(num_traj):
    plt.plot(X_full[i,:,3],X_full[i,:,5])

# %%
#x and y positions of the end effector

plt.xlabel("x")
plt.ylabel("y")
for i in range(num_traj):
    plt.plot(X_end[i,:,0],X_end[i,:,1])

# %% [markdown]
# ***Training and validation datasets***

# %%
# split training and vaidation datasets
xs_train, us_train = X_full[:num_train,:,:],U_full[:num_train,:,:]
xs_val, us_val = X_full[num_train:,:,:],U_full[num_train:,:,:]

# %%
# import scipy.io
# Data_set = {"x_end": X_end, "X_full": X_full}
# scipy.io.savemat("Data_set.mat",Data_set)

# %%
# import torch
# import torch.nn as nn
# import torch.nn.functional as F

# %% [markdown]
# ***Model Training***

# %%
net_params = {}
net_params['state_dim'] = num_states
net_params['ctrl_dim'] = num_inputs
net_params['encoder_hidden_width'] = 40
net_params['encoder_hidden_depth'] = 2
net_params['encoder_output_dim'] = 15
net_params['optimizer'] = 'adam'
net_params['activation_type'] = 'tanh'
net_params['lr'] = 4e-4 # 5e-4
net_params['epochs'] = 1000
net_params['batch_size'] = 128
net_params['lifted_loss_penalty'] = 0.4 
net_params['l2_reg'] = 0.0         
net_params['l1_reg'] = 0.0
net_params['first_obs_const'] = True
net_params['override_C'] = True # this makes the state a part of lifetd state
net_params['dt'] = dt

# %%
train = False

if train == True:
    file = 'saved_models/3R/koop_arch.pth'
    net = KoopmanNetCtrl(net_params)
    model_koop_dnn = KoopDNN(net)
    model_koop_dnn.set_datasets(xs_train, u_train=us_train, x_val=xs_val, u_val=us_val)
    model_koop_dnn.model_pipeline(net_params)
    model_koop_dnn.construct_koopman_model()
    torch.save(model_koop_dnn,file)
else:
    file = 'saved_models/3R/koop_arch.pth'
    model_koop_dnn = torch.load(file)

# %% [markdown]
# ***Learning Curves***

# %%
train_loss = [l[0] for l in model_koop_dnn.train_loss_hist]
train_pred_loss = [l[1] for l in model_koop_dnn.train_loss_hist]
train_lifted_loss = [l[2] for l in model_koop_dnn.train_loss_hist]
val_loss = [l[0] for l in model_koop_dnn.val_loss_hist]
val_pred_loss = [l[1] for l in model_koop_dnn.val_loss_hist]
val_lifted_loss = [l[2] for l in model_koop_dnn.val_loss_hist]
epochs = np.arange(0, net_params['epochs'])

plt.figure(figsize=(15,8))
plt.plot(epochs, train_loss, color='tab:orange', label='Training loss')
plt.plot(epochs, train_pred_loss, '--', color='tab:orange', label='Training prediction loss')
plt.plot(epochs, train_lifted_loss, ':', color='tab:orange', label='Training lifted loss')
plt.plot(epochs, val_loss, color='tab:blue', label='Validation loss')
plt.plot(epochs, val_pred_loss, '--', color='tab:blue', label='Validation prediction loss')
plt.plot(epochs, val_lifted_loss, ':', color='tab:blue', label='Validation lifted loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale('log')
plt.savefig("convergence plot for arch1")
plt.show()

# %%
map_net_params = {}
map_net_params["input_dim"] = 3 #number of joint angles
map_net_params["output_dim"] = 2 #x and y position of the end effector
map_net_params["hidden_width"] = 20
map_net_params["hidden_depth"] = 2
map_net_params["batch_size"] = 200
map_net_params["epochs"] = 1500
map_net_params["activation_type"] = 'tanh'
map_net_params["lr"] = 1e-3
map_net_params["optimizer"] = 'adam'
map_net_params['l2_reg'] = 0.0
map_net_params['l1_reg'] = 0.0

# %%
#dataset
# split training and vaidation datasets
xs_map_train, ys_map_train = X_full[:num_train,:,0:3],X_end[:num_train,:,:]
xs_map_val, ys_map_val = X_full[num_train:,:,0:3],X_end[num_train:,:,:]

# %%
#Initalize network
train = False

if train==True:
    file = "saved_models/map_net.pth"
    map_net = map_Net(map_net_params)
    map_net.set_dataset_map(xs_map_train,ys_map_train,xs_map_val,ys_map_val)
    map_net.data_pipeline()
    map_net.plot_loss()
    torch.save(map_net.state_dict(),file)
else:
    file = "saved_models/map_net.pth"
    map_net = map_Net(map_net_params)
    map_net.load_state_dict(torch.load(file))
# Out:
# Epoch   1: train loss: 0.0705779613, validation loss: 0.0414684347
# Epoch   2: train loss: 0.0136293740, validation loss: 0.0223047866
# Epoch   3: train loss: 0.0057702731, validation loss: 0.0192080085
# Epoch   4: train loss: 0.0034053401, validation loss: 0.0186326033
# Epoch   5: train loss: 0.0024499113, validation loss: 0.0173351412
# Epoch   6: train loss: 0.0018879426, validation loss: 0.0159017734
# Epoch   7: train loss: 0.0014872287, validation loss: 0.0145701719
# Epoch   8: train loss: 0.0012093464, validation loss: 0.0138286476
# Epoch   9: train loss: 0.0009939143, validation loss: 0.0126180139
# Epoch  10: train loss: 0.0008391075, validation loss: 0.0118772291
# Epoch  11: train loss: 0.0007116781, validation loss: 0.0111365204
# Epoch  12: train loss: 0.0006209440, validation loss: 0.0106123402
# Epoch  13: train loss: 0.0005414393, validation loss: 0.0101363614
# Epoch  14: train loss: 0.0004848832, validation loss: 0.0097332461
# Epoch  15: train loss: 0.0004367323, validation loss: 0.0090208319
# Epoch  16: train loss: 0.0003945394, validation loss: 0.0087348737
# Epoch  17: train loss: 0.0003626466, validation loss: 0.0086146252
# Epoch  18: train loss: 0.0003244258, validation loss: 0.0084062958
# Epoch  19: train loss: 0.0003020546, validation loss: 0.0082092130
# Epoch  20: train loss: 0.0002779375, validation loss: 0.0079982718
# Epoch  21: train loss: 0.0002594756, validation loss: 0.0079137738
# Epoch  22: train loss: 0.0002406349, validation loss: 0.0075606705
# Epoch  23: train loss: 0.0002214056, validation loss: 0.0074513755
# Epoch  24: train loss: 0.0002107994, validation loss: 0.0074145359
# Epoch  25: train loss: 0.0001996873, validation loss: 0.0069862313
# Epoch  26: train loss: 0.0001887370, validation loss: 0.0069370020
# Epoch  27: train loss: 0.0001762678, validation loss: 0.0071121484
# Epoch  28: train loss: 0.0001684053, validation loss: 0.0069740650
# Epoch  29: train loss: 0.0001608770, validation loss: 0.0066622021
# Epoch  30: train loss: 0.0001549682, validation loss: 0.0067492206
# Epoch  31: train loss: 0.0001504180, validation loss: 0.0064984229
# Epoch  32: train loss: 0.0001421484, validation loss: 0.0064714297
# Epoch  33: train loss: 0.0001389030, validation loss: 0.0063847992
# Epoch  34: train loss: 0.0001282905, validation loss: 0.0062687274
# Epoch  35: train loss: 0.0001257067, validation loss: 0.0062225455
# Epoch  36: train loss: 0.0001220869, validation loss: 0.0062896634
# Epoch  37: train loss: 0.0001159630, validation loss: 0.0060738644
# Epoch  38: train loss: 0.0001126097, validation loss: 0.0060859634
# Epoch  39: train loss: 0.0001086094, validation loss: 0.0061087358
# Epoch  40: train loss: 0.0001057472, validation loss: 0.0059454895
# Epoch  41: train loss: 0.0001034668, validation loss: 0.0059124012
# Epoch  42: train loss: 0.0000989364, validation loss: 0.0059062659
# Epoch  43: train loss: 0.0000942528, validation loss: 0.0058536225
# Epoch  44: train loss: 0.0000912012, validation loss: 0.0057808684
# Epoch  45: train loss: 0.0000922385, validation loss: 0.0058218104
# Epoch  46: train loss: 0.0000870027, validation loss: 0.0057928922
# Epoch  47: train loss: 0.0000830583, validation loss: 0.0057220992
# Epoch  48: train loss: 0.0000803236, validation loss: 0.0055666511
# Epoch  49: train loss: 0.0000783133, validation loss: 0.0055784489
# Epoch  50: train loss: 0.0000768577, validation loss: 0.0055763771
# Epoch  51: train loss: 0.0000749310, validation loss: 0.0054694287
# Epoch  52: train loss: 0.0000732359, validation loss: 0.0055117422
# Epoch  53: train loss: 0.0000699266, validation loss: 0.0055273530
# Epoch  54: train loss: 0.0000696273, validation loss: 0.0052397070
# Epoch  55: train loss: 0.0000649167, validation loss: 0.0053937055
# Epoch  56: train loss: 0.0000650857, validation loss: 0.0053592446
# Epoch  57: train loss: 0.0000633008, validation loss: 0.0053264159
# Epoch  58: train loss: 0.0000617093, validation loss: 0.0052613807
# Epoch  59: train loss: 0.0000586603, validation loss: 0.0052266765
# Epoch  60: train loss: 0.0000583089, validation loss: 0.0052335175
# Epoch  61: train loss: 0.0000570009, validation loss: 0.0052354320
# Epoch  62: train loss: 0.0000566107, validation loss: 0.0052934552
# Epoch  63: train loss: 0.0000541121, validation loss: 0.0051783640
# Epoch  64: train loss: 0.0000518451, validation loss: 0.0051622188
# Epoch  65: train loss: 0.0000521665, validation loss: 0.0053728090
# Epoch  66: train loss: 0.0000513627, validation loss: 0.0051474450
# Epoch  67: train loss: 0.0000503651, validation loss: 0.0050540816
# Epoch  68: train loss: 0.0000467224, validation loss: 0.0050445168
# Epoch  69: train loss: 0.0000472169, validation loss: 0.0050794804
# Epoch  70: train loss: 0.0000455262, validation loss: 0.0050884251
# Epoch  71: train loss: 0.0000462189, validation loss: 0.0049959131
# Epoch  72: train loss: 0.0000443127, validation loss: 0.0049486813
# Epoch  73: train loss: 0.0000440834, validation loss: 0.0050095740
# Epoch  74: train loss: 0.0000415293, validation loss: 0.0049143397
# Epoch  75: train loss: 0.0000416485, validation loss: 0.0049694356
# Epoch  76: train loss: 0.0000396899, validation loss: 0.0049330186
# Epoch  77: train loss: 0.0000404531, validation loss: 0.0048908631
# Epoch  78: train loss: 0.0000386407, validation loss: 0.0047950353
# Epoch  79: train loss: 0.0000383750, validation loss: 0.0047810124
# Epoch  80: train loss: 0.0000378991, validation loss: 0.0048460038
# Epoch  81: train loss: 0.0000376758, validation loss: 0.0048190759
# Epoch  82: train loss: 0.0000358403, validation loss: 0.0047594130
# Epoch  83: train loss: 0.0000361678, validation loss: 0.0047353623
# Epoch  84: train loss: 0.0000358193, validation loss: 0.0046713794
# Epoch  85: train loss: 0.0000345003, validation loss: 0.0046911893
# Epoch  86: train loss: 0.0000337739, validation loss: 0.0047161498
# Epoch  87: train loss: 0.0000315311, validation loss: 0.0046325309
# Epoch  88: train loss: 0.0000330508, validation loss: 0.0045913748
# Epoch  89: train loss: 0.0000329712, validation loss: 0.0045830782
# Epoch  90: train loss: 0.0000323249, validation loss: 0.0044966506
# Epoch  91: train loss: 0.0000311949, validation loss: 0.0046704833
# Epoch  92: train loss: 0.0000316535, validation loss: 0.0045017597
# Epoch  93: train loss: 0.0000294553, validation loss: 0.0044513229
# Epoch  94: train loss: 0.0000309813, validation loss: 0.0044494843
# Epoch  95: train loss: 0.0000293486, validation loss: 0.0044594296
# Epoch  96: train loss: 0.0000293004, validation loss: 0.0043539296
# Epoch  97: train loss: 0.0000281163, validation loss: 0.0044144120
# Epoch  98: train loss: 0.0000269010, validation loss: 0.0043303603
# Epoch  99: train loss: 0.0000279850, validation loss: 0.0043569594
# Epoch 100: train loss: 0.0000270337, validation loss: 0.0043228174
# Epoch 101: train loss: 0.0000275584, validation loss: 0.0042513890
# Epoch 102: train loss: 0.0000272396, validation loss: 0.0043199584
# Epoch 103: train loss: 0.0000262899, validation loss: 0.0043335997
# Epoch 104: train loss: 0.0000260221, validation loss: 0.0042476922
# Epoch 105: train loss: 0.0000244946, validation loss: 0.0042471679
# Epoch 106: train loss: 0.0000256553, validation loss: 0.0041791253
# Epoch 107: train loss: 0.0000251634, validation loss: 0.0041783531
# Epoch 108: train loss: 0.0000244721, validation loss: 0.0041573727
# Epoch 109: train loss: 0.0000243684, validation loss: 0.0041406817
# Epoch 110: train loss: 0.0000255775, validation loss: 0.0042257525
# Epoch 111: train loss: 0.0000235051, validation loss: 0.0040567456
# Epoch 112: train loss: 0.0000237057, validation loss: 0.0040216619
# Epoch 113: train loss: 0.0000236138, validation loss: 0.0040441830
# Epoch 114: train loss: 0.0000226077, validation loss: 0.0040492508
# Epoch 115: train loss: 0.0000229841, validation loss: 0.0040518365
# Epoch 116: train loss: 0.0000232364, validation loss: 0.0040475424
# Epoch 117: train loss: 0.0000232155, validation loss: 0.0040839305
# Epoch 118: train loss: 0.0000221199, validation loss: 0.0039657246
# Epoch 119: train loss: 0.0000226373, validation loss: 0.0039081176
# Epoch 120: train loss: 0.0000220662, validation loss: 0.0039253817
# Epoch 121: train loss: 0.0000216824, validation loss: 0.0039206790
# Epoch 122: train loss: 0.0000213627, validation loss: 0.0038331271
# Epoch 123: train loss: 0.0000215597, validation loss: 0.0038230152
# Epoch 124: train loss: 0.0000214672, validation loss: 0.0038010628
# Epoch 125: train loss: 0.0000209857, validation loss: 0.0037823387
# Epoch 126: train loss: 0.0000207588, validation loss: 0.0037813031
# Epoch 127: train loss: 0.0000204321, validation loss: 0.0037688744
# Epoch 128: train loss: 0.0000204852, validation loss: 0.0037848200
# Epoch 129: train loss: 0.0000194732, validation loss: 0.0038540040
# Epoch 130: train loss: 0.0000200649, validation loss: 0.0037650739
# Epoch 131: train loss: 0.0000201082, validation loss: 0.0037623748
# Epoch 132: train loss: 0.0000188620, validation loss: 0.0036593616
# Epoch 133: train loss: 0.0000205762, validation loss: 0.0036952450
# Epoch 134: train loss: 0.0000194999, validation loss: 0.0037878638
# Epoch 135: train loss: 0.0000187000, validation loss: 0.0036932872
# Epoch 136: train loss: 0.0000189109, validation loss: 0.0036257652
# Epoch 137: train loss: 0.0000196214, validation loss: 0.0036326932
# Epoch 138: train loss: 0.0000188407, validation loss: 0.0038047159
# Epoch 139: train loss: 0.0000185358, validation loss: 0.0036020567
# Epoch 140: train loss: 0.0000197667, validation loss: 0.0036311198
# Epoch 141: train loss: 0.0000180029, validation loss: 0.0036293374
# Epoch 142: train loss: 0.0000186643, validation loss: 0.0035963009
# Epoch 143: train loss: 0.0000188544, validation loss: 0.0035986646
# Epoch 144: train loss: 0.0000180842, validation loss: 0.0036558888
# Epoch 145: train loss: 0.0000182138, validation loss: 0.0035515785
# Epoch 146: train loss: 0.0000173076, validation loss: 0.0035529495
# Epoch 147: train loss: 0.0000168364, validation loss: 0.0035311289
# Epoch 148: train loss: 0.0000182321, validation loss: 0.0035680155
# Epoch 149: train loss: 0.0000178050, validation loss: 0.0035041484
# Epoch 150: train loss: 0.0000172529, validation loss: 0.0034187925
# Epoch 151: train loss: 0.0000162684, validation loss: 0.0034630687
# Epoch 152: train loss: 0.0000179029, validation loss: 0.0034233192
# Epoch 153: train loss: 0.0000175345, validation loss: 0.0035326854
# Epoch 154: train loss: 0.0000168767, validation loss: 0.0033855772
# Epoch 155: train loss: 0.0000158830, validation loss: 0.0034714424
# Epoch 156: train loss: 0.0000170889, validation loss: 0.0034173299
# Epoch 157: train loss: 0.0000165155, validation loss: 0.0034012818
# Epoch 158: train loss: 0.0000181380, validation loss: 0.0033182133
# Epoch 159: train loss: 0.0000157753, validation loss: 0.0034100287
# Epoch 160: train loss: 0.0000158887, validation loss: 0.0034151703
# Epoch 161: train loss: 0.0000161150, validation loss: 0.0033074000
# Epoch 162: train loss: 0.0000172595, validation loss: 0.0032776170
# Epoch 163: train loss: 0.0000154865, validation loss: 0.0033343047
# Epoch 164: train loss: 0.0000166951, validation loss: 0.0033291097
# Epoch 165: train loss: 0.0000148457, validation loss: 0.0033098806
# Epoch 166: train loss: 0.0000159074, validation loss: 0.0033210998
# Epoch 167: train loss: 0.0000150046, validation loss: 0.0032925165
# Epoch 168: train loss: 0.0000160070, validation loss: 0.0032604211
# Epoch 169: train loss: 0.0000154906, validation loss: 0.0032639604
# Epoch 170: train loss: 0.0000146195, validation loss: 0.0032631564
# Epoch 171: train loss: 0.0000156117, validation loss: 0.0032696951
# Epoch 172: train loss: 0.0000154336, validation loss: 0.0031597728
# Epoch 173: train loss: 0.0000157137, validation loss: 0.0031917223
# Epoch 174: train loss: 0.0000142290, validation loss: 0.0031582358
# Epoch 175: train loss: 0.0000147582, validation loss: 0.0032154475
# Epoch 176: train loss: 0.0000145955, validation loss: 0.0031246969
# Epoch 177: train loss: 0.0000154353, validation loss: 0.0031195781
# Epoch 178: train loss: 0.0000141129, validation loss: 0.0031623356
# Epoch 179: train loss: 0.0000155214, validation loss: 0.0031595724
# Epoch 180: train loss: 0.0000146601, validation loss: 0.0030718748
# Epoch 181: train loss: 0.0000140463, validation loss: 0.0031291906
# Epoch 182: train loss: 0.0000146221, validation loss: 0.0031924409
# Epoch 183: train loss: 0.0000140286, validation loss: 0.0031179104
# Epoch 184: train loss: 0.0000141097, validation loss: 0.0030981569
# Epoch 185: train loss: 0.0000142666, validation loss: 0.0030209923
# Epoch 186: train loss: 0.0000138325, validation loss: 0.0030240371
# Epoch 187: train loss: 0.0000143686, validation loss: 0.0030199808
# Epoch 188: train loss: 0.0000146933, validation loss: 0.0030715866
# Epoch 189: train loss: 0.0000135889, validation loss: 0.0031104998
# Epoch 190: train loss: 0.0000131697, validation loss: 0.0030299087
# Epoch 191: train loss: 0.0000144933, validation loss: 0.0030720779
# Epoch 192: train loss: 0.0000135257, validation loss: 0.0031084287
# Epoch 193: train loss: 0.0000142547, validation loss: 0.0030255552
# Epoch 194: train loss: 0.0000132482, validation loss: 0.0029575592
# Epoch 195: train loss: 0.0000129064, validation loss: 0.0029505752
# Epoch 196: train loss: 0.0000139184, validation loss: 0.0029936900
# Epoch 197: train loss: 0.0000129472, validation loss: 0.0029576836
# Epoch 198: train loss: 0.0000139372, validation loss: 0.0030212645
# Epoch 199: train loss: 0.0000128878, validation loss: 0.0029005460
# Epoch 200: train loss: 0.0000140409, validation loss: 0.0028922771
# Epoch 201: train loss: 0.0000127373, validation loss: 0.0030033712
# Epoch 202: train loss: 0.0000131349, validation loss: 0.0030315170
# Epoch 203: train loss: 0.0000135390, validation loss: 0.0029592246
# Epoch 204: train loss: 0.0000135785, validation loss: 0.0029394177
# Epoch 205: train loss: 0.0000126571, validation loss: 0.0029080415
# Epoch 206: train loss: 0.0000126647, validation loss: 0.0028830012
# Epoch 207: train loss: 0.0000130700, validation loss: 0.0029269793
# Epoch 208: train loss: 0.0000127106, validation loss: 0.0029363014
# Epoch 209: train loss: 0.0000126626, validation loss: 0.0028437032
# Epoch 210: train loss: 0.0000129104, validation loss: 0.0028380808
# Epoch 211: train loss: 0.0000133161, validation loss: 0.0028196781
# Epoch 212: train loss: 0.0000120646, validation loss: 0.0028314283
# Epoch 213: train loss: 0.0000127076, validation loss: 0.0028216802
# Epoch 214: train loss: 0.0000123082, validation loss: 0.0028466844
# Epoch 215: train loss: 0.0000126658, validation loss: 0.0028792072
# Epoch 216: train loss: 0.0000128131, validation loss: 0.0027745330
# Epoch 217: train loss: 0.0000129503, validation loss: 0.0028171746
# Epoch 218: train loss: 0.0000127177, validation loss: 0.0027724620
# Epoch 219: train loss: 0.0000122690, validation loss: 0.0027613281
# Epoch 220: train loss: 0.0000119801, validation loss: 0.0028341780
# Epoch 221: train loss: 0.0000122453, validation loss: 0.0027682640
# Epoch 222: train loss: 0.0000125947, validation loss: 0.0028153855
# Epoch 223: train loss: 0.0000123563, validation loss: 0.0027985361
# Epoch 224: train loss: 0.0000120851, validation loss: 0.0027175422
# Epoch 225: train loss: 0.0000117101, validation loss: 0.0027685987
# Epoch 226: train loss: 0.0000129118, validation loss: 0.0026776350
# Epoch 227: train loss: 0.0000126069, validation loss: 0.0027620140
# Epoch 228: train loss: 0.0000117039, validation loss: 0.0027072887
# Epoch 229: train loss: 0.0000116598, validation loss: 0.0027225604
# Epoch 230: train loss: 0.0000120448, validation loss: 0.0027240846
# Epoch 231: train loss: 0.0000120639, validation loss: 0.0026336109
# Epoch 232: train loss: 0.0000123947, validation loss: 0.0026677057
# Epoch 233: train loss: 0.0000125007, validation loss: 0.0027306720
# Epoch 234: train loss: 0.0000115322, validation loss: 0.0026689830
# Epoch 235: train loss: 0.0000109907, validation loss: 0.0026377353
# Epoch 236: train loss: 0.0000119966, validation loss: 0.0026854576
# Epoch 237: train loss: 0.0000116043, validation loss: 0.0026304665
# Epoch 238: train loss: 0.0000115716, validation loss: 0.0026347600
# Epoch 239: train loss: 0.0000115871, validation loss: 0.0026522831
# Epoch 240: train loss: 0.0000108638, validation loss: 0.0026946160
# Epoch 241: train loss: 0.0000118494, validation loss: 0.0025495335
# Epoch 242: train loss: 0.0000113601, validation loss: 0.0025933568
# Epoch 243: train loss: 0.0000112433, validation loss: 0.0026229306
# Epoch 244: train loss: 0.0000111311, validation loss: 0.0026021758
# Epoch 245: train loss: 0.0000120162, validation loss: 0.0025588999
# Epoch 246: train loss: 0.0000113162, validation loss: 0.0025835182
# Epoch 247: train loss: 0.0000114569, validation loss: 0.0026392339
# Epoch 248: train loss: 0.0000116230, validation loss: 0.0026240625
# Epoch 249: train loss: 0.0000109769, validation loss: 0.0025556089
# Epoch 250: train loss: 0.0000112135, validation loss: 0.0025317002
# Epoch 251: train loss: 0.0000107786, validation loss: 0.0025505224
# Epoch 252: train loss: 0.0000110503, validation loss: 0.0025421475
# Epoch 253: train loss: 0.0000112893, validation loss: 0.0025882851
# Epoch 254: train loss: 0.0000117544, validation loss: 0.0025588504
# Epoch 255: train loss: 0.0000108669, validation loss: 0.0024878652
# Epoch 256: train loss: 0.0000104583, validation loss: 0.0025694600
# Epoch 257: train loss: 0.0000111343, validation loss: 0.0025509137
# Epoch 258: train loss: 0.0000104585, validation loss: 0.0025382913
# Epoch 259: train loss: 0.0000115152, validation loss: 0.0025366506
# Epoch 260: train loss: 0.0000107090, validation loss: 0.0025153640
# Epoch 261: train loss: 0.0000113378, validation loss: 0.0025543992
# Epoch 262: train loss: 0.0000099155, validation loss: 0.0025870834
# Epoch 263: train loss: 0.0000118081, validation loss: 0.0024959309
# Epoch 264: train loss: 0.0000109398, validation loss: 0.0025051496
# Epoch 265: train loss: 0.0000104282, validation loss: 0.0024498820
# Epoch 266: train loss: 0.0000108614, validation loss: 0.0024752830
# Epoch 267: train loss: 0.0000108266, validation loss: 0.0025030926
# Epoch 268: train loss: 0.0000109339, validation loss: 0.0024919683
# Epoch 269: train loss: 0.0000106356, validation loss: 0.0024848530
# Epoch 270: train loss: 0.0000104445, validation loss: 0.0024840592
# Epoch 271: train loss: 0.0000104083, validation loss: 0.0025214392
# Epoch 272: train loss: 0.0000107337, validation loss: 0.0024665864
# Epoch 273: train loss: 0.0000106654, validation loss: 0.0024569397
# Epoch 274: train loss: 0.0000106102, validation loss: 0.0024793741
# Epoch 275: train loss: 0.0000107258, validation loss: 0.0024663437
# Epoch 276: train loss: 0.0000103847, validation loss: 0.0024475510
# Epoch 277: train loss: 0.0000110222, validation loss: 0.0024362341
# Epoch 278: train loss: 0.0000102166, validation loss: 0.0024394039
# Epoch 279: train loss: 0.0000111335, validation loss: 0.0024193094
# Epoch 280: train loss: 0.0000104206, validation loss: 0.0024148487
# Epoch 281: train loss: 0.0000104298, validation loss: 0.0024670641
# Epoch 282: train loss: 0.0000096520, validation loss: 0.0024366439
# Epoch 283: train loss: 0.0000096644, validation loss: 0.0023898570
# Epoch 284: train loss: 0.0000111355, validation loss: 0.0023829976
# Epoch 285: train loss: 0.0000102586, validation loss: 0.0023521089
# Epoch 286: train loss: 0.0000097269, validation loss: 0.0023793446
# Epoch 287: train loss: 0.0000108153, validation loss: 0.0024190314
# Epoch 288: train loss: 0.0000098691, validation loss: 0.0023715393
# Epoch 289: train loss: 0.0000104568, validation loss: 0.0023509192
# Epoch 290: train loss: 0.0000098535, validation loss: 0.0023435821
# Epoch 291: train loss: 0.0000100092, validation loss: 0.0022960357
# Epoch 292: train loss: 0.0000104520, validation loss: 0.0023633012
# Epoch 293: train loss: 0.0000097410, validation loss: 0.0024141344
# Epoch 294: train loss: 0.0000107148, validation loss: 0.0023765443
# Epoch 295: train loss: 0.0000101726, validation loss: 0.0022876819
# Epoch 296: train loss: 0.0000098358, validation loss: 0.0023052450
# Epoch 297: train loss: 0.0000101484, validation loss: 0.0022957338
# Epoch 298: train loss: 0.0000098619, validation loss: 0.0023029187
# Epoch 299: train loss: 0.0000106933, validation loss: 0.0023426253
# Epoch 300: train loss: 0.0000098058, validation loss: 0.0023226318
# Epoch 301: train loss: 0.0000097892, validation loss: 0.0023209202
# Epoch 302: train loss: 0.0000099630, validation loss: 0.0022319530
# Epoch 303: train loss: 0.0000102057, validation loss: 0.0022965447
# Epoch 304: train loss: 0.0000108401, validation loss: 0.0023334769
# Epoch 305: train loss: 0.0000094976, validation loss: 0.0022978797
# Epoch 306: train loss: 0.0000094646, validation loss: 0.0022201677
# Epoch 307: train loss: 0.0000096513, validation loss: 0.0022827435
# Epoch 308: train loss: 0.0000100619, validation loss: 0.0022419387
# Epoch 309: train loss: 0.0000094206, validation loss: 0.0023101702
# Epoch 310: train loss: 0.0000103190, validation loss: 0.0022425981
# Epoch 311: train loss: 0.0000092335, validation loss: 0.0022485841
# Epoch 312: train loss: 0.0000102817, validation loss: 0.0022897682
# Epoch 313: train loss: 0.0000095699, validation loss: 0.0022419915
# Epoch 314: train loss: 0.0000093458, validation loss: 0.0022727186
# Epoch 315: train loss: 0.0000091959, validation loss: 0.0022108570
# Epoch 316: train loss: 0.0000097343, validation loss: 0.0022822904
# Epoch 317: train loss: 0.0000096229, validation loss: 0.0022048256
# Epoch 318: train loss: 0.0000103797, validation loss: 0.0022277076
# Epoch 319: train loss: 0.0000110405, validation loss: 0.0022566538
# Epoch 320: train loss: 0.0000091212, validation loss: 0.0022459754
# Epoch 321: train loss: 0.0000092440, validation loss: 0.0022298877
# Epoch 322: train loss: 0.0000095412, validation loss: 0.0022320966
# Epoch 323: train loss: 0.0000096591, validation loss: 0.0022401176
# Epoch 324: train loss: 0.0000095381, validation loss: 0.0021940707
# Epoch 325: train loss: 0.0000085787, validation loss: 0.0022029977
# Epoch 326: train loss: 0.0000101707, validation loss: 0.0022035461
# Epoch 327: train loss: 0.0000098379, validation loss: 0.0021795481
# Epoch 328: train loss: 0.0000095546, validation loss: 0.0021842931
# Epoch 329: train loss: 0.0000098335, validation loss: 0.0022042734
# Epoch 330: train loss: 0.0000091911, validation loss: 0.0021659811
# Epoch 331: train loss: 0.0000091015, validation loss: 0.0021794223
# Epoch 332: train loss: 0.0000091685, validation loss: 0.0022046472
# Epoch 333: train loss: 0.0000092427, validation loss: 0.0021319896
# Epoch 334: train loss: 0.0000092807, validation loss: 0.0021387470
# Epoch 335: train loss: 0.0000096255, validation loss: 0.0022258564
# Epoch 336: train loss: 0.0000089054, validation loss: 0.0021808670
# Epoch 337: train loss: 0.0000093767, validation loss: 0.0021089942
# Epoch 338: train loss: 0.0000091521, validation loss: 0.0021718895
# Epoch 339: train loss: 0.0000093127, validation loss: 0.0021945666
# Epoch 340: train loss: 0.0000090940, validation loss: 0.0021584938
# Epoch 341: train loss: 0.0000093565, validation loss: 0.0020840726
# Epoch 342: train loss: 0.0000092448, validation loss: 0.0021681725
# Epoch 343: train loss: 0.0000086807, validation loss: 0.0021292828
# Epoch 344: train loss: 0.0000083278, validation loss: 0.0021103395
# Epoch 345: train loss: 0.0000092560, validation loss: 0.0021551069
# Epoch 346: train loss: 0.0000091175, validation loss: 0.0021436063
# Epoch 347: train loss: 0.0000087310, validation loss: 0.0021152617
# Epoch 348: train loss: 0.0000096029, validation loss: 0.0021079856
# Epoch 349: train loss: 0.0000084204, validation loss: 0.0021003083
# Epoch 350: train loss: 0.0000097345, validation loss: 0.0021091070
# Epoch 351: train loss: 0.0000086257, validation loss: 0.0021016063
# Epoch 352: train loss: 0.0000096514, validation loss: 0.0021573998
# Epoch 353: train loss: 0.0000087793, validation loss: 0.0021069989
# Epoch 354: train loss: 0.0000089265, validation loss: 0.0020914507
# Epoch 355: train loss: 0.0000086331, validation loss: 0.0021005346
# Epoch 356: train loss: 0.0000087310, validation loss: 0.0021042469
# Epoch 357: train loss: 0.0000093815, validation loss: 0.0021016195
# Epoch 358: train loss: 0.0000094786, validation loss: 0.0021538644
# Epoch 359: train loss: 0.0000081341, validation loss: 0.0020768207
# Epoch 360: train loss: 0.0000094989, validation loss: 0.0020849914
# Epoch 361: train loss: 0.0000083072, validation loss: 0.0020515308
# Epoch 362: train loss: 0.0000101326, validation loss: 0.0020873498
# Epoch 363: train loss: 0.0000089098, validation loss: 0.0020450816
# Epoch 364: train loss: 0.0000078390, validation loss: 0.0020698201
# Epoch 365: train loss: 0.0000096978, validation loss: 0.0020335868
# Epoch 366: train loss: 0.0000080959, validation loss: 0.0020728045
# Epoch 367: train loss: 0.0000092731, validation loss: 0.0020623362
# Epoch 368: train loss: 0.0000087173, validation loss: 0.0020471739
# Epoch 369: train loss: 0.0000088169, validation loss: 0.0020668154
# Epoch 370: train loss: 0.0000087551, validation loss: 0.0020845374
# Epoch 371: train loss: 0.0000083794, validation loss: 0.0020521391
# Epoch 372: train loss: 0.0000087137, validation loss: 0.0020380686
# Epoch 373: train loss: 0.0000103137, validation loss: 0.0020778128
# Epoch 374: train loss: 0.0000077063, validation loss: 0.0020710386
# Epoch 375: train loss: 0.0000096689, validation loss: 0.0020954159
# Epoch 376: train loss: 0.0000079495, validation loss: 0.0020004601
# Epoch 377: train loss: 0.0000079260, validation loss: 0.0019700446
# Epoch 378: train loss: 0.0000091928, validation loss: 0.0020458418
# Epoch 379: train loss: 0.0000085533, validation loss: 0.0019983418
# Epoch 380: train loss: 0.0000088298, validation loss: 0.0020413752
# Epoch 381: train loss: 0.0000085858, validation loss: 0.0019879048
# Epoch 382: train loss: 0.0000084888, validation loss: 0.0019658643
# Epoch 383: train loss: 0.0000082591, validation loss: 0.0020647911
# Epoch 384: train loss: 0.0000086217, validation loss: 0.0020172278
# Epoch 385: train loss: 0.0000082014, validation loss: 0.0019887442
# Epoch 386: train loss: 0.0000084279, validation loss: 0.0019884612
# Epoch 387: train loss: 0.0000084907, validation loss: 0.0020273375
# Epoch 388: train loss: 0.0000084460, validation loss: 0.0019913897
# Epoch 389: train loss: 0.0000087972, validation loss: 0.0020101801
# Epoch 390: train loss: 0.0000087254, validation loss: 0.0019509318
# Epoch 391: train loss: 0.0000084643, validation loss: 0.0019512334
# Epoch 392: train loss: 0.0000083089, validation loss: 0.0019751497
# Epoch 393: train loss: 0.0000087280, validation loss: 0.0019540372
# Epoch 394: train loss: 0.0000081814, validation loss: 0.0019646243
# Epoch 395: train loss: 0.0000083467, validation loss: 0.0019710658
# Epoch 396: train loss: 0.0000076609, validation loss: 0.0019547186
# Epoch 397: train loss: 0.0000094691, validation loss: 0.0020336354
# Epoch 398: train loss: 0.0000085456, validation loss: 0.0019720111
# Epoch 399: train loss: 0.0000083368, validation loss: 0.0019529913
# Epoch 400: train loss: 0.0000080616, validation loss: 0.0019670122
# Epoch 401: train loss: 0.0000076469, validation loss: 0.0019379327
# Epoch 402: train loss: 0.0000084837, validation loss: 0.0019854633
# Epoch 403: train loss: 0.0000078738, validation loss: 0.0019638783
# Epoch 404: train loss: 0.0000084282, validation loss: 0.0019244280
# Epoch 405: train loss: 0.0000080713, validation loss: 0.0019273197
# Epoch 406: train loss: 0.0000083580, validation loss: 0.0019544230
# Epoch 407: train loss: 0.0000085184, validation loss: 0.0019261550
# Epoch 408: train loss: 0.0000081908, validation loss: 0.0019112588
# Epoch 409: train loss: 0.0000080695, validation loss: 0.0019676586
# Epoch 410: train loss: 0.0000085594, validation loss: 0.0019391275
# Epoch 411: train loss: 0.0000082105, validation loss: 0.0019368629
# Epoch 412: train loss: 0.0000080572, validation loss: 0.0019566101
# Epoch 413: train loss: 0.0000082120, validation loss: 0.0018970013
# Epoch 414: train loss: 0.0000084064, validation loss: 0.0020202195
# Epoch 415: train loss: 0.0000081705, validation loss: 0.0019032361
# Epoch 416: train loss: 0.0000079483, validation loss: 0.0019351799
# Epoch 417: train loss: 0.0000077454, validation loss: 0.0019387483
# Epoch 418: train loss: 0.0000085776, validation loss: 0.0018993103
# Epoch 419: train loss: 0.0000081021, validation loss: 0.0018633333
# Epoch 420: train loss: 0.0000077206, validation loss: 0.0018979129
# Epoch 421: train loss: 0.0000090207, validation loss: 0.0019196716
# Epoch 422: train loss: 0.0000079737, validation loss: 0.0019120106
# Epoch 423: train loss: 0.0000076403, validation loss: 0.0019094447
# Epoch 424: train loss: 0.0000079295, validation loss: 0.0019112418
# Epoch 425: train loss: 0.0000078883, validation loss: 0.0018865233
# Epoch 426: train loss: 0.0000084267, validation loss: 0.0018958664
# Epoch 427: train loss: 0.0000075252, validation loss: 0.0018362953
# Epoch 428: train loss: 0.0000088584, validation loss: 0.0019656021
# Epoch 429: train loss: 0.0000084061, validation loss: 0.0018649938
# Epoch 430: train loss: 0.0000076275, validation loss: 0.0018461426
# Epoch 431: train loss: 0.0000074721, validation loss: 0.0018722666
# Epoch 432: train loss: 0.0000082009, validation loss: 0.0018718229
# Epoch 433: train loss: 0.0000077562, validation loss: 0.0018430273
# Epoch 434: train loss: 0.0000082423, validation loss: 0.0018854049
# Epoch 435: train loss: 0.0000082549, validation loss: 0.0018223927
# Epoch 436: train loss: 0.0000076153, validation loss: 0.0018493209
# Epoch 437: train loss: 0.0000085598, validation loss: 0.0018869174
# Epoch 438: train loss: 0.0000075277, validation loss: 0.0019058148
# Epoch 439: train loss: 0.0000076813, validation loss: 0.0019051239
# Epoch 440: train loss: 0.0000080345, validation loss: 0.0018419921
# Epoch 441: train loss: 0.0000074823, validation loss: 0.0018708305
# Epoch 442: train loss: 0.0000086584, validation loss: 0.0018530963
# Epoch 443: train loss: 0.0000075995, validation loss: 0.0018553461
# Epoch 444: train loss: 0.0000084286, validation loss: 0.0018238036
# Epoch 445: train loss: 0.0000076298, validation loss: 0.0018293450
# Epoch 446: train loss: 0.0000081942, validation loss: 0.0018110054
# Epoch 447: train loss: 0.0000070928, validation loss: 0.0018047451
# Epoch 448: train loss: 0.0000077568, validation loss: 0.0018393432
# Epoch 449: train loss: 0.0000081837, validation loss: 0.0018312229
# Epoch 450: train loss: 0.0000075338, validation loss: 0.0017787712
# Epoch 451: train loss: 0.0000077868, validation loss: 0.0018247816
# Epoch 452: train loss: 0.0000084402, validation loss: 0.0018332579
# Epoch 453: train loss: 0.0000076019, validation loss: 0.0017967335
# Epoch 454: train loss: 0.0000076475, validation loss: 0.0018413284
# Epoch 455: train loss: 0.0000075739, validation loss: 0.0018168203
# Epoch 456: train loss: 0.0000080834, validation loss: 0.0018129809
# Epoch 457: train loss: 0.0000069270, validation loss: 0.0017494314
# Epoch 458: train loss: 0.0000080706, validation loss: 0.0018002801
# Epoch 459: train loss: 0.0000082832, validation loss: 0.0017796458
# Epoch 460: train loss: 0.0000080681, validation loss: 0.0017864419
# Epoch 461: train loss: 0.0000075282, validation loss: 0.0017728904
# Epoch 462: train loss: 0.0000079591, validation loss: 0.0017740962
# Epoch 463: train loss: 0.0000076261, validation loss: 0.0017821242
# Epoch 464: train loss: 0.0000078604, validation loss: 0.0017995019
# Epoch 465: train loss: 0.0000072950, validation loss: 0.0018080462
# Epoch 466: train loss: 0.0000070429, validation loss: 0.0018052431
# Epoch 467: train loss: 0.0000082051, validation loss: 0.0017660110
# Epoch 468: train loss: 0.0000080364, validation loss: 0.0017566687
# Epoch 469: train loss: 0.0000074448, validation loss: 0.0017709923
# Epoch 470: train loss: 0.0000079798, validation loss: 0.0017794300
# Epoch 471: train loss: 0.0000075474, validation loss: 0.0017381705
# Epoch 472: train loss: 0.0000076476, validation loss: 0.0017774322
# Epoch 473: train loss: 0.0000072171, validation loss: 0.0017874767
# Epoch 474: train loss: 0.0000078029, validation loss: 0.0017624599
# Epoch 475: train loss: 0.0000079490, validation loss: 0.0017750585
# Epoch 476: train loss: 0.0000073360, validation loss: 0.0017032508
# Epoch 477: train loss: 0.0000073888, validation loss: 0.0017460340
# Epoch 478: train loss: 0.0000072485, validation loss: 0.0017481224
# Epoch 479: train loss: 0.0000074424, validation loss: 0.0017461296
# Epoch 480: train loss: 0.0000072946, validation loss: 0.0017467581
# Epoch 481: train loss: 0.0000078637, validation loss: 0.0017778510
# Epoch 482: train loss: 0.0000077069, validation loss: 0.0017619531
# Epoch 483: train loss: 0.0000070974, validation loss: 0.0017227664
# Epoch 484: train loss: 0.0000073833, validation loss: 0.0017518402
# Epoch 485: train loss: 0.0000078662, validation loss: 0.0017567885
# Epoch 486: train loss: 0.0000078022, validation loss: 0.0017417207
# Epoch 487: train loss: 0.0000074784, validation loss: 0.0017368820
# Epoch 488: train loss: 0.0000068607, validation loss: 0.0017036916
# Epoch 489: train loss: 0.0000078376, validation loss: 0.0017170363
# Epoch 490: train loss: 0.0000069457, validation loss: 0.0017789367
# Epoch 491: train loss: 0.0000074061, validation loss: 0.0016628568
# Epoch 492: train loss: 0.0000075301, validation loss: 0.0017388448
# Epoch 493: train loss: 0.0000072563, validation loss: 0.0016971172
# Epoch 494: train loss: 0.0000075745, validation loss: 0.0016815897
# Epoch 495: train loss: 0.0000073309, validation loss: 0.0017108519
# Epoch 496: train loss: 0.0000069933, validation loss: 0.0017423783
# Epoch 497: train loss: 0.0000074703, validation loss: 0.0016820814
# Epoch 498: train loss: 0.0000073600, validation loss: 0.0017078466
# Epoch 499: train loss: 0.0000070752, validation loss: 0.0016794177
# Epoch 500: train loss: 0.0000070882, validation loss: 0.0016910265
# Epoch 501: train loss: 0.0000069670, validation loss: 0.0016806077
# Epoch 502: train loss: 0.0000080955, validation loss: 0.0016804837
# Epoch 503: train loss: 0.0000066549, validation loss: 0.0017106888
# Epoch 504: train loss: 0.0000075269, validation loss: 0.0017349373
# Epoch 505: train loss: 0.0000073094, validation loss: 0.0017167670
# Epoch 506: train loss: 0.0000069062, validation loss: 0.0016826705
# Epoch 507: train loss: 0.0000066119, validation loss: 0.0016890624
# Epoch 508: train loss: 0.0000076999, validation loss: 0.0017114757
# Epoch 509: train loss: 0.0000070792, validation loss: 0.0016843496
# Epoch 510: train loss: 0.0000070169, validation loss: 0.0016812269
# Epoch 511: train loss: 0.0000081792, validation loss: 0.0017375221
# Epoch 512: train loss: 0.0000070267, validation loss: 0.0016691466
# Epoch 513: train loss: 0.0000075370, validation loss: 0.0016905459
# Epoch 514: train loss: 0.0000073953, validation loss: 0.0016366411
# Epoch 515: train loss: 0.0000070169, validation loss: 0.0016553491
# Epoch 516: train loss: 0.0000075262, validation loss: 0.0016986792
# Epoch 517: train loss: 0.0000072038, validation loss: 0.0016913500
# Epoch 518: train loss: 0.0000070943, validation loss: 0.0016570522
# Epoch 519: train loss: 0.0000071844, validation loss: 0.0016439035
# Epoch 520: train loss: 0.0000073198, validation loss: 0.0016683787
# Epoch 521: train loss: 0.0000071950, validation loss: 0.0016416853
# Epoch 522: train loss: 0.0000074891, validation loss: 0.0016562922
# Epoch 523: train loss: 0.0000072437, validation loss: 0.0016126265
# Epoch 524: train loss: 0.0000069877, validation loss: 0.0016688142
# Epoch 525: train loss: 0.0000069764, validation loss: 0.0016733891
# Epoch 526: train loss: 0.0000076564, validation loss: 0.0016821157
# Epoch 527: train loss: 0.0000071649, validation loss: 0.0016959536
# Epoch 528: train loss: 0.0000074801, validation loss: 0.0016534597
# Epoch 529: train loss: 0.0000073979, validation loss: 0.0015966693
# Epoch 530: train loss: 0.0000068014, validation loss: 0.0016463090
# Epoch 531: train loss: 0.0000069671, validation loss: 0.0016984962
# Epoch 532: train loss: 0.0000087563, validation loss: 0.0016370076
# Epoch 533: train loss: 0.0000064768, validation loss: 0.0016401737
# Epoch 534: train loss: 0.0000068571, validation loss: 0.0016145283
# Epoch 535: train loss: 0.0000066094, validation loss: 0.0016492116
# Epoch 536: train loss: 0.0000071963, validation loss: 0.0016764847
# Epoch 537: train loss: 0.0000074860, validation loss: 0.0016225201
# Epoch 538: train loss: 0.0000070646, validation loss: 0.0016386249
# Epoch 539: train loss: 0.0000068453, validation loss: 0.0016455888
# Epoch 540: train loss: 0.0000072060, validation loss: 0.0015984770
# Epoch 541: train loss: 0.0000070769, validation loss: 0.0016475432
# Epoch 542: train loss: 0.0000070702, validation loss: 0.0016096629
# Epoch 543: train loss: 0.0000070626, validation loss: 0.0016035299
# Epoch 544: train loss: 0.0000068778, validation loss: 0.0016108034
# Epoch 545: train loss: 0.0000070289, validation loss: 0.0016150503
# Epoch 546: train loss: 0.0000064349, validation loss: 0.0015984745
# Epoch 547: train loss: 0.0000078169, validation loss: 0.0015714322
# Epoch 548: train loss: 0.0000071838, validation loss: 0.0016255446
# Epoch 549: train loss: 0.0000070857, validation loss: 0.0015802158
# Epoch 550: train loss: 0.0000065448, validation loss: 0.0016509883
# Epoch 551: train loss: 0.0000074137, validation loss: 0.0016227289
# Epoch 552: train loss: 0.0000067695, validation loss: 0.0016036990
# Epoch 553: train loss: 0.0000066951, validation loss: 0.0016137445
# Epoch 554: train loss: 0.0000074112, validation loss: 0.0016045789
# Epoch 555: train loss: 0.0000074358, validation loss: 0.0016155612
# Epoch 556: train loss: 0.0000059569, validation loss: 0.0016065084
# Epoch 557: train loss: 0.0000076149, validation loss: 0.0016373915
# Epoch 558: train loss: 0.0000062961, validation loss: 0.0016071400
# Epoch 559: train loss: 0.0000068473, validation loss: 0.0015965246
# Epoch 560: train loss: 0.0000071868, validation loss: 0.0015419325
# Epoch 561: train loss: 0.0000079882, validation loss: 0.0015689352
# Epoch 562: train loss: 0.0000068150, validation loss: 0.0015305507
# Epoch 563: train loss: 0.0000072577, validation loss: 0.0016767559
# Epoch 564: train loss: 0.0000064578, validation loss: 0.0015603724
# Epoch 565: train loss: 0.0000068443, validation loss: 0.0015948149
# Epoch 566: train loss: 0.0000072093, validation loss: 0.0016041037
# Epoch 567: train loss: 0.0000067695, validation loss: 0.0015880028
# Epoch 568: train loss: 0.0000075827, validation loss: 0.0015645950
# Epoch 569: train loss: 0.0000069377, validation loss: 0.0015722534
# Epoch 570: train loss: 0.0000066270, validation loss: 0.0015485735
# Epoch 571: train loss: 0.0000067232, validation loss: 0.0016104233
# Epoch 572: train loss: 0.0000066907, validation loss: 0.0015468674
# Epoch 573: train loss: 0.0000082129, validation loss: 0.0015772161
# Epoch 574: train loss: 0.0000064666, validation loss: 0.0015486700
# Epoch 575: train loss: 0.0000066863, validation loss: 0.0015380921
# Epoch 576: train loss: 0.0000071486, validation loss: 0.0015999016
# Epoch 577: train loss: 0.0000061401, validation loss: 0.0015434363
# Epoch 578: train loss: 0.0000073632, validation loss: 0.0015952177
# Epoch 579: train loss: 0.0000065618, validation loss: 0.0016005695
# Epoch 580: train loss: 0.0000066519, validation loss: 0.0015339414
# Epoch 581: train loss: 0.0000066866, validation loss: 0.0015624009
# Epoch 582: train loss: 0.0000069946, validation loss: 0.0015944313
# Epoch 583: train loss: 0.0000069187, validation loss: 0.0015331942
# Epoch 584: train loss: 0.0000065027, validation loss: 0.0015485672
# Epoch 585: train loss: 0.0000074534, validation loss: 0.0015425394
# Epoch 586: train loss: 0.0000065575, validation loss: 0.0016356060
# Epoch 587: train loss: 0.0000069082, validation loss: 0.0015556482
# Epoch 588: train loss: 0.0000065771, validation loss: 0.0015082897
# Epoch 589: train loss: 0.0000065330, validation loss: 0.0015764591
# Epoch 590: train loss: 0.0000068585, validation loss: 0.0015357180
# Epoch 591: train loss: 0.0000062973, validation loss: 0.0015834989
# Epoch 592: train loss: 0.0000066122, validation loss: 0.0015481825
# Epoch 593: train loss: 0.0000077779, validation loss: 0.0015591816
# Epoch 594: train loss: 0.0000069244, validation loss: 0.0015279267
# Epoch 595: train loss: 0.0000064830, validation loss: 0.0015463036
# Epoch 596: train loss: 0.0000071885, validation loss: 0.0015344950
# Epoch 597: train loss: 0.0000068936, validation loss: 0.0014773483
# Epoch 598: train loss: 0.0000059010, validation loss: 0.0015732685
# Epoch 599: train loss: 0.0000078600, validation loss: 0.0015519500
# Epoch 600: train loss: 0.0000064633, validation loss: 0.0015111653
# Epoch 601: train loss: 0.0000067046, validation loss: 0.0015144936
# Epoch 602: train loss: 0.0000067407, validation loss: 0.0015216662
# Epoch 603: train loss: 0.0000063600, validation loss: 0.0015418836
# Epoch 604: train loss: 0.0000067306, validation loss: 0.0015333187
# Epoch 605: train loss: 0.0000069982, validation loss: 0.0015105030
# Epoch 606: train loss: 0.0000066378, validation loss: 0.0015580628
# Epoch 607: train loss: 0.0000063347, validation loss: 0.0014851121
# Epoch 608: train loss: 0.0000065554, validation loss: 0.0015261436
# Epoch 609: train loss: 0.0000069228, validation loss: 0.0015128627
# Epoch 610: train loss: 0.0000062987, validation loss: 0.0015192317
# Epoch 611: train loss: 0.0000072107, validation loss: 0.0015182799
# Epoch 612: train loss: 0.0000061718, validation loss: 0.0014835204
# Epoch 613: train loss: 0.0000068571, validation loss: 0.0014979236
# Epoch 614: train loss: 0.0000063697, validation loss: 0.0015350546
# Epoch 615: train loss: 0.0000073419, validation loss: 0.0015007126
# Epoch 616: train loss: 0.0000060995, validation loss: 0.0015107308
# Epoch 617: train loss: 0.0000064898, validation loss: 0.0015117121
# Epoch 618: train loss: 0.0000074305, validation loss: 0.0015080900
# Epoch 619: train loss: 0.0000061540, validation loss: 0.0015047592
# Epoch 620: train loss: 0.0000064752, validation loss: 0.0015161605
# Epoch 621: train loss: 0.0000064376, validation loss: 0.0014962253
# Epoch 622: train loss: 0.0000071496, validation loss: 0.0014860360
# Epoch 623: train loss: 0.0000068571, validation loss: 0.0015417399
# Epoch 624: train loss: 0.0000062037, validation loss: 0.0015541838
# Epoch 625: train loss: 0.0000068479, validation loss: 0.0014744476
# Epoch 626: train loss: 0.0000066810, validation loss: 0.0014698685
# Epoch 627: train loss: 0.0000062372, validation loss: 0.0015072578
# Epoch 628: train loss: 0.0000074729, validation loss: 0.0014711541
# Epoch 629: train loss: 0.0000064600, validation loss: 0.0014449862
# Epoch 630: train loss: 0.0000062063, validation loss: 0.0014788109
# Epoch 631: train loss: 0.0000079065, validation loss: 0.0014919904
# Epoch 632: train loss: 0.0000059169, validation loss: 0.0014650633
# Epoch 633: train loss: 0.0000063746, validation loss: 0.0014537433
# Epoch 634: train loss: 0.0000068557, validation loss: 0.0014775279
# Epoch 635: train loss: 0.0000057530, validation loss: 0.0015258999
# Epoch 636: train loss: 0.0000070124, validation loss: 0.0014758319
# Epoch 637: train loss: 0.0000058875, validation loss: 0.0014985399
# Epoch 638: train loss: 0.0000066845, validation loss: 0.0015003452
# Epoch 639: train loss: 0.0000068359, validation loss: 0.0014830951
# Epoch 640: train loss: 0.0000061355, validation loss: 0.0014879593
# Epoch 641: train loss: 0.0000068985, validation loss: 0.0015317089
# Epoch 642: train loss: 0.0000059657, validation loss: 0.0014874995
# Epoch 643: train loss: 0.0000075986, validation loss: 0.0014800853
# Epoch 644: train loss: 0.0000058546, validation loss: 0.0014760040
# Epoch 645: train loss: 0.0000070680, validation loss: 0.0014491640
# Epoch 646: train loss: 0.0000060308, validation loss: 0.0014597570
# Epoch 647: train loss: 0.0000067440, validation loss: 0.0014388946
# Epoch 648: train loss: 0.0000071304, validation loss: 0.0014680826
# Epoch 649: train loss: 0.0000059130, validation loss: 0.0014481038
# Epoch 650: train loss: 0.0000068932, validation loss: 0.0014644158
# Epoch 651: train loss: 0.0000061593, validation loss: 0.0014631450
# Epoch 652: train loss: 0.0000064987, validation loss: 0.0014614607
# Epoch 653: train loss: 0.0000063166, validation loss: 0.0014500230
# Epoch 654: train loss: 0.0000059979, validation loss: 0.0014710774
# Epoch 655: train loss: 0.0000068650, validation loss: 0.0014492350
# Epoch 656: train loss: 0.0000069177, validation loss: 0.0014557159
# Epoch 657: train loss: 0.0000059490, validation loss: 0.0014445034
# Epoch 658: train loss: 0.0000068157, validation loss: 0.0014941461
# Epoch 659: train loss: 0.0000064676, validation loss: 0.0014332551
# Epoch 660: train loss: 0.0000061185, validation loss: 0.0014214432
# Epoch 661: train loss: 0.0000068994, validation loss: 0.0014965649
# Epoch 662: train loss: 0.0000054681, validation loss: 0.0014778934
# Epoch 663: train loss: 0.0000068556, validation loss: 0.0014541133
# Epoch 664: train loss: 0.0000059612, validation loss: 0.0014525121
# Epoch 665: train loss: 0.0000070330, validation loss: 0.0014500332
# Epoch 666: train loss: 0.0000062649, validation loss: 0.0014422720
# Epoch 667: train loss: 0.0000062116, validation loss: 0.0014202436
# Epoch 668: train loss: 0.0000056920, validation loss: 0.0014445476
# Epoch 669: train loss: 0.0000072902, validation loss: 0.0014608672
# Epoch 670: train loss: 0.0000060369, validation loss: 0.0014735831
# Epoch 671: train loss: 0.0000068365, validation loss: 0.0014423263
# Epoch 672: train loss: 0.0000057807, validation loss: 0.0014657346
# Epoch 673: train loss: 0.0000066126, validation loss: 0.0014413156
# Epoch 674: train loss: 0.0000068486, validation loss: 0.0014344849
# Epoch 675: train loss: 0.0000060531, validation loss: 0.0014433822
# Epoch 676: train loss: 0.0000060718, validation loss: 0.0014555767
# Epoch 677: train loss: 0.0000073211, validation loss: 0.0014413369
# Epoch 678: train loss: 0.0000059394, validation loss: 0.0014139350
# Epoch 679: train loss: 0.0000058790, validation loss: 0.0014046776
# Epoch 680: train loss: 0.0000069789, validation loss: 0.0014402901
# Epoch 681: train loss: 0.0000062039, validation loss: 0.0014183347
# Epoch 682: train loss: 0.0000063635, validation loss: 0.0014388943
# Epoch 683: train loss: 0.0000061128, validation loss: 0.0014394757
# Epoch 684: train loss: 0.0000062486, validation loss: 0.0014337334
# Epoch 685: train loss: 0.0000062506, validation loss: 0.0014420853
# Epoch 686: train loss: 0.0000068452, validation loss: 0.0014277851
# Epoch 687: train loss: 0.0000062478, validation loss: 0.0014338275
# Epoch 688: train loss: 0.0000065916, validation loss: 0.0014119120
# Epoch 689: train loss: 0.0000065131, validation loss: 0.0014072103
# Epoch 690: train loss: 0.0000061984, validation loss: 0.0013969926
# Epoch 691: train loss: 0.0000057971, validation loss: 0.0014224063
# Epoch 692: train loss: 0.0000060337, validation loss: 0.0014176648
# Epoch 693: train loss: 0.0000061936, validation loss: 0.0014114822
# Epoch 694: train loss: 0.0000063488, validation loss: 0.0014351635
# Epoch 695: train loss: 0.0000064176, validation loss: 0.0014047295
# Epoch 696: train loss: 0.0000058102, validation loss: 0.0014003309
# Epoch 697: train loss: 0.0000061963, validation loss: 0.0014204632
# Epoch 698: train loss: 0.0000062907, validation loss: 0.0014333864
# Epoch 699: train loss: 0.0000064475, validation loss: 0.0014101771
# Epoch 700: train loss: 0.0000062037, validation loss: 0.0014229488
# Epoch 701: train loss: 0.0000057549, validation loss: 0.0014110616
# Epoch 702: train loss: 0.0000073357, validation loss: 0.0014024297
# Epoch 703: train loss: 0.0000056551, validation loss: 0.0014214421
# Epoch 704: train loss: 0.0000063579, validation loss: 0.0014051257
# Epoch 705: train loss: 0.0000071047, validation loss: 0.0014031930
# Epoch 706: train loss: 0.0000057734, validation loss: 0.0014106535
# Epoch 707: train loss: 0.0000058857, validation loss: 0.0013946362
# Epoch 708: train loss: 0.0000060086, validation loss: 0.0014109461
# Epoch 709: train loss: 0.0000067826, validation loss: 0.0014305329
# Epoch 710: train loss: 0.0000061562, validation loss: 0.0014016536
# Epoch 711: train loss: 0.0000058131, validation loss: 0.0014013521
# Epoch 712: train loss: 0.0000059794, validation loss: 0.0014357607
# Epoch 713: train loss: 0.0000066730, validation loss: 0.0014117481
# Epoch 714: train loss: 0.0000058923, validation loss: 0.0013896781
# Epoch 715: train loss: 0.0000061433, validation loss: 0.0013860656
# Epoch 716: train loss: 0.0000064512, validation loss: 0.0013756990
# ...
# Epoch 1279: train loss: 0.0000045983, validation loss: 0.0011672695
# Epoch 1280: train loss: 0.0000044632, validation loss: 0.0011577285
# Epoch 1281: train loss: 0.0000056223, validation loss: 0.0011758609
# Epoch 1282: train loss: 0.0000043926, validation loss: 0.0011672334
# Epoch 1283: train loss: 0.0000045672, validation loss: 0.0011815357
# Epoch 1284: train loss: 0.0000054508, validation loss: 0.0011499496
# Epoch 1285: train loss: 0.0000042189, validation loss: 0.0011512080
# Epoch 1286: train loss: 0.0000047190, validation loss: 0.0011681670
# Epoch 1287: train loss: 0.0000047771, validation loss: 0.0011956134
# Epoch 1288: train loss: 0.0000048150, validation loss: 0.0011279077
# Epoch 1289: train loss: 0.0000051679, validation loss: 0.0011606269
# Epoch 1290: train loss: 0.0000043720, validation loss: 0.0011691274
# Epoch 1291: train loss: 0.0000051939, validation loss: 0.0011663066
# Epoch 1292: train loss: 0.0000050026, validation loss: 0.0011471918
# Epoch 1293: train loss: 0.0000044764, validation loss: 0.0011451534
# Epoch 1294: train loss: 0.0000043756, validation loss: 0.0011485714
# Epoch 1295: train loss: 0.0000052651, validation loss: 0.0011635573
# Epoch 1296: train loss: 0.0000044471, validation loss: 0.0011431596
# Epoch 1297: train loss: 0.0000045676, validation loss: 0.0011647439
# Epoch 1298: train loss: 0.0000048442, validation loss: 0.0011764924
# Epoch 1299: train loss: 0.0000049752, validation loss: 0.0011791053
# Epoch 1300: train loss: 0.0000051528, validation loss: 0.0011785327
# Epoch 1301: train loss: 0.0000043836, validation loss: 0.0011498121
# Epoch 1302: train loss: 0.0000045717, validation loss: 0.0011200189
# Epoch 1303: train loss: 0.0000049006, validation loss: 0.0011549366
# Epoch 1304: train loss: 0.0000047597, validation loss: 0.0011583764
# Epoch 1305: train loss: 0.0000044847, validation loss: 0.0011562501
# Epoch 1306: train loss: 0.0000048660, validation loss: 0.0011564950
# Epoch 1307: train loss: 0.0000046976, validation loss: 0.0011379173
# Epoch 1308: train loss: 0.0000050027, validation loss: 0.0011602417
# Epoch 1309: train loss: 0.0000043701, validation loss: 0.0011645442
# Epoch 1310: train loss: 0.0000044160, validation loss: 0.0011649892
# Epoch 1311: train loss: 0.0000050272, validation loss: 0.0011514232
# Epoch 1312: train loss: 0.0000046385, validation loss: 0.0011646931
# Epoch 1313: train loss: 0.0000046421, validation loss: 0.0011620685
# Epoch 1314: train loss: 0.0000046545, validation loss: 0.0011424384
# Epoch 1315: train loss: 0.0000052614, validation loss: 0.0011863883
# Epoch 1316: train loss: 0.0000043754, validation loss: 0.0011573438
# Epoch 1317: train loss: 0.0000044471, validation loss: 0.0011531887
# Epoch 1318: train loss: 0.0000048712, validation loss: 0.0011848641
# Epoch 1319: train loss: 0.0000047567, validation loss: 0.0011411916
# Epoch 1320: train loss: 0.0000045150, validation loss: 0.0011931056
# Epoch 1321: train loss: 0.0000046811, validation loss: 0.0011775333
# Epoch 1322: train loss: 0.0000047321, validation loss: 0.0011586278
# Epoch 1323: train loss: 0.0000046214, validation loss: 0.0011261098
# Epoch 1324: train loss: 0.0000045414, validation loss: 0.0011577960
# Epoch 1325: train loss: 0.0000051066, validation loss: 0.0011744387
# Epoch 1326: train loss: 0.0000046419, validation loss: 0.0011356790
# Epoch 1327: train loss: 0.0000047916, validation loss: 0.0011500323
# Epoch 1328: train loss: 0.0000052589, validation loss: 0.0011543606
# Epoch 1329: train loss: 0.0000043177, validation loss: 0.0011332282
# Epoch 1330: train loss: 0.0000056837, validation loss: 0.0011729707
# Epoch 1331: train loss: 0.0000038852, validation loss: 0.0011565152
# Epoch 1332: train loss: 0.0000046371, validation loss: 0.0011715635
# Epoch 1333: train loss: 0.0000049187, validation loss: 0.0011644041
# Epoch 1334: train loss: 0.0000049156, validation loss: 0.0011527076
# Epoch 1335: train loss: 0.0000047110, validation loss: 0.0011660705
# Epoch 1336: train loss: 0.0000046065, validation loss: 0.0011674353
# Epoch 1337: train loss: 0.0000045952, validation loss: 0.0011652006
# Epoch 1338: train loss: 0.0000047740, validation loss: 0.0011581198
# Epoch 1339: train loss: 0.0000039543, validation loss: 0.0011498096
# Epoch 1340: train loss: 0.0000050672, validation loss: 0.0011640550
# Epoch 1341: train loss: 0.0000046032, validation loss: 0.0011321349
# Epoch 1342: train loss: 0.0000045658, validation loss: 0.0011663732
# Epoch 1343: train loss: 0.0000049638, validation loss: 0.0011557977
# Epoch 1344: train loss: 0.0000043705, validation loss: 0.0011540192
# Epoch 1345: train loss: 0.0000049276, validation loss: 0.0011632516
# Epoch 1346: train loss: 0.0000044305, validation loss: 0.0011550085
# Epoch 1347: train loss: 0.0000048894, validation loss: 0.0011372952
# Epoch 1348: train loss: 0.0000045741, validation loss: 0.0011490386
# Epoch 1349: train loss: 0.0000045713, validation loss: 0.0011646981
# Epoch 1350: train loss: 0.0000049995, validation loss: 0.0011460730
# Epoch 1351: train loss: 0.0000045601, validation loss: 0.0011638307
# Epoch 1352: train loss: 0.0000047851, validation loss: 0.0011556456
# Epoch 1353: train loss: 0.0000044188, validation loss: 0.0011414022
# Epoch 1354: train loss: 0.0000044052, validation loss: 0.0011593273
# Epoch 1355: train loss: 0.0000046422, validation loss: 0.0011544813
# Epoch 1356: train loss: 0.0000048640, validation loss: 0.0011461261
# Epoch 1357: train loss: 0.0000046576, validation loss: 0.0011304784
# Epoch 1358: train loss: 0.0000043293, validation loss: 0.0011284397
# Epoch 1359: train loss: 0.0000049079, validation loss: 0.0011500992
# Epoch 1360: train loss: 0.0000041870, validation loss: 0.0011434481
# Epoch 1361: train loss: 0.0000054473, validation loss: 0.0011486714
# Epoch 1362: train loss: 0.0000045314, validation loss: 0.0011713836
# Epoch 1363: train loss: 0.0000044361, validation loss: 0.0011585692
# Epoch 1364: train loss: 0.0000044160, validation loss: 0.0011792496
# Epoch 1365: train loss: 0.0000046289, validation loss: 0.0011541533
# Epoch 1366: train loss: 0.0000046585, validation loss: 0.0011586472
# Epoch 1367: train loss: 0.0000044143, validation loss: 0.0011588704
# Epoch 1368: train loss: 0.0000048564, validation loss: 0.0011573840
# Epoch 1369: train loss: 0.0000042020, validation loss: 0.0011607465
# Epoch 1370: train loss: 0.0000046619, validation loss: 0.0011560362
# Epoch 1371: train loss: 0.0000049877, validation loss: 0.0011437043
# Epoch 1372: train loss: 0.0000054946, validation loss: 0.0011994830
# Epoch 1373: train loss: 0.0000045657, validation loss: 0.0011560617
# Epoch 1374: train loss: 0.0000040006, validation loss: 0.0011472246
# Epoch 1375: train loss: 0.0000047448, validation loss: 0.0011580348
# Epoch 1376: train loss: 0.0000051418, validation loss: 0.0011506078
# Epoch 1377: train loss: 0.0000047048, validation loss: 0.0011533866
# Epoch 1378: train loss: 0.0000045301, validation loss: 0.0011626709
# Epoch 1379: train loss: 0.0000043284, validation loss: 0.0011599012
# Epoch 1380: train loss: 0.0000046226, validation loss: 0.0011430571
# Epoch 1381: train loss: 0.0000043700, validation loss: 0.0011610055
# Epoch 1382: train loss: 0.0000054717, validation loss: 0.0011480319
# Epoch 1383: train loss: 0.0000043879, validation loss: 0.0011669790
# Epoch 1384: train loss: 0.0000042284, validation loss: 0.0011399049
# Epoch 1385: train loss: 0.0000047681, validation loss: 0.0011502923
# Epoch 1386: train loss: 0.0000046703, validation loss: 0.0011600198
# Epoch 1387: train loss: 0.0000042050, validation loss: 0.0011473660
# Epoch 1388: train loss: 0.0000047227, validation loss: 0.0011317173
# Epoch 1389: train loss: 0.0000043039, validation loss: 0.0011419781
# Epoch 1390: train loss: 0.0000044394, validation loss: 0.0011444336
# Epoch 1391: train loss: 0.0000050566, validation loss: 0.0011704750
# Epoch 1392: train loss: 0.0000042029, validation loss: 0.0011699508
# Epoch 1393: train loss: 0.0000047799, validation loss: 0.0011691433
# Epoch 1394: train loss: 0.0000045094, validation loss: 0.0011621914
# Epoch 1395: train loss: 0.0000044495, validation loss: 0.0011513187
# Epoch 1396: train loss: 0.0000047986, validation loss: 0.0011315128
# Epoch 1397: train loss: 0.0000047374, validation loss: 0.0011551563
# Epoch 1398: train loss: 0.0000044027, validation loss: 0.0011439391
# Epoch 1399: train loss: 0.0000044576, validation loss: 0.0011434795
# Epoch 1400: train loss: 0.0000047527, validation loss: 0.0011693217
# Epoch 1401: train loss: 0.0000045958, validation loss: 0.0011411397
# Epoch 1402: train loss: 0.0000041810, validation loss: 0.0011569675
# Epoch 1403: train loss: 0.0000047302, validation loss: 0.0011346603
# Epoch 1404: train loss: 0.0000042719, validation loss: 0.0011449969
# Epoch 1405: train loss: 0.0000044593, validation loss: 0.0011868734
# Epoch 1406: train loss: 0.0000049903, validation loss: 0.0011314796
# Epoch 1407: train loss: 0.0000044329, validation loss: 0.0011581401
# Epoch 1408: train loss: 0.0000046478, validation loss: 0.0011430123
# Epoch 1409: train loss: 0.0000045402, validation loss: 0.0011440805
# Epoch 1410: train loss: 0.0000046756, validation loss: 0.0011438073
# Epoch 1411: train loss: 0.0000042945, validation loss: 0.0011647552
# Epoch 1412: train loss: 0.0000044231, validation loss: 0.0011511666
# Epoch 1413: train loss: 0.0000047857, validation loss: 0.0011559415
# Epoch 1414: train loss: 0.0000045470, validation loss: 0.0011492044
# Epoch 1415: train loss: 0.0000044868, validation loss: 0.0011654170
# Epoch 1416: train loss: 0.0000042813, validation loss: 0.0011889037
# Epoch 1417: train loss: 0.0000046561, validation loss: 0.0011539461
# Epoch 1418: train loss: 0.0000047205, validation loss: 0.0011432226
# Epoch 1419: train loss: 0.0000045408, validation loss: 0.0011392840
# Epoch 1420: train loss: 0.0000043655, validation loss: 0.0011325665
# Epoch 1421: train loss: 0.0000041181, validation loss: 0.0011670023
# Epoch 1422: train loss: 0.0000047085, validation loss: 0.0011596449
# Epoch 1423: train loss: 0.0000051135, validation loss: 0.0011520898
# Epoch 1424: train loss: 0.0000044064, validation loss: 0.0011493240
# Epoch 1425: train loss: 0.0000044500, validation loss: 0.0011549419
# Epoch 1426: train loss: 0.0000043116, validation loss: 0.0011417992
# Epoch 1427: train loss: 0.0000042883, validation loss: 0.0011642277
# Epoch 1428: train loss: 0.0000050839, validation loss: 0.0011522586
# Epoch 1429: train loss: 0.0000045995, validation loss: 0.0011590742
# Epoch 1430: train loss: 0.0000042878, validation loss: 0.0011660594
# Epoch 1431: train loss: 0.0000043174, validation loss: 0.0011661027
# Epoch 1432: train loss: 0.0000044856, validation loss: 0.0011618716
# Epoch 1433: train loss: 0.0000044486, validation loss: 0.0011638935
# Epoch 1434: train loss: 0.0000041083, validation loss: 0.0011539672
# Epoch 1435: train loss: 0.0000050398, validation loss: 0.0011597079
# Epoch 1436: train loss: 0.0000046647, validation loss: 0.0011572101
# Epoch 1437: train loss: 0.0000044813, validation loss: 0.0011576681
# Epoch 1438: train loss: 0.0000043737, validation loss: 0.0011472168
# Epoch 1439: train loss: 0.0000046524, validation loss: 0.0011466421
# Epoch 1440: train loss: 0.0000044263, validation loss: 0.0011459696
# Epoch 1441: train loss: 0.0000048202, validation loss: 0.0011508286
# Epoch 1442: train loss: 0.0000041277, validation loss: 0.0011298541
# Epoch 1443: train loss: 0.0000041905, validation loss: 0.0011532809
# Epoch 1444: train loss: 0.0000053122, validation loss: 0.0011339251
# Epoch 1445: train loss: 0.0000042918, validation loss: 0.0011699567
# Epoch 1446: train loss: 0.0000046459, validation loss: 0.0011580822
# Epoch 1447: train loss: 0.0000046609, validation loss: 0.0011640816
# Epoch 1448: train loss: 0.0000054461, validation loss: 0.0011244081
# Epoch 1449: train loss: 0.0000037430, validation loss: 0.0011335920
# Epoch 1450: train loss: 0.0000040815, validation loss: 0.0011509835
# Epoch 1451: train loss: 0.0000046615, validation loss: 0.0011280803
# Epoch 1452: train loss: 0.0000047585, validation loss: 0.0011544149
# Epoch 1453: train loss: 0.0000043231, validation loss: 0.0011705530
# Epoch 1454: train loss: 0.0000044386, validation loss: 0.0011459298
# Epoch 1455: train loss: 0.0000045083, validation loss: 0.0011773216
# Epoch 1456: train loss: 0.0000047811, validation loss: 0.0011684490
# Epoch 1457: train loss: 0.0000044640, validation loss: 0.0011440876
# Epoch 1458: train loss: 0.0000044359, validation loss: 0.0011534045
# Epoch 1459: train loss: 0.0000044191, validation loss: 0.0011354116
# Epoch 1460: train loss: 0.0000046176, validation loss: 0.0011560933
# Epoch 1461: train loss: 0.0000043631, validation loss: 0.0011499898
# Epoch 1462: train loss: 0.0000044300, validation loss: 0.0011463630
# Epoch 1463: train loss: 0.0000042249, validation loss: 0.0011430954
# Epoch 1464: train loss: 0.0000045238, validation loss: 0.0011720066
# Epoch 1465: train loss: 0.0000047395, validation loss: 0.0011379161
# Epoch 1466: train loss: 0.0000041871, validation loss: 0.0011454727
# Epoch 1467: train loss: 0.0000041056, validation loss: 0.0011570517
# Epoch 1468: train loss: 0.0000044023, validation loss: 0.0011481546
# Epoch 1469: train loss: 0.0000047700, validation loss: 0.0011649315
# Epoch 1470: train loss: 0.0000043590, validation loss: 0.0011465023
# Epoch 1471: train loss: 0.0000042086, validation loss: 0.0011498821
# Epoch 1472: train loss: 0.0000043291, validation loss: 0.0011503367
# Epoch 1473: train loss: 0.0000048737, validation loss: 0.0011590198
# Epoch 1474: train loss: 0.0000047799, validation loss: 0.0011364162
# Epoch 1475: train loss: 0.0000046487, validation loss: 0.0011651477
# Epoch 1476: train loss: 0.0000045865, validation loss: 0.0011650453
# Epoch 1477: train loss: 0.0000042513, validation loss: 0.0011568776
# Epoch 1478: train loss: 0.0000044435, validation loss: 0.0011620233
# Epoch 1479: train loss: 0.0000046166, validation loss: 0.0011453090
# Epoch 1480: train loss: 0.0000051036, validation loss: 0.0011442938
# Epoch 1481: train loss: 0.0000046384, validation loss: 0.0011473711
# Epoch 1482: train loss: 0.0000040142, validation loss: 0.0011505098
# Epoch 1483: train loss: 0.0000041637, validation loss: 0.0011381046
# Epoch 1484: train loss: 0.0000047950, validation loss: 0.0011351494
# Epoch 1485: train loss: 0.0000051118, validation loss: 0.0011649512
# Epoch 1486: train loss: 0.0000039874, validation loss: 0.0011707829
# Epoch 1487: train loss: 0.0000045101, validation loss: 0.0011503628
# Epoch 1488: train loss: 0.0000046071, validation loss: 0.0011699369
# Epoch 1489: train loss: 0.0000042834, validation loss: 0.0011699128
# Epoch 1490: train loss: 0.0000046848, validation loss: 0.0011825261
# Epoch 1491: train loss: 0.0000043610, validation loss: 0.0011719545
# Epoch 1492: train loss: 0.0000038278, validation loss: 0.0011568647
# Epoch 1493: train loss: 0.0000056826, validation loss: 0.0011417616
# Epoch 1494: train loss: 0.0000039525, validation loss: 0.0011624872
# Epoch 1495: train loss: 0.0000042236, validation loss: 0.0011492773
# Epoch 1496: train loss: 0.0000045513, validation loss: 0.0011567283
# Epoch 1497: train loss: 0.0000042000, validation loss: 0.0011552812
# Epoch 1498: train loss: 0.0000050130, validation loss: 0.0011794595
# Epoch 1499: train loss: 0.0000041314, validation loss: 0.0011705303
# Epoch 1500: train loss: 0.0000043961, validation loss: 0.0011688986
# Finished training
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [17], line 9
#       7     map_net.set_dataset_map(xs_map_train,ys_map_train,xs_map_val,ys_map_val)
#       8     map_net.data_pipeline()
# ----> 9     map_net.plot_loss()
#      10     torch.save(map_net.state_dict(),file)
#      11 else:
#
# File ~/github_dat/Koopman_ZNN/core/neural_fwd_map.py:189, in map_Net.plot_loss(self)
#     186 def plot_loss(self):
#     187     #plot
#     188     epochs = np.arange(0, self.map_net_params['epochs'])
# --> 189     plt.figure(figsize=(15,8))
#     190     plt.plot(epochs, self.train_loss_hist, color='tab:orange', label='Training loss')
#     191     plt.plot(epochs, self.val_loss_hist, color='tab:blue', label='Validation loss')
#
# NameError: name 'plt' is not defined

# %%
epochs = np.arange(0, map_net_params['epochs'])
plt.figure(figsize=(15,8))
plt.plot(epochs, map_net.train_loss_hist, color='tab:orange', label='Training loss')
plt.plot(epochs, map_net.val_loss_hist, color='tab:blue', label='Validation loss')

plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale('log')
plt.savefig("convergence plot of map net for arch1[3,20,20,2]")
plt.show()

# %%
# import scipy.io

# #save net parameters
# scipy.io.savemat("map_in_weights.mat", {"map_in_weights": map_net.map_net_in.weight.detach().numpy()})
# scipy.io.savemat("map_in_bias.mat", {"map_in_bias": map_net.map_net_in.bias.detach().numpy()})

# scipy.io.savemat("map_hidden_weights_1.mat",
#                  {"map_hidden_weights_1": map_net.map_net_hid[0].weight.detach().numpy()})
# scipy.io.savemat("map_hidden_bias_1.mat",
#                  {"map_hidden_bias_1": map_net.map_net_hid[0].bias.detach().numpy()})

# scipy.io.savemat("map_hidden_weights_2.mat",
#                  {"map_hidden_weights_2": map_net.map_net_hid[1].weight.detach().numpy()})
# scipy.io.savemat("map_hidden_bias_2.mat",
#                  {"map_hidden_bias_2": map_net.map_net_hid[1].bias.detach().numpy()})

# scipy.io.savemat("map_hidden_weights_3.mat",
#                  {"map_hidden_weights_3": map_net.map_net_hid[2].weight.detach().numpy()})
# scipy.io.savemat("map_hidden_bias_3.mat",
#                  {"map_hidden_bias_3": map_net.map_net_hid[2].bias.detach().numpy()})

# scipy.io.savemat("map_out_weights.mat", {"map_out_weights": map_net.map_net_out.weight.detach().numpy()})
# scipy.io.savemat("map_out_bias.mat", {"map_out_bias": map_net.map_net_out.bias.detach().numpy()})

# %% [markdown]
# ## Test Data Parameters

# %%
# test data parameters
num_snaps_val = 2000 # no. of snapshots
T = np.linspace(0,num_snaps_val*dt, num_snaps_val+1)
num_traj_val = 1 # no. of training examples
first_obs_const = int(net_params['first_obs_const']) #only one state
override_C = net_params['override_C']
if override_C:
    n_obs = int(net_params['encoder_output_dim']) + num_states + first_obs_const 
else:
    n_obs = int(net_params['encoder_output_dim']) + first_obs_const

# %% [markdown]
# ***Koopman Bilinear Model***

# %%
A = np.array(model_koop_dnn.A)
#B = np.array(model_koop_dnn.B).reshape(-1,num_inputs*n_obs)
B = np.array(model_koop_dnn.B)
#B_tensor = np.empty((num_inputs,n_obs, n_obs))
#for ii, b in enumerate(B):
    #B_tensor[ii] = b
C = np.array(model_koop_dnn.C)

print(A.shape, B.shape, C.shape)
# Out:
# (17, 17) (17, 51) (6, 17)

# %%
# #SAVE MATRIX PARAMETERS AS MATLAB FILE
# import scipy.io

# dyn_matrices = {"A": A, "B": B, "C": C}
# scipy.io.savemat("dyn_mat.mat", dyn_matrices)
# #save encoder parameters
# scipy.io.savemat("in_weights.mat", {"encode_in_weights": model_koop_dnn.net.encoder_fc_in.weight.detach().numpy()})
# scipy.io.savemat("in_bias.mat", {"encode_in_bias": model_koop_dnn.net.encoder_fc_in.bias.detach().numpy()})

# scipy.io.savemat("hidden_weights_1.mat",
#                  {"encode_hidden_weights_1": model_koop_dnn.net.encoder_fc_hid[0].weight.detach().numpy()})
# scipy.io.savemat("hidden_bias_1.mat",
#                  {"encode_hidden_bias_1": model_koop_dnn.net.encoder_fc_hid[0].bias.detach().numpy()})

# scipy.io.savemat("hidden_weights_2.mat",
#                  {"encode_hidden_weights_2": model_koop_dnn.net.encoder_fc_hid[1].weight.detach().numpy()})
# scipy.io.savemat("hidden_bias_2.mat",
#                  {"encode_hidden_bias_2": model_koop_dnn.net.encoder_fc_hid[1].bias.detach().numpy()})

# scipy.io.savemat("out_weights.mat", {"encode_out_weights": model_koop_dnn.net.encoder_fc_out.weight.detach().numpy()})
# scipy.io.savemat("out_bias.mat", {"encode_out_bias": model_koop_dnn.net.encoder_fc_out.bias.detach().numpy()})

# %%
encode_out_bias = model_koop_dnn.net.encoder_fc_out.bias.detach().numpy()
encode_out_weights = model_koop_dnn.net.encoder_fc_out.weight.detach().numpy()

# %% [markdown]
# ***Test Data Generation***

# %%
# data_gen
xs_end_test,xs_test, us_test = dynamics_3R_data_gen(dt,num_traj_val, num_snaps_val,num_states,num_inputs, robot_pars)

# %%
print(model_koop_dnn.test_loss(xs_test,u_test = us_test))
# Out:
# tensor(2.8247e-05)

# %%
basis = model_koop_dnn.net.encode_forward_

# %%
X,_ = model_koop_dnn.net.process(xs_test,data_u = us_test)
print(X.shape)
# Out:
# (2000, 15)

# %%
x = X[:, :num_states]
u = X[:, num_states:num_states+num_inputs]
x_prime = X[:,num_states+num_inputs:]

print(x.shape, u.shape, x_prime.shape)
# Out:
# (2000, 6) (2000, 3) (2000, 6)

# %% [markdown]
# ***Initial Condition Lifting***

# %%
# initialize the matricies
z = np.empty((n_obs,num_snaps_val+1)).T
x_est = np.zeros((num_states,num_snaps_val+1)).T

# %%
z[0,:] = lift(x[0,:],model_koop_dnn, net_params)
x_est[0,:] = x[0,:]

# %% [markdown]
# ***Time Evolution***

# %%
for i in range(num_snaps_val):
  #bilinear
    z[i+1,:] = np.matmul(z[i,:],A.T)+np.matmul(np.kron(u[i,:],z[i,:]),B.T)
    x_est[i+1,:] = np.matmul(z[i+1,:],C.T)

# %%
# theta to end effector positions
# Function for dynamics
def cartesian_pos_gen_3R(th_data, robot_pars):
    #define parameters
    # link lengths
    a1 = robot_pars['a1']
    a2 = robot_pars['a2']
    a3 = robot_pars['a3']
    #link masses
    m1 = robot_pars['m1']
    m2 = robot_pars['m2']
    m3 = robot_pars['m3']
    # link inertias
    I1 = robot_pars['I1']
    I2 = robot_pars['I2']
    I3 = robot_pars['I3']
    #position of CM
    l1 = robot_pars['l1']
    l2 = robot_pars['l2']
    l3 = robot_pars['l3']

    
    # X  = rows are joint and effector positions and velocities
    num_states = 2*th_data.shape[1]
    num_snaps = th_data.shape[0]
    X = np.empty((num_snaps,num_states)) # cartesian state matrix

    for i in range(num_snaps):
        # time evolution
        X[i,0] = a1*np.cos(th_data[i,0]) + a2*np.cos(th_data[i,0]+th_data[i,1])+a3*np.cos(th_data[i,0]+th_data[i,1]+th_data[i,2]) # end_eff_x
        X[i,1] = a1*np.sin(th_data[i,0]) + a2*np.sin(th_data[i,0]+th_data[i,1])+a3*np.sin(th_data[i,0]+th_data[i,1]+th_data[i,2]) # end_eff_y
        X[i,2] = a1*np.cos(th_data[i,0]) + a2*np.cos(th_data[i,0]+th_data[i,1]) # jt2_x
        X[i,3] = l1*np.sin(th_data[i,0]) + l2*np.sin(th_data[i,0]+th_data[i,1]) # jt2_y
        X[i,4] = l1*np.cos(th_data[i,0]) #jt1_x
        X[i,5] = l1*np.sin(th_data[i,0]) #jt1_y

        #joint velocities
        X[i,6] = -a1*np.sin(th_data[i,0])*th_data[i,3] - a2*np.sin(th_data[i,0]+th_data[i,1])*(th_data[i,3]+th_data[i,4])-a3*np.sin(th_data[i,0]+th_data[i,1]+th_data[i,2])*(th_data[i,3]+th_data[i,4]+th_data[i,5]) # end_eff_x
        X[i,7] = a1*np.cos(th_data[i,0])*th_data[i,3] + a2*np.cos(th_data[i,0]+th_data[i,1])*(th_data[i,3]+th_data[i,4])+a3*np.cos(th_data[i,0]+th_data[i,1]+th_data[i,2])*(th_data[i,3]+th_data[i,4]+th_data[i,5]) # end_eff_y
        X[i,8] = -a1*np.sin(th_data[i,0])*th_data[i,3] - a2*np.sin(th_data[i,0]+th_data[i,1])*(th_data[i,3]+th_data[i,4]) # end_eff_x
        X[i,9] = a1*np.cos(th_data[i,0])*th_data[i,3] + a2*np.cos(th_data[i,0]+th_data[i,1])*(th_data[i,3]+th_data[i,4]) # end_eff_y
        X[i,10] = -a1*np.sin(th_data[i,0])*th_data[i,3] #jt_x
        X[i,11] = a1*np.cos(th_data[i,0])*th_data[i,3] #jt_y
    return X

# %% [markdown]
# # Cartesian Positions

# %%
x_cart = cartesian_pos_gen_3R(x, robot_pars)
x_cart_est = cartesian_pos_gen_3R(x_est, robot_pars)

# %% [markdown]
# ***Visualization***

# %% [markdown]
# # Joint Space

# %%
plt.figure()
plt.plot(T[:-1],x[:,0],label ='Actual')
plt.plot(T,x_est[:,0],label = 'estimated(bilinear)')
plt.xlabel('t')
plt.ylabel('theta_1')
plt.title('theta_1 Comparison')
plt.legend()

# %%
plt.figure()
plt.plot(T[:-1],x[:,1],label ='Actual')
plt.plot(T,x_est[:,1],label = 'estimated(bilinear)')
plt.title('Theta_2')
plt.xlabel('t')
plt.ylabel('Theta_2_comparison')
plt.legend()

# %%
plt.figure()
plt.plot(T[:-1],x[:,2],label ='Actual')
plt.plot(T,x_est[:,2],label = 'estimated(bilinear)')
plt.title('Theta_3')
plt.xlabel('t')
plt.ylabel('theta_3')
plt.legend()

# %%
plt.figure()
plt.plot(T[:-1],x[:,3],label ='Actual')
plt.plot(T,x_est[:,3],label = 'estimated(bilinear)')
plt.title('Theta_1_dot')
plt.xlabel('t')
plt.ylabel('theta_1_dot')
plt.legend()

# %%
plt.figure()
plt.plot(T[:-1],x[:,4],label ='Actual')
plt.plot(T,x_est[:,4],label = 'estimated(bilinear)')
plt.title('Theta_2_dot')
plt.xlabel('t')
plt.ylabel('theta_2_dot')
plt.legend()

# %%
plt.figure()
plt.plot(T[:-1],x[:,5],label ='Actual')
plt.plot(T,x_est[:,5],label = 'estimated(bilinear)')
plt.title('Theta_3_dot')
plt.xlabel('t')
plt.ylabel('theta_3_dot')
plt.legend()

# %% [markdown]
# # Cartesian Space

# %%
plt.figure()
plt.plot(T[:-1],x_cart[:,0],label ='Actual')
plt.plot(T[:],x_cart_est[:,0],label = 'estimated(bilinear)')
plt.title('end effector x position comparison')
plt.xlabel('t')
plt.ylabel('x_1')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-92f44998d475> in <module>
#       1 plt.figure()
# ----> 2 plt.plot(T[:-1],x_cart[:,0],label ='Actual')
#       3 plt.plot(T[:],x_cart_est[:,0],label = 'estimated(bilinear)')
#       4 plt.title('end effector x position comparison')
#       5 plt.xlabel('t')
#
# NameError: name 'x_cart' is not defined

# %%
plt.figure()
plt.plot(T[:-1],x_cart[:,1],label ='Actual')
plt.plot(T[:],x_cart_est[:,1],label = 'estimated(bilinear)')
plt.title('end effector y position comparison')
plt.xlabel('t')
plt.ylabel('y_1')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-89f320174cf0> in <module>
#       1 plt.figure()
# ----> 2 plt.plot(T[:-1],x_cart[:,1],label ='Actual')
#       3 plt.plot(T[:],x_cart_est[:,1],label = 'estimated(bilinear)')
#       4 plt.title('end effector y position comparison')
#       5 plt.xlabel('t')
#
# NameError: name 'x_cart' is not defined

# %%
plt.figure()
plt.plot(x_cart[:,0],x_cart[:,1],label ='Actual')
plt.plot(x_cart_est[:,0],x_cart_est[:,1],label = 'estimated(bilinear)')
plt.xlabel('x')
plt.ylabel('y')
plt.title('end effector position comparison')
plt.legend()

# %%
plt.figure()
plt.plot(x_cart[:,2],x_cart[:,3],label ='Actual')
plt.plot(x_cart_est[:,2],x_cart_est[:,3],label = 'estimated(bilinear)')
plt.xlabel('j2_x')
plt.ylabel('j2_y')
plt.title('end effector of joint 2 position comparison')
plt.legend()

# %%
plt.figure()
plt.plot(x_cart[:,4],x_cart[:,5],label ='Actual')
plt.plot(x_cart_est[:,4],x_cart_est[:,5],label = 'estimated(bilinear)')
plt.xlabel('j3_x')
plt.ylabel('j3_y')
plt.title('end effector position comparison of joint 3')
plt.legend()

# %%
plt.figure()
plt.plot(T[:-1],x_cart[:,6],label ='Actual')
plt.plot(T[:],x_cart_est[:,6],label = 'estimated(bilinear)')
plt.title('end effector x velocity position comparison')
plt.xlabel('t')
plt.ylabel('x_1_dot')
plt.legend()

# %%
plt.figure()
plt.plot(T[:-1],x_cart[:,7],label ='Actual')
plt.plot(T[:],x_cart_est[:,7],label = 'estimated(bilinear)')
plt.title('end effector y velocity position comparison')
plt.xlabel('t')
plt.ylabel('y_1_dot')
plt.legend()

# %%
plt.figure()
plt.plot(T[:-1],x_cart[:,8],label ='Actual')
plt.plot(T[:],x_cart_est[:,8],label = 'estimated(bilinear)')
plt.title('Joint 2 x velocity position comparison')
plt.xlabel('t')
plt.ylabel('x dot')
plt.legend()

# %%
plt.figure()
plt.plot(T[:-1],x_cart[:,9],label ='Actual')
plt.plot(T[:],x_cart_est[:,9],label = 'estimated(bilinear)')
plt.title('Joint 2 y velocity comparison')
plt.xlabel('t')
plt.ylabel('y dot')
plt.legend()

# %%
plt.figure()
plt.plot(T[:-1],x_cart[:,10],label ='Actual')
plt.plot(T[:],x_cart_est[:,10],label = 'estimated(bilinear)')
plt.title('Joint 1 x velocity comparison')
plt.xlabel('t')
plt.ylabel('x dot')
plt.legend()

# %%
plt.figure()
plt.plot(T[:-1],x_cart[:,7],label ='Actual')
plt.plot(T[:],x_cart_est[:,7],label = 'estimated(bilinear)')
plt.title('Joint 1 y velocity position comparison')
plt.xlabel('t')
plt.ylabel('y dot')
plt.legend()

# %%
plt.figure()
plt.plot(T[:-1],error_mse_joint_tot)
plt.xlabel('t')
plt.ylabel('error_mse_joint_tot')
plt.title('Total Joint space error evolution')
plt.savefig("output.jpg",format ='jpg', dpi = 100)

# %%
plt.figure()
plt.plot(T[:-1],error_mse_joint_pos)
plt.xlabel('t')
plt.ylabel('error_mse_joint_pos')
plt.title('Joint position error evolution')
plt.savefig("output.jpg",format ='jpg', dpi = 100)

# %%
plt.figure()
plt.plot(T[:-1],error_mse_joint_vel)
plt.xlabel('t')
plt.ylabel('error_mse_joint_vel')
plt.title('Joint vel error evolution')
plt.savefig("output.jpg",format ='jpg', dpi = 100)

# %%
plt.figure()
plt.plot(T[:-1],error_mse_cart_tot)
plt.xlabel('t')
plt.ylabel('error_mse_cart_tot')
plt.title('Total cartesian space error evolution')

# %%
plt.figure()
plt.plot(T[:-1],error_mse_cart_pos_ef)
plt.xlabel('t')
plt.ylabel('error_mse_cart_pos_ef')
plt.title('End Effector position error evolution')

# %%
plt.figure()
plt.plot(T[:-1],error_mse_cart_vel_ef)
plt.xlabel('t')
plt.ylabel('error_mse_cart_vel_ef')
plt.title('End Effector vel error evolution')

# %%
# data_gen
xs_end_test,xs_test, us_test = dataset_dyn_gen_3R(dt,num_traj_val, num_snaps_val,num_states,num_inputs, robot_pars)

# %%
#testing the map network
theta_test = xs_test[:,:,0:3]
theta_test = theta_test.T.reshape((3,2001),order='F')
theta_test = theta_test.T
x_end_pred = np.empty((num_snaps_val+1,2))

# %%
for i in range(num_snaps_val):
    th_t = torch.from_numpy(theta_test[i,:]).float()
    x_end_pred[i,:] = map_net(th_t).detach().numpy()

# %%
#plot
plt.figure()
plt.plot(T[:-1],xs_end_test[:,0:-1,0].T,label='x end actual')
plt.plot(T[:-1],x_end_pred[0:-1,0],label='x end predicted')
plt.xlabel('t')
plt.ylabel('x end')
plt.legend()
plt.title('actual and predicted position of end effector')
plt.show()

# %%
plt.figure()
plt.plot(T[:-1],xs_end_test[:,0:-1,1].T,label='y end actual')
plt.plot(T[:-1],x_end_pred[0:-1,1],label='y end predicted')
plt.xlabel('t')
plt.ylabel('x end')
plt.legend()
plt.title('actual and predicted position of end effector')
plt.show()

# %%
#error plot
plt.figure()
error_x = xs_end_test[:,0:-1,0]-x_end_pred[0:-1,0]
error_y = xs_end_test[:,0:-1,1]-x_end_pred[0:-1,1]
plt.plot(T[:-1],error_x.T,label='error in x position')
plt.plot(T[:-1],error_y.T,label='error in y position')
plt.xlabel('t')
plt.ylabel('error')
plt.legend()
plt.title('x and y error')
plt.show()

# %% [markdown]
# # Control of the bilinear model

# %%
# continious matricies
# continious matricies
Ac = (A-np.eye(n_obs))/dt
Bc = B/dt
Cc = C
Crc = Cc[0:2,:]

# %%
# control process pars
# test data parameters
t_con = 10
num_snaps_con = int(t_con/dt) # no. of snapshots
T = np.linspace(0,num_snaps_con*dt, num_snaps_con+1)

# %%
# comparison of continious and discreate matricies
# initilizations
z_disc = np.empty((n_obs,num_snaps_con+1)).T
z_cont = np.empty((n_obs,num_snaps_con+1)).T
u = np.zeros((num_inputs,num_snaps_con)).T
# initial values
x = np.random.rand(1,num_states)

# %%
z_disc[0,:] = lift(x[0,:],model_koop_dnn, first_obs_const, override_C)
z_cont[0,:] = z_disc[0,:]
u[0,:] = (2*np.random.rand(1,num_inputs)-1)

# %%
for i in range(num_snaps_con):
  #bilinear
    u[i,:] = (2*np.random.rand(1,num_inputs)-1)
    z_disc[i+1,:] = np.matmul(z_disc[i,:],A.T)+np.matmul(np.kron(u[i,:],z_disc[i,:]),B.T)
    #z[i+1,:] = z[i,:] + z_dot[i,:]
    z_dot = np.matmul(z_cont[i,:],Ac.T)+np.matmul(np.kron(u[i,:],z_cont[i,:]),Bc.T)
    z_cont[i+1,:] = z_cont[i,:] + z_dot*dt

# %%
error_disc = np.sqrt(np.square(z_cont-z_disc).mean(axis=1))

# %%
plt.figure()
plt.plot(T[:],error_disc)
plt.xlabel('t')
plt.ylabel('error_disc')
plt.title('discreatization error evolution')

# %% [markdown]
# ## Dynamics

# %%
# theta to end effector positions
# Function for dynamics
def forward_kinematics_2r(th_data,th_dot_data, robot_pars):
    #define parameters
    # link lengths
    l1 = robot_pars['l1']
    l2 = robot_pars['l2']
    #link masses
    m1 = robot_pars['m1']
    m2 = robot_pars['m2']
    # link inertias
    I1 = robot_pars['I1']
    I2 = robot_pars['I1']
    # theta_data = (num_snaps, num_states)
    
    # X  = rows are joint and effector positions and velocities
    num_states = 4*th_data.shape[1]
    num_snaps = th_data.shape[0]
    X = np.empty((num_snaps,num_states)) # cartesian state matrix

    for i in range(num_snaps):
        # time evolution
        X[i,0] = l1*np.cos(th_data[i,0]) + l2*np.cos(th_data[i,0]+th_data[i,1]) # end_eff_x
        X[i,1] = l1*np.sin(th_data[i,0]) + l2*np.sin(th_data[i,0]+th_data[i,1]) # end_eff_y
        X[i,2] = l1*np.cos(th_data[i,0]) #jt_x
        X[i,3] = l1*np.sin(th_data[i,0]) #jt_y
        X[i,4] = -l1*np.sin(th_data[i,0])*th_dot_data[i,0] - l2*np.sin(th_data[i,0]+th_data[i,1])*(th_dot_data[i,0]+th_dot_data[i,1]) # end_eff_x
        X[i,5] = l1*np.cos(th_data[i,0])*th_dot_data[i,0] + l2*np.cos(th_data[i,0]+th_data[i,1])*(th_dot_data[i,0]+th_dot_data[i,1]) # end_eff_y
        X[i,6] = -l1*np.sin(th_data[i,0])*th_dot_data[i,0] #jt_x
        X[i,7] = l1*np.cos(th_data[i,0])*th_dot_data[i,0] #jt_y
    return X

# %%
# theta to end effector positions
# Function for dynamics
def forward_map_2r(th_data, robot_pars):
    #define parameters
    # link lengths
    l1 = robot_pars['l1']
    l2 = robot_pars['l2']
    #link masses
    m1 = robot_pars['m1']
    m2 = robot_pars['m2']
    # link inertias
    I1 = robot_pars['I1']
    I2 = robot_pars['I1']
    # theta_data = (num_snaps, num_states)
    
    # X  = rows are joint and effector positions and velocities
    num_states = 4
    num_snaps = 1
    X = np.empty((num_states,)) # cartesian state matrix

    # time evolution
    X[0] = l1*np.cos(th_data[0]) + l2*np.cos(th_data[0]+th_data[1]) # end_eff_x
    X[1] = l1*np.sin(th_data[0]) + l2*np.sin(th_data[0]+th_data[1]) # end_eff_y
    X[2] = l1*np.cos(th_data[0]) #jt_x
    X[3] = l1*np.sin(th_data[0]) #jt_y  
    
    return X

# %%
def Jacobian_2r(th_data, robot_pars):
    #define parameters
    # link lengths
    l1 = robot_pars['l1']
    l2 = robot_pars['l2']
    #link masses
    m1 = robot_pars['m1']
    m2 = robot_pars['m2']
    # link inertias
    I1 = robot_pars['I1']
    I2 = robot_pars['I1']
    # theta_data = (num_snaps, num_states)
    
    # X  = rows are joint and effector positions and velocities
    J = np.empty((2,2)) # cartesian state matrix

    # time evolution
    J[0,0] = -l1*np.sin(th_data[0]) - l2*np.sin(th_data[0]+th_data[1]) # end_eff_x
    J[0,1] = -l2*np.sin(th_data[0]+th_data[1])
    J[1,0] = l1*np.cos(th_data[0]) + l2*np.cos(th_data[0]+th_data[1])
    J[1,1] = l2*np.cos(th_data[0]+th_data[1])
    
    return J

# %%
#function for dynamics in tau to theta conversion
def dynamics_2R(dt, u, th, th_dot, robot_pars):
    #define parameters
    # link lengths
    l1 = robot_pars['l1']
    l2 = robot_pars['l2']
    #link masses
    m1 = robot_pars['m1']
    m2 = robot_pars['m2']
    # link inertias
    I1 = robot_pars['I1']
    I2 = robot_pars['I1']

    # gravity
    g = 9.81*0
    # matrix initializations
    tau = u.reshape(-1,1)
    # mass matrix
    m11 = (I1+I2+m1*l1**2) + (m2*l2**2/4+m1*l1**2)/4 + (2*m2*l1*l2*np.cos(th[1]));
    m12 = I2+(m2*l2**2)/4 + m2*l1*l2*np.cos(th[1])/2;
    m21=m12;
    m22 = I2 + (m2*l2**2)/4;

    M = np.array([[m11,m12],[m21,m22]])

    # coriolis tersms
    c1 = -m2*l1*l2*0.5*np.sin(th[1])*(2*th_dot[0]*th_dot[1]+th_dot[1]**2);
    c2 = m2*l1*l2*np.sin(th[1])*th_dot[1]**2;

    C = np.array([[c1],[c2]]) 

    # gravity terms     
    g1 = m2*g*(l1*np.cos(th[0])+l2*np.cos(th[0]+th[1]))+m1*g*l1*0.5*np.cos(th[0]);
    g2 = m2*g*l2*0.5*np.cos(th[0]+th[1]);

    G = np.array([[g1],[g2]]) 

    # inputs
    
    # theta evolution
    th_ddot = np.matmul(np.linalg.inv(M),(tau-G-C)).reshape(2,)
    th_dot_next = th_dot + th_ddot*dt
    th_next = th + th_dot*dt + (1/2)*th_ddot*dt**2

    return th_next, th_dot_next

# %% [markdown]
# ## Noise Generation

# %%
def gen_noise(t,amp,state,noise_nature):
    num_states = int(state.shape[0])
    noise = np.empty((1,num_states))
    if noise_nature == 'constant':
        noise[0,:] = np.ones((1,num_states))*ep
    elif noise_nature == 'sinosoidal':
        for j in range(num_states):
            if j%2 == 0:
                noise[0,j] = ep*np.sin(4*np.pi*t)
            else:
                noise[0,j] = ep*np.cos(4*np.pi*t)
    elif noise_nature == 'state_dependent':
        noise[0,0] = ep*np.sin(4*np.pi*t*state[0])
        noise[0,1] = ep*np.cos(4*np.pi*t*state[0])
        noise[0,2] = ep*np.sin(4*np.pi*t)
        noise[0,3] = ep*np.cos(4*np.pi*t)
    else:
        noise[0,:] = np.zeros((1,num_states))
    return noise

# %% [markdown]
# ## Control Parameters

# %%
# initialize parameters
# control process pars
t_run = 10
n_p = 1 #no of periods
t_sim = n_p*t_run 
num_snaps_sim = int(t_sim/dt) # no. of snapshots
T = np.linspace(0,num_snaps_sim*dt, num_snaps_sim+1)
num_cont_outs = 2 # no of controllable outputs
gamma_traced = 10
gamma_res = 40

l = 1
c = 0.02;

# noise parameters
noise = False
noise_nature = 'constant'
if noise:
    ep = 0.01 # amplitude of noise
else:
    ep = 0

# %%
#initialize matricies
# comparison of continious and discreate matricies
# initilizations
z = np.empty((n_obs,num_snaps_sim+1)).T # from the measurement
z_dot_est = np.empty((n_obs,num_snaps_sim)).T # from the measurement
z_dot_actual = np.empty((n_obs,num_snaps_sim)).T # from the measurement
z_m = np.empty((n_obs,num_snaps_sim+1)).T # from the model
u = np.zeros((num_inputs,num_snaps_sim)).T
#
# initial values
th = np.zeros((num_states,num_snaps_sim+1)).T #[th th_dot]
th_actual = np.empty((num_states,num_snaps_sim+1)).T
# considering only the end effecctor
x_desired = np.empty((num_cont_outs,num_snaps_sim+1)).T
x_desired_dot = np.empty((num_cont_outs,num_snaps_sim+1)).T
x_traced = np.empty((num_cont_outs,num_snaps_sim+1)).T
x_actual = np.empty((num_cont_outs,num_snaps_sim+1)).T
error_traced = np.zeros((num_cont_outs,num_snaps_sim)).T
#considering the full state matrix
x_actual = np.empty((num_states,num_snaps_sim+1)).T
noise = np.empty((num_states,num_snaps_sim+1)).T #full states
# residual initialization
rd = np.empty((n_obs,num_snaps_sim+1)).T
rd_dot = np.empty((n_obs,num_snaps_sim)).T

# %%
# set initial values
th[0,:2] = np.array([0.1, np.pi*0.9])
th[0,2:4] = np.zeros((2,))
# end effector quantities
x_actual[0,:] = forward_map_2r(th[0,:2],robot_pars)
print(x_actual[0,:])

#noise addition
noise[0,:] = gen_noise(0,ep,x_actual[0,:],noise_nature)
x_actual[0,:] += noise[0,:]
print(x_actual[0,:])
x_traced[0,:] = x_actual[0,:2]
x_desired[0,:] = x_traced[0,:]


# inputs
u[0,:] = np.zeros((1,num_inputs))
x_desired_dot[0,0] = -2*c*2*np.pi*np.sin(2*np.pi*0/t_run)/t_run+c*4*np.pi*np.sin(4*np.pi*0/t_run)/t_run;
x_desired_dot[0,1] =  2*c*2*np.pi*np.cos(2*np.pi*0/t_run)/t_run-c*4*np.pi*np.cos(4*np.pi*0/t_run)/t_run

#lifted quantities
z[0,:] = lift(th[0,:],model_koop_dnn, first_obs_const, override_C) # estimated lifed state        
z_m[0,:] = z[0,:]
# residual
rd[0,:] = np.zeros((n_obs,1)).T

# %%
for i in range(num_snaps_sim):
  #bilinear
    t = T[i+1]
    # desired positions
    x_desired[i+1,0] = 2*c*np.cos(2*np.pi*t/t_run)-c*np.cos(4*np.pi*t/t_run) + x_desired[0,0] - c
    x_desired[i+1,1] = 2*c*np.sin(2*np.pi*t/t_run)-c*np.sin(4*np.pi*t/t_run) + x_desired[0,1]
    # desirded velocities
    x_desired_dot[i+1,0] = -2*c*2*np.pi*np.sin(2*np.pi*t/t_run)/t_run+c*4*np.pi*np.sin(4*np.pi*t/t_run)/t_run;
    x_desired_dot[i+1,1] =  2*c*2*np.pi*np.cos(2*np.pi*t/t_run)/t_run-c*4*np.pi*np.cos(4*np.pi*t/t_run)/t_run
    
    # tracking error
    error_traced[i,:] = x_actual[i,0:2] - x_desired[i,:]
    u[i,:] = np.matmul(np.linalg.pinv(np.matmul(Jacobian_2r(th[i,:2], robot_pars),
                np.matmul(Crc,np.matmul(Bc,np.kron(np.identity(2),z[i,:]).T)))),
                (x_desired_dot[i,:].T - np.matmul(Jacobian_2r(th[i,:2],robot_pars),
                np.matmul(Crc,np.matmul(Ac,z[i,:].T))) - np.matmul(Jacobian_2r(th[i,:2],robot_pars),
                np.matmul(Crc,rd[i,:].T)) 
                 - gamma_traced*error_traced[i,:].T))                                    
    
    
    #u[i,:] = gamma_traced*error_traced[i,:].T # proportional control
    # lifted state velocities
    z_dot_est[i,:] = np.matmul(z[i,:],Ac.T) + np.matmul(np.kron(u[i,:],z[i,:]),Bc.T) + rd[i,:]
    if i == 0:
        z_dot_actual[i,:] = np.zeros((1,n_obs))
    else:
        z_dot_actual[i,:] = (z[i,:]-z[i-1,:])/dt
    
    rd_dot[i,:] = gamma_res*(z_dot_actual[i,:] - z_dot_est[i-1,:])
    rd[i+1,:] = rd[i,:] + rd_dot[i,:]*dt
    

    
   # next state raise
    th[i+1,:2],th[i+1,2:] = dynamics_2R(dt, u[i,:], th[i,:2], th[i,2:], robot_pars)
    z[i+1,:] = lift(th[i+1,:],model_koop_dnn, first_obs_const, override_C)
    x_actual[i+1,:] = forward_map_2r(th[i+1,:2],robot_pars)
    noise[i+1,:] = gen_noise(t,ep,x_actual[i+1,:],noise_nature)
    x_actual[i+1,:] += noise[i+1,:]
    
    # model states
    z_m[i+1,:] = z[i,:] + z_dot_est[i,:]*dt            
    th_traced_full = np.matmul(z_m[i+1,:],Crc.T)
    x_traced_full = forward_map_2r(th_traced_full[:2],robot_pars)
    x_traced[i+1,:] = x_traced_full[:2]

# %%
print(A)

# %%
plt.figure()
plt.plot(x_desired[:,0],x_desired[:,1],label ='desired')
plt.plot(x_traced[:,0],x_traced[:,1],'r--',label = 'esimated(bilinear)', )
plt.xlabel('x')
plt.ylabel('y')
plt.title('end effector position comparison')
plt.legend()

# %%
plt.figure()
plt.plot(x_desired[:,0],x_desired[:,1],label ='desired')
plt.plot(x_actual[:,0],x_actual[:,1],'r--',label = 'Actual Model' )
plt.xlabel('x')
plt.ylabel('y')
plt.title('end effector position comparison')
plt.legend()

# %%
plt.figure()
plt.plot(x_actual[:,0],x_actual[:,1],label ='Actual')
plt.plot(x_traced[:,0],x_traced[:,1],'r--',label = 'esimated(bilinear)')
plt.xlabel('x')
plt.ylabel('y')
plt.title('end effector position comparison')
plt.legend()

# %%
u_norm = np.sqrt(np.square(u).mean(axis=1))

# %%
plt.figure()
plt.plot(T[:-1],u_norm)
plt.xlabel('t')
plt.ylabel('||u||')
plt.title('control norm evolution')

# %%
plt.figure()
plt.plot(T,x_actual[:,0],label = 'x')
plt.plot(T,x_actual[:,1],label = 'y')

# %%
error_model = np.sqrt(np.square(x_traced-x_actual[:,:2]).mean(axis=1))
error_tracking = np.sqrt(np.square(x_actual[:,:2]-x_desired).mean(axis=1))

# %%
plt.figure()
plt.plot(T[:],error_model)
plt.xlabel('t')
plt.ylabel('error_model')
plt.title('model error evolution')

# %%
plt.figure()
plt.plot(T[:],error_tracking)
plt.xlabel('t')
plt.ylabel('error_track')
plt.title('tracking error evolution')

# %%
z_norm = np.sqrt(np.square(z).mean(axis=1))
x_norm = np.sqrt(np.square(x_actual).mean(axis=1))
noise_norm = np.sqrt(np.square(noise).mean(axis=1))

# %%
plt.figure()
plt.plot(T[:],x_norm)
plt.xlabel('t')
plt.ylabel('||x||')
plt.title('x norm evolution')

# %%
plt.figure()
plt.plot(T[:],z_norm)
plt.xlabel('t')
plt.ylabel('||z||')
plt.title('z norm evolution')

# %%
plt.figure()
plt.plot(T[:],noise_norm)
plt.xlabel('t')
plt.ylabel('error_model')
plt.title('noise norm evolution')

# %%
lift(np.array([-1,2,-3,7.4]),model_koop_dnn,first_obs_const,override_C)
